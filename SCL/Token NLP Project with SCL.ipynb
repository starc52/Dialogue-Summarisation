# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

# %%
import torch

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
print()

if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    
    print('Memory Usage:',round(torch.cuda.get_device_properties(0).total_memory/1024**3,1), 'GB')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_cached(0)/1024**3,1), 'GB')
# Out:
# Using device: cuda
#
# Tesla T4
# Memory Usage: 14.8 GB
# Allocated: 2.1 GB
# Cached:    11.6 GB
# /usr/local/lib/python3.7/dist-packages/torch/cuda/memory.py:386: FutureWarning: torch.cuda.memory_cached has been renamed to torch.cuda.memory_reserved
#   FutureWarning)

# %%
import torch
import numpy as np
import random

def set_random_seed(seed):
     torch.manual_seed(seed)
     torch.cuda.manual_seed_all(seed)
     np.random.seed(seed)
     random.seed(seed)
     torch.backends.cudnn.deterministic = True
set_random_seed(0)

# %%
! pip install datasets transformers rouge-score nltk py7zr
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.7/dist-packages (2.7.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.25.1)
# Requirement already satisfied: rouge-score in /usr/local/lib/python3.7/dist-packages (0.1.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.2.5)
# Requirement already satisfied: py7zr in /usr/local/lib/python3.7/dist-packages (0.20.2)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets) (0.70.12.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets) (21.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.7/dist-packages (from datasets) (3.1.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2.23.0)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.18.0)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (2022.11.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets) (3.8.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: dill<0.3.7 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.4)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets) (1.21.5)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (4.62.3)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.11.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets) (4.11.1)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (0.13.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (21.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (3.10.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (2.0.12)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (3.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets) (3.0.7)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2021.10.8)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.13.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from rouge-score) (1.0.0)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from rouge-score) (1.15.0)
# Requirement already satisfied: pyppmd<1.1.0,>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from py7zr) (1.0.0)
# Requirement already satisfied: pybcj>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from py7zr) (1.0.1)
# Requirement already satisfied: inflate64>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from py7zr) (0.3.1)
# Requirement already satisfied: texttable in /usr/local/lib/python3.7/dist-packages (from py7zr) (1.6.7)
# Requirement already satisfied: brotli>=1.0.9 in /usr/local/lib/python3.7/dist-packages (from py7zr) (1.0.9)
# Requirement already satisfied: pycryptodomex>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from py7zr) (3.16.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from py7zr) (5.4.8)
# Requirement already satisfied: pyzstd>=0.14.4 in /usr/local/lib/python3.7/dist-packages (from py7zr) (0.15.3)
# Requirement already satisfied: multivolumefile>=0.2.3 in /usr/local/lib/python3.7/dist-packages (from py7zr) (0.2.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets) (3.7.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.2)

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/NLP Project with SCL

# %% [markdown]
# # Fine-tuning a model on a summarization task

# %% [markdown]
# ## Loading the dataset

# %%
from datasets import load_dataset, load_metric

raw_datasets = load_dataset("samsum")

metric = load_metric("rouge")
# Out:
# WARNING:datasets.builder:Found cached dataset samsum (/root/.cache/huggingface/datasets/samsum/samsum/0.0.0/f1d7c6b7353e6de335d444e424dc002ef70d1277109031327bc9cc6af5d3d46e)
#   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ## BART

# %% [markdown]
# ### Preprocessing the data

# %%
model_checkpoint = "facebook/bart-base"

# %%
from transformers import AutoTokenizer
    
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)
# Out:
# Could not locate the tokenizer configuration file, will try to use the model config instead.
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--facebook--bart-base/snapshots/aadd2ab0ae0c8268c7c9693540e9904811f36177/config.json
# Model config BartConfig {
#   "_name_or_path": "facebook/bart-base",
#   "activation_dropout": 0.1,
#   "activation_function": "gelu",
#   "add_bias_logits": false,
#   "add_final_layer_norm": false,
#   "architectures": [
#     "BartModel"
#   ],
#   "attention_dropout": 0.1,
#   "bos_token_id": 0,
#   "classif_dropout": 0.1,
#   "classifier_dropout": 0.0,
#   "d_model": 768,
#   "decoder_attention_heads": 12,
#   "decoder_ffn_dim": 3072,
#   "decoder_layerdrop": 0.0,
#   "decoder_layers": 6,
#   "decoder_start_token_id": 2,
#   "dropout": 0.1,
#   "early_stopping": true,
#   "encoder_attention_heads": 12,
#   "encoder_ffn_dim": 3072,
#   "encoder_layerdrop": 0.0,
#   "encoder_layers": 6,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2"
#   },
#   "init_std": 0.02,
#   "is_encoder_decoder": true,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2
#   },
#   "max_position_embeddings": 1024,
#   "model_type": "bart",
#   "no_repeat_ngram_size": 3,
#   "normalize_before": false,
#   "normalize_embedding": true,
#   "num_beams": 4,
#   "num_hidden_layers": 6,
#   "pad_token_id": 1,
#   "scale_embedding": false,
#   "task_specific_params": {
#     "summarization": {
#       "length_penalty": 1.0,
#       "max_length": 128,
#       "min_length": 12,
#       "num_beams": 4
#     },
#     "summarization_cnn": {
#       "length_penalty": 2.0,
#       "max_length": 142,
#       "min_length": 56,
#       "num_beams": 4
#     },
#     "summarization_xsum": {
#       "length_penalty": 1.0,
#       "max_length": 62,
#       "min_length": 11,
#       "num_beams": 6
#     }
#   },
#   "torch_dtype": "float32",
#   "transformers_version": "4.25.1",
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading file vocab.json from cache at /root/.cache/huggingface/hub/models--facebook--bart-base/snapshots/aadd2ab0ae0c8268c7c9693540e9904811f36177/vocab.json
# loading file merges.txt from cache at /root/.cache/huggingface/hub/models--facebook--bart-base/snapshots/aadd2ab0ae0c8268c7c9693540e9904811f36177/merges.txt
# loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--facebook--bart-base/snapshots/aadd2ab0ae0c8268c7c9693540e9904811f36177/tokenizer.json
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at None
# loading file tokenizer_config.json from cache at None
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--facebook--bart-base/snapshots/aadd2ab0ae0c8268c7c9693540e9904811f36177/config.json
# Model config BartConfig {
#   "_name_or_path": "facebook/bart-base",
#   "activation_dropout": 0.1,
#   "activation_function": "gelu",
#   "add_bias_logits": false,
#   "add_final_layer_norm": false,
#   "architectures": [
#     "BartModel"
#   ],
#   "attention_dropout": 0.1,
#   "bos_token_id": 0,
#   "classif_dropout": 0.1,
#   "classifier_dropout": 0.0,
#   "d_model": 768,
#   "decoder_attention_heads": 12,
#   "decoder_ffn_dim": 3072,
#   "decoder_layerdrop": 0.0,
#   "decoder_layers": 6,
#   "decoder_start_token_id": 2,
#   "dropout": 0.1,
#   "early_stopping": true,
#   "encoder_attention_heads": 12,
#   "encoder_ffn_dim": 3072,
#   "encoder_layerdrop": 0.0,
#   "encoder_layers": 6,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2"
#   },
#   "init_std": 0.02,
#   "is_encoder_decoder": true,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2
#   },
#   "max_position_embeddings": 1024,
#   "model_type": "bart",
#   "no_repeat_ngram_size": 3,
#   "normalize_before": false,
#   "normalize_embedding": true,
#   "num_beams": 4,
#   "num_hidden_layers": 6,
#   "pad_token_id": 1,
#   "scale_embedding": false,
#   "task_specific_params": {
#     "summarization": {
#       "length_penalty": 1.0,
#       "max_length": 128,
#       "min_length": 12,
#       "num_beams": 4
#     },
#     "summarization_cnn": {
#       "length_penalty": 2.0,
#       "max_length": 142,
#       "min_length": 56,
#       "num_beams": 4
#     },
#     "summarization_xsum": {
#       "length_penalty": 1.0,
#       "max_length": 62,
#       "min_length": 11,
#       "num_beams": 6
#     }
#   },
#   "torch_dtype": "float32",
#   "transformers_version": "4.25.1",
#   "use_cache": true,
#   "vocab_size": 50265
# }

# %%
def check_token_length(dataset):
    ids=[]
    for i in range(len(dataset['dialogue'])):
        if len(tokenizer(dataset['dialogue'][i])['input_ids'])>1000:
            ids.append(i)
    print(ids)
    return ids
def remove_idx(list_idx, dataset):
    return dataset.select((
          i for i in range(len(dataset)) 
          if i not in set(list_idx)))
    
train_ids=check_token_length(raw_datasets['train'])
validation_ids=check_token_length(raw_datasets['validation'])
test_ids = check_token_length(raw_datasets['test'])
changed_datasets_train=remove_idx(train_ids, raw_datasets['train'])
changed_datasets_val = remove_idx(validation_ids, raw_datasets['validation'])
changed_datasets_test = remove_idx(test_ids, raw_datasets['test'])
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (1081 > 1024). Running this sequence through the model will result in indexing errors
# [4269, 8198]
# []
# []

# %%
max_input_length = 1024
max_target_length = 128

def make_one_hot_sequence(input_ids, sequence_ids):
    changed_sequence_id=[0]
    token_to_speaker_id={}
    uniq_id = 1
    for dic in sequence_ids:
        if str(input_ids[dic['spk'][0]:dic['spk'][1]]) in token_to_speaker_id:
            speaker_id = token_to_speaker_id[str(input_ids[dic['spk'][0]:dic['spk'][1]])]
        else:
            token_to_speaker_id[str(input_ids[dic['spk'][0]:dic['spk'][1]])] = uniq_id
            speaker_id = uniq_id
            uniq_id+=1
        for _ in range(dic['spk'][0], dic['spk'][1]):
            changed_sequence_id.append(speaker_id)
        for _ in range(dic['utt'][0], dic['utt'][1]):
            changed_sequence_id.append(-1)
    changed_sequence_id.append(0)
    return changed_sequence_id 


def preprocess_function(examples): ## hit gold here. change this preprocess function to include speaker and turn information. 
    slash_n = tokenizer(["\r\n"])['input_ids'][0][1:-1]
    slash_n_mask = tokenizer(["\r\n"])['attention_mask'][0][1:-1]
    inputs_list=[]
    masks_list=[]
    pos_list=[]
    for index in range(len(examples['dialogue'])):
        # breaking the dialogue for spk:utt info
        broken=[]
        for utt in examples['dialogue'][index].split("\r\n"):
            first_ind = utt.find(':')
            broken.append(utt[:first_ind])
            broken.append(utt[first_ind:])
        
        tokenized_broken = tokenizer(broken)['input_ids']
        attention_broken = tokenizer(broken)['attention_mask']
        
        # adding \r\n tokens
        for i in range(1, len(tokenized_broken)-1, 2):
            tokenized_broken[i].insert(-1, slash_n[0])
            tokenized_broken[i].insert(-1, slash_n[1])
            attention_broken[i].insert(-1, slash_n_mask[0])
            attention_broken[i].insert(-1, slash_n_mask[1])
        joined = tokenized_broken[0]

        # annotating for spk_utt_pos
        assoc_dict={}
        assoc_dict['spk'] = [1, len(tokenized_broken[0])-1] # the range is actually exclusive of the last index. 
        odd_bool = True
        running_length = len(tokenized_broken[0])
        sequence_ids=[]
        for inner in tokenized_broken[1:]:
            if odd_bool==True:
                assoc_dict['utt']=[running_length-1, running_length+len(inner)-3]
                odd_bool=False
                sequence_ids.append(assoc_dict)
                assoc_dict={}
            else:
                assoc_dict['spk']=[running_length-1, running_length+len(inner)-3]
                odd_bool=True
            joined = joined[:-1]+inner[1:]
            running_length += (len(inner)-2)
        
        # test for CUDA assert error
        if(len(joined)>1024):
            print("input tokens list length greater than 1024, skipping example", end=' ')
            print("equal to", len(joined))
            print(tokenizer.decode(joined))
        
        # creating inputs list
        inputs_list.append(joined)
        pos_list.append(make_one_hot_sequence(joined, sequence_ids))
        
        # creating new mask
        joined_mask = attention_broken[0]
        for inner_attention in attention_broken[1:]:
            joined_mask = joined_mask[:-1]+inner_attention[1:]
        masks_list.append(joined_mask)
    
    # overriding normal model_inputs
    inputs = [doc for doc in examples["dialogue"]]
    model_inputs = tokenizer(inputs, max_length=max_input_length, truncation=True)
    model_inputs['input_ids'] = inputs_list
    model_inputs['attention_mask'] = masks_list
    model_inputs['spk_utt_pos'] = pos_list
    with tokenizer.as_target_tokenizer():
        labels = tokenizer(examples["summary"], max_length=max_target_length, truncation=True)

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# %%
tokenized_datasets_train_o = changed_datasets_train.map(preprocess_function, batched=True)
tokenized_datasets_val_o = changed_datasets_val.map(preprocess_function, batched=True)
tokenized_datasets_test_o = changed_datasets_test.map(preprocess_function, batched=True)

# tokenized_datasets = raw_datasets.map(preprocess_function, batched=True)
tokenized_datasets_train = tokenized_datasets_train_o.remove_columns(['id', 'dialogue', 'summary'])
tokenized_datasets_val = tokenized_datasets_val_o.remove_columns(['id', 'dialogue', 'summary'])
tokenized_datasets_test = tokenized_datasets_test_o.remove_columns(['id', 'dialogue', 'summary'])
# Out:
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/samsum/samsum/0.0.0/f1d7c6b7353e6de335d444e424dc002ef70d1277109031327bc9cc6af5d3d46e/cache-af3edf4ad62c7168.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/samsum/samsum/0.0.0/f1d7c6b7353e6de335d444e424dc002ef70d1277109031327bc9cc6af5d3d46e/cache-9650456eeb2f172d.arrow
#   0%|          | 0/1 [00:00<?, ?ba/s]
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:3579: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   "`as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your "

# %%
# tokenized_datasets_train = tokenized_datasets_train.select(range(2500))
# tokenized_datasets_val = tokenized_datasets_val.select(range(500))
# tokenized_datasets_train = tokenized_datasets_train
# tokenized_datasets_val = tokenized_datasets_val

# %%
from transformers import Seq2SeqTrainer
from transformers.modeling_utils import unwrap_model
from transformers.models.auto.modeling_auto import MODEL_FOR_CAUSAL_LM_MAPPING_NAMES


class CustomTrainer(Seq2SeqTrainer):
    def compute_loss(self, model, inputs, return_outputs=False):
        # How the loss is computed by Trainer. By default, all models return the loss in the first element.
        # Subclass and override for custom behavior.
        # print(inputs)
        if self.label_smoother is not None and "labels" in inputs:
            labels = inputs.pop("labels")
        else:
            labels = None
        outputs = model(**inputs)

        # Save past state if it exists
        # TODO: this needs to be fixed and mselfade cleaner later.

        if self.args.past_index >= 0:
            self._past = outputs[self.args.past_index]

        if labels is not None:
            if unwrap_model(model)._get_name() in MODEL_FOR_CAUSAL_LM_MAPPING_NAMES.values():
                loss = self.label_smoother(outputs, labels, shift_labels=True)
            else:
                loss = self.label_smoother(outputs, labels)
        else:
            if isinstance(outputs, dict) and "loss" not in outputs:
                raise ValueError(
                    "The model did not return a loss from the inputs, only the following keys: "
                    f"{','.join(outputs.keys())}. For reference, the inputs it received are {','.join(inputs.keys())}."
                )
            # We don't use .loss here since the model may return tuples instead of ModelOutput.
            loss = outputs["loss"] if isinstance(outputs, dict) else outputs[0]
        return (loss, outputs) if return_outputs else loss

# %%
from transformers import PreTrainedTokenizerBase
from transformers.utils import PaddingStrategy
from transformers import DataCollatorForSeq2Seq
from typing import Optional, Any, Union
import numpy as np


class CustomCollatorForSeq2Seq(DataCollatorForSeq2Seq):
    r"""
    Data collator that will dynamically pad the inputs received, as well as the labels.
    Args:
        tokenizer ([`PreTrainedTokenizer`] or [`PreTrainedTokenizerFast`]):
            The tokenizer used for encoding the data.
        model ([`PreTrainedModel`]):
            The model that is being trained. If set and has the *prepare_decoder_input_ids_from_labels*, use it to
            prepare the *decoder_input_ids*
            This is useful when using *label_smoothing* to avoid calculating loss twice.
        padding (`bool`, `str` or [`~utils.PaddingStrategy`], *optional*, defaults to `True`):
            Select a strategy to pad the returned sequences (according to the model's padding side and padding index)
            among:
            - `True` or `'longest'`: Pad to the longest sequence in the batch (or no padding if only a single sequence
              is provided).
            - `'max_length'`: Pad to a maximum length specified with the argument `max_length` or to the maximum
              acceptable input length for the model if that argument is not provided.
            - `False` or `'do_not_pad'` (default): No padding (i.e., can output a batch with sequences of different
              lengths).
        max_length (`int`, *optional*):
            Maximum length of the returned list and optionally padding length (see above).
        pad_to_multiple_of (`int`, *optional*):
            If set will pad the sequence to a multiple of the provided value.
            This is especially useful to enable the use of Tensor Cores on NVIDIA hardware with compute capability >=
            7.5 (Volta).
        label_pad_token_id (`int`, *optional*, defaults to -100):
            The id to use when padding the labels (-100 will be automatically ignored by PyTorch loss functions).
        return_tensors (`str`):
            The type of Tensor to return. Allowable values are "np", "pt" and "tf".
    """

    tokenizer: PreTrainedTokenizerBase
    model: Optional[Any] = None
    padding: Union[bool, str, PaddingStrategy] = True
    max_length: Optional[int] = None
    pad_to_multiple_of: Optional[int] = None
    label_pad_token_id: int = -100
    return_tensors: str = "pt"

    def __call__(self, features, return_tensors=None):
        if return_tensors is None:
            return_tensors = self.return_tensors
        labels = [feature["labels"] for feature in features] if "labels" in features[0].keys() else None
        # We have to pad the labels before calling `tokenizer.pad` as this method won't pad them and needs them of the
        # same length to return tensors.
        if labels is not None:
            max_label_length = max(len(l) for l in labels)
            if self.pad_to_multiple_of is not None:
                max_label_length = (
                        (max_label_length + self.pad_to_multiple_of - 1)
                        // self.pad_to_multiple_of
                        * self.pad_to_multiple_of
                )

            padding_side = self.tokenizer.padding_side
            for feature in features:
                remainder = [self.label_pad_token_id] * (max_label_length - len(feature["labels"]))
                if isinstance(feature["labels"], list):
                    feature["labels"] = (
                        feature["labels"] + remainder if padding_side == "right" else remainder + feature["labels"]
                    )
                elif padding_side == "right":
                    feature["labels"] = np.concatenate([feature["labels"], remainder]).astype(np.int64)
                else:
                    feature["labels"] = np.concatenate([remainder, feature["labels"]]).astype(np.int64)
        # added here
        spk_utt_pos = [feature["spk_utt_pos"] for feature in features]
        max_spk_utt_pos_length = max(len(l) for l in spk_utt_pos)

        if self.pad_to_multiple_of is not None:
            max_spk_utt_pos_length = (
                    (max_spk_utt_pos_length + self.pad_to_multiple_of - 1)
                    // self.pad_to_multiple_of
                    * self.pad_to_multiple_of
            )

        padding_side = self.tokenizer.padding_side
        for feature in features:
            remainder = [0] * (max_spk_utt_pos_length - len(feature["spk_utt_pos"]))
            if isinstance(feature["spk_utt_pos"], list):
                feature["spk_utt_pos"] = (
                    feature["spk_utt_pos"] + remainder if padding_side == "right" else remainder + feature[
                        "spk_utt_pos"]
                )
            elif padding_side == "right":
                feature["spk_utt_pos"] = np.concatenate([feature["spk_utt_pos"], remainder]).astype(np.int64)
            else:
                feature["spk_utt_pos"] = np.concatenate([remainder, feature["spk_utt_pos"]]).astype(np.int64)

        features = self.tokenizer.pad(
            features,
            padding=self.padding,
            max_length=self.max_length,
            pad_to_multiple_of=self.pad_to_multiple_of,
            return_tensors=return_tensors,
        )

        # prepare decoder_input_ids
        if (
                labels is not None
                and self.model is not None
                and hasattr(self.model, "prepare_decoder_input_ids_from_labels")
        ):
            decoder_input_ids = self.model.prepare_decoder_input_ids_from_labels(labels=features["labels"])
            features["decoder_input_ids"] = decoder_input_ids

        return features

# %%
from torch import nn
from transformers import BartForConditionalGeneration, DataCollatorForSeq2Seq, Seq2SeqTrainingArguments, Seq2SeqTrainer
from transformers.modeling_utils import unwrap_model
from transformers.models.auto.modeling_auto import MODEL_FOR_CAUSAL_LM_MAPPING_NAMES

from transformers.models.bart.modeling_bart import BartConfig
import torch
from typing import *
from transformers.modeling_outputs import Seq2SeqLMOutput
from transformers.models.bart.modeling_bart import shift_tokens_right
import random
from tqdm import tqdm
import gc
import itertools

class BartWithSCL(BartForConditionalGeneration):
    def __init__(self, config: BartConfig):
        super().__init__(config)

    def set_losses_list(self, SCLossesList=['token']):
        self.SCLossesList = SCLossesList
    def set_scl_coeff(self, scl_coeff=1e-1):
        self.scl_coeff=scl_coeff
    def token_scl(self,
                  last_hidden_state: torch.FloatTensor,
                  spk_utt_pos: torch.LongTensor,
    ) -> torch.FloatTensor:
        r"""
        last_hidden_state (torch.LongTensor) of shape (batch_size, sequence_length, n_dims):
            Output of the last layer of the encoder.
        spk_utt_pos (torch.LongTensor) of shape (batch_size, sequence_length,):
            metadata about the speaker tokens and utterance tokens
        Returns:
        Token Level Supervised Constrastive Loss (torch.LongTensor)
        """
        batch_scl = 0
        for i in range(len(spk_utt_pos)):
            batch_element = spk_utt_pos[i]
            spk_utt_list = []
            spk_dict = {'start': 0, 'end': 0, 'spk_id': 0, 'bool': False}
            utt_dict = {'start': 0, 'end': 0, 'spk_id': 0, 'bool': False}
            for j in range(len(batch_element)):
                if batch_element[j] == 0 and j > 0:
                    utt_dict['end'] = j
                    utt_dict['bool'] = False
                    spk_utt_list.append({'spk': [spk_dict['start'], spk_dict['end'], spk_dict['spk_id']],
                                         'utt': [utt_dict['start'], utt_dict['end'], utt_dict['spk_id']]})
                    break
                if batch_element[j] > 0 and spk_dict['bool'] == False:
                    utt_dict['end'] = j
                    utt_dict['bool'] = False
                    if j > 1:
                        spk_utt_list.append({'spk': [spk_dict['start'], spk_dict['end'], spk_dict['spk_id']],
                                             'utt': [utt_dict['start'], utt_dict['end'], utt_dict['spk_id']]})
                    spk_dict['start'] = j
                    spk_dict['bool'] = True
                    spk_dict['spk_id'] = batch_element[j]
                    

                if batch_element[j] < 0 and spk_dict['bool'] == True:
                    spk_dict['end'] = j
                    spk_dict['bool'] = False
                    utt_dict['spk_id'] = spk_dict['spk_id']
                    utt_dict['start'] = j
                    utt_dict['bool'] = True
            # uniq spks
            if spk_utt_list[0]['spk'][2]==0:
                continue
            uniq_spks = list(set([int(dic['spk'][2].cpu()) for dic in spk_utt_list]))
            if len(uniq_spks)==1:
                continue
            # spk_utt_states
            spk_utt_states = {spk: [] for spk in uniq_spks}

            for spk in uniq_spks:
                for dic in spk_utt_list:
                    if spk == dic['utt'][2]:
                        spk_utt_states[spk].append(last_hidden_state[i, dic['utt'][0]:dic['utt'][1]])
            
            
            #---------- hitesh------------------------------
            # positive samples
            # L_pos = 0
            # L_neg = 0 

            # sampled_spk_utt_states = []           

            # for spk in uniq_spks:
            #     utts = len(spk_utt_states[spk])
            #     spk_utt = []
            #     if utts > 1:
            #         # ids = random.sample(list(range(len(spk_utt_states[spk]))), random.randint(1, utts))
            #         ids = random.sample(list(range(len(spk_utt_states[spk]))), 2)
            #         for i in ids:
            #           spk_utt.append(spk_utt_states[spk][i])
            #     sampled_spk_utt_states.append(spk_utt)

            # for instance in sampled_spk_utt_states:
            #   for i in range(len(instance)):
            #     for j in range(len(instance)):
            #       mat_mul = torch.einsum('ij, kj->ik', instance[i], instance[j])
            #       sigm = torch.sigmoid(mat_mul)
            #       log = torch.log(sigm)
            #       L_pos += torch.sum(-1 * log)
            # # print("L_pos", L_pos)

            # #negative loss
            # for i in range(0,len(sampled_spk_utt_states)):
            #   instance = sampled_spk_utt_states[i]

            #   neg_instances = sampled_spk_utt_states[:i]+sampled_spk_utt_states[i+1:]
            #   neg_instances = list(itertools.chain(*neg_instances))
            #   # neg_instances = random.choices(neg_instances,k = random.randint(1, len(neg_instances)))
            #   if len(neg_instances)>0:
            #     # print(len(neg_instances))
            #     # print("-------------------------")
            #     # print(sampled_spk_utt_states)
            #     neg_instances = random.choices(neg_instances,k = 2)
            #     for i in range(len(instance)):
            #       for j in range(len(neg_instances)):
            #         mat_mul = torch.einsum('ij, kj->ik', instance[i], neg_instances[j])
            #         sigm = torch.sigmoid(mat_mul)
            #         log = torch.log(1 - sigm+1e-5)
            #         L_neg += torch.sum(-1 * log)
            #---------- hitesh------------------------------
            
            
            # positive samples
            L_pos = 0
            for spk in uniq_spks:
                if len(spk_utt_states[spk]) > 1:
                    ids = random.sample(list(range(len(spk_utt_states[spk]))), 2)
                    id1 = ids[0]
                    id2 = ids[1]
                    mat_mul = torch.einsum('ij, kj->ik', spk_utt_states[spk][id1], spk_utt_states[spk][id1])
                    sigm = torch.sigmoid(mat_mul)
                    log = torch.log(sigm)
                    L_pos += torch.sum(-1 * log)
                    L_pos = torch.nan_to_num(L_pos, posinf = 1e10, neginf = -1e10)
            # print("L_pos", L_pos)
            # negative samples
            
            L_neg = 0
            for spk in uniq_spks:
                new_uniq_spks = uniq_spks.copy()
                new_uniq_spks.remove(spk)

                spk2 = random.choice(new_uniq_spks)

                id1 = random.randint(0, len(spk_utt_states[spk])-1)
                id2 = random.randint(0, len(spk_utt_states[spk2])-1)

                mat_mul = torch.einsum('ij, kj->ik', spk_utt_states[spk][id1], spk_utt_states[spk2][id2])
                sigm = torch.sigmoid(mat_mul)
                # print(1 - sigm)
                # print(1 - sigm+1e-5)
                log = torch.log(1 - sigm+1e-5)
                L_neg += torch.sum(-1 * log)
                
                L_neg = torch.nan_to_num(L_neg, posinf = 1e10, neginf = -1e10)

            # print("L_neg", L_neg)
            
            batch_scl += L_pos
            batch_scl += L_neg
        batch_scl /= last_hidden_state.size(0)
        gc.collect()
        return batch_scl
    
    def turn_scl(self,
                  last_hidden_state: torch.FloatTensor,
                  spk_utt_pos: torch.LongTensor,
    ) -> torch.FloatTensor:
        r"""
        last_hidden_state (torch.LongTensor) of shape (batch_size, sequence_length, n_dims):
            Output of the last layer of the encoder.
        spk_utt_pos (torch.LongTensor) of shape (batch_size, sequence_length,):
            metadata about the speaker tokens and utterance tokens
        Returns:
        Turn Level Supervised Constrastive Loss (torch.LongTensor)
        """
        batch_scl = 0
        for i in range(len(spk_utt_pos)):
            batch_element = spk_utt_pos[i]
            spk_utt_list = []
            spk_dict = {'start': 0, 'end': 0, 'spk_id': 0, 'bool': False}
            utt_dict = {'start': 0, 'end': 0, 'spk_id': 0, 'bool': False}
            for j in range(len(batch_element)):
                if batch_element[j] == 0 and j > 0:
                    utt_dict['end'] = j
                    utt_dict['bool'] = False
                    spk_utt_list.append({'spk': [spk_dict['start'], spk_dict['end'], spk_dict['spk_id']],
                                         'utt': [utt_dict['start'], utt_dict['end'], utt_dict['spk_id']]})
                    break
                if batch_element[j] > 0 and spk_dict['bool'] == False:
                    utt_dict['end'] = j
                    utt_dict['bool'] = False
                    if j > 1:
                        spk_utt_list.append({'spk': [spk_dict['start'], spk_dict['end'], spk_dict['spk_id']],
                                             'utt': [utt_dict['start'], utt_dict['end'], utt_dict['spk_id']]})
                    spk_dict['start'] = j
                    spk_dict['bool'] = True
                    spk_dict['spk_id'] = batch_element[j]
                    

                if batch_element[j] < 0 and spk_dict['bool'] == True:
                    spk_dict['end'] = j
                    spk_dict['bool'] = False
                    utt_dict['spk_id'] = spk_dict['spk_id']
                    utt_dict['start'] = j
                    utt_dict['bool'] = True
            # uniq spks
            if spk_utt_list[0]['spk'][2]==0:
                continue
            uniq_spks = list(set([int(dic['spk'][2].cpu()) for dic in spk_utt_list]))
            if len(uniq_spks)==1:
                continue
            # spk_utt_states
            spk_utt_states = {spk: [] for spk in uniq_spks}

            for spk in uniq_spks:
                for dic in spk_utt_list:
                    if spk == dic['utt'][2]:
                        mean_pool = torch.mean(last_hidden_state[i, dic['utt'][0]:dic['utt'][1]], 0)
                        spk_utt_states[spk].append(mean_pool)

            # positive samples
            L_pos = 0
            for spk in uniq_spks:
                if len(spk_utt_states[spk]) > 1:
                    ids = random.sample(list(range(len(spk_utt_states[spk]))), 2)
                    id1 = ids[0]
                    id2 = ids[1]
                    mat_mul = torch.einsum('i, j->', spk_utt_states[spk][id1], spk_utt_states[spk][id1])
                    sigm = torch.sigmoid(mat_mul)
                    log = torch.log(sigm)
                    L_pos += torch.sum(-1 * log)
                    # L_pos = torch.nan_to_num(L_pos, posinf = 1e10, neginf = -1e10)
            # print("L_pos", L_pos)
            # negative samples
            L_neg = 0
            for spk in uniq_spks:
                new_uniq_spks = uniq_spks.copy()
                new_uniq_spks.remove(spk)

                spk2 = random.choice(new_uniq_spks)

                id1 = random.randint(0, len(spk_utt_states[spk])-1)
                id2 = random.randint(0, len(spk_utt_states[spk2])-1)

                mat_mul = torch.einsum('i, j->', spk_utt_states[spk][id1], spk_utt_states[spk2][id2])
                sigm = torch.sigmoid(mat_mul)
                # print(1 - sigm)
                # print(1 - sigm+1e-5)
                log = torch.log(1 - sigm+1e-5)
                L_neg += torch.sum(-1 * log)
                
                # L_neg = torch.nan_to_num(L_neg, posinf = 1e10, neginf = -1e10)

            # print("L_neg", L_neg)
            
            batch_scl += L_pos
            batch_scl += L_neg
        batch_scl /= last_hidden_state.size(0)
        gc.collect()
        return batch_scl
    
    def global_scl(self,
                  last_hidden_state: torch.FloatTensor,
                  spk_utt_pos: torch.LongTensor,
    ) -> torch.FloatTensor:
        r"""
        last_hidden_state (torch.LongTensor) of shape (batch_size, sequence_length, n_dims):
            Output of the last layer of the encoder.
        spk_utt_pos (torch.LongTensor) of shape (batch_size, sequence_length,):
            metadata about the speaker tokens and utterance tokens
        Returns:
        Turn Level Supervised Constrastive Loss (torch.LongTensor)
        """
        batch_scl = 0
        for i in range(len(spk_utt_pos)):
            batch_element = spk_utt_pos[i]
            spk_utt_list = []
            spk_dict = {'start': 0, 'end': 0, 'spk_id': 0, 'bool': False}
            utt_dict = {'start': 0, 'end': 0, 'spk_id': 0, 'bool': False}
            for j in range(len(batch_element)):
                if batch_element[j] == 0 and j > 0:
                    utt_dict['end'] = j
                    utt_dict['bool'] = False
                    spk_utt_list.append({'spk': [spk_dict['start'], spk_dict['end'], spk_dict['spk_id']],
                                         'utt': [utt_dict['start'], utt_dict['end'], utt_dict['spk_id']]})
                    break
                if batch_element[j] > 0 and spk_dict['bool'] == False:
                    utt_dict['end'] = j
                    utt_dict['bool'] = False
                    if j > 1:
                        spk_utt_list.append({'spk': [spk_dict['start'], spk_dict['end'], spk_dict['spk_id']],
                                             'utt': [utt_dict['start'], utt_dict['end'], utt_dict['spk_id']]})
                    spk_dict['start'] = j
                    spk_dict['bool'] = True
                    spk_dict['spk_id'] = batch_element[j]
                    

                if batch_element[j] < 0 and spk_dict['bool'] == True:
                    spk_dict['end'] = j
                    spk_dict['bool'] = False
                    utt_dict['spk_id'] = spk_dict['spk_id']
                    utt_dict['start'] = j
                    utt_dict['bool'] = True
            # uniq spks
            if spk_utt_list[0]['spk'][2]==0:
                continue
            uniq_spks = list(set([int(dic['spk'][2].cpu()) for dic in spk_utt_list]))
            if len(uniq_spks)==1:
                continue
            # spk_utt_states
            spk_utt_states = {spk: [] for spk in uniq_spks}

            for spk in uniq_spks:
                for dic in spk_utt_list:
                    if spk == dic['utt'][2]:
                        mean_pool = torch.mean(last_hidden_state[i, dic['utt'][0]:dic['utt'][1]], 0)
                        spk_utt_states[spk].append(mean_pool)

            # positive samples
            L_pos = 0
            L_neg = 0
            for spk in uniq_spks:
                if len(spk_utt_states[spk]) > 1:
                    ids = random.choice(list(range(len(spk_utt_states[spk]))))
                    
                    spk_mean_exc = torch.mean(torch.vstack([spk_utt_states[spk][temp] for temp in range(len(spk_utt_states[spk])) if temp != ids]), 0)
                    
                    pos_mat_mul = torch.einsum('i, j->', spk_utt_states[spk][ids], spk_mean_exc)
                    pos_sigm = torch.sigmoid(pos_mat_mul)
                    pos_log = torch.log(pos_sigm)
                    L_pos += torch.sum(-1 * pos_log)

                    # negative sample

                    new_uniq_spks = uniq_spks.copy()
                    new_uniq_spks.remove(spk)
                    
                    spk2 = random.choice(new_uniq_spks)
                    id_neg = random.choice(list(range(len(spk_utt_states[spk2]))))
                    neg_mat_mul = torch.einsum('i, j->', spk_utt_states[spk2][id_neg], spk_mean_exc)
                    neg_sigm = torch.sigmoid(neg_mat_mul)
                    neg_log = torch.log(1 - neg_sigm+1e-5)
                    L_neg += torch.sum(-1 * neg_log)
                

            # print("L_neg", L_neg)
            
            batch_scl += L_pos
            batch_scl += L_neg
        batch_scl /= last_hidden_state.size(0)
        gc.collect()
        return batch_scl

    def forward(
            self,
            input_ids: torch.LongTensor = None,
            attention_mask: Optional[torch.Tensor] = None,
            spk_utt_pos: Optional[torch.Tensor] = None, ##changed here
            decoder_input_ids: Optional[torch.LongTensor] = None,
            decoder_attention_mask: Optional[torch.LongTensor] = None,
            head_mask: Optional[torch.Tensor] = None,
            decoder_head_mask: Optional[torch.Tensor] = None,
            cross_attn_head_mask: Optional[torch.Tensor] = None,
            encoder_outputs: Optional[List[torch.FloatTensor]] = None,
            past_key_values: Optional[List[torch.FloatTensor]] = None,
            inputs_embeds: Optional[torch.FloatTensor] = None,
            decoder_inputs_embeds: Optional[torch.FloatTensor] = None,
            labels: Optional[torch.LongTensor] = None,
            use_cache: Optional[bool] = None,
            output_attentions: Optional[bool] = None,
            output_hidden_states: Optional[bool] = None,
            return_dict: Optional[bool] = None,
    ) -> Union[Tuple, Seq2SeqLMOutput]:
        r"""
        labels (`torch.LongTensor` of shape `(batch_size, sequence_length)`, *optional*):
            Labels for computing the masked language modeling loss. Indices should either be in `[0, ...,
            config.vocab_size]` or -100 (see `input_ids` docstring). Tokens with indices set to `-100` are ignored
            (masked), the loss is only computed for the tokens with labels in `[0, ..., config.vocab_size]`.
        Returns:
        """
        return_dict = return_dict if return_dict is not None else self.config.use_return_dict

        if labels is not None:
            if use_cache:
                logger.warning("The `use_cache` argument is changed to `False` since `labels` is provided.")
            use_cache = False
            if decoder_input_ids is None and decoder_inputs_embeds is None:
                decoder_input_ids = shift_tokens_right(
                    labels, self.config.pad_token_id, self.config.decoder_start_token_id
                )
        outputs = self.model(
            input_ids,
            attention_mask=attention_mask,
            decoder_input_ids=decoder_input_ids,
            encoder_outputs=encoder_outputs,
            decoder_attention_mask=decoder_attention_mask,
            head_mask=head_mask,
            decoder_head_mask=decoder_head_mask,
            cross_attn_head_mask=cross_attn_head_mask,
            past_key_values=past_key_values,
            inputs_embeds=inputs_embeds,
            decoder_inputs_embeds=decoder_inputs_embeds,
            use_cache=use_cache,
            output_attentions=output_attentions,
            output_hidden_states=output_hidden_states,
            return_dict=return_dict,
        )

        if encoder_outputs is None:
            encoder = self.get_encoder()
            # TODO: mask the speaker names from the input IDs using the speaker pos info
            turn_attention_mask=None
            token_encoder_outputs=None
            tog_encoder_outputs=None
            
            if 'token' in self.SCLossesList:
                token_encoder_outputs = encoder(
                    input_ids=input_ids,
                    attention_mask=attention_mask,
                    head_mask=head_mask,
                    inputs_embeds=inputs_embeds,
                    output_attentions=output_attentions,
                    output_hidden_states=output_hidden_states,
                    return_dict=return_dict,
                )

            if 'turn' in self.SCLossesList or 'global' in self.SCLossesList:
                tog_attention_mask = torch.where(spk_utt_pos>0, 0, attention_mask)
                tog_encoder_outputs = encoder(
                    input_ids=input_ids,
                    attention_mask=tog_attention_mask,
                    head_mask=head_mask,
                    inputs_embeds=inputs_embeds,
                    output_attentions=output_attentions,
                    output_hidden_states=output_hidden_states,
                    return_dict=return_dict,
                )
        # if 'hidden_states' in encoder_outputs:
        #     print("encoder_outputs['last_hidden_state'].size(), encoder_outputs['hidden_states'].size()",
        #     encoder_outputs['last_hidden_state'].size(), encoder_outputs['hidden_states'].size())
        # else:
        #     print("encoder_outputs['last_hidden_state'].size()", encoder_outputs['last_hidden_state'].size())

        lm_logits = self.lm_head(outputs[0])
        lm_logits = lm_logits + self.final_logits_bias.to(lm_logits.device)

        masked_lm_loss = None
        if labels is not None:
            loss_fct = torch.nn.CrossEntropyLoss()
            masked_lm_loss = loss_fct(lm_logits.view(-1, self.config.vocab_size), labels.view(-1))
        # added here
        sc_loss = 0
        if 'token' in self.SCLossesList and labels is not None:
            sc_loss += self.token_scl(last_hidden_state=token_encoder_outputs['last_hidden_state'], spk_utt_pos=spk_utt_pos)
            # print(sc_loss)
        if 'turn' in self.SCLossesList and labels is not None:
            sc_loss += self.turn_scl(last_hidden_state=tog_encoder_outputs['last_hidden_state'], spk_utt_pos=spk_utt_pos)
        
        if 'global' in self.SCLossesList and labels is not None:
            sc_loss += self.global_scl(last_hidden_state=tog_encoder_outputs['last_hidden_state'], spk_utt_pos=spk_utt_pos)
        
        if not return_dict:
            output = (lm_logits,) + outputs[1:]
            return ((masked_lm_loss+(self.scl_coeff*sc_loss),) + output) if masked_lm_loss is not None else output
        loss = None
        if masked_lm_loss is None:
            loss = None
        else:
            loss = masked_lm_loss+(self.scl_coeff*sc_loss)
        return Seq2SeqLMOutput(
            loss=loss,
            logits=lm_logits,
            past_key_values=outputs.past_key_values,
            decoder_hidden_states=outputs.decoder_hidden_states,
            decoder_attentions=outputs.decoder_attentions,
            cross_attentions=outputs.cross_attentions,
            encoder_last_hidden_state=outputs.encoder_last_hidden_state,
            encoder_hidden_states=outputs.encoder_hidden_states,
            encoder_attentions=outputs.encoder_attentions,
        )

# %% [markdown]
# ### Fine-tuning the model

# %%
# from models import BartWithSCL
# from datacollator import CustomCollatorForSeq2Seq
# from trainer import CustomTrainer


from transformers import BartForConditionalGeneration, DataCollatorForSeq2Seq, Seq2SeqTrainingArguments, Seq2SeqTrainer
from transformers.modeling_utils import unwrap_model
from transformers.models.auto.modeling_auto import MODEL_FOR_CAUSAL_LM_MAPPING_NAMES

# %%
model = BartWithSCL.from_pretrained(model_checkpoint)
model.set_losses_list(['turn','token','global'])
model.set_scl_coeff(1)
# Out:
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--facebook--bart-base/snapshots/aadd2ab0ae0c8268c7c9693540e9904811f36177/config.json
# Model config BartConfig {
#   "_name_or_path": "bart-base",
#   "activation_dropout": 0.1,
#   "activation_function": "gelu",
#   "add_bias_logits": false,
#   "add_final_layer_norm": false,
#   "architectures": [
#     "BartModel"
#   ],
#   "attention_dropout": 0.1,
#   "bos_token_id": 0,
#   "classif_dropout": 0.1,
#   "classifier_dropout": 0.0,
#   "d_model": 768,
#   "decoder_attention_heads": 12,
#   "decoder_ffn_dim": 3072,
#   "decoder_layerdrop": 0.0,
#   "decoder_layers": 6,
#   "decoder_start_token_id": 2,
#   "dropout": 0.1,
#   "early_stopping": true,
#   "encoder_attention_heads": 12,
#   "encoder_ffn_dim": 3072,
#   "encoder_layerdrop": 0.0,
#   "encoder_layers": 6,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2"
#   },
#   "init_std": 0.02,
#   "is_encoder_decoder": true,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2
#   },
#   "max_position_embeddings": 1024,
#   "model_type": "bart",
#   "no_repeat_ngram_size": 3,
#   "normalize_before": false,
#   "normalize_embedding": true,
#   "num_beams": 4,
#   "num_hidden_layers": 6,
#   "pad_token_id": 1,
#   "scale_embedding": false,
#   "task_specific_params": {
#     "summarization": {
#       "length_penalty": 1.0,
#       "max_length": 128,
#       "min_length": 12,
#       "num_beams": 4
#     },
#     "summarization_cnn": {
#       "length_penalty": 2.0,
#       "max_length": 142,
#       "min_length": 56,
#       "num_beams": 4
#     },
#     "summarization_xsum": {
#       "length_penalty": 1.0,
#       "max_length": 62,
#       "min_length": 11,
#       "num_beams": 6
#     }
#   },
#   "torch_dtype": "float32",
#   "transformers_version": "4.25.1",
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading weights file pytorch_model.bin from cache at /root/.cache/huggingface/hub/models--facebook--bart-base/snapshots/aadd2ab0ae0c8268c7c9693540e9904811f36177/pytorch_model.bin
# All model checkpoint weights were used when initializing BartWithSCL.
#
# All the weights of BartWithSCL were initialized from the model checkpoint at facebook/bart-base.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BartWithSCL for predictions without further training.

# %%
batch_size = 4
args = Seq2SeqTrainingArguments(
    "test-joint2batch3c1",
    evaluation_strategy = "epoch",
    # eval_steps=5,
    learning_rate=2e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    gradient_accumulation_steps=2,
    weight_decay=0.01,
    # save_total_limit=2,
    num_train_epochs=5,
    logging_steps = 10, ## added
    predict_with_generate=True,
    remove_unused_columns=False, ## added
    fp16=True,
)
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
data_collator = CustomCollatorForSeq2Seq(tokenizer, model=model)

# %%
import nltk
import numpy as np
import torch
torch.cuda.empty_cache()
def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    # Replace -100 in the labels as we can't decode them.
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)
    
    # Rouge expects a newline after each sentence
    decoded_preds = ["\n".join(nltk.sent_tokenize(pred.strip())) for pred in decoded_preds]
    decoded_labels = ["\n".join(nltk.sent_tokenize(label.strip())) for label in decoded_labels]
    for i in range(0,50):
      # print(tokenized_datasets_val["dialogue"][i])
      print("-----------",i,"--------------")
      print("------>Predictions by Model")
      print(decoded_preds[i])
      print("----->Predictions Original")
      print(decoded_labels[i])
      print("**************************")
    result = metric.compute(predictions=decoded_preds, references=decoded_labels, use_stemmer=True)
    # Extract a few results
    result = {key: value.mid.fmeasure * 100 for key, value in result.items()}
    
    # Add mean generated length
    prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id) for pred in predictions]
    result["gen_len"] = np.mean(prediction_lens)
    
    return {k: round(v, 4) for k, v in result.items()}

# %%
trainer = CustomTrainer(
    model,
    args,
    train_dataset=tokenized_datasets_train,
    eval_dataset=tokenized_datasets_val,
    data_collator=data_collator,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)
# Out:
# Using cuda_amp half precision backend

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
trainer.train() #1 turn+token+global batch 3
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 14730
#   Num Epochs = 2
#   Instantaneous batch size per device = 3
#   Total train batch size (w. parallel, distributed & accumulation) = 6
#   Gradient Accumulation steps = 2
#   Total optimization steps = 4910
#   Number of trainable parameters = 139420416
# You're using a BartTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='3412' max='4910' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3412/4910 1:47:31 < 47:14, 0.53 it/s, Epoch 1.39/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>49.001300</td>
#       <td>149.014801</td>
#       <td>42.392500</td>
#       <td>18.348800</td>
#       <td>34.518600</td>
#       <td>38.642300</td>
#       <td>17.846000</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to test-joint2batch3c1/checkpoint-500
# Configuration saved in test-joint2batch3c1/checkpoint-500/config.json
# Model weights saved in test-joint2batch3c1/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in test-joint2batch3c1/checkpoint-500/tokenizer_config.json
# Special tokens file saved in test-joint2batch3c1/checkpoint-500/special_tokens_map.json
# Saving model checkpoint to test-joint2batch3c1/checkpoint-1000
# Configuration saved in test-joint2batch3c1/checkpoint-1000/config.json
# Model weights saved in test-joint2batch3c1/checkpoint-1000/pytorch_model.bin
# tokenizer config file saved in test-joint2batch3c1/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in test-joint2batch3c1/checkpoint-1000/special_tokens_map.json
# Saving model checkpoint to test-joint2batch3c1/checkpoint-1500
# Configuration saved in test-joint2batch3c1/checkpoint-1500/config.json
# Model weights saved in test-joint2batch3c1/checkpoint-1500/pytorch_model.bin
# tokenizer config file saved in test-joint2batch3c1/checkpoint-1500/tokenizer_config.json
# Special tokens file saved in test-joint2batch3c1/checkpoint-1500/special_tokens_map.json
# Saving model checkpoint to test-joint2batch3c1/checkpoint-2000
# Configuration saved in test-joint2batch3c1/checkpoint-2000/config.json
# Model weights saved in test-joint2batch3c1/checkpoint-2000/pytorch_model.bin
# tokenizer config file saved in test-joint2batch3c1/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in test-joint2batch3c1/checkpoint-2000/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 818
#   Batch size = 3
# ----------- 0 --------------
# ------>Predictions by Model
# A wants to go with Tom to the animal shelter tomorrow.
# He wants to get a
# ----->Predictions Original
# A will go to the animal shelter tomorrow to get a puppy for her son.
# They already visited the shelter last Monday and the son chose the puppy.
# **************************
# ----------- 1 --------------
# ------>Predictions by Model
# Emma wants to buy a new advent calendar for her kids.
# Rob and Lauren are
# ----->Predictions Original
# Emma and Rob love the advent calendar.
# Lauren fits inside calendar various items, for instance, small toys and Christmas decorations.
# Her children are excited whenever they get the calendar.
# **************************
# ----------- 2 --------------
# ------>Predictions by Model
# Jackie is pregnant with Madison.
# She doesn't want to talk about it.
# She
# ----->Predictions Original
# Madison is pregnant but she doesn't want to talk about it.
# Patricia Stevens got married and she thought she was pregnant.
# **************************
# ----------- 3 --------------
# ------>Predictions by Model
# Marla finds a box of boxers under her bed.
# ----->Predictions Original
# Marla found a pair of boxers under her bed.
# **************************
# ----------- 4 --------------
# ------>Predictions by Model
# Robert has to buy guitar cable.
# Fred will catch it on google maps.
# ----->Predictions Original
# Robert wants Fred to send him the address of the music shop as he needs to buy guitar cable.
# **************************
# ----------- 5 --------------
# ------>Predictions by Model
# Keith and Meg are running out of cereal and cereals.
# Megan will check in the
# ----->Predictions Original
# Megan needn't buy milk and cereals.
# They're in the drawer next to the fridge.
# **************************
# ----------- 6 --------------
# ------>Predictions by Model
# Samantha is surprised by Hector's video.
# ----->Predictions Original
# Samantha and Evelyn after watching the video cannot believe she is able to make that noise.
# **************************
# ----------- 7 --------------
# ------>Predictions by Model
# Theresa has been at Tom's new place.
# ----->Predictions Original
# Tom's new place is in Fiesole.
# Luis and Marion has been there.
# **************************
# ----------- 8 --------------
# ------>Predictions by Model
# Jane wants to make a reservation for 6 people tonight around 20:00.
# Vegan
# ----->Predictions Original
# Jane made a 9 PM reservation for 6 people tonight at Vegano Resto.
# **************************
# ----------- 9 --------------
# ------>Predictions by Model
# Nancy is coming home in 6 weeks.
# Tina is having trouble with her accent.
# ----->Predictions Original
# Nancy's working in Texas, but the kids laugh at her Welsh accent.
# She's coming home in 6 weeks.
# Earlier than that she's going to travel with 3 other Brits.
# **************************
# ----------- 10 --------------
# ------>Predictions by Model
# Laura needs a new printer.
# Jamie will buy a second hand one.
# ----->Predictions Original
# Laura is going to buy a printer.
# **************************
# ----------- 11 --------------
# ------>Predictions by Model
# Haylee is in dairy section.
# Barbara got coconut milk.
# ----->Predictions Original
# Haylee can't find the coconut milk yoghurt.
# **************************
# ----------- 12 --------------
# ------>Predictions by Model
# Norbert and Wendy are waiting for the tour.
# They will meet at the register now
# ----->Predictions Original
# Wendy is shopping, but she needs to hurry up to catch the tour.
# **************************
# ----------- 13 --------------
# ------>Predictions by Model
# Lidia, Cecil and Peter are going to Fuerteventura tomorrow.
# They
# ----->Predictions Original
# Cecil, Cheryl and Peter went to the Jandia Peninsula today.
# Cecil would like to explore the south of the island tomorrow, but they will decide what to do after dinner.
# **************************
# ----------- 14 --------------
# ------>Predictions by Model
# Nickola has found Sophie's pocket and handbag.
# Sophie is looking for it.
# ----->Predictions Original
# Sophie still hasn't found it despite checking pockets and handbags twice.
# **************************
# ----------- 15 --------------
# ------>Predictions by Model
# Rosie wants to write an essay about sharknado and zombeavers.
# ----->Predictions Original
# Dennis and Elle are helping Rosie think of bad movies for her essay.
# **************************
# ----------- 16 --------------
# ------>Predictions by Model
# Julia wants to listen to James as a voice actor.
# James has already made a
# ----->Predictions Original
# James has a dream of becoming a voice actor.
# He considers making a home radio station.
# **************************
# ----------- 17 --------------
# ------>Predictions by Model
# Poppy cannot think any more today because she had errands to run.
# Alice will
# ----->Predictions Original
# Poppy and Alice are meeting for drinks after work at Nick's at 5:30.
# Alice fancies Fred, she will invite him and a bunch of other coworkers.
# **************************
# ----------- 18 --------------
# ------>Predictions by Model
# Caron will be out from 12:30.
# ----->Predictions Original
# Sash needs to see Caron who'll be out from 12.
# **************************
# ----------- 19 --------------
# ------>Predictions by Model
# Matteo doesn't like football and video games.
# Giuseppe and Gosia
# ----->Predictions Original
# Matteo is not sure about his relationship with Gosia but likes her a lot.
# **************************
# ----------- 20 --------------
# ------>Predictions by Model
# Jannette is calling Ramzi for supper.
# ----->Predictions Original
# Ramzi and Jannette are going for supper.
# **************************
# ----------- 21 --------------
# ------>Predictions by Model
# Jeniffer got the recipe from her grandmother.
# ----->Predictions Original
# Jeniffer is preparing ravioli following her grandmothers recipe.
# **************************
# ----------- 22 --------------
# ------>Predictions by Model
# Lawrence will get back to Madison in a few minutes.
# ----->Predictions Original
# Lawrence will finish writing the article soon.
# **************************
# ----------- 23 --------------
# ------>Predictions by Model
# Chad wants Brennen to be there.
# ----->Predictions Original
# Chad has sent Brennen a funny photo.
# Brennen does not find it very funny.
# **************************
# ----------- 24 --------------
# ------>Predictions by Model
# Chloe will pick Sadie up from the dentist quickly after work.
# Chloe will pick
# ----->Predictions Original
# Sadie will borrow Chloe's bike on Wednesday evening.
# She has a dentist appointment on Thursday after work.
# **************************
# ----------- 25 --------------
# ------>Predictions by Model
# Carter is working on a new restaurant in the city centre.
# Olivia and Carter are looking
# ----->Predictions Original
# Carter is launching a restaurant business next month.
# Olivia wants him to include a restaurant she's working for in the discount app.
# They will meet in person to discuss it.
# **************************
# ----------- 26 --------------
# ------>Predictions by Model
# Kristine is back from surgery.
# Guy will come to the hospital to check on her
# ----->Predictions Original
# Kenny had a surgery, as Kristine reports.
# He will have another surgery tomorrow.
# Guy will come to St. Mark's Hospital near Asda to stay with Kristine.
# **************************
# ----------- 27 --------------
# ------>Predictions by Model
# Adam broke up with Joey and Olivia because he cheated on her with numerous girls.
# ----->Predictions Original
# Skyler and Adam are surprised that Joey and Olivia broke up.
# **************************
# ----------- 28 --------------
# ------>Predictions by Model
# Amanda and Chris are going to dance classes with Michael and Michael.
# ----->Predictions Original
# Amanda goes to dancing classes with Michael.
# She volunteered to show the English Waltz steps with the instructor yesterday.
# Amanda is shy and goes to therapy.
# **************************
# ----------- 29 --------------
# ------>Predictions by Model
# Taylor has a question about Isabel's bf.
# Isabel hasn't had any of her
# ----->Predictions Original
# Taylor wants to meet Isabel's boyfriend but she has never had any.
# **************************
# ----------- 30 --------------
# ------>Predictions by Model
# Toby will come back by train on Friday.
# Theo is thinking about the Italian
# ----->Predictions Original
# Theo's going to stay near Torino in the region of Italian Alpes.
# Toby wants to join the trip.
# Theo agrees and will pick Toby up on Friday at 7 am.
# **************************
# ----------- 31 --------------
# ------>Predictions by Model
# Brandon is late for work.
# He will be late by Friday.
# ----->Predictions Original
# Brandon is late again.
# Clara will prepare a report on the absenteeism and lateness for Phil by Friday.
# **************************
# ----------- 32 --------------
# ------>Predictions by Model
# Suzie is sick again.
# Olga has to apologise to Suzie.
# Suzie
# ----->Predictions Original
# Olga and Suzie will postpone their meeting due to Suzie's sickness.
# **************************
# ----------- 33 --------------
# ------>Predictions by Model
# Diane and Kate are going to meet at Lorelai.
# Diane is worried about
# ----->Predictions Original
# Diane is pregnant and can't wait to give birth, she thinks the waiting is the worst.
# Kate thinks she'll be an amazing mother.
# **************************
# ----------- 34 --------------
# ------>Predictions by Model
# Andrew had to call in sick because he had a cold.
# Daniel will drop by after
# ----->Predictions Original
# Andrew has a cold.
# Daniel will buy him some medication.
# **************************
# ----------- 35 --------------
# ------>Predictions by Model
# Alex and Sam are watching "Millionaires" on tv.
# ----->Predictions Original
# Alex and Sam are watching Millionaires.
# **************************
# ----------- 36 --------------
# ------>Predictions by Model
# Kelly wants Angelica to make cinnamon cookies recipe.
# ----->Predictions Original
# Angelica sent the cinnamon cookies recipe at Kelly's request.
# **************************
# ----------- 37 --------------
# ------>Predictions by Model
# Sophie is waiting for Dee at the restaurant.
# Gwen will let Dee know
# ----->Predictions Original
# Sophie is waiting for a client, who is late.
# She will meet Gwen later.
# **************************
# ----------- 38 --------------
# ------>Predictions by Model
# Daniel is on his way to meet Sue in a few minutes.
# ----->Predictions Original
# Daniel is with the Volvo on his way and will be there soon.
# Sue is going downstairs to meet him.
# **************************
# ----------- 39 --------------
# ------>Predictions by Model
# Betty is going to CVS to pick up some squash for George.
# George will
# ----->Predictions Original
# George is making salmon and stuffed squash for dinner.
# Betty will buy a shaving cream at CVS at his request,
# **************************
# ----------- 40 --------------
# ------>Predictions by Model
# Ken doesn't use endomondo because it doesn't work properly.
# Martha's friend
# ----->Predictions Original
# Ken has installed an app for running but it is not working properly on his phone.
# **************************
# ----------- 41 --------------
# ------>Predictions by Model
# Ann hasn't been at Ivan's birthday party yet.
# Ivan will come next week.
# ----->Predictions Original
# Ivan and Ann will meet next week.
# **************************
# ----------- 42 --------------
# ------>Predictions by Model
# Ashley posted a photo of her fb page on Ashley's request.
# Ashley is
# ----->Predictions Original
# Ashley posted some nude photos on her fb page.
# **************************
# ----------- 43 --------------
# ------>Predictions by Model
# Mikolaj and Magda are waiting for the government to send the letter to
# ----->Predictions Original
# Mikolaj's wife needs a work permit as a foreigner.
# Government officials missed the deadline for sending it and will need another month.
# **************************
# ----------- 44 --------------
# ------>Predictions by Model
# Maria is on the way to the hotel.
# Ann is hanging around the lobby and the
# ----->Predictions Original
# Thomas, Ann and Maria will have lunch together at the hotel.
# Ann is already in the 3rd floor lobby at the red table.
# **************************
# ----------- 45 --------------
# ------>Predictions by Model
# Sus is sleepy and wants to work.
# ----->Predictions Original
# Sus and Val don't want to work and are sleepy.
# **************************
# ----------- 46 --------------
# ------>Predictions by Model
# Kate wants to go to the Museum of the city of NY.
# She will join her
# ----->Predictions Original
# Kate is at the Guggenheim Museum now, but will be in the Museum of the City of New York around 2-2:30.
# Kai may join her.
# Ish won't.
# Terry will join them for a coffee after they finish visiting the museum.
# Terry has already seen the museum.
# **************************
# ----------- 47 --------------
# ------>Predictions by Model
# Broke is waiting for Cathy at her house at 10 tonight.
# ----->Predictions Original
# Cathy left her sunglasses at Broke's house.
# She will come collect them at 10.
# **************************
# ----------- 48 --------------
# ------>Predictions by Model
# Frederica will come to Bradley's birthday party tomorrow at 8 pm.
# ----->Predictions Original
# Bradley will come to Frederica's birthday party tomorrow at 8pm.
# **************************
# ----------- 49 --------------
# ------>Predictions by Model
# Adrian received the money from Camilla.
# ----->Predictions Original
# Camilla still hasn't received the 250.
# She will check and let Adrian know.
# Money usually takes around two days to arrive.
# **************************
# Saving model checkpoint to test-joint2batch3c1/checkpoint-2500
# Configuration saved in test-joint2batch3c1/checkpoint-2500/config.json
# Model weights saved in test-joint2batch3c1/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in test-joint2batch3c1/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in test-joint2batch3c1/checkpoint-2500/special_tokens_map.json
# Saving model checkpoint to test-joint2batch3c1/checkpoint-3000
# Configuration saved in test-joint2batch3c1/checkpoint-3000/config.json
# Model weights saved in test-joint2batch3c1/checkpoint-3000/pytorch_model.bin
# tokenizer config file saved in test-joint2batch3c1/checkpoint-3000/tokenizer_config.json
# Special tokens file saved in test-joint2batch3c1/checkpoint-3000/special_tokens_map.json
#     <div>
#
#       <progress value='4910' max='4910' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [4910/4910 2:37:40, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>49.001300</td>
#       <td>149.014801</td>
#       <td>42.392500</td>
#       <td>18.348800</td>
#       <td>34.518600</td>
#       <td>38.642300</td>
#       <td>17.846000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>183.944000</td>
#       <td>101.739494</td>
#       <td>43.296200</td>
#       <td>19.879800</td>
#       <td>35.760400</td>
#       <td>39.428100</td>
#       <td>17.338600</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to test-joint2batch3c1/checkpoint-3500
# Configuration saved in test-joint2batch3c1/checkpoint-3500/config.json
# Model weights saved in test-joint2batch3c1/checkpoint-3500/pytorch_model.bin
# tokenizer config file saved in test-joint2batch3c1/checkpoint-3500/tokenizer_config.json
# Special tokens file saved in test-joint2batch3c1/checkpoint-3500/special_tokens_map.json
# Saving model checkpoint to test-joint2batch3c1/checkpoint-4000
# Configuration saved in test-joint2batch3c1/checkpoint-4000/config.json
# Model weights saved in test-joint2batch3c1/checkpoint-4000/pytorch_model.bin
# tokenizer config file saved in test-joint2batch3c1/checkpoint-4000/tokenizer_config.json
# Special tokens file saved in test-joint2batch3c1/checkpoint-4000/special_tokens_map.json
# Saving model checkpoint to test-joint2batch3c1/checkpoint-4500
# Configuration saved in test-joint2batch3c1/checkpoint-4500/config.json
# Model weights saved in test-joint2batch3c1/checkpoint-4500/pytorch_model.bin
# tokenizer config file saved in test-joint2batch3c1/checkpoint-4500/tokenizer_config.json
# Special tokens file saved in test-joint2batch3c1/checkpoint-4500/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 818
#   Batch size = 3
# ----------- 0 --------------
# ------>Predictions by Model
# A wants to get a puppy for her son.
# She will take him to the animal
# ----->Predictions Original
# A will go to the animal shelter tomorrow to get a puppy for her son.
# They already visited the shelter last Monday and the son chose the puppy.
# **************************
# ----------- 1 --------------
# ------>Predictions by Model
# Rob and Lauren are going to buy an advent calendar for their kids.
# Emma and Rob
# ----->Predictions Original
# Emma and Rob love the advent calendar.
# Lauren fits inside calendar various items, for instance, small toys and Christmas decorations.
# Her children are excited whenever they get the calendar.
# **************************
# ----------- 2 --------------
# ------>Predictions by Model
# Madison is pregnant.
# She is taking every commitment seriously.
# She wants an abortion.
# She
# ----->Predictions Original
# Madison is pregnant but she doesn't want to talk about it.
# Patricia Stevens got married and she thought she was pregnant.
# **************************
# ----------- 3 --------------
# ------>Predictions by Model
# Marla and Kiki are looking for underwear under their bed.
# They found them under
# ----->Predictions Original
# Marla found a pair of boxers under her bed.
# **************************
# ----------- 4 --------------
# ------>Predictions by Model
# Robert has to buy guitar cable.
# Fred will catch it on google maps.
# ----->Predictions Original
# Robert wants Fred to send him the address of the music shop as he needs to buy guitar cable.
# **************************
# ----------- 5 --------------
# ------>Predictions by Model
# Keith has run out of milk and cereals.
# Megan will check in the drawer next
# ----->Predictions Original
# Megan needn't buy milk and cereals.
# They're in the drawer next to the fridge.
# **************************
# ----------- 6 --------------
# ------>Predictions by Model
# Samantha and Evelyn are surprised.
# ----->Predictions Original
# Samantha and Evelyn after watching the video cannot believe she is able to make that noise.
# **************************
# ----------- 7 --------------
# ------>Predictions by Model
# Theresa has been at Tom's new place.
# Marion invited her for a dinner
# ----->Predictions Original
# Tom's new place is in Fiesole.
# Luis and Marion has been there.
# **************************
# ----------- 8 --------------
# ------>Predictions by Model
# Jane will make a reservation for 6 people tonight around 20:00.
# ----->Predictions Original
# Jane made a 9 PM reservation for 6 people tonight at Vegano Resto.
# **************************
# ----------- 9 --------------
# ------>Predictions by Model
# Nancy is going travelling with 3 other Brits from Belfast and Annie in 6 weeks
# ----->Predictions Original
# Nancy's working in Texas, but the kids laugh at her Welsh accent.
# She's coming home in 6 weeks.
# Earlier than that she's going to travel with 3 other Brits.
# **************************
# ----------- 10 --------------
# ------>Predictions by Model
# Laura needs a new printer.
# Jamie will buy a second hand one.
# ----->Predictions Original
# Laura is going to buy a printer.
# **************************
# ----------- 11 --------------
# ------>Predictions by Model
# Haylee got coconut milk and coconut milk.
# ----->Predictions Original
# Haylee can't find the coconut milk yoghurt.
# **************************
# ----------- 12 --------------
# ------>Predictions by Model
# Norbert needs to hurry to catch the tour.
# Wendy will be at the register now
# ----->Predictions Original
# Wendy is shopping, but she needs to hurry up to catch the tour.
# **************************
# ----------- 13 --------------
# ------>Predictions by Model
# Lidia, Cecil and Peter are going to Fuerteventura tomorrow.
# Cec
# ----->Predictions Original
# Cecil, Cheryl and Peter went to the Jandia Peninsula today.
# Cecil would like to explore the south of the island tomorrow, but they will decide what to do after dinner.
# **************************
# ----------- 14 --------------
# ------>Predictions by Model
# Nickola has found Sophie's pockets and handbags.
# Sophie has checked them twice already
# ----->Predictions Original
# Sophie still hasn't found it despite checking pockets and handbags twice.
# **************************
# ----------- 15 --------------
# ------>Predictions by Model
# Rosie is looking for a good b-movie to cover "The Room".
# She
# ----->Predictions Original
# Dennis and Elle are helping Rosie think of bad movies for her essay.
# **************************
# ----------- 16 --------------
# ------>Predictions by Model
# Julia wants James to become a voice actor.
# ----->Predictions Original
# James has a dream of becoming a voice actor.
# He considers making a home radio station.
# **************************
# ----------- 17 --------------
# ------>Predictions by Model
# Poppy has an errands to do.
# Alice will invite Pete for drinks after work
# ----->Predictions Original
# Poppy and Alice are meeting for drinks after work at Nick's at 5:30.
# Alice fancies Fred, she will invite him and a bunch of other coworkers.
# **************************
# ----------- 18 --------------
# ------>Predictions by Model
# Caron will be out from 12.
# ----->Predictions Original
# Sash needs to see Caron who'll be out from 12.
# **************************
# ----------- 19 --------------
# ------>Predictions by Model
# Matteo doesn't like football and video games.
# ----->Predictions Original
# Matteo is not sure about his relationship with Gosia but likes her a lot.
# **************************
# ----------- 20 --------------
# ------>Predictions by Model
# Jannette will call Ramzi for supper.
# ----->Predictions Original
# Ramzi and Jannette are going for supper.
# **************************
# ----------- 21 --------------
# ------>Predictions by Model
# Jeniffer got the recipe from her grandmother.
# ----->Predictions Original
# Jeniffer is preparing ravioli following her grandmothers recipe.
# **************************
# ----------- 22 --------------
# ------>Predictions by Model
# Lawrence will get back to Madison in a few minutes.
# ----->Predictions Original
# Lawrence will finish writing the article soon.
# **************************
# ----------- 23 --------------
# ------>Predictions by Model
# Chad and Brennen are laughing at Chad's joke.
# ----->Predictions Original
# Chad has sent Brennen a funny photo.
# Brennen does not find it very funny.
# **************************
# ----------- 24 --------------
# ------>Predictions by Model
# Chloe will borrow Sadie's bike on wednesday evening.
# Chloe will pick it
# ----->Predictions Original
# Sadie will borrow Chloe's bike on Wednesday evening.
# She has a dentist appointment on Thursday after work.
# **************************
# ----------- 25 --------------
# ------>Predictions by Model
# Carter and Olivia are planning to launch a new restaurant in the city centre next month.
# ----->Predictions Original
# Carter is launching a restaurant business next month.
# Olivia wants him to include a restaurant she's working for in the discount app.
# They will meet in person to discuss it.
# **************************
# ----------- 26 --------------
# ------>Predictions by Model
# Kristine has a surgery scheduled tomorrow.
# Guy will come to the hospital to look after
# ----->Predictions Original
# Kenny had a surgery, as Kristine reports.
# He will have another surgery tomorrow.
# Guy will come to St. Mark's Hospital near Asda to stay with Kristine.
# **************************
# ----------- 27 --------------
# ------>Predictions by Model
# Adam broke up with Joey and Olivia because he cheated on her with numerous girls.
# ----->Predictions Original
# Skyler and Adam are surprised that Joey and Olivia broke up.
# **************************
# ----------- 28 --------------
# ------>Predictions by Model
# Amanda and Chris went to dance classes yesterday and the instructor needed a partner.
# Amanda
# ----->Predictions Original
# Amanda goes to dancing classes with Michael.
# She volunteered to show the English Waltz steps with the instructor yesterday.
# Amanda is shy and goes to therapy.
# **************************
# ----------- 29 --------------
# ------>Predictions by Model
# Taylor has a question about Isabel's relationship with her mother.
# Isabel hasn't had any
# ----->Predictions Original
# Taylor wants to meet Isabel's boyfriend but she has never had any.
# **************************
# ----------- 30 --------------
# ------>Predictions by Model
# Toby and Theo are leaving on Friday.
# Toby will come back by train on Monday
# ----->Predictions Original
# Theo's going to stay near Torino in the region of Italian Alpes.
# Toby wants to join the trip.
# Theo agrees and will pick Toby up on Friday at 7 am.
# **************************
# ----------- 31 --------------
# ------>Predictions by Model
# Brandon will be late.
# ----->Predictions Original
# Brandon is late again.
# Clara will prepare a report on the absenteeism and lateness for Phil by Friday.
# **************************
# ----------- 32 --------------
# ------>Predictions by Model
# Suzie is sick again.
# Olga has to reschedule for Suzie.
# ----->Predictions Original
# Olga and Suzie will postpone their meeting due to Suzie's sickness.
# **************************
# ----------- 33 --------------
# ------>Predictions by Model
# Diane will be her kids' Lorelai's mother.
# Kate will hold her
# ----->Predictions Original
# Diane is pregnant and can't wait to give birth, she thinks the waiting is the worst.
# Kate thinks she'll be an amazing mother.
# **************************
# ----------- 34 --------------
# ------>Predictions by Model
# Andrew had to call in sick because he had a cold.
# Daniel will drop by after
# ----->Predictions Original
# Andrew has a cold.
# Daniel will buy him some medication.
# **************************
# ----------- 35 --------------
# ------>Predictions by Model
# Alex and Sam are watching 'Millionaires' on tvn.
# ----->Predictions Original
# Alex and Sam are watching Millionaires.
# **************************
# ----------- 36 --------------
# ------>Predictions by Model
# Kelly has the cinnamon cookies recipe.
# ----->Predictions Original
# Angelica sent the cinnamon cookies recipe at Kelly's request.
# **************************
# ----------- 37 --------------
# ------>Predictions by Model
# Sophie is waiting for a client.
# Gwen will let Sophie know in 15
# ----->Predictions Original
# Sophie is waiting for a client, who is late.
# She will meet Gwen later.
# **************************
# ----------- 38 --------------
# ------>Predictions by Model
# Daniel is on his way to Sue's with the Volvo.
# ----->Predictions Original
# Daniel is with the Volvo on his way and will be there soon.
# Sue is going downstairs to meet him.
# **************************
# ----------- 39 --------------
# ------>Predictions by Model
# Betty is going to CVS to pick up some squash and salmon for George.
# ----->Predictions Original
# George is making salmon and stuffed squash for dinner.
# Betty will buy a shaving cream at CVS at his request,
# **************************
# ----------- 40 --------------
# ------>Predictions by Model
# Ken started running and didn't use endomondo for more than an hour.
# Martha
# ----->Predictions Original
# Ken has installed an app for running but it is not working properly on his phone.
# **************************
# ----------- 41 --------------
# ------>Predictions by Model
# Ann hasn't been at Ivan's birthday party yet.
# Ivan will come next week.
# ----->Predictions Original
# Ivan and Ann will meet next week.
# **************************
# ----------- 42 --------------
# ------>Predictions by Model
# Ashley posted a photo of her fb page.
# Ashley has some important stuff to
# ----->Predictions Original
# Ashley posted some nude photos on her fb page.
# **************************
# ----------- 43 --------------
# ------>Predictions by Model
# Mikolaj got the letter from his wife.
# Magda will send it to
# ----->Predictions Original
# Mikolaj's wife needs a work permit as a foreigner.
# Government officials missed the deadline for sending it and will need another month.
# **************************
# ----------- 44 --------------
# ------>Predictions by Model
# Maria is on the way to the hotel.
# Ann is at the 3rd floor.
# ----->Predictions Original
# Thomas, Ann and Maria will have lunch together at the hotel.
# Ann is already in the 3rd floor lobby at the red table.
# **************************
# ----------- 45 --------------
# ------>Predictions by Model
# Sus is sleepy.
# ----->Predictions Original
# Sus and Val don't want to work and are sleepy.
# **************************
# ----------- 46 --------------
# ------>Predictions by Model
# Kate is at the Guggenheim right now.
# She will go to the Museum
# ----->Predictions Original
# Kate is at the Guggenheim Museum now, but will be in the Museum of the City of New York around 2-2:30.
# Kai may join her.
# Ish won't.
# Terry will join them for a coffee after they finish visiting the museum.
# Terry has already seen the museum.
# **************************
# ----------- 47 --------------
# ------>Predictions by Model
# Cathy left her sunglasses at Brooke's house.
# She will come round at 10 tonight
# ----->Predictions Original
# Cathy left her sunglasses at Broke's house.
# She will come collect them at 10.
# **************************
# ----------- 48 --------------
# ------>Predictions by Model
# Frederica will come to Bradley's birthday party tomorrow at 8 pm.
# ----->Predictions Original
# Bradley will come to Frederica's birthday party tomorrow at 8pm.
# **************************
# ----------- 49 --------------
# ------>Predictions by Model
# Camilla will check the money when she arrives.
# ----->Predictions Original
# Camilla still hasn't received the 250.
# She will check and let Adrian know.
# Money usually takes around two days to arrive.
# **************************
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=4910, training_loss=266.5653718408402, metrics={'train_runtime': 9462.5422, 'train_samples_per_second': 3.113, 'train_steps_per_second': 0.519, 'total_flos': 4489631853557760.0, 'train_loss': 266.5653718408402, 'epoch': 2.0})

# %%
trainer.train() #10 turn+token+global batch 3
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 14730
#   Num Epochs = 2
#   Instantaneous batch size per device = 3
#   Total train batch size (w. parallel, distributed & accumulation) = 6
#   Gradient Accumulation steps = 2
#   Total optimization steps = 4910
#   Number of trainable parameters = 139420416
# You're using a BartTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='4910' max='4910' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [4910/4910 2:36:55, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>444.943000</td>
#       <td>1512.910767</td>
#       <td>26.115900</td>
#       <td>4.968300</td>
#       <td>20.989500</td>
#       <td>23.548200</td>
#       <td>16.379000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1447.518000</td>
#       <td>940.147400</td>
#       <td>26.604800</td>
#       <td>5.406300</td>
#       <td>21.266900</td>
#       <td>23.796000</td>
#       <td>15.947400</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to test-joint2batch3c10/checkpoint-500
# Configuration saved in test-joint2batch3c10/checkpoint-500/config.json
# Model weights saved in test-joint2batch3c10/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in test-joint2batch3c10/checkpoint-500/tokenizer_config.json
# Special tokens file saved in test-joint2batch3c10/checkpoint-500/special_tokens_map.json
# Saving model checkpoint to test-joint2batch3c10/checkpoint-1000
# Configuration saved in test-joint2batch3c10/checkpoint-1000/config.json
# Model weights saved in test-joint2batch3c10/checkpoint-1000/pytorch_model.bin
# tokenizer config file saved in test-joint2batch3c10/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in test-joint2batch3c10/checkpoint-1000/special_tokens_map.json
# Saving model checkpoint to test-joint2batch3c10/checkpoint-1500
# Configuration saved in test-joint2batch3c10/checkpoint-1500/config.json
# Model weights saved in test-joint2batch3c10/checkpoint-1500/pytorch_model.bin
# tokenizer config file saved in test-joint2batch3c10/checkpoint-1500/tokenizer_config.json
# Special tokens file saved in test-joint2batch3c10/checkpoint-1500/special_tokens_map.json
# Saving model checkpoint to test-joint2batch3c10/checkpoint-2000
# Configuration saved in test-joint2batch3c10/checkpoint-2000/config.json
# Model weights saved in test-joint2batch3c10/checkpoint-2000/pytorch_model.bin
# tokenizer config file saved in test-joint2batch3c10/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in test-joint2batch3c10/checkpoint-2000/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 818
#   Batch size = 3
# ----------- 0 --------------
# ------>Predictions by Model
# Benny is going to eat a puppy for her birthday.
# She will bring her puppy
# ----->Predictions Original
# A will go to the animal shelter tomorrow to get a puppy for her son.
# They already visited the shelter last Monday and the son chose the puppy.
# **************************
# ----------- 1 --------------
# ------>Predictions by Model
# Emma and Lauren are going to celebrate the anniversary of their wedding.
# They are going
# ----->Predictions Original
# Emma and Rob love the advent calendar.
# Lauren fits inside calendar various items, for instance, small toys and Christmas decorations.
# Her children are excited whenever they get the calendar.
# **************************
# ----------- 2 --------------
# ------>Predictions by Model
# Jackie is worried about her daughter's pregnancy.
# She wants to talk to her parents
# ----->Predictions Original
# Madison is pregnant but she doesn't want to talk about it.
# Patricia Stevens got married and she thought she was pregnant.
# **************************
# ----------- 3 --------------
# ------>Predictions by Model
# Marla and Tammy are going to celebrate the anniversary ofarenthood.
# They will meet at
# ----->Predictions Original
# Marla found a pair of boxers under her bed.
# **************************
# ----------- 4 --------------
# ------>Predictions by Model
# Robert is going to listen to Eminem's music.
# Fred will pick him up at 5
# ----->Predictions Original
# Robert wants Fred to send him the address of the music shop as he needs to buy guitar cable.
# **************************
# ----------- 5 --------------
# ------>Predictions by Model
# Keith wants to buy some cereal for Megan.
# Megan will buy some milk.
# Keith will
# ----->Predictions Original
# Megan needn't buy milk and cereals.
# They're in the drawer next to the fridge.
# **************************
# ----------- 6 --------------
# ------>Predictions by Model
# Samantha wants Ethan to join her.
# ----->Predictions Original
# Samantha and Evelyn after watching the video cannot believe she is able to make that noise.
# **************************
# ----------- 7 --------------
# ------>Predictions by Model
# Tom and Martha are going to eat dinner at Tom's place.
# ----->Predictions Original
# Tom's new place is in Fiesole.
# Luis and Marion has been there.
# **************************
# ----------- 8 --------------
# ------>Predictions by Model
# Jane wants to go to the diner with Roberto.
# Roberto will pick her up at 6
# ----->Predictions Original
# Jane made a 9 PM reservation for 6 people tonight at Vegano Resto.
# **************************
# ----------- 9 --------------
# ------>Predictions by Model
# Nancy wants Tina to join her for a drink.
# Tina will join her.
# Nina
# ----->Predictions Original
# Nancy's working in Texas, but the kids laugh at her Welsh accent.
# She's coming home in 6 weeks.
# Earlier than that she's going to travel with 3 other Brits.
# **************************
# ----------- 10 --------------
# ------>Predictions by Model
# Laura wants Jamie to buy printer cartridges for her printer.
# Jamie will buy a printer.
# ----->Predictions Original
# Laura is going to buy a printer.
# **************************
# ----------- 11 --------------
# ------>Predictions by Model
# Haylee is going to eat yogurt with Barbara.
# Barbara will pick her up.
# ----->Predictions Original
# Haylee can't find the coconut milk yoghurt.
# **************************
# ----------- 12 --------------
# ------>Predictions by Model
# Norbert wants Wendy to join him in the tour.
# ----->Predictions Original
# Wendy is shopping, but she needs to hurry up to catch the tour.
# **************************
# ----------- 13 --------------
# ------>Predictions by Model
# Lidia and Cecily are going to meet for dinner.
# Cecily is going to
# ----->Predictions Original
# Cecil, Cheryl and Peter went to the Jandia Peninsula today.
# Cecil would like to explore the south of the island tomorrow, but they will decide what to do after dinner.
# **************************
# ----------- 14 --------------
# ------>Predictions by Model
# Nickola will pick Sophie up from school.
# ----->Predictions Original
# Sophie still hasn't found it despite checking pockets and handbags twice.
# **************************
# ----------- 15 --------------
# ------>Predictions by Model
# Rosie is looking for her boyfriend.
# ----->Predictions Original
# Dennis and Elle are helping Rosie think of bad movies for her essay.
# **************************
# ----------- 16 --------------
# ------>Predictions by Model
# Julia is going to listen to podcasts with James.
# James will listen to her.
# ----->Predictions Original
# James has a dream of becoming a voice actor.
# He considers making a home radio station.
# **************************
# ----------- 17 --------------
# ------>Predictions by Model
# Poppy wants Alice to join her for a drink.
# Alice is going to meet Pete
# ----->Predictions Original
# Poppy and Alice are meeting for drinks after work at Nick's at 5:30.
# Alice fancies Fred, she will invite him and a bunch of other coworkers.
# **************************
# ----------- 18 --------------
# ------>Predictions by Model
# Sash is going to see Cheryl at the cinema.
# ----->Predictions Original
# Sash needs to see Caron who'll be out from 12.
# **************************
# ----------- 19 --------------
# ------>Predictions by Model
# Giuseppe wants to see Matthew again.
# Matthew is going to meet him at the
# ----->Predictions Original
# Matteo is not sure about his relationship with Gosia but likes her a lot.
# **************************
# ----------- 20 --------------
# ------>Predictions by Model
# Jannette is going to eat supper tonight.
# ----->Predictions Original
# Ramzi and Jannette are going for supper.
# **************************
# ----------- 21 --------------
# ------>Predictions by Model
# Jeniffer is going to eat pasta.
# ----->Predictions Original
# Jeniffer is preparing ravioli following her grandmothers recipe.
# **************************
# ----------- 22 --------------
# ------>Predictions by Model
# Madison wants Lawrence to join her.
# ----->Predictions Original
# Lawrence will finish writing the article soon.
# **************************
# ----------- 23 --------------
# ------>Predictions by Model
# Chad wants to see Benny's picture.
# ----->Predictions Original
# Chad has sent Brennen a funny photo.
# Brennen does not find it very funny.
# **************************
# ----------- 24 --------------
# ------>Predictions by Model
# Chloe is going to ride her bike to the bike ride.
# Chloe will pick her
# ----->Predictions Original
# Sadie will borrow Chloe's bike on Wednesday evening.
# She has a dentist appointment on Thursday after work.
# **************************
# ----------- 25 --------------
# ------>Predictions by Model
# Carter will pick Olivia up from the restaurant.
# Carter will bring Olivia a pizza.
# Carter
# ----->Predictions Original
# Carter is launching a restaurant business next month.
# Olivia wants him to include a restaurant she's working for in the discount app.
# They will meet in person to discuss it.
# **************************
# ----------- 26 --------------
# ------>Predictions by Model
# Kristine is waiting for Kenny at Kenny's place.
# They will meet at 5:
# ----->Predictions Original
# Kenny had a surgery, as Kristine reports.
# He will have another surgery tomorrow.
# Guy will come to St. Mark's Hospital near Asda to stay with Kristine.
# **************************
# ----------- 27 --------------
# ------>Predictions by Model
# Adam will pick Olivia up at Olivia's tomorrow.
# ----->Predictions Original
# Skyler and Adam are surprised that Joey and Olivia broke up.
# **************************
# ----------- 28 --------------
# ------>Predictions by Model
# Amanda wants Chris to help her with her homework.
# Chris is going to teach Amanda
# ----->Predictions Original
# Amanda goes to dancing classes with Michael.
# She volunteered to show the English Waltz steps with the instructor yesterday.
# Amanda is shy and goes to therapy.
# **************************
# ----------- 29 --------------
# ------>Predictions by Model
# Taylor wants Isabel to come to the party with him.
# ----->Predictions Original
# Taylor wants to meet Isabel's boyfriend but she has never had any.
# **************************
# ----------- 30 --------------
# ------>Predictions by Model
# Toby wants to go to the supermarket to buy groceries.
# He wants to buy a
# ----->Predictions Original
# Theo's going to stay near Torino in the region of Italian Alpes.
# Toby wants to join the trip.
# Theo agrees and will pick Toby up on Friday at 7 am.
# **************************
# ----------- 31 --------------
# ------>Predictions by Model
# Phil is waiting for Clara to arrive.
# ----->Predictions Original
# Brandon is late again.
# Clara will prepare a report on the absenteeism and lateness for Phil by Friday.
# **************************
# ----------- 32 --------------
# ------>Predictions by Model
# Suzie is going to visit Olga.
# Olga will pick her up from school
# ----->Predictions Original
# Olga and Suzie will postpone their meeting due to Suzie's sickness.
# **************************
# ----------- 33 --------------
# ------>Predictions by Model
# Diane wants Kate to join her for dinner.
# Kate will pick her up at 5
# ----->Predictions Original
# Diane is pregnant and can't wait to give birth, she thinks the waiting is the worst.
# Kate thinks she'll be an amazing mother.
# **************************
# ----------- 34 --------------
# ------>Predictions by Model
# Andrew wants Danielle to join him in the pharmacy.
# Danielle will take Andrew to the pharmacy
# ----->Predictions Original
# Andrew has a cold.
# Daniel will buy him some medication.
# **************************
# ----------- 35 --------------
# ------>Predictions by Model
# John and Sam are going to meet at John's tomorrow.
# ----->Predictions Original
# Alex and Sam are watching Millionaires.
# **************************
# ----------- 36 --------------
# ------>Predictions by Model
# Kelly is going to bake cookies for Angela.
# ----->Predictions Original
# Angelica sent the cinnamon cookies recipe at Kelly's request.
# **************************
# ----------- 37 --------------
# ------>Predictions by Model
# Gwen wants Sophie to join her.
# Sophie is going to meet Gina at the restaurant
# ----->Predictions Original
# Sophie is waiting for a client, who is late.
# She will meet Gwen later.
# **************************
# ----------- 38 --------------
# ------>Predictions by Model
# Daniel is waiting for Sue at Volvo Volvo Volvo.
# ----->Predictions Original
# Daniel is with the Volvo on his way and will be there soon.
# Sue is going downstairs to meet him.
# **************************
# ----------- 39 --------------
# ------>Predictions by Model
# Betty and George are going to eat sushi tonight.
# They will meet at Wendy's
# ----->Predictions Original
# George is making salmon and stuffed squash for dinner.
# Betty will buy a shaving cream at CVS at his request,
# **************************
# ----------- 40 --------------
# ------>Predictions by Model
# Ken wants to go to the gym with Martha, but Martha doesn't want to go
# ----->Predictions Original
# Ken has installed an app for running but it is not working properly on his phone.
# **************************
# ----------- 41 --------------
# ------>Predictions by Model
# Ivan wants to go to the party with Ann.
# ----->Predictions Original
# Ivan and Ann will meet next week.
# **************************
# ----------- 42 --------------
# ------>Predictions by Model
# Rowan is going to meet Ashley at Ashley's place.
# ----->Predictions Original
# Ashley posted some nude photos on her fb page.
# **************************
# ----------- 43 --------------
# ------>Predictions by Model
# Mikolaj is going to see Maggie at the cinema tonight.
# Maggie is going
# ----->Predictions Original
# Mikolaj's wife needs a work permit as a foreigner.
# Government officials missed the deadline for sending it and will need another month.
# **************************
# ----------- 44 --------------
# ------>Predictions by Model
# Maria and Thomas are going to the hotel.
# They're going to stay at the hotel
# ----->Predictions Original
# Thomas, Ann and Maria will have lunch together at the hotel.
# Ann is already in the 3rd floor lobby at the red table.
# **************************
# ----------- 45 --------------
# ------>Predictions by Model
# Susie wants to go to the cinema with Valerie.
# ----->Predictions Original
# Sus and Val don't want to work and are sleepy.
# **************************
# ----------- 46 --------------
# ------>Predictions by Model
# Kate wants to go to the museum with Kevin.
# ----->Predictions Original
# Kate is at the Guggenheim Museum now, but will be in the Museum of the City of New York around 2-2:30.
# Kai may join her.
# Ish won't.
# Terry will join them for a coffee after they finish visiting the museum.
# Terry has already seen the museum.
# **************************
# ----------- 47 --------------
# ------>Predictions by Model
# Cathy wants to buy sunglasses for Brooke.
# ----->Predictions Original
# Cathy left her sunglasses at Broke's house.
# She will come collect them at 10.
# **************************
# ----------- 48 --------------
# ------>Predictions by Model
# Bradley wants Freddy to come to his birthday party.
# Frederica is going to
# ----->Predictions Original
# Bradley will come to Frederica's birthday party tomorrow at 8pm.
# **************************
# ----------- 49 --------------
# ------>Predictions by Model
# Adrian wants to buy some money for his money.
# He will give it to Camden
# ----->Predictions Original
# Camilla still hasn't received the 250.
# She will check and let Adrian know.
# Money usually takes around two days to arrive.
# **************************
# Saving model checkpoint to test-joint2batch3c10/checkpoint-2500
# Configuration saved in test-joint2batch3c10/checkpoint-2500/config.json
# Model weights saved in test-joint2batch3c10/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in test-joint2batch3c10/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in test-joint2batch3c10/checkpoint-2500/special_tokens_map.json
# Saving model checkpoint to test-joint2batch3c10/checkpoint-3000
# Configuration saved in test-joint2batch3c10/checkpoint-3000/config.json
# Model weights saved in test-joint2batch3c10/checkpoint-3000/pytorch_model.bin
# tokenizer config file saved in test-joint2batch3c10/checkpoint-3000/tokenizer_config.json
# Special tokens file saved in test-joint2batch3c10/checkpoint-3000/special_tokens_map.json
# Saving model checkpoint to test-joint2batch3c10/checkpoint-3500
# Configuration saved in test-joint2batch3c10/checkpoint-3500/config.json
# Model weights saved in test-joint2batch3c10/checkpoint-3500/pytorch_model.bin
# tokenizer config file saved in test-joint2batch3c10/checkpoint-3500/tokenizer_config.json
# Special tokens file saved in test-joint2batch3c10/checkpoint-3500/special_tokens_map.json
# Saving model checkpoint to test-joint2batch3c10/checkpoint-4000
# Configuration saved in test-joint2batch3c10/checkpoint-4000/config.json
# Model weights saved in test-joint2batch3c10/checkpoint-4000/pytorch_model.bin
# tokenizer config file saved in test-joint2batch3c10/checkpoint-4000/tokenizer_config.json
# Special tokens file saved in test-joint2batch3c10/checkpoint-4000/special_tokens_map.json
# Saving model checkpoint to test-joint2batch3c10/checkpoint-4500
# Configuration saved in test-joint2batch3c10/checkpoint-4500/config.json
# Model weights saved in test-joint2batch3c10/checkpoint-4500/pytorch_model.bin
# tokenizer config file saved in test-joint2batch3c10/checkpoint-4500/tokenizer_config.json
# Special tokens file saved in test-joint2batch3c10/checkpoint-4500/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 818
#   Batch size = 3
# ----------- 0 --------------
# ------>Predictions by Model
# Beth will bring the puppy to the puppy.
# ----->Predictions Original
# A will go to the animal shelter tomorrow to get a puppy for her son.
# They already visited the shelter last Monday and the son chose the puppy.
# **************************
# ----------- 1 --------------
# ------>Predictions by Model
# Emma and Lauren are going to celebrate the anniversary of the wedding.
# ----->Predictions Original
# Emma and Rob love the advent calendar.
# Lauren fits inside calendar various items, for instance, small toys and Christmas decorations.
# Her children are excited whenever they get the calendar.
# **************************
# ----------- 2 --------------
# ------>Predictions by Model
# Jackie is going to marry Martha.
# ----->Predictions Original
# Madison is pregnant but she doesn't want to talk about it.
# Patricia Stevens got married and she thought she was pregnant.
# **************************
# ----------- 3 --------------
# ------>Predictions by Model
# Marla is looking for someone to help her find someone.
# She has a boyfriend.
# ----->Predictions Original
# Marla found a pair of boxers under her bed.
# **************************
# ----------- 4 --------------
# ------>Predictions by Model
# Robert will pick Freddie up at 5.
# ----->Predictions Original
# Robert wants Fred to send him the address of the music shop as he needs to buy guitar cable.
# **************************
# ----------- 5 --------------
# ------>Predictions by Model
# Keith and Megan are going to eat cereal at the supermarket.
# Megan will buy milk for
# ----->Predictions Original
# Megan needn't buy milk and cereals.
# They're in the drawer next to the fridge.
# **************************
# ----------- 6 --------------
# ------>Predictions by Model
# Samantha is going to watch a movie with Ethanlyn tonight.
# Ethanlyn will
# ----->Predictions Original
# Samantha and Evelyn after watching the video cannot believe she is able to make that noise.
# **************************
# ----------- 7 --------------
# ------>Predictions by Model
# Luis and Adam will meet at Tom's place in 5 minutes.
# ----->Predictions Original
# Tom's new place is in Fiesole.
# Luis and Marion has been there.
# **************************
# ----------- 8 --------------
# ------>Predictions by Model
# Jane is looking for a reservation for a restaurant in Warsaw.
# She has a reservation.
# ----->Predictions Original
# Jane made a 9 PM reservation for 6 people tonight at Vegano Resto.
# **************************
# ----------- 9 --------------
# ------>Predictions by Model
# Tina is going to organise a wedding for Natalie.
# Nina will join her.
# ----->Predictions Original
# Nancy's working in Texas, but the kids laugh at her Welsh accent.
# She's coming home in 6 weeks.
# Earlier than that she's going to travel with 3 other Brits.
# **************************
# ----------- 10 --------------
# ------>Predictions by Model
# Laura will send Jamie a printer.
# Jamie will send Laura the printer.
# ----->Predictions Original
# Laura is going to buy a printer.
# **************************
# ----------- 11 --------------
# ------>Predictions by Model
# Haylee will pick Barbara up at 8.
# ----->Predictions Original
# Haylee can't find the coconut milk yoghurt.
# **************************
# ----------- 12 --------------
# ------>Predictions by Model
# Wendy is waiting for Nina at Wendy's.
# ----->Predictions Original
# Wendy is shopping, but she needs to hurry up to catch the tour.
# **************************
# ----------- 13 --------------
# ------>Predictions by Model
# Lidia and Cecyl are going to meet for dinner.
# Cecyl is going to
# ----->Predictions Original
# Cecil, Cheryl and Peter went to the Jandia Peninsula today.
# Cecil would like to explore the south of the island tomorrow, but they will decide what to do after dinner.
# **************************
# ----------- 14 --------------
# ------>Predictions by Model
# Sophie will pick Nicky up in 5 minutes.
# ----->Predictions Original
# Sophie still hasn't found it despite checking pockets and handbags twice.
# **************************
# ----------- 15 --------------
# ------>Predictions by Model
# Rosie and Elise are going to watch a movie tonight.
# ----->Predictions Original
# Dennis and Elle are helping Rosie think of bad movies for her essay.
# **************************
# ----------- 16 --------------
# ------>Predictions by Model
# Julia wants James to listen to her podcasts.
# James will listen to Julia's podcasts
# ----->Predictions Original
# James has a dream of becoming a voice actor.
# He considers making a home radio station.
# **************************
# ----------- 17 --------------
# ------>Predictions by Model
# Poppy is waiting for Alice at the diner.
# Alice is going to meet Pete at
# ----->Predictions Original
# Poppy and Alice are meeting for drinks after work at Nick's at 5:30.
# Alice fancies Fred, she will invite him and a bunch of other coworkers.
# **************************
# ----------- 18 --------------
# ------>Predictions by Model
# Caron is going to see Samantha tonight.
# ----->Predictions Original
# Sash needs to see Caron who'll be out from 12.
# **************************
# ----------- 19 --------------
# ------>Predictions by Model
# Giuseppe wants to go to Greece with Matthew.
# Matthew doesn't want to go
# ----->Predictions Original
# Matteo is not sure about his relationship with Gosia but likes her a lot.
# **************************
# ----------- 20 --------------
# ------>Predictions by Model
# Jannette is going to eat supper tonight.
# ----->Predictions Original
# Ramzi and Jannette are going for supper.
# **************************
# ----------- 21 --------------
# ------>Predictions by Model
# Jeniffer and Hanna are going to eat pasta.
# ----->Predictions Original
# Jeniffer is preparing ravioli following her grandmothers recipe.
# **************************
# ----------- 22 --------------
# ------>Predictions by Model
# Madison is going to teach Lawrence how to write a poem.
# ----->Predictions Original
# Lawrence will finish writing the article soon.
# **************************
# ----------- 23 --------------
# ------>Predictions by Model
# Brennen will pick Chloe up from school.
# ----->Predictions Original
# Chad has sent Brennen a funny photo.
# Brennen does not find it very funny.
# **************************
# ----------- 24 --------------
# ------>Predictions by Model
# Chloe will pick Sophie up at 8 pm.
# ----->Predictions Original
# Sadie will borrow Chloe's bike on Wednesday evening.
# She has a dentist appointment on Thursday after work.
# **************************
# ----------- 25 --------------
# ------>Predictions by Model
# Olivia and Carter are going to eat dinner at the restaurant tonight.
# ----->Predictions Original
# Carter is launching a restaurant business next month.
# Olivia wants him to include a restaurant she's working for in the discount app.
# They will meet in person to discuss it.
# **************************
# ----------- 26 --------------
# ------>Predictions by Model
# Kristine is waiting for Kenny at Kenny's place.
# Kenny is going to get a
# ----->Predictions Original
# Kenny had a surgery, as Kristine reports.
# He will have another surgery tomorrow.
# Guy will come to St. Mark's Hospital near Asda to stay with Kristine.
# **************************
# ----------- 27 --------------
# ------>Predictions by Model
# Adam is waiting for Olivia at Olivia's place.
# ----->Predictions Original
# Skyler and Adam are surprised that Joey and Olivia broke up.
# **************************
# ----------- 28 --------------
# ------>Predictions by Model
# Amanda and Chris are going to meet at the cinema tonight.
# Chris is going to
# ----->Predictions Original
# Amanda goes to dancing classes with Michael.
# She volunteered to show the English Waltz steps with the instructor yesterday.
# Amanda is shy and goes to therapy.
# **************************
# ----------- 29 --------------
# ------>Predictions by Model
# Taylor wants Isabel to join him for lunch.
# ----->Predictions Original
# Taylor wants to meet Isabel's boyfriend but she has never had any.
# **************************
# ----------- 30 --------------
# ------>Predictions by Model
# Toby wants to go to the cinema with Theresa.
# They will meet on Saturday at
# ----->Predictions Original
# Theo's going to stay near Torino in the region of Italian Alpes.
# Toby wants to join the trip.
# Theo agrees and will pick Toby up on Friday at 7 am.
# **************************
# ----------- 31 --------------
# ------>Predictions by Model
# Phil and Clara are going to meet at Brandon's tomorrow.
# ----->Predictions Original
# Brandon is late again.
# Clara will prepare a report on the absenteeism and lateness for Phil by Friday.
# **************************
# ----------- 32 --------------
# ------>Predictions by Model
# Olga is waiting for Suzanne to arrive.
# ----->Predictions Original
# Olga and Suzie will postpone their meeting due to Suzie's sickness.
# **************************
# ----------- 33 --------------
# ------>Predictions by Model
# Kate is waiting for Lorelai to arrive.
# ----->Predictions Original
# Diane is pregnant and can't wait to give birth, she thinks the waiting is the worst.
# Kate thinks she'll be an amazing mother.
# **************************
# ----------- 34 --------------
# ------>Predictions by Model
# Andrew is going to buy a pharmacy for Danielle and Danielle.
# Danielle will buy a bottle
# ----->Predictions Original
# Andrew has a cold.
# Daniel will buy him some medication.
# **************************
# ----------- 35 --------------
# ------>Predictions by Model
# John and Sam are going to meet tomorrow.
# ----->Predictions Original
# Alex and Sam are watching Millionaires.
# **************************
# ----------- 36 --------------
# ------>Predictions by Model
# Kelly and Angelica are going to bake cinnamon cookies.
# ----->Predictions Original
# Angelica sent the cinnamon cookies recipe at Kelly's request.
# **************************
# ----------- 37 --------------
# ------>Predictions by Model
# Sophie is waiting for Gina at the diner.
# ----->Predictions Original
# Sophie is waiting for a client, who is late.
# She will meet Gwen later.
# **************************
# ----------- 38 --------------
# ------>Predictions by Model
# Daniel is waiting for Sue at the entrance.
# ----->Predictions Original
# Daniel is with the Volvo on his way and will be there soon.
# Sue is going downstairs to meet him.
# **************************
# ----------- 39 --------------
# ------>Predictions by Model
# Betty is going to eat sushi with George.
# George will pick her up at 8
# ----->Predictions Original
# George is making salmon and stuffed squash for dinner.
# Betty will buy a shaving cream at CVS at his request,
# **************************
# ----------- 40 --------------
# ------>Predictions by Model
# Ken is going to meet Martha at the gym tomorrow.
# Martha will pick her up at
# ----->Predictions Original
# Ken has installed an app for running but it is not working properly on his phone.
# **************************
# ----------- 41 --------------
# ------>Predictions by Model
# Ann is going to attend the party tonight.
# ----->Predictions Original
# Ivan and Ann will meet next week.
# **************************
# ----------- 42 --------------
# ------>Predictions by Model
# Rowan will send Ashley a picture of Ashley's facebook page.
# Ashley will send her
# ----->Predictions Original
# Ashley posted some nude photos on her fb page.
# **************************
# ----------- 43 --------------
# ------>Predictions by Model
# Mikolaj is waiting for Maggie to arrive.
# ----->Predictions Original
# Mikolaj's wife needs a work permit as a foreigner.
# Government officials missed the deadline for sending it and will need another month.
# **************************
# ----------- 44 --------------
# ------>Predictions by Model
# Maria is going to stay at the hotel with her husband.
# They are going to meet
# ----->Predictions Original
# Thomas, Ann and Maria will have lunch together at the hotel.
# Ann is already in the 3rd floor lobby at the red table.
# **************************
# ----------- 45 --------------
# ------>Predictions by Model
# Sus and Valerie are going to eat sushi.
# ----->Predictions Original
# Sus and Val don't want to work and are sleepy.
# **************************
# ----------- 46 --------------
# ------>Predictions by Model
# Kate wants to go to the museum with Kevin.
# Kevin will join her.
# ----->Predictions Original
# Kate is at the Guggenheim Museum now, but will be in the Museum of the City of New York around 2-2:30.
# Kai may join her.
# Ish won't.
# Terry will join them for a coffee after they finish visiting the museum.
# Terry has already seen the museum.
# **************************
# ----------- 47 --------------
# ------>Predictions by Model
# Cathy is going to buy sunglasses for Brooke.
# ----->Predictions Original
# Cathy left her sunglasses at Broke's house.
# She will come collect them at 10.
# **************************
# ----------- 48 --------------
# ------>Predictions by Model
# Bradley and Frederica are going to celebrate the birthday of Freddie.
# Freder
# ----->Predictions Original
# Bradley will come to Frederica's birthday party tomorrow at 8pm.
# **************************
# ----------- 49 --------------
# ------>Predictions by Model
# Camilla will buy some money for Adrian.
# ----->Predictions Original
# Camilla still hasn't received the 250.
# She will check and let Adrian know.
# Money usually takes around two days to arrive.
# **************************
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=4910, training_loss=2774.420476281813, metrics={'train_runtime': 9417.6812, 'train_samples_per_second': 3.128, 'train_steps_per_second': 0.521, 'total_flos': 4489631853557760.0, 'train_loss': 2774.420476281813, 'epoch': 2.0})

# %%
trainer.train() #0.1 turn+token+global
# Out:
# /usr/local/lib/python3.8/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 14730
#   Num Epochs = 2
#   Instantaneous batch size per device = 3
#   Total train batch size (w. parallel, distributed & accumulation) = 6
#   Gradient Accumulation steps = 2
#   Total optimization steps = 4910
#   Number of trainable parameters = 139420416
# You're using a BartTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='4910' max='4910' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [4910/4910 2:46:03, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>4.272500</td>
#       <td>13.099684</td>
#       <td>46.757400</td>
#       <td>23.447100</td>
#       <td>39.271100</td>
#       <td>43.207300</td>
#       <td>18.227400</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>6.324900</td>
#       <td>6.558846</td>
#       <td>47.080000</td>
#       <td>24.177000</td>
#       <td>40.343400</td>
#       <td>43.692100</td>
#       <td>17.678500</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to test-jointbatch6/checkpoint-500
# Configuration saved in test-jointbatch6/checkpoint-500/config.json
# Model weights saved in test-jointbatch6/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in test-jointbatch6/checkpoint-500/tokenizer_config.json
# Special tokens file saved in test-jointbatch6/checkpoint-500/special_tokens_map.json
# Saving model checkpoint to test-jointbatch6/checkpoint-1000
# Configuration saved in test-jointbatch6/checkpoint-1000/config.json
# Model weights saved in test-jointbatch6/checkpoint-1000/pytorch_model.bin
# tokenizer config file saved in test-jointbatch6/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in test-jointbatch6/checkpoint-1000/special_tokens_map.json
# Saving model checkpoint to test-jointbatch6/checkpoint-1500
# Configuration saved in test-jointbatch6/checkpoint-1500/config.json
# Model weights saved in test-jointbatch6/checkpoint-1500/pytorch_model.bin
# tokenizer config file saved in test-jointbatch6/checkpoint-1500/tokenizer_config.json
# Special tokens file saved in test-jointbatch6/checkpoint-1500/special_tokens_map.json
# Saving model checkpoint to test-jointbatch6/checkpoint-2000
# Configuration saved in test-jointbatch6/checkpoint-2000/config.json
# Model weights saved in test-jointbatch6/checkpoint-2000/pytorch_model.bin
# tokenizer config file saved in test-jointbatch6/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in test-jointbatch6/checkpoint-2000/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 818
#   Batch size = 3
# ----------- 0 --------------
# ------>Predictions by Model
# A wants to get a puppy for her son.
# She will take him to the animal
# ----->Predictions Original
# A will go to the animal shelter tomorrow to get a puppy for her son.
# They already visited the shelter last Monday and the son chose the puppy.
# **************************
# ----------- 1 --------------
# ------>Predictions by Model
# Emma wants to buy an advent calendar for her kids.
# Rob, Rob and Lauren
# ----->Predictions Original
# Emma and Rob love the advent calendar.
# Lauren fits inside calendar various items, for instance, small toys and Christmas decorations.
# Her children are excited whenever they get the calendar.
# **************************
# ----------- 2 --------------
# ------>Predictions by Model
# Madison is pregnant.
# She doesn't want to talk about it because she's worried about
# ----->Predictions Original
# Madison is pregnant but she doesn't want to talk about it.
# Patricia Stevens got married and she thought she was pregnant.
# **************************
# ----------- 3 --------------
# ------>Predictions by Model
# Marla found a pair of boxers under her bed.
# Kiki and Tamara
# ----->Predictions Original
# Marla found a pair of boxers under her bed.
# **************************
# ----------- 4 --------------
# ------>Predictions by Model
# Robert has to buy guitar cable.
# Fred will find it on google maps.
# ----->Predictions Original
# Robert wants Fred to send him the address of the music shop as he needs to buy guitar cable.
# **************************
# ----------- 5 --------------
# ------>Predictions by Model
# Keith will buy some milk and cereals.
# Megan will check in the drawer next to
# ----->Predictions Original
# Megan needn't buy milk and cereals.
# They're in the drawer next to the fridge.
# **************************
# ----------- 6 --------------
# ------>Predictions by Model
# Samantha sends Evelyn a video of herself making noise.
# ----->Predictions Original
# Samantha and Evelyn after watching the video cannot believe she is able to make that noise.
# **************************
# ----------- 7 --------------
# ------>Predictions by Model
# Theresa, Luis and Adam are going to Tom's new place for dinner.
# ----->Predictions Original
# Tom's new place is in Fiesole.
# Luis and Marion has been there.
# **************************
# ----------- 8 --------------
# ------>Predictions by Model
# Jane wants to make a reservation for 6 people tonight at 20:00 for six at
# ----->Predictions Original
# Jane made a 9 PM reservation for 6 people tonight at Vegano Resto.
# **************************
# ----------- 9 --------------
# ------>Predictions by Model
# Nancy is coming home in 6 weeks.
# She has a Texan drawl.
# ----->Predictions Original
# Nancy's working in Texas, but the kids laugh at her Welsh accent.
# She's coming home in 6 weeks.
# Earlier than that she's going to travel with 3 other Brits.
# **************************
# ----------- 10 --------------
# ------>Predictions by Model
# Laura needs a new printer.
# Jamie will buy a second hand one.
# ----->Predictions Original
# Laura is going to buy a printer.
# **************************
# ----------- 11 --------------
# ------>Predictions by Model
# Barbara is in dairy section.
# Haylee can't find the coconut milk one.
# ----->Predictions Original
# Haylee can't find the coconut milk yoghurt.
# **************************
# ----------- 12 --------------
# ------>Predictions by Model
# Norbert and Wendy are going to catch the tour.
# They are waiting for the last
# ----->Predictions Original
# Wendy is shopping, but she needs to hurry up to catch the tour.
# **************************
# ----------- 13 --------------
# ------>Predictions by Model
# Cecil and Cecil are going to the Jandia Peninsula.
# Cecil is driving
# ----->Predictions Original
# Cecil, Cheryl and Peter went to the Jandia Peninsula today.
# Cecil would like to explore the south of the island tomorrow, but they will decide what to do after dinner.
# **************************
# ----------- 14 --------------
# ------>Predictions by Model
# Sophie hasn't found Nickola's pockets and handbags yet.
# Nickola
# ----->Predictions Original
# Sophie still hasn't found it despite checking pockets and handbags twice.
# **************************
# ----------- 15 --------------
# ------>Predictions by Model
# Rosie has to write an essay about bad movies.
# Dennis recommends "The Room"
# ----->Predictions Original
# Dennis and Elle are helping Rosie think of bad movies for her essay.
# **************************
# ----------- 16 --------------
# ------>Predictions by Model
# James has a dream to become a voice actor.
# ----->Predictions Original
# James has a dream of becoming a voice actor.
# He considers making a home radio station.
# **************************
# ----------- 17 --------------
# ------>Predictions by Model
# Poppy and Alice are going for drinks after work.
# Poppy has errands to
# ----->Predictions Original
# Poppy and Alice are meeting for drinks after work at Nick's at 5:30.
# Alice fancies Fred, she will invite him and a bunch of other coworkers.
# **************************
# ----------- 18 --------------
# ------>Predictions by Model
# Caron is out from 12.
# Sash will open the door for Caron.
# ----->Predictions Original
# Sash needs to see Caron who'll be out from 12.
# **************************
# ----------- 19 --------------
# ------>Predictions by Model
# Matteo doesn't like Gosia because she likes football and video games.
# Gi
# ----->Predictions Original
# Matteo is not sure about his relationship with Gosia but likes her a lot.
# **************************
# ----------- 20 --------------
# ------>Predictions by Model
# Jannette is coming for supper.
# ----->Predictions Original
# Ramzi and Jannette are going for supper.
# **************************
# ----------- 21 --------------
# ------>Predictions by Model
# Jeniffer, Alois and Hildegard are preparing ravioli.
# ----->Predictions Original
# Jeniffer is preparing ravioli following her grandmothers recipe.
# **************************
# ----------- 22 --------------
# ------>Predictions by Model
# Lawrence will be through with the article in a few minutes.
# ----->Predictions Original
# Lawrence will finish writing the article soon.
# **************************
# ----------- 23 --------------
# ------>Predictions by Model
# Chad sent Brennen a funny photo.
# ----->Predictions Original
# Chad has sent Brennen a funny photo.
# Brennen does not find it very funny.
# **************************
# ----------- 24 --------------
# ------>Predictions by Model
# Sadie needs to go to the dentist quickly after work.
# Chloe will pick up Sad
# ----->Predictions Original
# Sadie will borrow Chloe's bike on Wednesday evening.
# She has a dentist appointment on Thursday after work.
# **************************
# ----------- 25 --------------
# ------>Predictions by Model
# Carter and Olivia are planning to launch a new restaurant in the city centre next month.
# ----->Predictions Original
# Carter is launching a restaurant business next month.
# Olivia wants him to include a restaurant she's working for in the discount app.
# They will meet in person to discuss it.
# **************************
# ----------- 26 --------------
# ------>Predictions by Model
# Kristine is worried about Kenny's health.
# He has another surgery scheduled tomorrow.
# He
# ----->Predictions Original
# Kenny had a surgery, as Kristine reports.
# He will have another surgery tomorrow.
# Guy will come to St. Mark's Hospital near Asda to stay with Kristine.
# **************************
# ----------- 27 --------------
# ------>Predictions by Model
# Joey and Olivia broke up 2 days ago.
# Olivia cheated on her with numerous girls
# ----->Predictions Original
# Skyler and Adam are surprised that Joey and Olivia broke up.
# **************************
# ----------- 28 --------------
# ------>Predictions by Model
# Amanda went to dance classes with Michael yesterday.
# The instructor needed a partner to show
# ----->Predictions Original
# Amanda goes to dancing classes with Michael.
# She volunteered to show the English Waltz steps with the instructor yesterday.
# Amanda is shy and goes to therapy.
# **************************
# ----------- 29 --------------
# ------>Predictions by Model
# Taylor wants Isabel to bring her boyfriend to her.
# ----->Predictions Original
# Taylor wants to meet Isabel's boyfriend but she has never had any.
# **************************
# ----------- 30 --------------
# ------>Predictions by Model
# Theo is leaving on Friday.
# Toby will come back by train on Monday.
# Toby
# ----->Predictions Original
# Theo's going to stay near Torino in the region of Italian Alpes.
# Toby wants to join the trip.
# Theo agrees and will pick Toby up on Friday at 7 am.
# **************************
# ----------- 31 --------------
# ------>Predictions by Model
# Brandon will be late, but he hasn't called to say he'd be late.
# ----->Predictions Original
# Brandon is late again.
# Clara will prepare a report on the absenteeism and lateness for Phil by Friday.
# **************************
# ----------- 32 --------------
# ------>Predictions by Model
# Suzie is sick again.
# Olga will reschedule her meeting with Suzie
# ----->Predictions Original
# Olga and Suzie will postpone their meeting due to Suzie's sickness.
# **************************
# ----------- 33 --------------
# ------>Predictions by Model
# Kate will be Lorelai's mother.
# ----->Predictions Original
# Diane is pregnant and can't wait to give birth, she thinks the waiting is the worst.
# Kate thinks she'll be an amazing mother.
# **************************
# ----------- 34 --------------
# ------>Predictions by Model
# Andrew has a cold.
# He will drop by after work to pick up some stuff from
# ----->Predictions Original
# Andrew has a cold.
# Daniel will buy him some medication.
# **************************
# ----------- 35 --------------
# ------>Predictions by Model
# Alex and Sam are watching "Millionaires" on tv.
# Sam has a chance
# ----->Predictions Original
# Alex and Sam are watching Millionaires.
# **************************
# ----------- 36 --------------
# ------>Predictions by Model
# Jessica and Angelica have the cinnamon cookies recipe.
# ----->Predictions Original
# Angelica sent the cinnamon cookies recipe at Kelly's request.
# **************************
# ----------- 37 --------------
# ------>Predictions by Model
# Sophie is waiting for a client.
# Gwen will let Sophie know in 15
# ----->Predictions Original
# Sophie is waiting for a client, who is late.
# She will meet Gwen later.
# **************************
# ----------- 38 --------------
# ------>Predictions by Model
# Daniel is on his way to meet Sue with the Volvo.
# ----->Predictions Original
# Daniel is with the Volvo on his way and will be there soon.
# Sue is going downstairs to meet him.
# **************************
# ----------- 39 --------------
# ------>Predictions by Model
# Betty is going to CVS to buy some salmon and some shaving cream.
# George
# ----->Predictions Original
# George is making salmon and stuffed squash for dinner.
# Betty will buy a shaving cream at CVS at his request,
# **************************
# ----------- 40 --------------
# ------>Predictions by Model
# Ken started running and wanted to track his progress.
# He didn't use endomondo
# ----->Predictions Original
# Ken has installed an app for running but it is not working properly on his phone.
# **************************
# ----------- 41 --------------
# ------>Predictions by Model
# Ann couldn't come to Ivan's birthday party.
# Ivan bought her something for her birthday
# ----->Predictions Original
# Ivan and Ann will meet next week.
# **************************
# ----------- 42 --------------
# ------>Predictions by Model
# Ashley posted some pictures of her fb page on Facebook.
# Rowan doesn't
# ----->Predictions Original
# Ashley posted some nude photos on her fb page.
# **************************
# ----------- 43 --------------
# ------>Predictions by Model
# Mikolaj got the letter from the government.
# Magda has no words.
# ----->Predictions Original
# Mikolaj's wife needs a work permit as a foreigner.
# Government officials missed the deadline for sending it and will need another month.
# **************************
# ----------- 44 --------------
# ------>Predictions by Model
# Maria is on her way to the hotel.
# Ann is at the 3rd floor.
# ----->Predictions Original
# Thomas, Ann and Maria will have lunch together at the hotel.
# Ann is already in the 3rd floor lobby at the red table.
# **************************
# ----------- 45 --------------
# ------>Predictions by Model
# Sus is sleepy and doesn't want to work.
# ----->Predictions Original
# Sus and Val don't want to work and are sleepy.
# **************************
# ----------- 46 --------------
# ------>Predictions by Model
# Kate, Kai and Terry are going to the Museum of the city of NY.
# Kate
# ----->Predictions Original
# Kate is at the Guggenheim Museum now, but will be in the Museum of the City of New York around 2-2:30.
# Kai may join her.
# Ish won't.
# Terry will join them for a coffee after they finish visiting the museum.
# Terry has already seen the museum.
# **************************
# ----------- 47 --------------
# ------>Predictions by Model
# Cathy left her sunglasses at Brooke's house.
# Brooke will pick them up at 10
# ----->Predictions Original
# Cathy left her sunglasses at Broke's house.
# She will come collect them at 10.
# **************************
# ----------- 48 --------------
# ------>Predictions by Model
# Frederica will come to Bradley's birthday party tomorrow at 8 p.m.
# ----->Predictions Original
# Bradley will come to Frederica's birthday party tomorrow at 8pm.
# **************************
# ----------- 49 --------------
# ------>Predictions by Model
# Camilla received 250 from Adrian.
# Camilla needs to check if she has received the
# ----->Predictions Original
# Camilla still hasn't received the 250.
# She will check and let Adrian know.
# Money usually takes around two days to arrive.
# **************************
# Saving model checkpoint to test-jointbatch6/checkpoint-2500
# Configuration saved in test-jointbatch6/checkpoint-2500/config.json
# Model weights saved in test-jointbatch6/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in test-jointbatch6/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in test-jointbatch6/checkpoint-2500/special_tokens_map.json
# Saving model checkpoint to test-jointbatch6/checkpoint-3000
# Configuration saved in test-jointbatch6/checkpoint-3000/config.json
# Model weights saved in test-jointbatch6/checkpoint-3000/pytorch_model.bin
# tokenizer config file saved in test-jointbatch6/checkpoint-3000/tokenizer_config.json
# Special tokens file saved in test-jointbatch6/checkpoint-3000/special_tokens_map.json
# Saving model checkpoint to test-jointbatch6/checkpoint-3500
# Configuration saved in test-jointbatch6/checkpoint-3500/config.json
# Model weights saved in test-jointbatch6/checkpoint-3500/pytorch_model.bin
# tokenizer config file saved in test-jointbatch6/checkpoint-3500/tokenizer_config.json
# Special tokens file saved in test-jointbatch6/checkpoint-3500/special_tokens_map.json
# Saving model checkpoint to test-jointbatch6/checkpoint-4000
# Configuration saved in test-jointbatch6/checkpoint-4000/config.json
# Model weights saved in test-jointbatch6/checkpoint-4000/pytorch_model.bin
# tokenizer config file saved in test-jointbatch6/checkpoint-4000/tokenizer_config.json
# Special tokens file saved in test-jointbatch6/checkpoint-4000/special_tokens_map.json
# Saving model checkpoint to test-jointbatch6/checkpoint-4500
# Configuration saved in test-jointbatch6/checkpoint-4500/config.json
# Model weights saved in test-jointbatch6/checkpoint-4500/pytorch_model.bin
# tokenizer config file saved in test-jointbatch6/checkpoint-4500/tokenizer_config.json
# Special tokens file saved in test-jointbatch6/checkpoint-4500/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 818
#   Batch size = 3
# ----------- 0 --------------
# ------>Predictions by Model
# A wants to get a puppy for her son.
# She will take him to the animal
# ----->Predictions Original
# A will go to the animal shelter tomorrow to get a puppy for her son.
# They already visited the shelter last Monday and the son chose the puppy.
# **************************
# ----------- 1 --------------
# ------>Predictions by Model
# Emma wants to buy an advent calendar for her kids.
# Rob and Lauren like it
# ----->Predictions Original
# Emma and Rob love the advent calendar.
# Lauren fits inside calendar various items, for instance, small toys and Christmas decorations.
# Her children are excited whenever they get the calendar.
# **************************
# ----------- 2 --------------
# ------>Predictions by Model
# Madison is pregnant.
# She doesn't want to talk about it because she's worried about
# ----->Predictions Original
# Madison is pregnant but she doesn't want to talk about it.
# Patricia Stevens got married and she thought she was pregnant.
# **************************
# ----------- 3 --------------
# ------>Predictions by Model
# Marla found a pair of boxers under her bed.
# ----->Predictions Original
# Marla found a pair of boxers under her bed.
# **************************
# ----------- 4 --------------
# ------>Predictions by Model
# Robert needs to buy guitar cable.
# Fred gives him the address of the music shop.
# ----->Predictions Original
# Robert wants Fred to send him the address of the music shop as he needs to buy guitar cable.
# **************************
# ----------- 5 --------------
# ------>Predictions by Model
# Keith will buy some milk and cereals.
# Megan checked in the drawer next to the
# ----->Predictions Original
# Megan needn't buy milk and cereals.
# They're in the drawer next to the fridge.
# **************************
# ----------- 6 --------------
# ------>Predictions by Model
# Samantha sends a video to Evelyn.
# ----->Predictions Original
# Samantha and Evelyn after watching the video cannot believe she is able to make that noise.
# **************************
# ----------- 7 --------------
# ------>Predictions by Model
# Tom's new place is in Fiesole.
# He invited Theresa and Luis for a
# ----->Predictions Original
# Tom's new place is in Fiesole.
# Luis and Marion has been there.
# **************************
# ----------- 8 --------------
# ------>Predictions by Model
# Jane wants to make a reservation for 6 people tonight around 20:00.
# Vegano
# ----->Predictions Original
# Jane made a 9 PM reservation for 6 people tonight at Vegano Resto.
# **************************
# ----------- 9 --------------
# ------>Predictions by Model
# Nancy is coming home in 6 weeks.
# She has a Texan drawl.
# ----->Predictions Original
# Nancy's working in Texas, but the kids laugh at her Welsh accent.
# She's coming home in 6 weeks.
# Earlier than that she's going to travel with 3 other Brits.
# **************************
# ----------- 10 --------------
# ------>Predictions by Model
# Laura needs a new printer.
# Jamie will buy a second hand one.
# ----->Predictions Original
# Laura is going to buy a printer.
# **************************
# ----------- 11 --------------
# ------>Predictions by Model
# Barbara bought coconut milk one.
# Haylee is in dairy section.
# ----->Predictions Original
# Haylee can't find the coconut milk yoghurt.
# **************************
# ----------- 12 --------------
# ------>Predictions by Model
# Norbert and Wendy are going to catch the tour.
# They missed the last one because
# ----->Predictions Original
# Wendy is shopping, but she needs to hurry up to catch the tour.
# **************************
# ----------- 13 --------------
# ------>Predictions by Model
# Cecil and Cecil went to the Jandia Peninsula.
# They will decide after
# ----->Predictions Original
# Cecil, Cheryl and Peter went to the Jandia Peninsula today.
# Cecil would like to explore the south of the island tomorrow, but they will decide what to do after dinner.
# **************************
# ----------- 14 --------------
# ------>Predictions by Model
# Sophie has checked pockets and handbags twice already.
# ----->Predictions Original
# Sophie still hasn't found it despite checking pockets and handbags twice.
# **************************
# ----------- 15 --------------
# ------>Predictions by Model
# Rosie has to write an essay about bad movies.
# She will cover "The Room
# ----->Predictions Original
# Dennis and Elle are helping Rosie think of bad movies for her essay.
# **************************
# ----------- 16 --------------
# ------>Predictions by Model
# James has a dream to become a voice actor.
# He has a microphone at home and
# ----->Predictions Original
# James has a dream of becoming a voice actor.
# He considers making a home radio station.
# **************************
# ----------- 17 --------------
# ------>Predictions by Model
# Poppy and Alice are going for drinks after work.
# Poppy will invite Fred and
# ----->Predictions Original
# Poppy and Alice are meeting for drinks after work at Nick's at 5:30.
# Alice fancies Fred, she will invite him and a bunch of other coworkers.
# **************************
# ----------- 18 --------------
# ------>Predictions by Model
# Caron is out from 12.
# Sash will open the door for Caron.
# ----->Predictions Original
# Sash needs to see Caron who'll be out from 12.
# **************************
# ----------- 19 --------------
# ------>Predictions by Model
# Giuseppe is dating Gosia.
# Giuseppe doesn't like games either.
# ----->Predictions Original
# Matteo is not sure about his relationship with Gosia but likes her a lot.
# **************************
# ----------- 20 --------------
# ------>Predictions by Model
# Mom is calling for supper.
# ----->Predictions Original
# Ramzi and Jannette are going for supper.
# **************************
# ----------- 21 --------------
# ------>Predictions by Model
# Jeniffer and Hildegard are preparing ravioli.
# ----->Predictions Original
# Jeniffer is preparing ravioli following her grandmothers recipe.
# **************************
# ----------- 22 --------------
# ------>Predictions by Model
# Lawrence will get back to Madison once he is through with the article.
# ----->Predictions Original
# Lawrence will finish writing the article soon.
# **************************
# ----------- 23 --------------
# ------>Predictions by Model
# Chad sent Brennen a funny photo.
# ----->Predictions Original
# Chad has sent Brennen a funny photo.
# Brennen does not find it very funny.
# **************************
# ----------- 24 --------------
# ------>Predictions by Model
# Chloe will borrow Sadie's bike on Wednesday evening.
# ----->Predictions Original
# Sadie will borrow Chloe's bike on Wednesday evening.
# She has a dentist appointment on Thursday after work.
# **************************
# ----------- 25 --------------
# ------>Predictions by Model
# Carter and Olivia are planning to launch a new restaurant next month.
# Olivia loves the restaurant
# ----->Predictions Original
# Carter is launching a restaurant business next month.
# Olivia wants him to include a restaurant she's working for in the discount app.
# They will meet in person to discuss it.
# **************************
# ----------- 26 --------------
# ------>Predictions by Model
# Kristine is worried about Kenny's health.
# He has another surgery scheduled tomorrow.
# He
# ----->Predictions Original
# Kenny had a surgery, as Kristine reports.
# He will have another surgery tomorrow.
# Guy will come to St. Mark's Hospital near Asda to stay with Kristine.
# **************************
# ----------- 27 --------------
# ------>Predictions by Model
# Joey and Olivia broke up 2 days ago.
# Olivia cheated on Joey with numerous girls
# ----->Predictions Original
# Skyler and Adam are surprised that Joey and Olivia broke up.
# **************************
# ----------- 28 --------------
# ------>Predictions by Model
# Amanda went to dance classes yesterday.
# The instructor needed a partner to show the steps
# ----->Predictions Original
# Amanda goes to dancing classes with Michael.
# She volunteered to show the English Waltz steps with the instructor yesterday.
# Amanda is shy and goes to therapy.
# **************************
# ----------- 29 --------------
# ------>Predictions by Model
# Taylor's friends' daughters bring their bf to her.
# Isabel hasn't had any
# ----->Predictions Original
# Taylor wants to meet Isabel's boyfriend but she has never had any.
# **************************
# ----------- 30 --------------
# ------>Predictions by Model
# Theo is leaving on Friday.
# Toby will come back by train on Monday.
# Toby
# ----->Predictions Original
# Theo's going to stay near Torino in the region of Italian Alpes.
# Toby wants to join the trip.
# Theo agrees and will pick Toby up on Friday at 7 am.
# **************************
# ----------- 31 --------------
# ------>Predictions by Model
# Brandon will be late.
# Clara will prepare a report on the absenteeism and lateness
# ----->Predictions Original
# Brandon is late again.
# Clara will prepare a report on the absenteeism and lateness for Phil by Friday.
# **************************
# ----------- 32 --------------
# ------>Predictions by Model
# Suzie is sick again.
# She cancelled last time because she didn't want to catch
# ----->Predictions Original
# Olga and Suzie will postpone their meeting due to Suzie's sickness.
# **************************
# ----------- 33 --------------
# ------>Predictions by Model
# Kate will be Diane's daughter Lorelai's mother.
# ----->Predictions Original
# Diane is pregnant and can't wait to give birth, she thinks the waiting is the worst.
# Kate thinks she'll be an amazing mother.
# **************************
# ----------- 34 --------------
# ------>Predictions by Model
# Andrew had to call in sick because he has a cold.
# Daniel will drop by after
# ----->Predictions Original
# Andrew has a cold.
# Daniel will buy him some medication.
# **************************
# ----------- 35 --------------
# ------>Predictions by Model
# Alex and Sam are watching "Millionaires" on tv.
# Sam has a chance
# ----->Predictions Original
# Alex and Sam are watching Millionaires.
# **************************
# ----------- 36 --------------
# ------>Predictions by Model
# Jessica and Angelica have the cinnamon cookies recipe.
# ----->Predictions Original
# Angelica sent the cinnamon cookies recipe at Kelly's request.
# **************************
# ----------- 37 --------------
# ------>Predictions by Model
# Sophie is waiting for a client.
# Gwen will let Sophie know in 15
# ----->Predictions Original
# Sophie is waiting for a client, who is late.
# She will meet Gwen later.
# **************************
# ----------- 38 --------------
# ------>Predictions by Model
# Sue is going downstairs now.
# Daniel is on his way.
# ----->Predictions Original
# Daniel is with the Volvo on his way and will be there soon.
# Sue is going downstairs to meet him.
# **************************
# ----------- 39 --------------
# ------>Predictions by Model
# Betty is going to CVS to buy some salmon and some shaving cream.
# George
# ----->Predictions Original
# George is making salmon and stuffed squash for dinner.
# Betty will buy a shaving cream at CVS at his request,
# **************************
# ----------- 40 --------------
# ------>Predictions by Model
# Ken started running and wanted to track his progress, but his phone battery was almost depleted
# ----->Predictions Original
# Ken has installed an app for running but it is not working properly on his phone.
# **************************
# ----------- 41 --------------
# ------>Predictions by Model
# Ann couldn't come to Ivan's birthday party.
# Ivan bought her something for her birthday
# ----->Predictions Original
# Ivan and Ann will meet next week.
# **************************
# ----------- 42 --------------
# ------>Predictions by Model
# Ashley posted some pictures of her fb page on Facebook.
# Rowan doesn't
# ----->Predictions Original
# Ashley posted some nude photos on her fb page.
# **************************
# ----------- 43 --------------
# ------>Predictions by Model
# Mikolaj got the letter with the working permission from the government.
# Magda
# ----->Predictions Original
# Mikolaj's wife needs a work permit as a foreigner.
# Government officials missed the deadline for sending it and will need another month.
# **************************
# ----------- 44 --------------
# ------>Predictions by Model
# Maria is on her way to the hotel.
# Ann is at the 3rd floor lobby
# ----->Predictions Original
# Thomas, Ann and Maria will have lunch together at the hotel.
# Ann is already in the 3rd floor lobby at the red table.
# **************************
# ----------- 45 --------------
# ------>Predictions by Model
# Sus and Val don't want to work.
# ----->Predictions Original
# Sus and Val don't want to work and are sleepy.
# **************************
# ----------- 46 --------------
# ------>Predictions by Model
# Kate and Terry are going to the Museum of the city of NY around 2-2
# ----->Predictions Original
# Kate is at the Guggenheim Museum now, but will be in the Museum of the City of New York around 2-2:30.
# Kai may join her.
# Ish won't.
# Terry will join them for a coffee after they finish visiting the museum.
# Terry has already seen the museum.
# **************************
# ----------- 47 --------------
# ------>Predictions by Model
# Cathy left her sunglasses at Brooke's house.
# Brooke will come round at 10 tonight
# ----->Predictions Original
# Cathy left her sunglasses at Broke's house.
# She will come collect them at 10.
# **************************
# ----------- 48 --------------
# ------>Predictions by Model
# Frederica will come to Bradley's birthday party tomorrow at 8 pm.
# ----->Predictions Original
# Bradley will come to Frederica's birthday party tomorrow at 8pm.
# **************************
# ----------- 49 --------------
# ------>Predictions by Model
# Camilla received 250 from Adrian.
# ----->Predictions Original
# Camilla still hasn't received the 250.
# She will check and let Adrian know.
# Money usually takes around two days to arrive.
# **************************
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=4910, training_loss=5.850273959748371, metrics={'train_runtime': 9968.9159, 'train_samples_per_second': 2.955, 'train_steps_per_second': 0.493, 'total_flos': 4493420674928640.0, 'train_loss': 5.850273959748371, 'epoch': 2.0})

# %%
trainer.evaluate()
# Out:
# ***** Running Evaluation *****
#   Num examples = 818
#   Batch size = 3
# You're using a BartTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='273' max='273' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [273/273 05:11]
#     </div>
# -------------------------
# ------>Predictions by Model
# A wants to get a puppy for his son.
# He wants to name it Lemmy
# ----->Predictions Original
# A will go to the animal shelter tomorrow to get a puppy for her son.
# They already visited the shelter last Monday and the son chose the puppy.
# **************************
# -------------------------
# ------>Predictions by Model
# Emma wants to buy an advent calendar for her kids.
# Rob doesn't like the
# ----->Predictions Original
# Emma and Rob love the advent calendar.
# Lauren fits inside calendar various items, for instance, small toys and Christmas decorations.
# Her children are excited whenever they get the calendar.
# **************************
# -------------------------
# ------>Predictions by Model
# Jackie is pregnant with Madison's child.
# She doesn't want to talk about it
# ----->Predictions Original
# Madison is pregnant but she doesn't want to talk about it.
# Patricia Stevens got married and she thought she was pregnant.
# **************************
# -------------------------
# ------>Predictions by Model
# Marla found a pair of boxers under her bed.
# Kiki and Tamara
# ----->Predictions Original
# Marla found a pair of boxers under her bed.
# **************************
# -------------------------
# ------>Predictions by Model
# Robert has to buy guitar cable.
# Fred will catch it on google maps.
# ----->Predictions Original
# Robert wants Fred to send him the address of the music shop as he needs to buy guitar cable.
# **************************
# -------------------------
# ------>Predictions by Model
# Keith will buy some milk and cereals.
# Megan will check in the drawer next to
# ----->Predictions Original
# Megan needn't buy milk and cereals.
# They're in the drawer next to the fridge.
# **************************
# -------------------------
# ------>Predictions by Model
# Samantha sends Evelyn a video.
# ----->Predictions Original
# Samantha and Evelyn after watching the video cannot believe she is able to make that noise.
# **************************
# -------------------------
# ------>Predictions by Model
# Theresa has been at Tom's new place.
# ----->Predictions Original
# Tom's new place is in Fiesole.
# Luis and Marion has been there.
# **************************
# -------------------------
# ------>Predictions by Model
# Jane will make a reservation for 6 people tonight around 20:00.
# ----->Predictions Original
# Jane made a 9 PM reservation for 6 people tonight at Vegano Resto.
# **************************
# -------------------------
# ------>Predictions by Model
# Nancy is coming home in 6 weeks.
# Tina and Nancy are not sure if she
# ----->Predictions Original
# Nancy's working in Texas, but the kids laugh at her Welsh accent.
# She's coming home in 6 weeks.
# Earlier than that she's going to travel with 3 other Brits.
# **************************
# -------------------------
# ------>Predictions by Model
# Laura needs a new printer.
# Jamie will buy a second hand one.
# ----->Predictions Original
# Laura is going to buy a printer.
# **************************
# -------------------------
# ------>Predictions by Model
# Barbara got coconut milk one.
# Haylee is in dairy section.
# ----->Predictions Original
# Haylee can't find the coconut milk yoghurt.
# **************************
# -------------------------
# ------>Predictions by Model
# Norbert missed the last tour.
# Wendy will buy something for him at the register.
# ----->Predictions Original
# Wendy is shopping, but she needs to hurry up to catch the tour.
# **************************
# -------------------------
# ------>Predictions by Model
# Cecil and Lidia are going to go to the Jandia Peninsula tomorrow
# ----->Predictions Original
# Cecil, Cheryl and Peter went to the Jandia Peninsula today.
# Cecil would like to explore the south of the island tomorrow, but they will decide what to do after dinner.
# **************************
# -------------------------
# ------>Predictions by Model
# Nickola will check Sophie's pockets and handbags.
# ----->Predictions Original
# Sophie still hasn't found it despite checking pockets and handbags twice.
# **************************
# -------------------------
# ------>Predictions by Model
# Rosie has to write an essay for the film "The Room".
# She will check
# ----->Predictions Original
# Dennis and Elle are helping Rosie think of bad movies for her essay.
# **************************
# -------------------------
# ------>Predictions by Model
# Julia wants James to become a voice actor.
# ----->Predictions Original
# James has a dream of becoming a voice actor.
# He considers making a home radio station.
# **************************
# -------------------------
# ------>Predictions by Model
# Alice didn't get lunch because she had errands to do.
# Poppy will invite
# ----->Predictions Original
# Poppy and Alice are meeting for drinks after work at Nick's at 5:30.
# Alice fancies Fred, she will invite him and a bunch of other coworkers.
# **************************
# -------------------------
# ------>Predictions by Model
# Caron is out from 12.
# ----->Predictions Original
# Sash needs to see Caron who'll be out from 12.
# **************************
# -------------------------
# ------>Predictions by Model
# Giuseppe doesn't like Gosia.
# ----->Predictions Original
# Matteo is not sure about his relationship with Gosia but likes her a lot.
# **************************
# -------------------------
# ------>Predictions by Model
# Ramzi is calling for supper.
# ----->Predictions Original
# Ramzi and Jannette are going for supper.
# **************************
# -------------------------
# ------>Predictions by Model
# Jeniffer is preparing ravioli for Alois.
# ----->Predictions Original
# Jeniffer is preparing ravioli following her grandmothers recipe.
# **************************
# -------------------------
# ------>Predictions by Model
# Lawrence will get back to Madison in a few minutes.
# ----->Predictions Original
# Lawrence will finish writing the article soon.
# **************************
# -------------------------
# ------>Predictions by Model
# Chad sent Brennen a photo of a funny joke.
# ----->Predictions Original
# Chad has sent Brennen a funny photo.
# Brennen does not find it very funny.
# **************************
# -------------------------
# ------>Predictions by Model
# Sadie needs Chloe to pick up Chloe's bike from the dentist.
# Chloe will lock
# ----->Predictions Original
# Sadie will borrow Chloe's bike on Wednesday evening.
# She has a dentist appointment on Thursday after work.
# **************************
# -------------------------
# ------>Predictions by Model
# Olivia and Carter want to launch a new restaurant in the city centre next month
# ----->Predictions Original
# Carter is launching a restaurant business next month.
# Olivia wants him to include a restaurant she's working for in the discount app.
# They will meet in person to discuss it.
# **************************
# -------------------------
# ------>Predictions by Model
# Kristine is back from surgery.
# Guy will come to the hospital soon.
# ----->Predictions Original
# Kenny had a surgery, as Kristine reports.
# He will have another surgery tomorrow.
# Guy will come to St. Mark's Hospital near Asda to stay with Kristine.
# **************************
# -------------------------
# ------>Predictions by Model
# Joey and Olivia broke up 2 days ago.
# Joey cheated on Olivia with numerous girls
# ----->Predictions Original
# Skyler and Adam are surprised that Joey and Olivia broke up.
# **************************
# -------------------------
# ------>Predictions by Model
# Amanda went to dance classes with Michael yesterday.
# She needed a partner to show the
# ----->Predictions Original
# Amanda goes to dancing classes with Michael.
# She volunteered to show the English Waltz steps with the instructor yesterday.
# Amanda is shy and goes to therapy.
# **************************
# -------------------------
# ------>Predictions by Model
# Taylor will bring Isabel's bf to Isabel's birthday party.
# ----->Predictions Original
# Taylor wants to meet Isabel's boyfriend but she has never had any.
# **************************
# -------------------------
# ------>Predictions by Model
# Toby will come back by train on Friday.
# Theo will write Toby the details
# ----->Predictions Original
# Theo's going to stay near Torino in the region of Italian Alpes.
# Toby wants to join the trip.
# Theo agrees and will pick Toby up on Friday at 7 am.
# **************************
# -------------------------
# ------>Predictions by Model
# Clara hasn't called Phil yet.
# ----->Predictions Original
# Brandon is late again.
# Clara will prepare a report on the absenteeism and lateness for Phil by Friday.
# **************************
# -------------------------
# ------>Predictions by Model
# Suzie is sick again.
# Olga will reschedule.
# ----->Predictions Original
# Olga and Suzie will postpone their meeting due to Suzie's sickness.
# **************************
# -------------------------
# ------>Predictions by Model
# Diane will be Lorelai's mother.
# Kate will hold her in her arms
# ----->Predictions Original
# Diane is pregnant and can't wait to give birth, she thinks the waiting is the worst.
# Kate thinks she'll be an amazing mother.
# **************************
# -------------------------
# ------>Predictions by Model
# Andrew had to call in sick because he had a flu.
# Daniel will drop by after
# ----->Predictions Original
# Andrew has a cold.
# Daniel will buy him some medication.
# **************************
# -------------------------
# ------>Predictions by Model
# John is watching 'Millionaires' on tv.
# Sam has a chance to win
# ----->Predictions Original
# Alex and Sam are watching Millionaires.
# **************************
# -------------------------
# ------>Predictions by Model
# Kelly has the cinnamon cookies recipe.
# ----->Predictions Original
# Angelica sent the cinnamon cookies recipe at Kelly's request.
# **************************
# -------------------------
# ------>Predictions by Model
# Sophie is waiting for a client.
# Gwen will let Sophie know in 15
# ----->Predictions Original
# Sophie is waiting for a client, who is late.
# She will meet Gwen later.
# **************************
# -------------------------
# ------>Predictions by Model
# Daniel will see Sue downstairs in a few minutes.
# ----->Predictions Original
# Daniel is with the Volvo on his way and will be there soon.
# Sue is going downstairs to meet him.
# **************************
# -------------------------
# ------>Predictions by Model
# Betty is going to CVS to pick up some squash for George.
# George will
# ----->Predictions Original
# George is making salmon and stuffed squash for dinner.
# Betty will buy a shaving cream at CVS at his request,
# **************************
# -------------------------
# ------>Predictions by Model
# Ken's phone doesn't work properly.
# He started running and wanted to track his progress
# ----->Predictions Original
# Ken has installed an app for running but it is not working properly on his phone.
# **************************
# -------------------------
# ------>Predictions by Model
# Ann hasn't been at Ivan's birthday party yet.
# She will come next week.
# ----->Predictions Original
# Ivan and Ann will meet next week.
# **************************
# -------------------------
# ------>Predictions by Model
# Rowan has some important stuff to do on Ashley's fb page.
# Delil
# ----->Predictions Original
# Ashley posted some nude photos on her fb page.
# **************************
# -------------------------
# ------>Predictions by Model
# Mikolaj got the letter from his wife's papers.
# Magda doesn't
# ----->Predictions Original
# Mikolaj's wife needs a work permit as a foreigner.
# Government officials missed the deadline for sending it and will need another month.
# **************************
# -------------------------
# ------>Predictions by Model
# Maria is on the way to the hotel.
# Ann and Peter are at the red table
# ----->Predictions Original
# Thomas, Ann and Maria will have lunch together at the hotel.
# Ann is already in the 3rd floor lobby at the red table.
# **************************
# -------------------------
# ------>Predictions by Model
# Sus is sleepy and wants to work.
# ----->Predictions Original
# Sus and Val don't want to work and are sleepy.
# **************************
# -------------------------
# ------>Predictions by Model
# Kate and Terry are going to the Museum of the City of NY.
# Kate will join
# ----->Predictions Original
# Kate is at the Guggenheim Museum now, but will be in the Museum of the City of New York around 2-2:30.
# Kai may join her.
# Ish won't.
# Terry will join them for a coffee after they finish visiting the museum.
# Terry has already seen the museum.
# **************************
# -------------------------
# ------>Predictions by Model
# Broke left his sunglasses at Cathy's house.
# ----->Predictions Original
# Cathy left her sunglasses at Broke's house.
# She will come collect them at 10.
# **************************
# -------------------------
# ------>Predictions by Model
# Frederica will come to Bradley's birthday party tomorrow at 8pm.
# ----->Predictions Original
# Bradley will come to Frederica's birthday party tomorrow at 8pm.
# **************************
# -------------------------
# ------>Predictions by Model
# Adrian received the money.
# Camilla still needs to check it.
# ----->Predictions Original
# Camilla still hasn't received the 250.
# She will check and let Adrian know.
# Money usually takes around two days to arrive.
# **************************
# {'eval_loss': 9.662054061889648,
#  'eval_rouge1': 42.9668,
#  'eval_rouge2': 19.5059,
#  'eval_rougeL': 35.4994,
#  'eval_rougeLsum': 39.1085,
#  'eval_gen_len': 16.6002,
#  'eval_runtime': 313.8526,
#  'eval_samples_per_second': 2.606,
#  'eval_steps_per_second': 0.87}

# %%
trainer.train() #1 turn
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 14730
#   Num Epochs = 5
#   Instantaneous batch size per device = 6
#   Total train batch size (w. parallel, distributed & accumulation) = 12
#   Gradient Accumulation steps = 2
#   Total optimization steps = 6135
#   Number of trainable parameters = 139420416
# You're using a BartTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='6135' max='6135' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [6135/6135 2:27:02, Epoch 4/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.840800</td>
#       <td>3.806844</td>
#       <td>46.061700</td>
#       <td>23.333100</td>
#       <td>38.556700</td>
#       <td>42.503700</td>
#       <td>18.099000</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.781200</td>
#       <td>3.588556</td>
#       <td>46.681200</td>
#       <td>23.970100</td>
#       <td>39.791500</td>
#       <td>43.322000</td>
#       <td>17.784800</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.894400</td>
#       <td>3.551383</td>
#       <td>47.601200</td>
#       <td>24.410000</td>
#       <td>40.294300</td>
#       <td>44.160600</td>
#       <td>18.111200</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.477600</td>
#       <td>3.566261</td>
#       <td>47.846100</td>
#       <td>24.717600</td>
#       <td>40.376300</td>
#       <td>44.157600</td>
#       <td>18.201700</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.281200</td>
#       <td>3.505859</td>
#       <td>48.090100</td>
#       <td>24.952400</td>
#       <td>40.789700</td>
#       <td>44.467100</td>
#       <td>18.169900</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to test-tokenbatch6/checkpoint-500
# Configuration saved in test-tokenbatch6/checkpoint-500/config.json
# Model weights saved in test-tokenbatch6/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-500/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-500/special_tokens_map.json
# Saving model checkpoint to test-tokenbatch6/checkpoint-1000
# Configuration saved in test-tokenbatch6/checkpoint-1000/config.json
# Model weights saved in test-tokenbatch6/checkpoint-1000/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-1000/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 818
#   Batch size = 6
# -------------------------
# ------>Predictions by Model
# A wants to get a puppy for her son.
# She will take him to the animal
# ----->Predictions Original
# A will go to the animal shelter tomorrow to get a puppy for her son.
# They already visited the shelter last Monday and the son chose the puppy.
# **************************
# -------------------------
# ------>Predictions by Model
# Emma wants to buy an advent calendar for her kids.
# ----->Predictions Original
# Emma and Rob love the advent calendar.
# Lauren fits inside calendar various items, for instance, small toys and Christmas decorations.
# Her children are excited whenever they get the calendar.
# **************************
# -------------------------
# ------>Predictions by Model
# Madison is pregnant.
# She doesn't want to talk about it because she has money problems
# ----->Predictions Original
# Madison is pregnant but she doesn't want to talk about it.
# Patricia Stevens got married and she thought she was pregnant.
# **************************
# -------------------------
# ------>Predictions by Model
# Marla found a pair of boxers under her bed.
# She thinks it's because
# ----->Predictions Original
# Marla found a pair of boxers under her bed.
# **************************
# -------------------------
# ------>Predictions by Model
# Fred will give Robert the address of a music shop.
# ----->Predictions Original
# Robert wants Fred to send him the address of the music shop as he needs to buy guitar cable.
# **************************
# -------------------------
# ------>Predictions by Model
# Keith will check in the drawer next to the fridge to make sure there's cereal and
# ----->Predictions Original
# Megan needn't buy milk and cereals.
# They're in the drawer next to the fridge.
# **************************
# -------------------------
# ------>Predictions by Model
# Samantha is surprised by Evelyn's noise.
# ----->Predictions Original
# Samantha and Evelyn after watching the video cannot believe she is able to make that noise.
# **************************
# -------------------------
# ------>Predictions by Model
# Theresa, Luis and Adam are at Tom's new place in Fiesole.
# ----->Predictions Original
# Tom's new place is in Fiesole.
# Luis and Marion has been there.
# **************************
# -------------------------
# ------>Predictions by Model
# Jane wants to make a reservation tonight around 20:00 for 6 people under her name
# ----->Predictions Original
# Jane made a 9 PM reservation for 6 people tonight at Vegano Resto.
# **************************
# -------------------------
# ------>Predictions by Model
# Nancy is coming home in 6 weeks.
# She's going travelling with 3 other Brit
# ----->Predictions Original
# Nancy's working in Texas, but the kids laugh at her Welsh accent.
# She's coming home in 6 weeks.
# Earlier than that she's going to travel with 3 other Brits.
# **************************
# -------------------------
# ------>Predictions by Model
# Laura needs a new printer.
# Jamie will buy a second hand one.
# ----->Predictions Original
# Laura is going to buy a printer.
# **************************
# -------------------------
# ------>Predictions by Model
# Haylee is in dairy section and can't find the coconut milk one she wanted.
# ----->Predictions Original
# Haylee can't find the coconut milk yoghurt.
# **************************
# -------------------------
# ------>Predictions by Model
# Norbert and Wendy need to hurry to catch the tour.
# Wendy is at the register
# ----->Predictions Original
# Wendy is shopping, but she needs to hurry up to catch the tour.
# **************************
# -------------------------
# ------>Predictions by Model
# Cecil and Peter went to Fuerteventura in the south of the
# ----->Predictions Original
# Cecil, Cheryl and Peter went to the Jandia Peninsula today.
# Cecil would like to explore the south of the island tomorrow, but they will decide what to do after dinner.
# **************************
# -------------------------
# ------>Predictions by Model
# Sophie has checked pockets and handbags twice already.
# ----->Predictions Original
# Sophie still hasn't found it despite checking pockets and handbags twice.
# **************************
# -------------------------
# ------>Predictions by Model
# Rosie has to write an essay about bad movies.
# She will cover "The Room
# ----->Predictions Original
# Dennis and Elle are helping Rosie think of bad movies for her essay.
# **************************
# -------------------------
# ------>Predictions by Model
# James has a dream to become a voice actor.
# His mom liked reading outloud.
# ----->Predictions Original
# James has a dream of becoming a voice actor.
# He considers making a home radio station.
# **************************
# -------------------------
# ------>Predictions by Model
# Poppy has had a long day.
# Alice is going for drinks after work.
# She
# ----->Predictions Original
# Poppy and Alice are meeting for drinks after work at Nick's at 5:30.
# Alice fancies Fred, she will invite him and a bunch of other coworkers.
# **************************
# -------------------------
# ------>Predictions by Model
# Caron is out from 12.
# Sash will be before him.
# ----->Predictions Original
# Sash needs to see Caron who'll be out from 12.
# **************************
# -------------------------
# ------>Predictions by Model
# Matteo doesn't like Gosia because she criticizes him because he likes football
# ----->Predictions Original
# Matteo is not sure about his relationship with Gosia but likes her a lot.
# **************************
# -------------------------
# ------>Predictions by Model
# Jannette is calling Ramzi for supper.
# ----->Predictions Original
# Ramzi and Jannette are going for supper.
# **************************
# -------------------------
# ------>Predictions by Model
# Jeniffer, Alois and Hildegard are preparing ravioli.
# ----->Predictions Original
# Jeniffer is preparing ravioli following her grandmothers recipe.
# **************************
# -------------------------
# ------>Predictions by Model
# Madison wants Lawrence to finish the article by today.
# Lawrence will get back to Madison once
# ----->Predictions Original
# Lawrence will finish writing the article soon.
# **************************
# -------------------------
# ------>Predictions by Model
# Brennen doesn't like the photo Chad sent him.
# ----->Predictions Original
# Chad has sent Brennen a funny photo.
# Brennen does not find it very funny.
# **************************
# -------------------------
# ------>Predictions by Model
# Sadie needs to go to the dentist quickly after work.
# Chloe will come over on
# ----->Predictions Original
# Sadie will borrow Chloe's bike on Wednesday evening.
# She has a dentist appointment on Thursday after work.
# **************************
# -------------------------
# ------>Predictions by Model
# Olivia wants to launch a new restaurant in the city centre next month.
# Carter
# ----->Predictions Original
# Carter is launching a restaurant business next month.
# Olivia wants him to include a restaurant she's working for in the discount app.
# They will meet in person to discuss it.
# **************************
# -------------------------
# ------>Predictions by Model
# Kristine is worried about Kenny.
# He's back from surgery, but the doctors don
# ----->Predictions Original
# Kenny had a surgery, as Kristine reports.
# He will have another surgery tomorrow.
# Guy will come to St. Mark's Hospital near Asda to stay with Kristine.
# **************************
# -------------------------
# ------>Predictions by Model
# Joey cheated on Olivia with numerous girls and got some chick pregnant.
# Olivia is devastated
# ----->Predictions Original
# Skyler and Adam are surprised that Joey and Olivia broke up.
# **************************
# -------------------------
# ------>Predictions by Model
# Amanda went to dance classes with Michael yesterday.
# The instructor needed a partner to show
# ----->Predictions Original
# Amanda goes to dancing classes with Michael.
# She volunteered to show the English Waltz steps with the instructor yesterday.
# Amanda is shy and goes to therapy.
# **************************
# -------------------------
# ------>Predictions by Model
# Taylor has a question about Isabel's bf.
# Isabel hasn't introduced Taylor to her
# ----->Predictions Original
# Taylor wants to meet Isabel's boyfriend but she has never had any.
# **************************
# -------------------------
# ------>Predictions by Model
# Theo is leaving on Friday.
# Toby will come back by train on Monday.
# Toby
# ----->Predictions Original
# Theo's going to stay near Torino in the region of Italian Alpes.
# Toby wants to join the trip.
# Theo agrees and will pick Toby up on Friday at 7 am.
# **************************
# -------------------------
# ------>Predictions by Model
# Brandon hasn't called to say he'd be late.
# ----->Predictions Original
# Brandon is late again.
# Clara will prepare a report on the absenteeism and lateness for Phil by Friday.
# **************************
# -------------------------
# ------>Predictions by Model
# Suzie is sick again.
# She's caughing like crazy.
# She can't
# ----->Predictions Original
# Olga and Suzie will postpone their meeting due to Suzie's sickness.
# **************************
# -------------------------
# ------>Predictions by Model
# Diane wants Kate to be her kids' mother, but Kate doesn't know if
# ----->Predictions Original
# Diane is pregnant and can't wait to give birth, she thinks the waiting is the worst.
# Kate thinks she'll be an amazing mother.
# **************************
# -------------------------
# ------>Predictions by Model
# Andrew had to call in sick because of a cold.
# Daniel will drop by after work
# ----->Predictions Original
# Andrew has a cold.
# Daniel will buy him some medication.
# **************************
# -------------------------
# ------>Predictions by Model
# Alex and Sam are watching 'Millionaires' on tv.
# ----->Predictions Original
# Alex and Sam are watching Millionaires.
# **************************
# -------------------------
# ------>Predictions by Model
# Jessica has Angelica's cinnamon cookies recipe.
# ----->Predictions Original
# Angelica sent the cinnamon cookies recipe at Kelly's request.
# **************************
# -------------------------
# ------>Predictions by Model
# Sophie is waiting for a client at the restaurant.
# Gwen and Dee will
# ----->Predictions Original
# Sophie is waiting for a client, who is late.
# She will meet Gwen later.
# **************************
# -------------------------
# ------>Predictions by Model
# Daniel is on his way to meet Sue in a few minutes.
# ----->Predictions Original
# Daniel is with the Volvo on his way and will be there soon.
# Sue is going downstairs to meet him.
# **************************
# -------------------------
# ------>Predictions by Model
# Betty is going to CVS to buy some salmon and some shaving cream.
# George
# ----->Predictions Original
# George is making salmon and stuffed squash for dinner.
# Betty will buy a shaving cream at CVS at his request,
# **************************
# -------------------------
# ------>Predictions by Model
# Ken started running and wanted to track his progress, but the battery was almost depleted.
# ----->Predictions Original
# Ken has installed an app for running but it is not working properly on his phone.
# **************************
# -------------------------
# ------>Predictions by Model
# Ann hasn't been at Ivan's birthday party.
# Ivan bought her something for her birthday
# ----->Predictions Original
# Ivan and Ann will meet next week.
# **************************
# -------------------------
# ------>Predictions by Model
# Delilah wants to take a look at Ashley's fb page.
# Rowan
# ----->Predictions Original
# Ashley posted some nude photos on her fb page.
# **************************
# -------------------------
# ------>Predictions by Model
# Mikolaj has a breakthrough with his wife's papers.
# Magda got the
# ----->Predictions Original
# Mikolaj's wife needs a work permit as a foreigner.
# Government officials missed the deadline for sending it and will need another month.
# **************************
# -------------------------
# ------>Predictions by Model
# Ann is at the hotel.
# Thomas is on the way to the hotel as well.
# ----->Predictions Original
# Thomas, Ann and Maria will have lunch together at the hotel.
# Ann is already in the 3rd floor lobby at the red table.
# **************************
# -------------------------
# ------>Predictions by Model
# Sus is sleepy and doesn't want to work.
# ----->Predictions Original
# Sus and Val don't want to work and are sleepy.
# **************************
# -------------------------
# ------>Predictions by Model
# Kate and Terry are at the Guggenheim right now.
# They want to go
# ----->Predictions Original
# Kate is at the Guggenheim Museum now, but will be in the Museum of the City of New York around 2-2:30.
# Kai may join her.
# Ish won't.
# Terry will join them for a coffee after they finish visiting the museum.
# Terry has already seen the museum.
# **************************
# -------------------------
# ------>Predictions by Model
# Cathy left her sunglasses at Broke's house.
# He will come round at 10
# ----->Predictions Original
# Cathy left her sunglasses at Broke's house.
# She will come collect them at 10.
# **************************
# -------------------------
# ------>Predictions by Model
# Frederica will come to Bradley's birthday party tomorrow at 8 pm.
# ----->Predictions Original
# Bradley will come to Frederica's birthday party tomorrow at 8pm.
# **************************
# -------------------------
# ------>Predictions by Model
# Camilla needs to check the money.
# It usually takes around two days to arrive though
# ----->Predictions Original
# Camilla still hasn't received the 250.
# She will check and let Adrian know.
# Money usually takes around two days to arrive.
# **************************
# Saving model checkpoint to test-tokenbatch6/checkpoint-1500
# Configuration saved in test-tokenbatch6/checkpoint-1500/config.json
# Model weights saved in test-tokenbatch6/checkpoint-1500/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-1500/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-1500/special_tokens_map.json
# Saving model checkpoint to test-tokenbatch6/checkpoint-2000
# Configuration saved in test-tokenbatch6/checkpoint-2000/config.json
# Model weights saved in test-tokenbatch6/checkpoint-2000/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-2000/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 818
#   Batch size = 6
# -------------------------
# ------>Predictions by Model
# A wants to get a puppy for her son.
# She will take him to the animal
# ----->Predictions Original
# A will go to the animal shelter tomorrow to get a puppy for her son.
# They already visited the shelter last Monday and the son chose the puppy.
# **************************
# -------------------------
# ------>Predictions by Model
# Emma wants to buy an advent calendar for her kids.
# Rob used to get one
# ----->Predictions Original
# Emma and Rob love the advent calendar.
# Lauren fits inside calendar various items, for instance, small toys and Christmas decorations.
# Her children are excited whenever they get the calendar.
# **************************
# -------------------------
# ------>Predictions by Model
# Madison is pregnant.
# Madison doesn't want to talk about it.
# ----->Predictions Original
# Madison is pregnant but she doesn't want to talk about it.
# Patricia Stevens got married and she thought she was pregnant.
# **************************
# -------------------------
# ------>Predictions by Model
# Marla found a pair of boxers under her bed.
# ----->Predictions Original
# Marla found a pair of boxers under her bed.
# **************************
# -------------------------
# ------>Predictions by Model
# Robert has to buy guitar cable.
# Fred will give Robert the address of the music shop
# ----->Predictions Original
# Robert wants Fred to send him the address of the music shop as he needs to buy guitar cable.
# **************************
# -------------------------
# ------>Predictions by Model
# Keith will buy some milk and cereals and Megan will check in the drawer next to
# ----->Predictions Original
# Megan needn't buy milk and cereals.
# They're in the drawer next to the fridge.
# **************************
# -------------------------
# ------>Predictions by Model
# Samantha sends Evelyn a video of herself making a noise.
# ----->Predictions Original
# Samantha and Evelyn after watching the video cannot believe she is able to make that noise.
# **************************
# -------------------------
# ------>Predictions by Model
# Marion and Luis are at Tom's new place.
# It's a bit outside the
# ----->Predictions Original
# Tom's new place is in Fiesole.
# Luis and Marion has been there.
# **************************
# -------------------------
# ------>Predictions by Model
# Vegano Resto will make a reservation for 6 people tonight around 20:00
# ----->Predictions Original
# Jane made a 9 PM reservation for 6 people tonight at Vegano Resto.
# **************************
# -------------------------
# ------>Predictions by Model
# Nancy is working in a Texan drawl.
# They laugh at her accent.
# ----->Predictions Original
# Nancy's working in Texas, but the kids laugh at her Welsh accent.
# She's coming home in 6 weeks.
# Earlier than that she's going to travel with 3 other Brits.
# **************************
# -------------------------
# ------>Predictions by Model
# Laura needs a new printer.
# Jamie will buy a second hand one.
# ----->Predictions Original
# Laura is going to buy a printer.
# **************************
# -------------------------
# ------>Predictions by Model
# Barbara and Haylee are in the dairy section.
# They are looking for coconut milk
# ----->Predictions Original
# Haylee can't find the coconut milk yoghurt.
# **************************
# -------------------------
# ------>Predictions by Model
# Norbert and Wendy need to hurry to catch the tour.
# Wendy is at the register
# ----->Predictions Original
# Wendy is shopping, but she needs to hurry up to catch the tour.
# **************************
# -------------------------
# ------>Predictions by Model
# Cecil is driving to Fuerteventura Peninsula in the south of the
# ----->Predictions Original
# Cecil, Cheryl and Peter went to the Jandia Peninsula today.
# Cecil would like to explore the south of the island tomorrow, but they will decide what to do after dinner.
# **************************
# -------------------------
# ------>Predictions by Model
# Sophie hasn't found it yet.
# Nickola has checked pockets and handbags
# ----->Predictions Original
# Sophie still hasn't found it despite checking pockets and handbags twice.
# **************************
# -------------------------
# ------>Predictions by Model
# Rosie has to write an essay about bad movies.
# She will cover "The Room
# ----->Predictions Original
# Dennis and Elle are helping Rosie think of bad movies for her essay.
# **************************
# -------------------------
# ------>Predictions by Model
# James has a dream to become a voice actor.
# ----->Predictions Original
# James has a dream of becoming a voice actor.
# He considers making a home radio station.
# **************************
# -------------------------
# ------>Predictions by Model
# Poppy and Alice are going for drinks after work.
# They will meet at Nick's
# ----->Predictions Original
# Poppy and Alice are meeting for drinks after work at Nick's at 5:30.
# Alice fancies Fred, she will invite him and a bunch of other coworkers.
# **************************
# -------------------------
# ------>Predictions by Model
# Sash needs to see Caron.
# Caron is out from 12.
# Sash
# ----->Predictions Original
# Sash needs to see Caron who'll be out from 12.
# **************************
# -------------------------
# ------>Predictions by Model
# Matteo likes Gosia.
# She criticizes him because he likes football and video
# ----->Predictions Original
# Matteo is not sure about his relationship with Gosia but likes her a lot.
# **************************
# -------------------------
# ------>Predictions by Model
# Ramzi's mother is calling for supper.
# ----->Predictions Original
# Ramzi and Jannette are going for supper.
# **************************
# -------------------------
# ------>Predictions by Model
# Jeniffer, Alois and Hildegard are preparing ravioli.
# ----->Predictions Original
# Jeniffer is preparing ravioli following her grandmothers recipe.
# **************************
# -------------------------
# ------>Predictions by Model
# Lawrence will be through with the article by today.
# Madison will get back to Lawrence
# ----->Predictions Original
# Lawrence will finish writing the article soon.
# **************************
# -------------------------
# ------>Predictions by Model
# Chad sent Brennen a funny photo.
# ----->Predictions Original
# Chad has sent Brennen a funny photo.
# Brennen does not find it very funny.
# **************************
# -------------------------
# ------>Predictions by Model
# Sadie needs to go to the dentist on Thursday.
# Chloe will pick it up on
# ----->Predictions Original
# Sadie will borrow Chloe's bike on Wednesday evening.
# She has a dentist appointment on Thursday after work.
# **************************
# -------------------------
# ------>Predictions by Model
# Olivia and Carter want to launch a new restaurant in the city centre next month
# ----->Predictions Original
# Carter is launching a restaurant business next month.
# Olivia wants him to include a restaurant she's working for in the discount app.
# They will meet in person to discuss it.
# **************************
# -------------------------
# ------>Predictions by Model
# Kristine is worried about Kenny.
# He's back from surgery.
# He has another surgery
# ----->Predictions Original
# Kenny had a surgery, as Kristine reports.
# He will have another surgery tomorrow.
# Guy will come to St. Mark's Hospital near Asda to stay with Kristine.
# **************************
# -------------------------
# ------>Predictions by Model
# Joey and Olivia broke up after all these years.
# ----->Predictions Original
# Skyler and Adam are surprised that Joey and Olivia broke up.
# **************************
# -------------------------
# ------>Predictions by Model
# Amanda is pregnant.
# She went to dancing classes with Michael yesterday.
# The instructor needed
# ----->Predictions Original
# Amanda goes to dancing classes with Michael.
# She volunteered to show the English Waltz steps with the instructor yesterday.
# Amanda is shy and goes to therapy.
# **************************
# -------------------------
# ------>Predictions by Model
# Isabel hasn't introduced Taylor's bf to her yet.
# Taylor will bring him
# ----->Predictions Original
# Taylor wants to meet Isabel's boyfriend but she has never had any.
# **************************
# -------------------------
# ------>Predictions by Model
# Theo is leaving for Italy on Friday.
# Toby will come back by train on Monday
# ----->Predictions Original
# Theo's going to stay near Torino in the region of Italian Alpes.
# Toby wants to join the trip.
# Theo agrees and will pick Toby up on Friday at 7 am.
# **************************
# -------------------------
# ------>Predictions by Model
# Brandon hasn't called to say he'd be late.
# ----->Predictions Original
# Brandon is late again.
# Clara will prepare a report on the absenteeism and lateness for Phil by Friday.
# **************************
# -------------------------
# ------>Predictions by Model
# Suzie is sick again.
# Olga will reschedule.
# ----->Predictions Original
# Olga and Suzie will postpone their meeting due to Suzie's sickness.
# **************************
# -------------------------
# ------>Predictions by Model
# Diane wants Kate to be her kids' mother.
# ----->Predictions Original
# Diane is pregnant and can't wait to give birth, she thinks the waiting is the worst.
# Kate thinks she'll be an amazing mother.
# **************************
# -------------------------
# ------>Predictions by Model
# Andrew has a cold and feels awful.
# Daniel will drop by after work to get some
# ----->Predictions Original
# Andrew has a cold.
# Daniel will buy him some medication.
# **************************
# -------------------------
# ------>Predictions by Model
# Alex and Sam are watching 'Millionaires' on tv.
# ----->Predictions Original
# Alex and Sam are watching Millionaires.
# **************************
# -------------------------
# ------>Predictions by Model
# Jessica has the cinnamon cookies recipe.
# ----->Predictions Original
# Angelica sent the cinnamon cookies recipe at Kelly's request.
# **************************
# -------------------------
# ------>Predictions by Model
# Sophie is waiting for a client who is 40 minutes late.
# Gwen will
# ----->Predictions Original
# Sophie is waiting for a client, who is late.
# She will meet Gwen later.
# **************************
# -------------------------
# ------>Predictions by Model
# Daniel is on his way downstairs and will see Sue in a few minutes.
# ----->Predictions Original
# Daniel is with the Volvo on his way and will be there soon.
# Sue is going downstairs to meet him.
# **************************
# -------------------------
# ------>Predictions by Model
# Betty is going to CVS to buy some salmon and some shaving cream.
# George
# ----->Predictions Original
# George is making salmon and stuffed squash for dinner.
# Betty will buy a shaving cream at CVS at his request,
# **************************
# -------------------------
# ------>Predictions by Model
# Ken's phone doesn't work properly.
# He used endomondo everyday.
# It works
# ----->Predictions Original
# Ken has installed an app for running but it is not working properly on his phone.
# **************************
# -------------------------
# ------>Predictions by Model
# Ann hasn't been at Ivan's birthday party.
# Ivan bought her something for her birthday
# ----->Predictions Original
# Ivan and Ann will meet next week.
# **************************
# -------------------------
# ------>Predictions by Model
# Delilah and Rowan are going to check Ashley's fb page.
# ----->Predictions Original
# Ashley posted some nude photos on her fb page.
# **************************
# -------------------------
# ------>Predictions by Model
# Mikolaj has a breakthrough with his wife's papers.
# Magda got the
# ----->Predictions Original
# Mikolaj's wife needs a work permit as a foreigner.
# Government officials missed the deadline for sending it and will need another month.
# **************************
# -------------------------
# ------>Predictions by Model
# Ann is at the hotel.
# Peter is still at the 3rd floor lobby.
# Ann
# ----->Predictions Original
# Thomas, Ann and Maria will have lunch together at the hotel.
# Ann is already in the 3rd floor lobby at the red table.
# **************************
# -------------------------
# ------>Predictions by Model
# Sus is sleepy and doesn't want to work.
# ----->Predictions Original
# Sus and Val don't want to work and are sleepy.
# **************************
# -------------------------
# ------>Predictions by Model
# Kate and Terry are at the Guggenheim right now.
# They want to go
# ----->Predictions Original
# Kate is at the Guggenheim Museum now, but will be in the Museum of the City of New York around 2-2:30.
# Kai may join her.
# Ish won't.
# Terry will join them for a coffee after they finish visiting the museum.
# Terry has already seen the museum.
# **************************
# -------------------------
# ------>Predictions by Model
# Cathy left her sunglasses at Brooke's house.
# She will come round at 10 tonight
# ----->Predictions Original
# Cathy left her sunglasses at Broke's house.
# She will come collect them at 10.
# **************************
# -------------------------
# ------>Predictions by Model
# Frederica will come to Bradley's birthday party tomorrow at 8 pm.
# ----->Predictions Original
# Bradley will come to Frederica's birthday party tomorrow at 8pm.
# **************************
# -------------------------
# ------>Predictions by Model
# Camilla received 250.
# Adrian will let her know when he has checked.
# ----->Predictions Original
# Camilla still hasn't received the 250.
# She will check and let Adrian know.
# Money usually takes around two days to arrive.
# **************************
# Saving model checkpoint to test-tokenbatch6/checkpoint-2500
# Configuration saved in test-tokenbatch6/checkpoint-2500/config.json
# Model weights saved in test-tokenbatch6/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-2500/special_tokens_map.json
# Saving model checkpoint to test-tokenbatch6/checkpoint-3000
# Configuration saved in test-tokenbatch6/checkpoint-3000/config.json
# Model weights saved in test-tokenbatch6/checkpoint-3000/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-3000/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-3000/special_tokens_map.json
# Saving model checkpoint to test-tokenbatch6/checkpoint-3500
# Configuration saved in test-tokenbatch6/checkpoint-3500/config.json
# Model weights saved in test-tokenbatch6/checkpoint-3500/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-3500/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-3500/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 818
#   Batch size = 6
# -------------------------
# ------>Predictions by Model
# A wants to get a puppy for her son.
# She will take him to the animal
# ----->Predictions Original
# A will go to the animal shelter tomorrow to get a puppy for her son.
# They already visited the shelter last Monday and the son chose the puppy.
# **************************
# -------------------------
# ------>Predictions by Model
# Emma wants an advent calendar for her kids.
# Rob used to get one every year
# ----->Predictions Original
# Emma and Rob love the advent calendar.
# Lauren fits inside calendar various items, for instance, small toys and Christmas decorations.
# Her children are excited whenever they get the calendar.
# **************************
# -------------------------
# ------>Predictions by Model
# Madison is pregnant.
# She doesn't want to talk about it because she's worried about
# ----->Predictions Original
# Madison is pregnant but she doesn't want to talk about it.
# Patricia Stevens got married and she thought she was pregnant.
# **************************
# -------------------------
# ------>Predictions by Model
# Marla found a pair of boxers under her bed.
# She thinks it was her
# ----->Predictions Original
# Marla found a pair of boxers under her bed.
# **************************
# -------------------------
# ------>Predictions by Model
# Robert has to buy guitar cable.
# Fred will give Robert the address of the music shop
# ----->Predictions Original
# Robert wants Fred to send him the address of the music shop as he needs to buy guitar cable.
# **************************
# -------------------------
# ------>Predictions by Model
# Keith will buy some milk and cereals for Meg.
# Megan checked in the drawer next
# ----->Predictions Original
# Megan needn't buy milk and cereals.
# They're in the drawer next to the fridge.
# **************************
# -------------------------
# ------>Predictions by Model
# Samantha, Evelyn and Holly are surprised by the noise.
# ----->Predictions Original
# Samantha and Evelyn after watching the video cannot believe she is able to make that noise.
# **************************
# -------------------------
# ------>Predictions by Model
# Marion and Luis are at Tom's new place.
# It's a bit outside the
# ----->Predictions Original
# Tom's new place is in Fiesole.
# Luis and Marion has been there.
# **************************
# -------------------------
# ------>Predictions by Model
# Vegano Resto will make a reservation for 6 people tonight around 20:00
# ----->Predictions Original
# Jane made a 9 PM reservation for 6 people tonight at Vegano Resto.
# **************************
# -------------------------
# ------>Predictions by Model
# Nancy has a Texan drawl and she's working in Cardiff.
# She's
# ----->Predictions Original
# Nancy's working in Texas, but the kids laugh at her Welsh accent.
# She's coming home in 6 weeks.
# Earlier than that she's going to travel with 3 other Brits.
# **************************
# -------------------------
# ------>Predictions by Model
# Laura needs a new printer.
# Jamie suggests she buy a second hand one.
# ----->Predictions Original
# Laura is going to buy a printer.
# **************************
# -------------------------
# ------>Predictions by Model
# Haylee is in dairy section.
# Barbara found coconut milk yoghurt next to eggs
# ----->Predictions Original
# Haylee can't find the coconut milk yoghurt.
# **************************
# -------------------------
# ------>Predictions by Model
# Norbert and Wendy need to hurry to catch the tour.
# Wendy is at the register
# ----->Predictions Original
# Wendy is shopping, but she needs to hurry up to catch the tour.
# **************************
# -------------------------
# ------>Predictions by Model
# Cheryl and Peter went to Fuerteventura Peninsula in the summer.
# ----->Predictions Original
# Cecil, Cheryl and Peter went to the Jandia Peninsula today.
# Cecil would like to explore the south of the island tomorrow, but they will decide what to do after dinner.
# **************************
# -------------------------
# ------>Predictions by Model
# Sophie hasn't found it yet.
# Nickola has checked pockets and handbags
# ----->Predictions Original
# Sophie still hasn't found it despite checking pockets and handbags twice.
# **************************
# -------------------------
# ------>Predictions by Model
# Rosie is looking for inspiration for her essay.
# Dennis recommends Troma Studio for her
# ----->Predictions Original
# Dennis and Elle are helping Rosie think of bad movies for her essay.
# **************************
# -------------------------
# ------>Predictions by Model
# James has a dream to become a voice actor.
# He wants to be a part of
# ----->Predictions Original
# James has a dream of becoming a voice actor.
# He considers making a home radio station.
# **************************
# -------------------------
# ------>Predictions by Model
# Poppy had a long day today.
# Alice didn't get lunch because she had err
# ----->Predictions Original
# Poppy and Alice are meeting for drinks after work at Nick's at 5:30.
# Alice fancies Fred, she will invite him and a bunch of other coworkers.
# **************************
# -------------------------
# ------>Predictions by Model
# Caron will be out from 12.
# Sash will open the door before Caron
# ----->Predictions Original
# Sash needs to see Caron who'll be out from 12.
# **************************
# -------------------------
# ------>Predictions by Model
# Matteo likes Gosia a lot.
# Giuseppe likes football and video games
# ----->Predictions Original
# Matteo is not sure about his relationship with Gosia but likes her a lot.
# **************************
# -------------------------
# ------>Predictions by Model
# Ramzi's mother is calling for supper.
# ----->Predictions Original
# Ramzi and Jannette are going for supper.
# **************************
# -------------------------
# ------>Predictions by Model
# Jeniffer, Alois and Hildegard are preparing ravioli.
# ----->Predictions Original
# Jeniffer is preparing ravioli following her grandmothers recipe.
# **************************
# -------------------------
# ------>Predictions by Model
# Lawrence is not done with the article yet.
# He will be in a few minutes
# ----->Predictions Original
# Lawrence will finish writing the article soon.
# **************************
# -------------------------
# ------>Predictions by Model
# Chad shares a funny photo with Brennen.
# ----->Predictions Original
# Chad has sent Brennen a funny photo.
# Brennen does not find it very funny.
# **************************
# -------------------------
# ------>Predictions by Model
# Sadie needs to borrow Chloe's bike on Thursday.
# Chloe will pick it up on
# ----->Predictions Original
# Sadie will borrow Chloe's bike on Wednesday evening.
# She has a dentist appointment on Thursday after work.
# **************************
# -------------------------
# ------>Predictions by Model
# Olivia wants to launch a new restaurant in the city centre next month.
# Carter
# ----->Predictions Original
# Carter is launching a restaurant business next month.
# Olivia wants him to include a restaurant she's working for in the discount app.
# They will meet in person to discuss it.
# **************************
# -------------------------
# ------>Predictions by Model
# Kenny is back from surgery.
# He has another surgery scheduled tomorrow.
# He might have
# ----->Predictions Original
# Kenny had a surgery, as Kristine reports.
# He will have another surgery tomorrow.
# Guy will come to St. Mark's Hospital near Asda to stay with Kristine.
# **************************
# -------------------------
# ------>Predictions by Model
# Joey and Olivia broke up after all these years.
# Olivia cheated on Joey with numerous
# ----->Predictions Original
# Skyler and Adam are surprised that Joey and Olivia broke up.
# **************************
# -------------------------
# ------>Predictions by Model
# Amanda is pregnant.
# She went to dancing classes with Michael yesterday.
# The instructor needed
# ----->Predictions Original
# Amanda goes to dancing classes with Michael.
# She volunteered to show the English Waltz steps with the instructor yesterday.
# Amanda is shy and goes to therapy.
# **************************
# -------------------------
# ------>Predictions by Model
# Taylor wants Isabel to bring her boyfriend to him.
# Isabel hasn't had any.
# ----->Predictions Original
# Taylor wants to meet Isabel's boyfriend but she has never had any.
# **************************
# -------------------------
# ------>Predictions by Model
# Theo is leaving on Friday.
# Toby will come back by train on Monday.
# Toby
# ----->Predictions Original
# Theo's going to stay near Torino in the region of Italian Alpes.
# Toby wants to join the trip.
# Theo agrees and will pick Toby up on Friday at 7 am.
# **************************
# -------------------------
# ------>Predictions by Model
# Brandon hasn't called to say he'd be late.
# ----->Predictions Original
# Brandon is late again.
# Clara will prepare a report on the absenteeism and lateness for Phil by Friday.
# **************************
# -------------------------
# ------>Predictions by Model
# Suzie is sick again.
# She cancelled last time because she was caughing.
# ----->Predictions Original
# Olga and Suzie will postpone their meeting due to Suzie's sickness.
# **************************
# -------------------------
# ------>Predictions by Model
# Diane wants Kate to be her kids' mother.
# Kate will be Lorelai
# ----->Predictions Original
# Diane is pregnant and can't wait to give birth, she thinks the waiting is the worst.
# Kate thinks she'll be an amazing mother.
# **************************
# -------------------------
# ------>Predictions by Model
# Andrew has a cold and feels awful.
# Daniel will drop by after work to get some
# ----->Predictions Original
# Andrew has a cold.
# Daniel will buy him some medication.
# **************************
# -------------------------
# ------>Predictions by Model
# Alex and Sam are watching 'Millionaires' on tv.
# ----->Predictions Original
# Alex and Sam are watching Millionaires.
# **************************
# -------------------------
# ------>Predictions by Model
# Jessica has the cinnamon cookies recipe.
# ----->Predictions Original
# Angelica sent the cinnamon cookies recipe at Kelly's request.
# **************************
# -------------------------
# ------>Predictions by Model
# Sophie is waiting for a client.
# Gwen and Dee will meet at the
# ----->Predictions Original
# Sophie is waiting for a client, who is late.
# She will meet Gwen later.
# **************************
# -------------------------
# ------>Predictions by Model
# Daniel is on his way downstairs.
# Sue is with the Volvo.
# ----->Predictions Original
# Daniel is with the Volvo on his way and will be there soon.
# Sue is going downstairs to meet him.
# **************************
# -------------------------
# ------>Predictions by Model
# Betty is going to CVS to buy some salmon and some shaving cream for George
# ----->Predictions Original
# George is making salmon and stuffed squash for dinner.
# Betty will buy a shaving cream at CVS at his request,
# **************************
# -------------------------
# ------>Predictions by Model
# Ken's phone doesn't work properly.
# Ken's friend had a similar issue.
# Ken
# ----->Predictions Original
# Ken has installed an app for running but it is not working properly on his phone.
# **************************
# -------------------------
# ------>Predictions by Model
# Ann couldn't come to Ivan's birthday party.
# Ivan bought her something for her birthday
# ----->Predictions Original
# Ivan and Ann will meet next week.
# **************************
# -------------------------
# ------>Predictions by Model
# Delilah and Rowan are going to check Ashley's fb page to see
# ----->Predictions Original
# Ashley posted some nude photos on her fb page.
# **************************
# -------------------------
# ------>Predictions by Model
# Mikolaj got his wife's papers with working permission.
# Magda's wife
# ----->Predictions Original
# Mikolaj's wife needs a work permit as a foreigner.
# Government officials missed the deadline for sending it and will need another month.
# **************************
# -------------------------
# ------>Predictions by Model
# Ann is at the hotel.
# There are some people hanging around at the lobby and the
# ----->Predictions Original
# Thomas, Ann and Maria will have lunch together at the hotel.
# Ann is already in the 3rd floor lobby at the red table.
# **************************
# -------------------------
# ------>Predictions by Model
# Sus is sleepy and doesn't want to work.
# ----->Predictions Original
# Sus and Val don't want to work and are sleepy.
# **************************
# -------------------------
# ------>Predictions by Model
# Kate and Terry are at the Guggenheim right now.
# They want to go
# ----->Predictions Original
# Kate is at the Guggenheim Museum now, but will be in the Museum of the City of New York around 2-2:30.
# Kai may join her.
# Ish won't.
# Terry will join them for a coffee after they finish visiting the museum.
# Terry has already seen the museum.
# **************************
# -------------------------
# ------>Predictions by Model
# Cathy left her sunglasses at Brooke's house.
# She will come round at 10 tonight
# ----->Predictions Original
# Cathy left her sunglasses at Broke's house.
# She will come collect them at 10.
# **************************
# -------------------------
# ------>Predictions by Model
# Frederica will come to Bradley's birthday party tomorrow at 8 pm.
# ----->Predictions Original
# Bradley will come to Frederica's birthday party tomorrow at 8pm.
# **************************
# -------------------------
# ------>Predictions by Model
# Camilla received 250.
# Adrian will let Camilla know when she has checked.
# ----->Predictions Original
# Camilla still hasn't received the 250.
# She will check and let Adrian know.
# Money usually takes around two days to arrive.
# **************************
# Saving model checkpoint to test-tokenbatch6/checkpoint-4000
# Configuration saved in test-tokenbatch6/checkpoint-4000/config.json
# Model weights saved in test-tokenbatch6/checkpoint-4000/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-4000/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-4000/special_tokens_map.json
# Saving model checkpoint to test-tokenbatch6/checkpoint-4500
# Configuration saved in test-tokenbatch6/checkpoint-4500/config.json
# Model weights saved in test-tokenbatch6/checkpoint-4500/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-4500/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-4500/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 818
#   Batch size = 6
# -------------------------
# ------>Predictions by Model
# A wants to get a puppy for her son.
# She took him to the animal shelter
# ----->Predictions Original
# A will go to the animal shelter tomorrow to get a puppy for her son.
# They already visited the shelter last Monday and the son chose the puppy.
# **************************
# -------------------------
# ------>Predictions by Model
# Emma wants an advent calendar for her kids.
# Rob used to get one every year
# ----->Predictions Original
# Emma and Rob love the advent calendar.
# Lauren fits inside calendar various items, for instance, small toys and Christmas decorations.
# Her children are excited whenever they get the calendar.
# **************************
# -------------------------
# ------>Predictions by Model
# Madison is pregnant.
# Madison doesn't want to talk about it because she's worried about
# ----->Predictions Original
# Madison is pregnant but she doesn't want to talk about it.
# Patricia Stevens got married and she thought she was pregnant.
# **************************
# -------------------------
# ------>Predictions by Model
# Marla found a pair of boxers under her bed.
# Her sister convinced someone to
# ----->Predictions Original
# Marla found a pair of boxers under her bed.
# **************************
# -------------------------
# ------>Predictions by Model
# Robert needs to buy guitar cable.
# Fred gives him the address of the music shop.
# ----->Predictions Original
# Robert wants Fred to send him the address of the music shop as he needs to buy guitar cable.
# **************************
# -------------------------
# ------>Predictions by Model
# Keith will buy some milk and cereals and Megan will check in the drawer next to
# ----->Predictions Original
# Megan needn't buy milk and cereals.
# They're in the drawer next to the fridge.
# **************************
# -------------------------
# ------>Predictions by Model
# Samantha and Evelyn are surprised by the noise.
# ...
# Kai may join her.
# Ish won't.
# Terry will join them for a coffee after they finish visiting the museum.
# Terry has already seen the museum.
# **************************
# -------------------------
# ------>Predictions by Model
# Cathy left her sunglasses at Brooke's house.
# She will come round at 10 tonight
# ----->Predictions Original
# Cathy left her sunglasses at Broke's house.
# She will come collect them at 10.
# **************************
# -------------------------
# ------>Predictions by Model
# Frederica will come to Bradley's birthday party tomorrow at 8 pm.
# ----->Predictions Original
# Bradley will come to Frederica's birthday party tomorrow at 8pm.
# **************************
# -------------------------
# ------>Predictions by Model
# Camilla received 250.
# Adrian will let Camilla know when she has received the money
# ----->Predictions Original
# Camilla still hasn't received the 250.
# She will check and let Adrian know.
# Money usually takes around two days to arrive.
# **************************
# Saving model checkpoint to test-tokenbatch6/checkpoint-5000
# Configuration saved in test-tokenbatch6/checkpoint-5000/config.json
# Model weights saved in test-tokenbatch6/checkpoint-5000/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-5000/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-5000/special_tokens_map.json
# Saving model checkpoint to test-tokenbatch6/checkpoint-5500
# Configuration saved in test-tokenbatch6/checkpoint-5500/config.json
# Model weights saved in test-tokenbatch6/checkpoint-5500/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-5500/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-5500/special_tokens_map.json
# Saving model checkpoint to test-tokenbatch6/checkpoint-6000
# Configuration saved in test-tokenbatch6/checkpoint-6000/config.json
# Model weights saved in test-tokenbatch6/checkpoint-6000/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-6000/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-6000/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 818
#   Batch size = 6
# -------------------------
# ------>Predictions by Model
# A wants to get a puppy for her son.
# She will take him to the animal
# ----->Predictions Original
# A will go to the animal shelter tomorrow to get a puppy for her son.
# They already visited the shelter last Monday and the son chose the puppy.
# **************************
# -------------------------
# ------>Predictions by Model
# Emma wants to buy an advent calendar for her kids.
# Rob used to get one
# ----->Predictions Original
# Emma and Rob love the advent calendar.
# Lauren fits inside calendar various items, for instance, small toys and Christmas decorations.
# Her children are excited whenever they get the calendar.
# **************************
# -------------------------
# ------>Predictions by Model
# Madison is pregnant.
# Madison doesn't want to talk about it because she's worried about
# ----->Predictions Original
# Madison is pregnant but she doesn't want to talk about it.
# Patricia Stevens got married and she thought she was pregnant.
# **************************
# -------------------------
# ------>Predictions by Model
# Marla found a pair of boxers under her bed.
# Her sister convinced someone to
# ----->Predictions Original
# Marla found a pair of boxers under her bed.
# **************************
# -------------------------
# ------>Predictions by Model
# Robert needs to buy guitar cable.
# Fred gives him the address of the music shop.
# ----->Predictions Original
# Robert wants Fred to send him the address of the music shop as he needs to buy guitar cable.
# **************************
# -------------------------
# ------>Predictions by Model
# Keith will buy some milk and cereals and Megan will check in the drawer next to
# ----->Predictions Original
# Megan needn't buy milk and cereals.
# They're in the drawer next to the fridge.
# **************************
# -------------------------
# ------>Predictions by Model
# Samantha and Evelyn are surprised by the noise.
# ----->Predictions Original
# Samantha and Evelyn after watching the video cannot believe she is able to make that noise.
# **************************
# -------------------------
# ------>Predictions by Model
# Theresa, Luis and Adam are at Tom's new place.
# It's a bit
# ----->Predictions Original
# Tom's new place is in Fiesole.
# Luis and Marion has been there.
# **************************
# -------------------------
# ------>Predictions by Model
# Vegano Resto will make a reservation for 6 people tonight at 20:00
# ----->Predictions Original
# Jane made a 9 PM reservation for 6 people tonight at Vegano Resto.
# **************************
# -------------------------
# ------>Predictions by Model
# Nancy has a Texan drawl and is working in a pub.
# She is
# ----->Predictions Original
# Nancy's working in Texas, but the kids laugh at her Welsh accent.
# She's coming home in 6 weeks.
# Earlier than that she's going to travel with 3 other Brits.
# **************************
# -------------------------
# ------>Predictions by Model
# Laura needs a new printer.
# Jamie will buy a second hand one.
# ----->Predictions Original
# Laura is going to buy a printer.
# **************************
# -------------------------
# ------>Predictions by Model
# Barbara is in the dairy section.
# Haylee wants coconut milk yoghurt.
# ----->Predictions Original
# Haylee can't find the coconut milk yoghurt.
# **************************
# -------------------------
# ------>Predictions by Model
# Norbert and Wendy need to hurry to catch the tour.
# Wendy is at the register
# ----->Predictions Original
# Wendy is shopping, but she needs to hurry up to catch the tour.
# **************************
# -------------------------
# ------>Predictions by Model
# Cheryl and Peter went to Fuerteventura Peninsula in the summer.
# ----->Predictions Original
# Cecil, Cheryl and Peter went to the Jandia Peninsula today.
# Cecil would like to explore the south of the island tomorrow, but they will decide what to do after dinner.
# **************************
# -------------------------
# ------>Predictions by Model
# Sophie hasn't found it yet.
# Nickola checked pockets and handbags twice
# ----->Predictions Original
# Sophie still hasn't found it despite checking pockets and handbags twice.
# **************************
# -------------------------
# ------>Predictions by Model
# Rosie has to write an essay about bad movies.
# She will cover "The Room
# ----->Predictions Original
# Dennis and Elle are helping Rosie think of bad movies for her essay.
# **************************
# -------------------------
# ------>Predictions by Model
# James has a dream to become a voice actor.
# He wants to be a part of
# ----->Predictions Original
# James has a dream of becoming a voice actor.
# He considers making a home radio station.
# **************************
# -------------------------
# ------>Predictions by Model
# Poppy and Alice are going for drinks after work.
# They will meet at Nick's
# ----->Predictions Original
# Poppy and Alice are meeting for drinks after work at Nick's at 5:30.
# Alice fancies Fred, she will invite him and a bunch of other coworkers.
# **************************
# -------------------------
# ------>Predictions by Model
# Sash will see Caron before 12.
# Caron will be out from 12.
# ----->Predictions Original
# Sash needs to see Caron who'll be out from 12.
# **************************
# -------------------------
# ------>Predictions by Model
# Matteo doesn't like Gosia because he likes football and video games.
# Gi
# ----->Predictions Original
# Matteo is not sure about his relationship with Gosia but likes her a lot.
# **************************
# -------------------------
# ------>Predictions by Model
# Jannette is coming for supper.
# ----->Predictions Original
# Ramzi and Jannette are going for supper.
# **************************
# -------------------------
# ------>Predictions by Model
# Jeniffer, Alois and Hildegard are preparing ravioli.
# ----->Predictions Original
# Jeniffer is preparing ravioli following her grandmothers recipe.
# **************************
# -------------------------
# ------>Predictions by Model
# Lawrence will be through with the article in a few minutes.
# The piece is needed
# ----->Predictions Original
# Lawrence will finish writing the article soon.
# **************************
# -------------------------
# ------>Predictions by Model
# Chad sent Brennen a funny photo.
# ----->Predictions Original
# Chad has sent Brennen a funny photo.
# Brennen does not find it very funny.
# **************************
# -------------------------
# ------>Predictions by Model
# Sadie needs to go to the dentist on Thursday.
# Chloe will pick it up on
# ----->Predictions Original
# Sadie will borrow Chloe's bike on Wednesday evening.
# She has a dentist appointment on Thursday after work.
# **************************
# -------------------------
# ------>Predictions by Model
# Olivia wants to launch a new restaurant in the city centre next month.
# Carter
# ----->Predictions Original
# Carter is launching a restaurant business next month.
# Olivia wants him to include a restaurant she's working for in the discount app.
# They will meet in person to discuss it.
# **************************
# -------------------------
# ------>Predictions by Model
# Kenny is back from surgery.
# He has another surgery scheduled tomorrow.
# He might have
# ----->Predictions Original
# Kenny had a surgery, as Kristine reports.
# He will have another surgery tomorrow.
# Guy will come to St. Mark's Hospital near Asda to stay with Kristine.
# **************************
# -------------------------
# ------>Predictions by Model
# Joey and Olivia broke up after all these years.
# Joey cheated on Olivia with numerous
# ----->Predictions Original
# Skyler and Adam are surprised that Joey and Olivia broke up.
# **************************
# -------------------------
# ------>Predictions by Model
# Amanda is pregnant.
# She went to dancing classes with Michael yesterday.
# The instructor needed
# ----->Predictions Original
# Amanda goes to dancing classes with Michael.
# She volunteered to show the English Waltz steps with the instructor yesterday.
# Amanda is shy and goes to therapy.
# **************************
# -------------------------
# ------>Predictions by Model
# Isabel hasn't introduced Taylor's boyfriend to her yet.
# Taylor is a cool mum
# ----->Predictions Original
# Taylor wants to meet Isabel's boyfriend but she has never had any.
# **************************
# -------------------------
# ------>Predictions by Model
# Theo is leaving on Friday.
# Toby will come back by train on Monday.
# Toby
# ----->Predictions Original
# Theo's going to stay near Torino in the region of Italian Alpes.
# Toby wants to join the trip.
# Theo agrees and will pick Toby up on Friday at 7 am.
# **************************
# -------------------------
# ------>Predictions by Model
# Brandon hasn't called to say he'd be late.
# Clara will prepare a report on
# ----->Predictions Original
# Brandon is late again.
# Clara will prepare a report on the absenteeism and lateness for Phil by Friday.
# **************************
# -------------------------
# ------>Predictions by Model
# Suzie is sick again.
# She will cancel the meeting with Olga.
# ----->Predictions Original
# Olga and Suzie will postpone their meeting due to Suzie's sickness.
# **************************
# -------------------------
# ------>Predictions by Model
# Diane wants Kate to be her kids' mother.
# Kate will be Lorelai
# ----->Predictions Original
# Diane is pregnant and can't wait to give birth, she thinks the waiting is the worst.
# Kate thinks she'll be an amazing mother.
# **************************
# -------------------------
# ------>Predictions by Model
# Andrew has a cold and feels awful.
# Daniel will pick up some stuff from the pharmacy
# ----->Predictions Original
# Andrew has a cold.
# Daniel will buy him some medication.
# **************************
# -------------------------
# ------>Predictions by Model
# Alex and Sam are watching 'Millionaires' on tv.
# ----->Predictions Original
# Alex and Sam are watching Millionaires.
# **************************
# -------------------------
# ------>Predictions by Model
# Jessica has the cinnamon cookies recipe.
# ----->Predictions Original
# Angelica sent the cinnamon cookies recipe at Kelly's request.
# **************************
# -------------------------
# ------>Predictions by Model
# Sophie is waiting for a client who is 40 minutes late.
# Gwen will
# ----->Predictions Original
# Sophie is waiting for a client, who is late.
# She will meet Gwen later.
# **************************
# -------------------------
# ------>Predictions by Model
# Daniel is on his way downstairs and will see Sue in a few minutes.
# ----->Predictions Original
# Daniel is with the Volvo on his way and will be there soon.
# Sue is going downstairs to meet him.
# **************************
# -------------------------
# ------>Predictions by Model
# Betty is going to CVS to buy some salmon and some shaving cream for George
# ----->Predictions Original
# George is making salmon and stuffed squash for dinner.
# Betty will buy a shaving cream at CVS at his request,
# **************************
# -------------------------
# ------>Predictions by Model
# Ken's phone doesn't work properly.
# He checked it for his results and it was
# ----->Predictions Original
# Ken has installed an app for running but it is not working properly on his phone.
# **************************
# -------------------------
# ------>Predictions by Model
# Ann couldn't come to Ivan's birthday party.
# Ivan bought her something for her birthday
# ----->Predictions Original
# Ivan and Ann will meet next week.
# **************************
# -------------------------
# ------>Predictions by Model
# Ashley posted nude pictures on her Facebook page.
# Rowan is going to check it
# ----->Predictions Original
# Ashley posted some nude photos on her fb page.
# **************************
# -------------------------
# ------>Predictions by Model
# Mikolaj got the working permission for his wife's papers.
# The government had
# ----->Predictions Original
# Mikolaj's wife needs a work permit as a foreigner.
# Government officials missed the deadline for sending it and will need another month.
# **************************
# -------------------------
# ------>Predictions by Model
# Maria is on her way to the hotel.
# Ann is at the 3rd floor lobby
# ----->Predictions Original
# Thomas, Ann and Maria will have lunch together at the hotel.
# Ann is already in the 3rd floor lobby at the red table.
# **************************
# -------------------------
# ------>Predictions by Model
# Sus and Val don't want to work.
# ----->Predictions Original
# Sus and Val don't want to work and are sleepy.
# **************************
# -------------------------
# ------>Predictions by Model
# Kate and Terry are at the Guggenheim right now.
# They want to go
# ----->Predictions Original
# Kate is at the Guggenheim Museum now, but will be in the Museum of the City of New York around 2-2:30.
# Kai may join her.
# Ish won't.
# Terry will join them for a coffee after they finish visiting the museum.
# Terry has already seen the museum.
# **************************
# -------------------------
# ------>Predictions by Model
# Cathy left her sunglasses at Brooke's house.
# She will come round at 10 tonight
# ----->Predictions Original
# Cathy left her sunglasses at Broke's house.
# She will come collect them at 10.
# **************************
# -------------------------
# ------>Predictions by Model
# Frederica will come to Bradley's birthday party tomorrow at 8 pm.
# ----->Predictions Original
# Bradley will come to Frederica's birthday party tomorrow at 8pm.
# **************************
# -------------------------
# ------>Predictions by Model
# Camilla received 250.
# She will let Adrian know when she has received the money.
# ----->Predictions Original
# Camilla still hasn't received the 250.
# She will check and let Adrian know.
# Money usually takes around two days to arrive.
# **************************
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=6135, training_loss=3.834668092642165, metrics={'train_runtime': 8826.7114, 'train_samples_per_second': 8.344, 'train_steps_per_second': 0.695, 'total_flos': 1.408779533371392e+16, 'train_loss': 3.834668092642165, 'epoch': 5.0})

# %%
trainer.train() #10 turn
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 14730
#   Num Epochs = 5
#   Instantaneous batch size per device = 6
#   Total train batch size (w. parallel, distributed & accumulation) = 12
#   Gradient Accumulation steps = 2
#   Total optimization steps = 6135
#   Number of trainable parameters = 139420416
# You're using a BartTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='6135' max='6135' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [6135/6135 2:17:53, Epoch 4/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>18.763200</td>
#       <td>20.683386</td>
#       <td>47.300700</td>
#       <td>23.917500</td>
#       <td>39.705700</td>
#       <td>43.396600</td>
#       <td>18.421800</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>20.253600</td>
#       <td>19.311647</td>
#       <td>47.868100</td>
#       <td>24.716200</td>
#       <td>40.309100</td>
#       <td>44.244100</td>
#       <td>18.191900</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>20.740500</td>
#       <td>19.342619</td>
#       <td>47.747200</td>
#       <td>24.873000</td>
#       <td>40.583100</td>
#       <td>44.043800</td>
#       <td>18.174800</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>16.413100</td>
#       <td>19.211998</td>
#       <td>48.163700</td>
#       <td>25.010700</td>
#       <td>40.603300</td>
#       <td>44.234900</td>
#       <td>18.355700</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>18.312100</td>
#       <td>19.103617</td>
#       <td>48.123600</td>
#       <td>24.787700</td>
#       <td>40.594300</td>
#       <td>44.315900</td>
#       <td>18.302000</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to test-tokenbatch6/checkpoint-500
# Configuration saved in test-tokenbatch6/checkpoint-500/config.json
# Model weights saved in test-tokenbatch6/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-500/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-500/special_tokens_map.json
# Saving model checkpoint to test-tokenbatch6/checkpoint-1000
# Configuration saved in test-tokenbatch6/checkpoint-1000/config.json
# Model weights saved in test-tokenbatch6/checkpoint-1000/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-1000/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 818
#   Batch size = 6
# -------------------------
# ------>Predictions by Model
# A wants to get a puppy for her son.
# She will take him to the animal
# ----->Predictions Original
# A will go to the animal shelter tomorrow to get a puppy for her son.
# They already visited the shelter last Monday and the son chose the puppy.
# **************************
# -------------------------
# ------>Predictions by Model
# Emma wants to buy an advent calendar for her kids.
# Rob used to get one
# ----->Predictions Original
# Emma and Rob love the advent calendar.
# Lauren fits inside calendar various items, for instance, small toys and Christmas decorations.
# Her children are excited whenever they get the calendar.
# **************************
# -------------------------
# ------>Predictions by Model
# Madison is pregnant but she doesn't want to talk about it.
# Iggy's friend
# ----->Predictions Original
# Madison is pregnant but she doesn't want to talk about it.
# Patricia Stevens got married and she thought she was pregnant.
# **************************
# -------------------------
# ------>Predictions by Model
# Marla found her underwear under Kiki's bed.
# ----->Predictions Original
# Marla found a pair of boxers under her bed.
# **************************
# -------------------------
# ------>Predictions by Model
# Robert needs to buy guitar cable.
# Fred gives him the address of the music shop.
# ----->Predictions Original
# Robert wants Fred to send him the address of the music shop as he needs to buy guitar cable.
# **************************
# -------------------------
# ------>Predictions by Model
# Keith will buy some milk and cereals.
# Megan will check in the drawer next to
# ----->Predictions Original
# Megan needn't buy milk and cereals.
# They're in the drawer next to the fridge.
# **************************
# -------------------------
# ------>Predictions by Model
# Samantha is surprised by the noise.
# ----->Predictions Original
# Samantha and Evelyn after watching the video cannot believe she is able to make that noise.
# **************************
# -------------------------
# ------>Predictions by Model
# Tom invited Theresa and Adam for dinner at Fiesole.
# ----->Predictions Original
# Tom's new place is in Fiesole.
# Luis and Marion has been there.
# **************************
# -------------------------
# ------>Predictions by Model
# Vegano Resto offers Jane a table for six at 18:30 or 21
# ----->Predictions Original
# Jane made a 9 PM reservation for 6 people tonight at Vegano Resto.
# **************************
# -------------------------
# ------>Predictions by Model
# Nancy is working in a Texan accent.
# She is coming home in 6 weeks
# ----->Predictions Original
# Nancy's working in Texas, but the kids laugh at her Welsh accent.
# She's coming home in 6 weeks.
# Earlier than that she's going to travel with 3 other Brits.
# **************************
# -------------------------
# ------>Predictions by Model
# Laura needs a new printer.
# Jamie suggests buying a second hand one.
# ----->Predictions Original
# Laura is going to buy a printer.
# **************************
# -------------------------
# ------>Predictions by Model
# Barbara will buy coconut milk for Haylee in the dairy section.
# ----->Predictions Original
# Haylee can't find the coconut milk yoghurt.
# **************************
# -------------------------
# ------>Predictions by Model
# Norbert and Wendy are going to catch the tour.
# Wendy is at the register now
# ----->Predictions Original
# Wendy is shopping, but she needs to hurry up to catch the tour.
# **************************
# -------------------------
# ------>Predictions by Model
# Cecil and Peter went to the Jandia Peninsula.
# Cecil wants to explore
# ----->Predictions Original
# Cecil, Cheryl and Peter went to the Jandia Peninsula today.
# Cecil would like to explore the south of the island tomorrow, but they will decide what to do after dinner.
# **************************
# -------------------------
# ------>Predictions by Model
# Sophie hasn't found it yet.
# Nickola checks pockets and handbags.
# ----->Predictions Original
# Sophie still hasn't found it despite checking pockets and handbags twice.
# **************************
# -------------------------
# ------>Predictions by Model
# Rosie has to write an essay about bad movies.
# She will cover "The Room
# ----->Predictions Original
# Dennis and Elle are helping Rosie think of bad movies for her essay.
# **************************
# -------------------------
# ------>Predictions by Model
# James has a dream to become a voice actor.
# He wants to be a part of
# ----->Predictions Original
# James has a dream of becoming a voice actor.
# He considers making a home radio station.
# **************************
# -------------------------
# ------>Predictions by Model
# Poppy and Alice are going for drinks after work.
# They will meet at Nick's
# ----->Predictions Original
# Poppy and Alice are meeting for drinks after work at Nick's at 5:30.
# Alice fancies Fred, she will invite him and a bunch of other coworkers.
# **************************
# -------------------------
# ------>Predictions by Model
# Sash wants to see Caron but Caron is out from 12.
# Sash
# ----->Predictions Original
# Sash needs to see Caron who'll be out from 12.
# **************************
# -------------------------
# ------>Predictions by Model
# Matteo doesn't like Gosia because she criticizes him for football and video
# ----->Predictions Original
# Matteo is not sure about his relationship with Gosia but likes her a lot.
# **************************
# -------------------------
# ------>Predictions by Model
# Ramzi's mother is calling for supper.
# Jannette is coming.
# ----->Predictions Original
# Ramzi and Jannette are going for supper.
# **************************
# -------------------------
# ------>Predictions by Model
# Jeniffer and her family are preparing ravioli.
# ----->Predictions Original
# Jeniffer is preparing ravioli following her grandmothers recipe.
# **************************
# -------------------------
# ------>Predictions by Model
# Lawrence will be in a few minutes to finish the article.
# ----->Predictions Original
# Lawrence will finish writing the article soon.
# **************************
# -------------------------
# ------>Predictions by Model
# Chad sent Brennen a funny photo.
# ----->Predictions Original
# Chad has sent Brennen a funny photo.
# Brennen does not find it very funny.
# **************************
# -------------------------
# ------>Predictions by Model
# Chloe will pick up Sadie's bike on Wednesday evening.
# ----->Predictions Original
# Sadie will borrow Chloe's bike on Wednesday evening.
# She has a dentist appointment on Thursday after work.
# **************************
# -------------------------
# ------>Predictions by Model
# Olivia wants to launch a new restaurant in the city centre next month.
# Carter
# ----->Predictions Original
# Carter is launching a restaurant business next month.
# Olivia wants him to include a restaurant she's working for in the discount app.
# They will meet in person to discuss it.
# **************************
# -------------------------
# ------>Predictions by Model
# Kenny has a surgery scheduled tomorrow.
# He might have to reschedule it depending
# ----->Predictions Original
# Kenny had a surgery, as Kristine reports.
# He will have another surgery tomorrow.
# Guy will come to St. Mark's Hospital near Asda to stay with Kristine.
# **************************
# -------------------------
# ------>Predictions by Model
# Joey cheated on Olivia with numerous girls and got some chick pregnant.
# Olivia and Joey
# ----->Predictions Original
# Skyler and Adam are surprised that Joey and Olivia broke up.
# **************************
# -------------------------
# ------>Predictions by Model
# Amanda went to dancing classes with Michael yesterday.
# The instructor needed a female partner to
# ----->Predictions Original
# Amanda goes to dancing classes with Michael.
# She volunteered to show the English Waltz steps with the instructor yesterday.
# Amanda is shy and goes to therapy.
# **************************
# -------------------------
# ------>Predictions by Model
# Taylor wants to know if Isabel has a boyfriend.
# Isabel hasn't.
# ----->Predictions Original
# Taylor wants to meet Isabel's boyfriend but she has never had any.
# **************************
# -------------------------
# ------>Predictions by Model
# Theo and Toby are leaving on Friday.
# Toby will come back by train on Monday
# ----->Predictions Original
# Theo's going to stay near Torino in the region of Italian Alpes.
# Toby wants to join the trip.
# Theo agrees and will pick Toby up on Friday at 7 am.
# **************************
# -------------------------
# ------>Predictions by Model
# Brandon hasn't called to say he'd be late.
# Clara will prepare a report on
# ----->Predictions Original
# Brandon is late again.
# Clara will prepare a report on the absenteeism and lateness for Phil by Friday.
# **************************
# -------------------------
# ------>Predictions by Model
# Suzie is sick again and wants Olga to cancel.
# ----->Predictions Original
# Olga and Suzie will postpone their meeting due to Suzie's sickness.
# **************************
# -------------------------
# ------>Predictions by Model
# Kate will be Lorelai's mother.
# ----->Predictions Original
# Diane is pregnant and can't wait to give birth, she thinks the waiting is the worst.
# Kate thinks she'll be an amazing mother.
# **************************
# -------------------------
# ------>Predictions by Model
# Andrew has a cold and he feels awful.
# Daniel will drop by after work to get
# ----->Predictions Original
# Andrew has a cold.
# Daniel will buy him some medication.
# **************************
# -------------------------
# ------>Predictions by Model
# Alex and Sam are watching 'Millionaires' on tv.
# Sam has a chance
# ----->Predictions Original
# Alex and Sam are watching Millionaires.
# **************************
# -------------------------
# ------>Predictions by Model
# Jessica has the cinnamon cookies recipe.
# ----->Predictions Original
# Angelica sent the cinnamon cookies recipe at Kelly's request.
# **************************
# -------------------------
# ------>Predictions by Model
# Gwen and Sophie are going to meet at the restaurant in 5 minutes.
# Dee is
# ----->Predictions Original
# Sophie is waiting for a client, who is late.
# She will meet Gwen later.
# **************************
# -------------------------
# ------>Predictions by Model
# Daniel is on his way to meet Sue in a few minutes.
# ----->Predictions Original
# Daniel is with the Volvo on his way and will be there soon.
# Sue is going downstairs to meet him.
# **************************
# -------------------------
# ------>Predictions by Model
# Betty is going to CVS to buy salmon and some shaving cream.
# George will
# ----->Predictions Original
# George is making salmon and stuffed squash for dinner.
# Betty will buy a shaving cream at CVS at his request,
# **************************
# -------------------------
# ------>Predictions by Model
# Ken's phone doesn't work properly.
# He checked it for his results and it was
# ----->Predictions Original
# Ken has installed an app for running but it is not working properly on his phone.
# **************************
# -------------------------
# ------>Predictions by Model
# Ann couldn't come to Ivan's birthday party.
# Ivan bought her something for her birthday
# ----->Predictions Original
# Ivan and Ann will meet next week.
# **************************
# -------------------------
# ------>Predictions by Model
# Ashley posted nude pictures on Facebook.
# Rowan has some important work to do.
# ----->Predictions Original
# Ashley posted some nude photos on her fb page.
# **************************
# -------------------------
# ------>Predictions by Model
# Mikolaj has a breakthrough with his wife's papers.
# Magda got the
# ----->Predictions Original
# Mikolaj's wife needs a work permit as a foreigner.
# Government officials missed the deadline for sending it and will need another month.
# **************************
# -------------------------
# ------>Predictions by Model
# Maria and Ann are on their way to the hotel.
# Peter is still at the hotel
# ----->Predictions Original
# Thomas, Ann and Maria will have lunch together at the hotel.
# Ann is already in the 3rd floor lobby at the red table.
# **************************
# -------------------------
# ------>Predictions by Model
# Sus is sleepy and doesn't want to work.
# ----->Predictions Original
# Sus and Val don't want to work and are sleepy.
# **************************
# -------------------------
# ------>Predictions by Model
# Kate and Terry are going to the Guggenheim and Museum of the city of
# ----->Predictions Original
# Kate is at the Guggenheim Museum now, but will be in the Museum of the City of New York around 2-2:30.
# Kai may join her.
# Ish won't.
# Terry will join them for a coffee after they finish visiting the museum.
# Terry has already seen the museum.
# **************************
# -------------------------
# ------>Predictions by Model
# Cathy left her sunglasses at Brooke's house.
# She will come round at 10 tonight
# ----->Predictions Original
# Cathy left her sunglasses at Broke's house.
# She will come collect them at 10.
# **************************
# -------------------------
# ------>Predictions by Model
# Bradley will come to Fred's birthday party tomorrow at 8 pm.
# ----->Predictions Original
# Bradley will come to Frederica's birthday party tomorrow at 8pm.
# **************************
# -------------------------
# ------>Predictions by Model
# Camilla received 250 from Adrian.
# Camilla needs to check if she received the money
# ----->Predictions Original
# Camilla still hasn't received the 250.
# She will check and let Adrian know.
# Money usually takes around two days to arrive.
# **************************
# Saving model checkpoint to test-tokenbatch6/checkpoint-1500
# Configuration saved in test-tokenbatch6/checkpoint-1500/config.json
# Model weights saved in test-tokenbatch6/checkpoint-1500/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-1500/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-1500/special_tokens_map.json
# Saving model checkpoint to test-tokenbatch6/checkpoint-2000
# Configuration saved in test-tokenbatch6/checkpoint-2000/config.json
# Model weights saved in test-tokenbatch6/checkpoint-2000/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-2000/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 818
#   Batch size = 6
# -------------------------
# ------>Predictions by Model
# A will go to the animal shelter tomorrow afternoon to get a puppy for her son.
# ----->Predictions Original
# A will go to the animal shelter tomorrow to get a puppy for her son.
# They already visited the shelter last Monday and the son chose the puppy.
# **************************
# -------------------------
# ------>Predictions by Model
# Emma is looking for an advent calendar for her children.
# Rob used to get one
# ----->Predictions Original
# Emma and Rob love the advent calendar.
# Lauren fits inside calendar various items, for instance, small toys and Christmas decorations.
# Her children are excited whenever they get the calendar.
# **************************
# -------------------------
# ------>Predictions by Model
# Madison is pregnant but she doesn't want to talk about it.
# Iggy's friend
# ----->Predictions Original
# Madison is pregnant but she doesn't want to talk about it.
# Patricia Stevens got married and she thought she was pregnant.
# **************************
# -------------------------
# ------>Predictions by Model
# Marla found underwear under her bed.
# She thinks it's male underwear.
# Kiki
# ----->Predictions Original
# Marla found a pair of boxers under her bed.
# **************************
# -------------------------
# ------>Predictions by Model
# Robert has to buy a guitar cable.
# Fred gives him the address of the music shop
# ----->Predictions Original
# Robert wants Fred to send him the address of the music shop as he needs to buy guitar cable.
# **************************
# -------------------------
# ------>Predictions by Model
# Keith will buy some milk and cereals.
# Megan will check in the drawer next to
# ----->Predictions Original
# Megan needn't buy milk and cereals.
# They're in the drawer next to the fridge.
# **************************
# -------------------------
# ------>Predictions by Model
# Samantha sends a video of herself making a noise.
# ----->Predictions Original
# Samantha and Evelyn after watching the video cannot believe she is able to make that noise.
# **************************
# -------------------------
# ------>Predictions by Model
# Tom invited Theresa and Adam for dinner at Fiesole.
# ----->Predictions Original
# Tom's new place is in Fiesole.
# Luis and Marion has been there.
# **************************
# -------------------------
# ------>Predictions by Model
# Vegano Resto will make a reservation for 6 people at 21:00.
# ----->Predictions Original
# Jane made a 9 PM reservation for 6 people tonight at Vegano Resto.
# **************************
# -------------------------
# ------>Predictions by Model
# Nancy is coming home in 6 weeks.
# She is travelling with 3 other Brits
# ----->Predictions Original
# Nancy's working in Texas, but the kids laugh at her Welsh accent.
# She's coming home in 6 weeks.
# Earlier than that she's going to travel with 3 other Brits.
# **************************
# -------------------------
# ------>Predictions by Model
# Laura needs a new printer.
# Jamie suggests she can buy a second hand one.
# ----->Predictions Original
# Laura is going to buy a printer.
# **************************
# -------------------------
# ------>Predictions by Model
# Barbara is in the dairy section.
# She will buy coconut milk for Haylee.
# ----->Predictions Original
# Haylee can't find the coconut milk yoghurt.
# **************************
# -------------------------
# ------>Predictions by Model
# Norbert is waiting for Wendy at the register now.
# ----->Predictions Original
# Wendy is shopping, but she needs to hurry up to catch the tour.
# **************************
# -------------------------
# ------>Predictions by Model
# Cecil and Peter went to Fuerteventura, the south of the
# ----->Predictions Original
# Cecil, Cheryl and Peter went to the Jandia Peninsula today.
# Cecil would like to explore the south of the island tomorrow, but they will decide what to do after dinner.
# **************************
# -------------------------
# ------>Predictions by Model
# Sophie hasn't found it yet.
# Nickola suggests checking pockets and handbags
# ----->Predictions Original
# Sophie still hasn't found it despite checking pockets and handbags twice.
# **************************
# -------------------------
# ------>Predictions by Model
# Rosie has to write an essay about bad movies.
# She will cover "The Room
# ----->Predictions Original
# Dennis and Elle are helping Rosie think of bad movies for her essay.
# **************************
# -------------------------
# ------>Predictions by Model
# James has a dream to become a voice actor.
# He has worked in radio during college
# ----->Predictions Original
# James has a dream of becoming a voice actor.
# He considers making a home radio station.
# **************************
# -------------------------
# ------>Predictions by Model
# Poppy and Alice are going for drinks after work.
# They will meet at Nick's
# ----->Predictions Original
# Poppy and Alice are meeting for drinks after work at Nick's at 5:30.
# Alice fancies Fred, she will invite him and a bunch of other coworkers.
# **************************
# -------------------------
# ------>Predictions by Model
# Caron is out from 12.
# Sash will be there before 12.
# Caron
# ----->Predictions Original
# Sash needs to see Caron who'll be out from 12.
# **************************
# -------------------------
# ------>Predictions by Model
# Matteo doesn't like Gosia because of football and video games.
# Giuse
# ----->Predictions Original
# Matteo is not sure about his relationship with Gosia but likes her a lot.
# **************************
# -------------------------
# ------>Predictions by Model
# Ramzi's mother is calling for supper.
# ----->Predictions Original
# Ramzi and Jannette are going for supper.
# **************************
# -------------------------
# ------>Predictions by Model
# Jeniffer got the recipe from her grandmother.
# ----->Predictions Original
# Jeniffer is preparing ravioli following her grandmothers recipe.
# **************************
# -------------------------
# ------>Predictions by Model
# Lawrence hasn't finished with the article yet.
# The piece is needed by today.
# ----->Predictions Original
# Lawrence will finish writing the article soon.
# **************************
# -------------------------
# ------>Predictions by Model
# Brennen doesn't like Chad's joke.
# ----->Predictions Original
# Chad has sent Brennen a funny photo.
# Brennen does not find it very funny.
# **************************
# -------------------------
# ------>Predictions by Model
# Chloe will pick up Sadie's bike on Wednesday evening.
# ----->Predictions Original
# Sadie will borrow Chloe's bike on Wednesday evening.
# She has a dentist appointment on Thursday after work.
# **************************
# -------------------------
# ------>Predictions by Model
# Olivia wants to launch a new restaurant in the city centre next month.
# Carter
# ----->Predictions Original
# Carter is launching a restaurant business next month.
# Olivia wants him to include a restaurant she's working for in the discount app.
# They will meet in person to discuss it.
# **************************
# -------------------------
# ------>Predictions by Model
# Kristine is scared she will lose Kenny.
# She is at St Marks Hospital near As
# ----->Predictions Original
# Kenny had a surgery, as Kristine reports.
# He will have another surgery tomorrow.
# Guy will come to St. Mark's Hospital near Asda to stay with Kristine.
# **************************
# -------------------------
# ------>Predictions by Model
# Joey cheated on Olivia with numerous girls and got some chick pregnant.
# Olivia is devastated
# ----->Predictions Original
# Skyler and Adam are surprised that Joey and Olivia broke up.
# **************************
# -------------------------
# ------>Predictions by Model
# Amanda is pregnant.
# She went to dancing classes with Michael yesterday.
# The instructor needed
# ----->Predictions Original
# Amanda goes to dancing classes with Michael.
# She volunteered to show the English Waltz steps with the instructor yesterday.
# Amanda is shy and goes to therapy.
# **************************
# -------------------------
# ------>Predictions by Model
# Taylor wants Isabel to introduce her boyfriend to him.
# Isabel hasn't had any.
# ----->Predictions Original
# Taylor wants to meet Isabel's boyfriend but she has never had any.
# **************************
# -------------------------
# ------>Predictions by Model
# Theo is leaving on Friday.
# He will come back by train on Monday.
# Toby
# ----->Predictions Original
# Theo's going to stay near Torino in the region of Italian Alpes.
# Toby wants to join the trip.
# Theo agrees and will pick Toby up on Friday at 7 am.
# **************************
# -------------------------
# ------>Predictions by Model
# Brandon hasn't arrived yet.
# Phil will prepare a report on the absenteeism and lat
# ----->Predictions Original
# Brandon is late again.
# Clara will prepare a report on the absenteeism and lateness for Phil by Friday.
# **************************
# -------------------------
# ------>Predictions by Model
# Suzie is sick again and wants Olga to cancel.
# ----->Predictions Original
# Olga and Suzie will postpone their meeting due to Suzie's sickness.
# **************************
# -------------------------
# ------>Predictions by Model
# Diane wants Kate to be her kids' mother.
# Kate will be Lorelai
# ----->Predictions Original
# Diane is pregnant and can't wait to give birth, she thinks the waiting is the worst.
# Kate thinks she'll be an amazing mother.
# **************************
# -------------------------
# ------>Predictions by Model
# Andrew has a cold.
# He's not sure if it's a flu or a cold
# ----->Predictions Original
# Andrew has a cold.
# Daniel will buy him some medication.
# **************************
# -------------------------
# ------>Predictions by Model
# Alex and Sam are watching 'Millionaires' on tv.
# Sam has a chance
# ----->Predictions Original
# Alex and Sam are watching Millionaires.
# **************************
# -------------------------
# ------>Predictions by Model
# Jessica has the cinnamon cookies recipe.
# ----->Predictions Original
# Angelica sent the cinnamon cookies recipe at Kelly's request.
# **************************
# -------------------------
# ------>Predictions by Model
# Sophie is waiting for a client.
# She will meet at the restaurant in 5
# ----->Predictions Original
# Sophie is waiting for a client, who is late.
# She will meet Gwen later.
# **************************
# -------------------------
# ------>Predictions by Model
# Daniel is on his way.
# He will meet Sue downstairs in a few minutes.
# ----->Predictions Original
# Daniel is with the Volvo on his way and will be there soon.
# Sue is going downstairs to meet him.
# **************************
# -------------------------
# ------>Predictions by Model
# Betty is going to CVS to buy some salmon and some shaving cream for George
# ----->Predictions Original
# George is making salmon and stuffed squash for dinner.
# Betty will buy a shaving cream at CVS at his request,
# **************************
# -------------------------
# ------>Predictions by Model
# Ken doesn't use endomondo because it doesn't work properly.
# He checked his
# ----->Predictions Original
# Ken has installed an app for running but it is not working properly on his phone.
# **************************
# -------------------------
# ------>Predictions by Model
# Ann couldn't come to Ivan's birthday party.
# Ivan bought her something for her birthday
# ----->Predictions Original
# Ivan and Ann will meet next week.
# **************************
# -------------------------
# ------>Predictions by Model
# Ashley posted nude pictures on Facebook.
# Rowan has some important work to do.
# ----->Predictions Original
# Ashley posted some nude photos on her fb page.
# **************************
# -------------------------
# ------>Predictions by Model
# Mikolaj has a breakthrough with his wife's papers since she's foreigner.
# ----->Predictions Original
# Mikolaj's wife needs a work permit as a foreigner.
# Government officials missed the deadline for sending it and will need another month.
# **************************
# -------------------------
# ------>Predictions by Model
# Ann is at the 3rd floor lobby.
# Peter is still there.
# Maria and Ann
# ----->Predictions Original
# Thomas, Ann and Maria will have lunch together at the hotel.
# Ann is already in the 3rd floor lobby at the red table.
# **************************
# -------------------------
# ------>Predictions by Model
# Sus and Val don't want to work.
# ----->Predictions Original
# Sus and Val don't want to work and are sleepy.
# **************************
# -------------------------
# ------>Predictions by Model
# Kate is at the Guggenheim right now.
# She wants to go to the
# ----->Predictions Original
# Kate is at the Guggenheim Museum now, but will be in the Museum of the City of New York around 2-2:30.
# Kai may join her.
# Ish won't.
# Terry will join them for a coffee after they finish visiting the museum.
# Terry has already seen the museum.
# **************************
# -------------------------
# ------>Predictions by Model
# Cathy left her sunglasses at Brooke's house.
# She will come round at 10 tonight
# ----->Predictions Original
# Cathy left her sunglasses at Broke's house.
# She will come collect them at 10.
# **************************
# -------------------------
# ------>Predictions by Model
# Frederica will come to Bradley's birthday party tomorrow at 8 pm.
# ----->Predictions Original
# Bradley will come to Frederica's birthday party tomorrow at 8pm.
# **************************
# -------------------------
# ------>Predictions by Model
# Camilla received 250 from Adrian.
# Camilla will check if she received the money.
# ----->Predictions Original
# Camilla still hasn't received the 250.
# She will check and let Adrian know.
# Money usually takes around two days to arrive.
# **************************
# Saving model checkpoint to test-tokenbatch6/checkpoint-2500
# Configuration saved in test-tokenbatch6/checkpoint-2500/config.json
# Model weights saved in test-tokenbatch6/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-2500/special_tokens_map.json
# Saving model checkpoint to test-tokenbatch6/checkpoint-3000
# Configuration saved in test-tokenbatch6/checkpoint-3000/config.json
# Model weights saved in test-tokenbatch6/checkpoint-3000/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-3000/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-3000/special_tokens_map.json
# Saving model checkpoint to test-tokenbatch6/checkpoint-3500
# Configuration saved in test-tokenbatch6/checkpoint-3500/config.json
# Model weights saved in test-tokenbatch6/checkpoint-3500/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-3500/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-3500/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 818
#   Batch size = 6
# -------------------------
# ------>Predictions by Model
# A is going to the animal shelter tomorrow afternoon.
# She wants to get a puppy for
# ----->Predictions Original
# A will go to the animal shelter tomorrow to get a puppy for her son.
# They already visited the shelter last Monday and the son chose the puppy.
# **************************
# -------------------------
# ------>Predictions by Model
# Emma is looking for an advent calendar for her children.
# Rob used to get one
# ----->Predictions Original
# Emma and Rob love the advent calendar.
# Lauren fits inside calendar various items, for instance, small toys and Christmas decorations.
# Her children are excited whenever they get the calendar.
# **************************
# -------------------------
# ------>Predictions by Model
# Madison is pregnant but she doesn't want to talk about it.
# ----->Predictions Original
# Madison is pregnant but she doesn't want to talk about it.
# Patricia Stevens got married and she thought she was pregnant.
# **************************
# -------------------------
# ------>Predictions by Model
# Marla found some pink underwear under her bed.
# Kiki and Tamara are investigating
# ----->Predictions Original
# Marla found a pair of boxers under her bed.
# **************************
# -------------------------
# ------>Predictions by Model
# Robert needs to buy guitar cable.
# Fred gives him the address of the music shop.
# ----->Predictions Original
# Robert wants Fred to send him the address of the music shop as he needs to buy guitar cable.
# **************************
# -------------------------
# ------>Predictions by Model
# Keith will buy some milk and cereals.
# Megan checked in the drawer next to the
# ----->Predictions Original
# Megan needn't buy milk and cereals.
# They're in the drawer next to the fridge.
# **************************
# -------------------------
# ------>Predictions by Model
# Samantha sends a video to Evelyn and Holly.
# ----->Predictions Original
# Samantha and Evelyn after watching the video cannot believe she is able to make that noise.
# **************************
# -------------------------
# ------>Predictions by Model
# Tom invited Theresa and Adam for dinner at Fiesole.
# ----->Predictions Original
# Tom's new place is in Fiesole.
# Luis and Marion has been there.
# **************************
# -------------------------
# ------>Predictions by Model
# Vegano Resto will make a reservation for 6 people tonight at 21:00
# ----->Predictions Original
# Jane made a 9 PM reservation for 6 people tonight at Vegano Resto.
# **************************
# -------------------------
# ------>Predictions by Model
# Nancy is in Texan drawl.
# She has 21 years of experience in Cardiff
# ----->Predictions Original
# Nancy's working in Texas, but the kids laugh at her Welsh accent.
# She's coming home in 6 weeks.
# Earlier than that she's going to travel with 3 other Brits.
# **************************
# -------------------------
# ------>Predictions by Model
# Laura needs a new printer.
# Jamie suggests she can buy a second hand printer.
# ----->Predictions Original
# Laura is going to buy a printer.
# **************************
# -------------------------
# ------>Predictions by Model
# Barbara will buy coconut milk for Haylee.
# ----->Predictions Original
# Haylee can't find the coconut milk yoghurt.
# **************************
# -------------------------
# ------>Predictions by Model
# Wendy will buy something for the tour at the register now.
# ----->Predictions Original
# Wendy is shopping, but she needs to hurry up to catch the tour.
# **************************
# -------------------------
# ------>Predictions by Model
# Cecil is driving to the Jandia Peninsula.
# Cheryl liked it a lot
# ----->Predictions Original
# Cecil, Cheryl and Peter went to the Jandia Peninsula today.
# Cecil would like to explore the south of the island tomorrow, but they will decide what to do after dinner.
# **************************
# -------------------------
# ------>Predictions by Model
# Sophie hasn't found it yet.
# Nickola advises Sophie to check pockets and
# ----->Predictions Original
# Sophie still hasn't found it despite checking pockets and handbags twice.
# **************************
# -------------------------
# ------>Predictions by Model
# Rosie has to write an essay on bad movies.
# She will cover "The Room
# ----->Predictions Original
# Dennis and Elle are helping Rosie think of bad movies for her essay.
# **************************
# -------------------------
# ------>Predictions by Model
# James has a dream to become a voice actor.
# He wants to be a part of
# ----->Predictions Original
# James has a dream of becoming a voice actor.
# He considers making a home radio station.
# **************************
# -------------------------
# ------>Predictions by Model
# Poppy and Alice are going for drinks after work.
# They will meet at Nick's
# ----->Predictions Original
# Poppy and Alice are meeting for drinks after work at Nick's at 5:30.
# Alice fancies Fred, she will invite him and a bunch of other coworkers.
# **************************
# -------------------------
# ------>Predictions by Model
# Caron is out from 12.
# Sash will be there before 12.
# Caron
# ----->Predictions Original
# Sash needs to see Caron who'll be out from 12.
# **************************
# -------------------------
# ------>Predictions by Model
# Matteo dislikes Gosia because she criticizes him for playing football and video
# ----->Predictions Original
# Matteo is not sure about his relationship with Gosia but likes her a lot.
# **************************
# -------------------------
# ------>Predictions by Model
# Ramzi's mom is calling for supper.
# ----->Predictions Original
# Ramzi and Jannette are going for supper.
# **************************
# -------------------------
# ------>Predictions by Model
# Jeniffer is preparing ravioli with the recipe from her grandmother.
# ----->Predictions Original
# Jeniffer is preparing ravioli following her grandmothers recipe.
# **************************
# -------------------------
# ------>Predictions by Model
# Lawrence will finish the article in a few minutes.
# The piece is needed by today
# ----->Predictions Original
# Lawrence will finish writing the article soon.
# **************************
# -------------------------
# ------>Predictions by Model
# Chad sends Brennen a funny photo.
# ----->Predictions Original
# Chad has sent Brennen a funny photo.
# Brennen does not find it very funny.
# **************************
# -------------------------
# ------>Predictions by Model
# Chloe will pick up Sadie's bike on Wednesday evening.
# ----->Predictions Original
# Sadie will borrow Chloe's bike on Wednesday evening.
# She has a dentist appointment on Thursday after work.
# **************************
# -------------------------
# ------>Predictions by Model
# Olivia is currently involved with a new restaurant in the city centre.
# Carter and
# ----->Predictions Original
# Carter is launching a restaurant business next month.
# Olivia wants him to include a restaurant she's working for in the discount app.
# They will meet in person to discuss it.
# **************************
# -------------------------
# ------>Predictions by Model
# Kristine is worried about Kenny's health.
# He has another surgery scheduled tomorrow.
# She
# ----->Predictions Original
# Kenny had a surgery, as Kristine reports.
# He will have another surgery tomorrow.
# Guy will come to St. Mark's Hospital near Asda to stay with Kristine.
# **************************
# -------------------------
# ------>Predictions by Model
# Joey cheated on Olivia with numerous girls and got some chick pregnant.
# Olivia and Joey
# ----->Predictions Original
# Skyler and Adam are surprised that Joey and Olivia broke up.
# **************************
# -------------------------
# ------>Predictions by Model
# Amanda went to dancing classes with Michael yesterday and the instructor needed a female partner.
# ----->Predictions Original
# Amanda goes to dancing classes with Michael.
# She volunteered to show the English Waltz steps with the instructor yesterday.
# Amanda is shy and goes to therapy.
# **************************
# -------------------------
# ------>Predictions by Model
# Taylor wants Isabel to introduce her boyfriend to her.
# Isabel hasn't had any.
# ----->Predictions Original
# Taylor wants to meet Isabel's boyfriend but she has never had any.
# **************************
# -------------------------
# ------>Predictions by Model
# Theo and Toby are leaving on Friday.
# Toby will come back by train on Monday
# ----->Predictions Original
# Theo's going to stay near Torino in the region of Italian Alpes.
# Toby wants to join the trip.
# Theo agrees and will pick Toby up on Friday at 7 am.
# **************************
# -------------------------
# ------>Predictions by Model
# Brandon hasn't called to say he'd be late.
# Clara will prepare a report on
# ----->Predictions Original
# Brandon is late again.
# Clara will prepare a report on the absenteeism and lateness for Phil by Friday.
# **************************
# -------------------------
# ------>Predictions by Model
# Suzie is sick again and she wants Olga to cancel.
# ----->Predictions Original
# Olga and Suzie will postpone their meeting due to Suzie's sickness.
# **************************
# -------------------------
# ------>Predictions by Model
# Diane wants Kate to be her kids' mother.
# ----->Predictions Original
# Diane is pregnant and can't wait to give birth, she thinks the waiting is the worst.
# Kate thinks she'll be an amazing mother.
# **************************
# -------------------------
# ------>Predictions by Model
# Andrew had to call in sick because he has a cold.
# Daniel will drop by after
# ----->Predictions Original
# Andrew has a cold.
# Daniel will buy him some medication.
# **************************
# -------------------------
# ------>Predictions by Model
# Alex and Sam are watching 'Millionaires' on tv.
# Sam has a chance
# ----->Predictions Original
# Alex and Sam are watching Millionaires.
# **************************
# -------------------------
# ------>Predictions by Model
# Jessica has the cinnamon cookies recipe.
# Angelica sends Kelly the recipe.
# ----->Predictions Original
# Angelica sent the cinnamon cookies recipe at Kelly's request.
# **************************
# -------------------------
# ------>Predictions by Model
# Sophie is waiting for a client.
# Gwen and Dee will meet at the
# ----->Predictions Original
# Sophie is waiting for a client, who is late.
# She will meet Gwen later.
# **************************
# -------------------------
# ------>Predictions by Model
# Daniel is on his way downstairs.
# Sue will join him in a few minutes.
# ----->Predictions Original
# Daniel is with the Volvo on his way and will be there soon.
# Sue is going downstairs to meet him.
# **************************
# -------------------------
# ------>Predictions by Model
# George is going to CVS to buy some shaving cream for Betty.
# ----->Predictions Original
# George is making salmon and stuffed squash for dinner.
# Betty will buy a shaving cream at CVS at his request,
# **************************
# -------------------------
# ------>Predictions by Model
# Ken's phone doesn't work properly.
# He checked it for his results and it was
# ----->Predictions Original
# Ken has installed an app for running but it is not working properly on his phone.
# **************************
# -------------------------
# ------>Predictions by Model
# Ann couldn't come to Ivan's birthday party.
# Ivan bought her something for her birthday
# ----->Predictions Original
# Ivan and Ann will meet next week.
# **************************
# -------------------------
# ------>Predictions by Model
# Ashley posted nude pictures on Facebook.
# Rowan has some important stuff to do.
# ----->Predictions Original
# Ashley posted some nude photos on her fb page.
# **************************
# -------------------------
# ------>Predictions by Model
# Mikolaj has a breakthrough with his wife's papers since she's foreigner.
# ----->Predictions Original
# Mikolaj's wife needs a work permit as a foreigner.
# Government officials missed the deadline for sending it and will need another month.
# **************************
# -------------------------
# ------>Predictions by Model
# Ann is at the 3rd floor lobby.
# Peter is still there.
# Ann and Thomas
# ----->Predictions Original
# Thomas, Ann and Maria will have lunch together at the hotel.
# Ann is already in the 3rd floor lobby at the red table.
# **************************
# -------------------------
# ------>Predictions by Model
# Sus and Val don't want to work.
# ----->Predictions Original
# Sus and Val don't want to work and are sleepy.
# **************************
# -------------------------
# ------>Predictions by Model
# Kate, Kai and Terry are going to the Museum of the City of NY around 2
# ----->Predictions Original
# Kate is at the Guggenheim Museum now, but will be in the Museum of the City of New York around 2-2:30.
# Kai may join her.
# Ish won't.
# Terry will join them for a coffee after they finish visiting the museum.
# Terry has already seen the museum.
# **************************
# -------------------------
# ------>Predictions by Model
# Cathy left her sunglasses at Brooke's house.
# She will come round at 10 tonight
# ----->Predictions Original
# Cathy left her sunglasses at Broke's house.
# She will come collect them at 10.
# **************************
# -------------------------
# ------>Predictions by Model
# Frederica will come to Bradley's birthday party tomorrow at 8 pm.
# ----->Predictions Original
# Bradley will come to Frederica's birthday party tomorrow at 8pm.
# **************************
# -------------------------
# ------>Predictions by Model
# Camilla received 250 from Adrian.
# ----->Predictions Original
# Camilla still hasn't received the 250.
# She will check and let Adrian know.
# Money usually takes around two days to arrive.
# **************************
# Saving model checkpoint to test-tokenbatch6/checkpoint-4000
# Configuration saved in test-tokenbatch6/checkpoint-4000/config.json
# Model weights saved in test-tokenbatch6/checkpoint-4000/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-4000/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-4000/special_tokens_map.json
# Saving model checkpoint to test-tokenbatch6/checkpoint-4500
# Configuration saved in test-tokenbatch6/checkpoint-4500/config.json
# Model weights saved in test-tokenbatch6/checkpoint-4500/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-4500/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-4500/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 818
#   Batch size = 6
# -------------------------
# ------>Predictions by Model
# A will go to the animal shelter tomorrow afternoon to get a puppy for her son.
# ----->Predictions Original
# A will go to the animal shelter tomorrow to get a puppy for her son.
# They already visited the shelter last Monday and the son chose the puppy.
# **************************
# -------------------------
# ------>Predictions by Model
# Emma wants to buy an advent calendar for her children.
# ----->Predictions Original
# Emma and Rob love the advent calendar.
# Lauren fits inside calendar various items, for instance, small toys and Christmas decorations.
# Her children are excited whenever they get the calendar.
# **************************
# -------------------------
# ------>Predictions by Model
# Madison is pregnant but she doesn't want to talk about it.
# Iggy's friend
# ----->Predictions Original
# Madison is pregnant but she doesn't want to talk about it.
# Patricia Stevens got married and she thought she was pregnant.
# **************************
# -------------------------
# ------>Predictions by Model
# Marla found underwear under her bed.
# She's 13 and her sister convinced her to
# ----->Predictions Original
# Marla found a pair of boxers under her bed.
# **************************
# -------------------------
# ------>Predictions by Model
# Robert needs to buy guitar cable.
# Fred gives him the address of the music shop.
# ----->Predictions Original
# Robert wants Fred to send him the address of the music shop as he needs to buy guitar cable.
# **************************
# -------------------------
# ------>Predictions by Model
# Keith will buy some milk and cereals.
# Megan will check in the drawer next to
# ----->Predictions Original
# Megan needn't buy milk and cereals.
# They're in the drawer next to the fridge.
# **************************
# -------------------------
# ------>Predictions by Model
# ...
# Kai may join her.
# Ish won't.
# Terry will join them for a coffee after they finish visiting the museum.
# Terry has already seen the museum.
# **************************
# -------------------------
# ------>Predictions by Model
# Cathy will pick up her sunglasses at Brooke's at 10 tonight.
# ----->Predictions Original
# Cathy left her sunglasses at Broke's house.
# She will come collect them at 10.
# **************************
# -------------------------
# ------>Predictions by Model
# Frederica will come to Bradley's birthday party tomorrow at 8 pm.
# ----->Predictions Original
# Bradley will come to Frederica's birthday party tomorrow at 8pm.
# **************************
# -------------------------
# ------>Predictions by Model
# Camilla received 250 from Adrian.
# Camilla will let Adrian know when she has received
# ----->Predictions Original
# Camilla still hasn't received the 250.
# She will check and let Adrian know.
# Money usually takes around two days to arrive.
# **************************
# Saving model checkpoint to test-tokenbatch6/checkpoint-5000
# Configuration saved in test-tokenbatch6/checkpoint-5000/config.json
# Model weights saved in test-tokenbatch6/checkpoint-5000/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-5000/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-5000/special_tokens_map.json
# Saving model checkpoint to test-tokenbatch6/checkpoint-5500
# Configuration saved in test-tokenbatch6/checkpoint-5500/config.json
# Model weights saved in test-tokenbatch6/checkpoint-5500/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-5500/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-5500/special_tokens_map.json
# Saving model checkpoint to test-tokenbatch6/checkpoint-6000
# Configuration saved in test-tokenbatch6/checkpoint-6000/config.json
# Model weights saved in test-tokenbatch6/checkpoint-6000/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-6000/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-6000/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 818
#   Batch size = 6
# -------------------------
# ------>Predictions by Model
# A will go to the animal shelter tomorrow afternoon to get a puppy for her son.
# ----->Predictions Original
# A will go to the animal shelter tomorrow to get a puppy for her son.
# They already visited the shelter last Monday and the son chose the puppy.
# **************************
# -------------------------
# ------>Predictions by Model
# Emma wants to buy an advent calendar for her children.
# ----->Predictions Original
# Emma and Rob love the advent calendar.
# Lauren fits inside calendar various items, for instance, small toys and Christmas decorations.
# Her children are excited whenever they get the calendar.
# **************************
# -------------------------
# ------>Predictions by Model
# Madison is pregnant but she doesn't want to talk about it.
# Iggy's friend
# ----->Predictions Original
# Madison is pregnant but she doesn't want to talk about it.
# Patricia Stevens got married and she thought she was pregnant.
# **************************
# -------------------------
# ------>Predictions by Model
# Marla found her underwear under her bed.
# She's 13 and she doesn't have
# ----->Predictions Original
# Marla found a pair of boxers under her bed.
# **************************
# -------------------------
# ------>Predictions by Model
# Robert needs to buy guitar cable.
# Fred gives him the address of the music shop.
# ----->Predictions Original
# Robert wants Fred to send him the address of the music shop as he needs to buy guitar cable.
# **************************
# -------------------------
# ------>Predictions by Model
# Keith will buy some milk and cereals.
# Megan will check in the drawer next to
# ----->Predictions Original
# Megan needn't buy milk and cereals.
# They're in the drawer next to the fridge.
# **************************
# -------------------------
# ------>Predictions by Model
# Samantha sends a video to Evelyn and Holly.
# ----->Predictions Original
# Samantha and Evelyn after watching the video cannot believe she is able to make that noise.
# **************************
# -------------------------
# ------>Predictions by Model
# Tom invited Theresa and Adam for dinner at Fiesole.
# ----->Predictions Original
# Tom's new place is in Fiesole.
# Luis and Marion has been there.
# **************************
# -------------------------
# ------>Predictions by Model
# Vegano Resto will make a reservation for 6 people tonight at 21:00
# ----->Predictions Original
# Jane made a 9 PM reservation for 6 people tonight at Vegano Resto.
# **************************
# -------------------------
# ------>Predictions by Model
# Nancy is in Texan drawl.
# She has 21 years of experience in Cardiff
# ----->Predictions Original
# Nancy's working in Texas, but the kids laugh at her Welsh accent.
# She's coming home in 6 weeks.
# Earlier than that she's going to travel with 3 other Brits.
# **************************
# -------------------------
# ------>Predictions by Model
# Laura needs a new printer.
# Jamie suggests buying a second hand printer.
# ----->Predictions Original
# Laura is going to buy a printer.
# **************************
# -------------------------
# ------>Predictions by Model
# Haylee is in the dairy section and she's looking for coconut milk one.
# Barbara
# ----->Predictions Original
# Haylee can't find the coconut milk yoghurt.
# **************************
# -------------------------
# ------>Predictions by Model
# Wendy will buy something for the tour at the register now.
# ----->Predictions Original
# Wendy is shopping, but she needs to hurry up to catch the tour.
# **************************
# -------------------------
# ------>Predictions by Model
# Cecil and Peter went to Fuerteventura Peninsula.
# Cecil wants to
# ----->Predictions Original
# Cecil, Cheryl and Peter went to the Jandia Peninsula today.
# Cecil would like to explore the south of the island tomorrow, but they will decide what to do after dinner.
# **************************
# -------------------------
# ------>Predictions by Model
# Sophie hasn't found it yet.
# Nickola advises Sophie to check pockets and
# ----->Predictions Original
# Sophie still hasn't found it despite checking pockets and handbags twice.
# **************************
# -------------------------
# ------>Predictions by Model
# Rosie has to write an essay about bad movies.
# She will cover "The Room
# ----->Predictions Original
# Dennis and Elle are helping Rosie think of bad movies for her essay.
# **************************
# -------------------------
# ------>Predictions by Model
# James has a dream to become a voice actor in a cartoon or video game.
# He
# ----->Predictions Original
# James has a dream of becoming a voice actor.
# He considers making a home radio station.
# **************************
# -------------------------
# ------>Predictions by Model
# Poppy and Alice are going for drinks after work.
# They will meet at Nick's
# ----->Predictions Original
# Poppy and Alice are meeting for drinks after work at Nick's at 5:30.
# Alice fancies Fred, she will invite him and a bunch of other coworkers.
# **************************
# -------------------------
# ------>Predictions by Model
# Caron is out from 12.
# Sash will be there before 12.
# Caron
# ----->Predictions Original
# Sash needs to see Caron who'll be out from 12.
# **************************
# -------------------------
# ------>Predictions by Model
# Matteo doesn't like football and video games.
# Giuseppe likes Gosia
# ----->Predictions Original
# Matteo is not sure about his relationship with Gosia but likes her a lot.
# **************************
# -------------------------
# ------>Predictions by Model
# Ramzi's mom is calling for supper.
# Jannette is coming.
# ----->Predictions Original
# Ramzi and Jannette are going for supper.
# **************************
# -------------------------
# ------>Predictions by Model
# Jeniffer got the recipe from her grandmother.
# ----->Predictions Original
# Jeniffer is preparing ravioli following her grandmothers recipe.
# **************************
# -------------------------
# ------>Predictions by Model
# Lawrence will get back to Madison once he's done with the article.
# ----->Predictions Original
# Lawrence will finish writing the article soon.
# **************************
# -------------------------
# ------>Predictions by Model
# Chad sent Brennen a funny photo.
# ----->Predictions Original
# Chad has sent Brennen a funny photo.
# Brennen does not find it very funny.
# **************************
# -------------------------
# ------>Predictions by Model
# Chloe will pick up Sadie's bike on Wednesday evening.
# ----->Predictions Original
# Sadie will borrow Chloe's bike on Wednesday evening.
# She has a dentist appointment on Thursday after work.
# **************************
# -------------------------
# ------>Predictions by Model
# Olivia wants to launch a new restaurant in the city centre next month.
# Carter
# ----->Predictions Original
# Carter is launching a restaurant business next month.
# Olivia wants him to include a restaurant she's working for in the discount app.
# They will meet in person to discuss it.
# **************************
# -------------------------
# ------>Predictions by Model
# Kristine is worried about Kenny's health.
# He has another surgery scheduled tomorrow.
# She
# ----->Predictions Original
# Kenny had a surgery, as Kristine reports.
# He will have another surgery tomorrow.
# Guy will come to St. Mark's Hospital near Asda to stay with Kristine.
# **************************
# -------------------------
# ------>Predictions by Model
# Joey cheated on Olivia with numerous girls and got pregnant.
# Olivia and Joey knew each
# ----->Predictions Original
# Skyler and Adam are surprised that Joey and Olivia broke up.
# **************************
# -------------------------
# ------>Predictions by Model
# Amanda went to dancing classes with Michael yesterday.
# The instructor needed a partner to show
# ----->Predictions Original
# Amanda goes to dancing classes with Michael.
# She volunteered to show the English Waltz steps with the instructor yesterday.
# Amanda is shy and goes to therapy.
# **************************
# -------------------------
# ------>Predictions by Model
# Taylor wants Isabel to bring her boyfriend to her.
# Isabel hasn't had any.
# ----->Predictions Original
# Taylor wants to meet Isabel's boyfriend but she has never had any.
# **************************
# -------------------------
# ------>Predictions by Model
# Theo and Toby are leaving on Friday.
# Toby will come back by train on Monday
# ----->Predictions Original
# Theo's going to stay near Torino in the region of Italian Alpes.
# Toby wants to join the trip.
# Theo agrees and will pick Toby up on Friday at 7 am.
# **************************
# -------------------------
# ------>Predictions by Model
# Brandon will be late.
# Clara will prepare a report on the absenteeism and lateness
# ----->Predictions Original
# Brandon is late again.
# Clara will prepare a report on the absenteeism and lateness for Phil by Friday.
# **************************
# -------------------------
# ------>Predictions by Model
# Suzie is sick again and wants Olga to cancel.
# ----->Predictions Original
# Olga and Suzie will postpone their meeting due to Suzie's sickness.
# **************************
# -------------------------
# ------>Predictions by Model
# Kate will be Lorelai's mother.
# ----->Predictions Original
# Diane is pregnant and can't wait to give birth, she thinks the waiting is the worst.
# Kate thinks she'll be an amazing mother.
# **************************
# -------------------------
# ------>Predictions by Model
# Andrew had to call in sick because he has a cold.
# Daniel will drop by after
# ----->Predictions Original
# Andrew has a cold.
# Daniel will buy him some medication.
# **************************
# -------------------------
# ------>Predictions by Model
# Alex and Sam are watching 'Millionaires' on tv.
# Sam has a chance
# ----->Predictions Original
# Alex and Sam are watching Millionaires.
# **************************
# -------------------------
# ------>Predictions by Model
# Jessica has the cinnamon cookies recipe.
# Angelica sends Kelly the recipe.
# ----->Predictions Original
# Angelica sent the cinnamon cookies recipe at Kelly's request.
# **************************
# -------------------------
# ------>Predictions by Model
# Sophie is waiting for a client.
# Gwen and Dee will meet at the
# ----->Predictions Original
# Sophie is waiting for a client, who is late.
# She will meet Gwen later.
# **************************
# -------------------------
# ------>Predictions by Model
# Daniel is on his way downstairs.
# He will see Sue in a few minutes.
# ----->Predictions Original
# Daniel is with the Volvo on his way and will be there soon.
# Sue is going downstairs to meet him.
# **************************
# -------------------------
# ------>Predictions by Model
# George is going to CVS to buy some shaving cream for Betty.
# ----->Predictions Original
# George is making salmon and stuffed squash for dinner.
# Betty will buy a shaving cream at CVS at his request,
# **************************
# -------------------------
# ------>Predictions by Model
# Ken's phone doesn't work properly.
# He checked it for his results and it was
# ----->Predictions Original
# Ken has installed an app for running but it is not working properly on his phone.
# **************************
# -------------------------
# ------>Predictions by Model
# Ann couldn't come to Ivan's birthday party.
# Ivan bought her something for her birthday
# ----->Predictions Original
# Ivan and Ann will meet next week.
# **************************
# -------------------------
# ------>Predictions by Model
# Ashley posted nude pictures on Facebook.
# Rowan has some important work to do.
# ----->Predictions Original
# Ashley posted some nude photos on her fb page.
# **************************
# -------------------------
# ------>Predictions by Model
# Mikolaj's wife has papers with working permission since she's a foreigner.
# ----->Predictions Original
# Mikolaj's wife needs a work permit as a foreigner.
# Government officials missed the deadline for sending it and will need another month.
# **************************
# -------------------------
# ------>Predictions by Model
# Ann is at the 3rd floor lobby.
# Peter is still there.
# Ann and Thomas
# ----->Predictions Original
# Thomas, Ann and Maria will have lunch together at the hotel.
# Ann is already in the 3rd floor lobby at the red table.
# **************************
# -------------------------
# ------>Predictions by Model
# Sus and Val don't want to work.
# ----->Predictions Original
# Sus and Val don't want to work and are sleepy.
# **************************
# -------------------------
# ------>Predictions by Model
# Kate is at the Guggenheim right now.
# She wants to go to the
# ----->Predictions Original
# Kate is at the Guggenheim Museum now, but will be in the Museum of the City of New York around 2-2:30.
# Kai may join her.
# Ish won't.
# Terry will join them for a coffee after they finish visiting the museum.
# Terry has already seen the museum.
# **************************
# -------------------------
# ------>Predictions by Model
# Cathy left her sunglasses at Brooke's house.
# She will come round at 10 tonight
# ----->Predictions Original
# Cathy left her sunglasses at Broke's house.
# She will come collect them at 10.
# **************************
# -------------------------
# ------>Predictions by Model
# Frederica will come to Bradley's birthday party tomorrow at 8 pm.
# ----->Predictions Original
# Bradley will come to Frederica's birthday party tomorrow at 8pm.
# **************************
# -------------------------
# ------>Predictions by Model
# Camilla received 250 from Adrian.
# Camilla needs to check if she received the money
# ----->Predictions Original
# Camilla still hasn't received the 250.
# She will check and let Adrian know.
# Money usually takes around two days to arrive.
# **************************
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=6135, training_loss=19.84097158965194, metrics={'train_runtime': 8277.4414, 'train_samples_per_second': 8.898, 'train_steps_per_second': 0.741, 'total_flos': 1.408779533371392e+16, 'train_loss': 19.84097158965194, 'epoch': 5.0})

# %%
trainer.train() #1 token
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 14730
#   Num Epochs = 5
#   Instantaneous batch size per device = 6
#   Total train batch size (w. parallel, distributed & accumulation) = 12
#   Gradient Accumulation steps = 2
#   Total optimization steps = 6135
#   Number of trainable parameters = 139420416
# You're using a BartTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='6135' max='6135' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [6135/6135 2:19:27, Epoch 4/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>27.652200</td>
#       <td>113.108192</td>
#       <td>44.246600</td>
#       <td>20.582100</td>
#       <td>36.350300</td>
#       <td>40.269000</td>
#       <td>17.700500</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>37.382200</td>
#       <td>47.435345</td>
#       <td>46.082400</td>
#       <td>22.650700</td>
#       <td>38.425400</td>
#       <td>41.936500</td>
#       <td>17.745700</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>48.190100</td>
#       <td>33.907181</td>
#       <td>46.754000</td>
#       <td>23.299600</td>
#       <td>39.197800</td>
#       <td>42.814000</td>
#       <td>17.762800</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>35.373200</td>
#       <td>48.250854</td>
#       <td>47.736500</td>
#       <td>24.335600</td>
#       <td>40.090200</td>
#       <td>43.858700</td>
#       <td>18.151600</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>48.903300</td>
#       <td>47.627300</td>
#       <td>48.314400</td>
#       <td>24.993700</td>
#       <td>40.440900</td>
#       <td>44.304700</td>
#       <td>18.020800</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to test-tokenbatch6/checkpoint-500
# Configuration saved in test-tokenbatch6/checkpoint-500/config.json
# Model weights saved in test-tokenbatch6/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-500/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-500/special_tokens_map.json
# Saving model checkpoint to test-tokenbatch6/checkpoint-1000
# Configuration saved in test-tokenbatch6/checkpoint-1000/config.json
# Model weights saved in test-tokenbatch6/checkpoint-1000/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-1000/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 818
#   Batch size = 6
# -------------------------
# ------>Predictions by Model
# A wants to get a puppy for her son, but he doesn't know what to
# ----->Predictions Original
# A will go to the animal shelter tomorrow to get a puppy for her son.
# They already visited the shelter last Monday and the son chose the puppy.
# **************************
# -------------------------
# ------>Predictions by Model
# Emma wants to buy an advent calendar for her kids.
# Rob suggests buying fabric/
# ----->Predictions Original
# Emma and Rob love the advent calendar.
# Lauren fits inside calendar various items, for instance, small toys and Christmas decorations.
# Her children are excited whenever they get the calendar.
# **************************
# -------------------------
# ------>Predictions by Model
# Jackie is pregnant with Madison.
# Iggy doesn't want to talk about it because
# ----->Predictions Original
# Madison is pregnant but she doesn't want to talk about it.
# Patricia Stevens got married and she thought she was pregnant.
# **************************
# -------------------------
# ------>Predictions by Model
# Marla found a pair of boxers under her bed.
# She found male underwear.
# ----->Predictions Original
# Marla found a pair of boxers under her bed.
# **************************
# -------------------------
# ------>Predictions by Model
# Robert has to buy guitar cable.
# Fred will catch it on google maps.
# ----->Predictions Original
# Robert wants Fred to send him the address of the music shop as he needs to buy guitar cable.
# **************************
# -------------------------
# ------>Predictions by Model
# Keith has run out of milk and cereals.
# Megan will check in the drawer next
# ----->Predictions Original
# Megan needn't buy milk and cereals.
# They're in the drawer next to the fridge.
# **************************
# -------------------------
# ------>Predictions by Model
# Samantha sends Evelyn a video of herself making noise.
# ----->Predictions Original
# Samantha and Evelyn after watching the video cannot believe she is able to make that noise.
# **************************
# -------------------------
# ------>Predictions by Model
# Theresa, Luis and Marion have been at Tom's new place for a dinner.
# ----->Predictions Original
# Tom's new place is in Fiesole.
# Luis and Marion has been there.
# **************************
# -------------------------
# ------>Predictions by Model
# Vegano Resto will make a reservation for 6 people tonight around 20:00
# ----->Predictions Original
# Jane made a 9 PM reservation for 6 people tonight at Vegano Resto.
# **************************
# -------------------------
# ------>Predictions by Model
# Nancy is travelling with her ex-boyfriend from Glasgow to Cardiff in 6 weeks
# ----->Predictions Original
# Nancy's working in Texas, but the kids laugh at her Welsh accent.
# She's coming home in 6 weeks.
# Earlier than that she's going to travel with 3 other Brits.
# **************************
# -------------------------
# ------>Predictions by Model
# Laura needs a new printer.
# Jamie will buy a second hand one.
# ----->Predictions Original
# Laura is going to buy a printer.
# **************************
# -------------------------
# ------>Predictions by Model
# Haylee is in dairy section.
# Barbara will buy coconut milk for her.
# ----->Predictions Original
# Haylee can't find the coconut milk yoghurt.
# **************************
# -------------------------
# ------>Predictions by Model
# Norbert is waiting for the tour.
# Wendy is at the register now.
# ----->Predictions Original
# Wendy is shopping, but she needs to hurry up to catch the tour.
# **************************
# -------------------------
# ------>Predictions by Model
# Cheryl went to the Jandia Peninsula, but she didn't like it
# ----->Predictions Original
# Cecil, Cheryl and Peter went to the Jandia Peninsula today.
# Cecil would like to explore the south of the island tomorrow, but they will decide what to do after dinner.
# **************************
# -------------------------
# ------>Predictions by Model
# Sophie checked her pockets and handbags twice already.
# ----->Predictions Original
# Sophie still hasn't found it despite checking pockets and handbags twice.
# **************************
# -------------------------
# ------>Predictions by Model
# Rosie wants to know what her favourite b-movie is.
# Dennis recommends Troma
# ----->Predictions Original
# Dennis and Elle are helping Rosie think of bad movies for her essay.
# **************************
# -------------------------
# ------>Predictions by Model
# Julia's biggest dream is to become a voice actor.
# James has already worked in
# ----->Predictions Original
# James has a dream of becoming a voice actor.
# He considers making a home radio station.
# **************************
# -------------------------
# ------>Predictions by Model
# Alice didn't get lunch because she had errands to do.
# Poppy will join
# ----->Predictions Original
# Poppy and Alice are meeting for drinks after work at Nick's at 5:30.
# Alice fancies Fred, she will invite him and a bunch of other coworkers.
# **************************
# -------------------------
# ------>Predictions by Model
# Caron is out from 12.
# Sash will see Caron before 12.
# ----->Predictions Original
# Sash needs to see Caron who'll be out from 12.
# **************************
# -------------------------
# ------>Predictions by Model
# Matteo doesn't like football and video games.
# Giuseppe doesn't want
# ----->Predictions Original
# Matteo is not sure about his relationship with Gosia but likes her a lot.
# **************************
# -------------------------
# ------>Predictions by Model
# Jannette is calling for supper.
# ----->Predictions Original
# Ramzi and Jannette are going for supper.
# **************************
# -------------------------
# ------>Predictions by Model
# Jeniffer is preparing ravioli for her grandmother.
# ----->Predictions Original
# Jeniffer is preparing ravioli following her grandmothers recipe.
# **************************
# -------------------------
# ------>Predictions by Model
# Lawrence will get back to Madison once he is through with the article.
# ----->Predictions Original
# Lawrence will finish writing the article soon.
# **************************
# -------------------------
# ------>Predictions by Model
# Chad sends Brennen a funny picture of Chad.
# ----->Predictions Original
# Chad has sent Brennen a funny photo.
# Brennen does not find it very funny.
# **************************
# -------------------------
# ------>Predictions by Model
# Chloe will borrow Sadie's bike on Thursday after work.
# ----->Predictions Original
# Sadie will borrow Chloe's bike on Wednesday evening.
# She has a dentist appointment on Thursday after work.
# **************************
# -------------------------
# ------>Predictions by Model
# Olivia is developing a new restaurant in the city centre next month.
# Carter and
# ----->Predictions Original
# Carter is launching a restaurant business next month.
# Olivia wants him to include a restaurant she's working for in the discount app.
# They will meet in person to discuss it.
# **************************
# -------------------------
# ------>Predictions by Model
# Kristine's back from surgery.
# She's going to St Marks Hospital near Asda
# ----->Predictions Original
# Kenny had a surgery, as Kristine reports.
# He will have another surgery tomorrow.
# Guy will come to St. Mark's Hospital near Asda to stay with Kristine.
# **************************
# -------------------------
# ------>Predictions by Model
# Joey cheated on Olivia with numerous girls.
# He cheated on her with many girls.
# ----->Predictions Original
# Skyler and Adam are surprised that Joey and Olivia broke up.
# **************************
# -------------------------
# ------>Predictions by Model
# Amanda needs a partner to show her steps to Michael and Chris how to dance.
# ----->Predictions Original
# Amanda goes to dancing classes with Michael.
# She volunteered to show the English Waltz steps with the instructor yesterday.
# Amanda is shy and goes to therapy.
# **************************
# -------------------------
# ------>Predictions by Model
# Taylor's daughters have introduced their bfs to their mothers.
# Isabel hasn't had any
# ----->Predictions Original
# Taylor wants to meet Isabel's boyfriend but she has never had any.
# **************************
# -------------------------
# ------>Predictions by Model
# Theo is leaving for Italy on Friday.
# Toby will pick him up by train on
# ----->Predictions Original
# Theo's going to stay near Torino in the region of Italian Alpes.
# Toby wants to join the trip.
# Theo agrees and will pick Toby up on Friday at 7 am.
# **************************
# -------------------------
# ------>Predictions by Model
# Phil is late for Brandon's arrival.
# Clara will prepare a report on the absenteeism
# ----->Predictions Original
# Brandon is late again.
# Clara will prepare a report on the absenteeism and lateness for Phil by Friday.
# **************************
# -------------------------
# ------>Predictions by Model
# Suzie is sick again.
# Olga will reschedule.
# ----->Predictions Original
# Olga and Suzie will postpone their meeting due to Suzie's sickness.
# **************************
# -------------------------
# ------>Predictions by Model
# Diane and Kate are going to Lorelai.
# Kate is scared before the birth
# ----->Predictions Original
# Diane is pregnant and can't wait to give birth, she thinks the waiting is the worst.
# Kate thinks she'll be an amazing mother.
# **************************
# -------------------------
# ------>Predictions by Model
# Andrew has a cold.
# Daniel will drop by after work to help him with it.
# ----->Predictions Original
# Andrew has a cold.
# Daniel will buy him some medication.
# **************************
# -------------------------
# ------>Predictions by Model
# John, Alex and Sam are thinking about doing something special.
# ----->Predictions Original
# Alex and Sam are watching Millionaires.
# **************************
# -------------------------
# ------>Predictions by Model
# Kelly has the cinnamon cookies recipe.
# Angelica has already sent Kelly a photo.
# ----->Predictions Original
# Angelica sent the cinnamon cookies recipe at Kelly's request.
# **************************
# -------------------------
# ------>Predictions by Model
# Sophie is waiting for a client at the restaurant.
# Dee will let her know
# ----->Predictions Original
# Sophie is waiting for a client, who is late.
# She will meet Gwen later.
# **************************
# -------------------------
# ------>Predictions by Model
# Daniel is on his way to pick Sue up from the Volvo.
# ----->Predictions Original
# Daniel is with the Volvo on his way and will be there soon.
# Sue is going downstairs to meet him.
# **************************
# -------------------------
# ------>Predictions by Model
# Betty is going to CVS to pick up some squash for George.
# George will
# ----->Predictions Original
# George is making salmon and stuffed squash for dinner.
# Betty will buy a shaving cream at CVS at his request,
# **************************
# -------------------------
# ------>Predictions by Model
# Ken's phone is not working properly and he needs to track his progress.
# Martha's
# ----->Predictions Original
# Ken has installed an app for running but it is not working properly on his phone.
# **************************
# -------------------------
# ------>Predictions by Model
# Ann hasn't been at Ivan's birthday party yet.
# Ivan will come next week.
# ----->Predictions Original
# Ivan and Ann will meet next week.
# **************************
# -------------------------
# ------>Predictions by Model
# Ashley posted a picture of her husband's nudes on Facebook.
# Rowan doesn
# ----->Predictions Original
# Ashley posted some nude photos on her fb page.
# **************************
# -------------------------
# ------>Predictions by Model
# Mikolaj's wife has a problem with her working permission.
# Magda will
# ----->Predictions Original
# Mikolaj's wife needs a work permit as a foreigner.
# Government officials missed the deadline for sending it and will need another month.
# **************************
# -------------------------
# ------>Predictions by Model
# Maria is on her way to the hotel.
# Ann hasn't seen Peter yet.
# She
# ----->Predictions Original
# Thomas, Ann and Maria will have lunch together at the hotel.
# Ann is already in the 3rd floor lobby at the red table.
# **************************
# -------------------------
# ------>Predictions by Model
# Sus and Val are sleepy.
# ----->Predictions Original
# Sus and Val don't want to work and are sleepy.
# **************************
# -------------------------
# ------>Predictions by Model
# Kate wants to go to the Museum of the city of NY, but she can't
# ----->Predictions Original
# Kate is at the Guggenheim Museum now, but will be in the Museum of the City of New York around 2-2:30.
# Kai may join her.
# Ish won't.
# Terry will join them for a coffee after they finish visiting the museum.
# Terry has already seen the museum.
# **************************
# -------------------------
# ------>Predictions by Model
# Cathy has left her sunglasses at her house.
# She will come round at 10 tonight
# ----->Predictions Original
# Cathy left her sunglasses at Broke's house.
# She will come collect them at 10.
# **************************
# -------------------------
# ------>Predictions by Model
# Frederica will come to Bradley's birthday party tomorrow at 8pm.
# ----->Predictions Original
# Bradley will come to Frederica's birthday party tomorrow at 8pm.
# **************************
# -------------------------
# ------>Predictions by Model
# Camilla still needs to check if she received the money.
# ----->Predictions Original
# Camilla still hasn't received the 250.
# She will check and let Adrian know.
# Money usually takes around two days to arrive.
# **************************
# Saving model checkpoint to test-tokenbatch6/checkpoint-1500
# Configuration saved in test-tokenbatch6/checkpoint-1500/config.json
# Model weights saved in test-tokenbatch6/checkpoint-1500/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-1500/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-1500/special_tokens_map.json
# Saving model checkpoint to test-tokenbatch6/checkpoint-2000
# Configuration saved in test-tokenbatch6/checkpoint-2000/config.json
# Model weights saved in test-tokenbatch6/checkpoint-2000/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-2000/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 818
#   Batch size = 6
# -------------------------
# ------>Predictions by Model
# A will take her son to the animal shelter tomorrow afternoon.
# He wants to get a
# ----->Predictions Original
# A will go to the animal shelter tomorrow to get a puppy for her son.
# They already visited the shelter last Monday and the son chose the puppy.
# **************************
# -------------------------
# ------>Predictions by Model
# Emma wants to buy an advent calendar for her kids.
# Rob and Lauren think it
# ----->Predictions Original
# Emma and Rob love the advent calendar.
# Lauren fits inside calendar various items, for instance, small toys and Christmas decorations.
# Her children are excited whenever they get the calendar.
# **************************
# -------------------------
# ------>Predictions by Model
# Madison is pregnant.
# She doesn't want to talk about it because she's worried about
# ----->Predictions Original
# Madison is pregnant but she doesn't want to talk about it.
# Patricia Stevens got married and she thought she was pregnant.
# **************************
# -------------------------
# ------>Predictions by Model
# Marla found a box of boxers under her bed.
# Tamara's sister convinced
# ----->Predictions Original
# Marla found a pair of boxers under her bed.
# **************************
# -------------------------
# ------>Predictions by Model
# Robert needs to buy guitar cable.
# Fred will give him the address of the music shop
# ----->Predictions Original
# Robert wants Fred to send him the address of the music shop as he needs to buy guitar cable.
# **************************
# -------------------------
# ------>Predictions by Model
# Keith will check in the drawer next to the fridge to buy some milk and cereals
# ----->Predictions Original
# Megan needn't buy milk and cereals.
# They're in the drawer next to the fridge.
# **************************
# -------------------------
# ------>Predictions by Model
# Samantha shares a video with Evelyn and Holly.
# ----->Predictions Original
# Samantha and Evelyn after watching the video cannot believe she is able to make that noise.
# **************************
# -------------------------
# ------>Predictions by Model
# Theresa and Luis haven't been to Tom's new place yet.
# Luis and Marion
# ----->Predictions Original
# Tom's new place is in Fiesole.
# Luis and Marion has been there.
# **************************
# -------------------------
# ------>Predictions by Model
# Jane will make a reservation for 6 people tonight around 20:00.
# ----->Predictions Original
# Jane made a 9 PM reservation for 6 people tonight at Vegano Resto.
# **************************
# -------------------------
# ------>Predictions by Model
# Nancy is coming home in 6 weeks.
# She asks Tina to repeat everything she says
# ----->Predictions Original
# Nancy's working in Texas, but the kids laugh at her Welsh accent.
# She's coming home in 6 weeks.
# Earlier than that she's going to travel with 3 other Brits.
# **************************
# -------------------------
# ------>Predictions by Model
# Laura needs a new printer.
# Jamie will buy a second hand one.
# ----->Predictions Original
# Laura is going to buy a printer.
# **************************
# -------------------------
# ------>Predictions by Model
# Barbara bought coconut milk.
# Haylee is in dairy section.
# ----->Predictions Original
# Haylee can't find the coconut milk yoghurt.
# **************************
# -------------------------
# ------>Predictions by Model
# Norbert and Wendy need to hurry to catch the tour.
# Wendy is at the register
# ----->Predictions Original
# Wendy is shopping, but she needs to hurry up to catch the tour.
# **************************
# -------------------------
# ------>Predictions by Model
# Cecil went to the Jandia Peninsula.
# Lidia and Cecil will decide
# ----->Predictions Original
# Cecil, Cheryl and Peter went to the Jandia Peninsula today.
# Cecil would like to explore the south of the island tomorrow, but they will decide what to do after dinner.
# **************************
# -------------------------
# ------>Predictions by Model
# Nickola has found Sophie's pockets and handbags.
# ----->Predictions Original
# Sophie still hasn't found it despite checking pockets and handbags twice.
# **************************
# -------------------------
# ------>Predictions by Model
# Rosie has to write an essay about her favourite b-movie.
# She will also
# ----->Predictions Original
# Dennis and Elle are helping Rosie think of bad movies for her essay.
# **************************
# -------------------------
# ------>Predictions by Model
# James's biggest dream is to become a voice actor.
# His mom liked his voice.
# ----->Predictions Original
# James has a dream of becoming a voice actor.
# He considers making a home radio station.
# **************************
# -------------------------
# ------>Predictions by Model
# Poppy and Alice are going for drinks after work.
# Poppy will invite Fred and
# ----->Predictions Original
# Poppy and Alice are meeting for drinks after work at Nick's at 5:30.
# Alice fancies Fred, she will invite him and a bunch of other coworkers.
# **************************
# -------------------------
# ------>Predictions by Model
# Sash will see Caron before 12.
# Caron is out from 12.
# ----->Predictions Original
# Sash needs to see Caron who'll be out from 12.
# **************************
# -------------------------
# ------>Predictions by Model
# Matteo doesn't like football and video games.
# Giuseppe doesn't want
# ----->Predictions Original
# Matteo is not sure about his relationship with Gosia but likes her a lot.
# **************************
# -------------------------
# ------>Predictions by Model
# Mom is calling for supper.
# ----->Predictions Original
# Ramzi and Jannette are going for supper.
# **************************
# -------------------------
# ------>Predictions by Model
# Jeniffer and Alois are preparing ravioli for dinner.
# ----->Predictions Original
# Jeniffer is preparing ravioli following her grandmothers recipe.
# **************************
# -------------------------
# ------>Predictions by Model
# Lawrence will get back to Madison once he is through with the article.
# ----->Predictions Original
# Lawrence will finish writing the article soon.
# **************************
# -------------------------
# ------>Predictions by Model
# Chad sent Brennen a funny photo.
# ----->Predictions Original
# Chad has sent Brennen a funny photo.
# Brennen does not find it very funny.
# **************************
# -------------------------
# ------>Predictions by Model
# Sadie will borrow Chloe's bike on Wednesday evening.
# ----->Predictions Original
# Sadie will borrow Chloe's bike on Wednesday evening.
# She has a dentist appointment on Thursday after work.
# **************************
# -------------------------
# ------>Predictions by Model
# Olivia is planning to launch a new restaurant in the city centre next month.
# ----->Predictions Original
# Carter is launching a restaurant business next month.
# Olivia wants him to include a restaurant she's working for in the discount app.
# They will meet in person to discuss it.
# **************************
# -------------------------
# ------>Predictions by Model
# Kristine is back from surgery.
# She will be at St Marks Hospital near Asda
# ----->Predictions Original
# Kenny had a surgery, as Kristine reports.
# He will have another surgery tomorrow.
# Guy will come to St. Mark's Hospital near Asda to stay with Kristine.
# **************************
# -------------------------
# ------>Predictions by Model
# Joey and Olivia broke up 2 days ago.
# Joey cheated on Olivia with numerous girls
# ----->Predictions Original
# Skyler and Adam are surprised that Joey and Olivia broke up.
# **************************
# -------------------------
# ------>Predictions by Model
# Amanda went to dance classes yesterday.
# The instructor needed a partner to show the steps
# ----->Predictions Original
# Amanda goes to dancing classes with Michael.
# She volunteered to show the English Waltz steps with the instructor yesterday.
# Amanda is shy and goes to therapy.
# **************************
# -------------------------
# ------>Predictions by Model
# Taylor has a question about Isabel's boyfriend.
# Isabel hasn't introduced Taylor to her boyfriend
# ----->Predictions Original
# Taylor wants to meet Isabel's boyfriend but she has never had any.
# **************************
# -------------------------
# ------>Predictions by Model
# Toby will come back by train to Torino on Friday.
# Theo will write Toby
# ----->Predictions Original
# Theo's going to stay near Torino in the region of Italian Alpes.
# Toby wants to join the trip.
# Theo agrees and will pick Toby up on Friday at 7 am.
# **************************
# -------------------------
# ------>Predictions by Model
# Brandon will be late.
# Phil will prepare a report on the absenteeism and lateness
# ----->Predictions Original
# Brandon is late again.
# Clara will prepare a report on the absenteeism and lateness for Phil by Friday.
# **************************
# -------------------------
# ------>Predictions by Model
# Suzie is sick again.
# She cancelled last time because she didn't want to catch
# ----->Predictions Original
# Olga and Suzie will postpone their meeting due to Suzie's sickness.
# **************************
# -------------------------
# ------>Predictions by Model
# Diane will be her kids' Lorelai's mom.
# ----->Predictions Original
# Diane is pregnant and can't wait to give birth, she thinks the waiting is the worst.
# Kate thinks she'll be an amazing mother.
# **************************
# -------------------------
# ------>Predictions by Model
# Andrew had to call in sick because he has a cold.
# Daniel will drop by after
# ----->Predictions Original
# Andrew has a cold.
# Daniel will buy him some medication.
# **************************
# -------------------------
# ------>Predictions by Model
# John, Alex and Sam are watching "Millionaires" on tv.
# ----->Predictions Original
# Alex and Sam are watching Millionaires.
# **************************
# -------------------------
# ------>Predictions by Model
# Kelly has the cinnamon cookies recipe.
# Angelica has it.
# ----->Predictions Original
# Angelica sent the cinnamon cookies recipe at Kelly's request.
# **************************
# -------------------------
# ------>Predictions by Model
# Sophie is waiting for a client.
# Gwen will let Sophie know in 15
# ----->Predictions Original
# Sophie is waiting for a client, who is late.
# She will meet Gwen later.
# **************************
# -------------------------
# ------>Predictions by Model
# Daniel is on his way to meet Sue in a few minutes.
# ----->Predictions Original
# Daniel is with the Volvo on his way and will be there soon.
# Sue is going downstairs to meet him.
# **************************
# -------------------------
# ------>Predictions by Model
# Betty is going to CVS to buy some salmon for George.
# ----->Predictions Original
# George is making salmon and stuffed squash for dinner.
# Betty will buy a shaving cream at CVS at his request,
# **************************
# -------------------------
# ------>Predictions by Model
# Ken doesn't use endomondo because it doesn't work properly.
# Martha's friend
# ----->Predictions Original
# Ken has installed an app for running but it is not working properly on his phone.
# **************************
# -------------------------
# ------>Predictions by Model
# Ann hasn't been at Ivan's birthday party.
# Ivan bought her something for her birthday
# ----->Predictions Original
# Ivan and Ann will meet next week.
# **************************
# -------------------------
# ------>Predictions by Model
# Ashley posted some pictures of her fb page.
# Rowan has some important stuff
# ----->Predictions Original
# Ashley posted some nude photos on her fb page.
# **************************
# -------------------------
# ------>Predictions by Model
# Mikolaj got a breakthrough with his wife's papers.
# The government didn't
# ----->Predictions Original
# Mikolaj's wife needs a work permit as a foreigner.
# Government officials missed the deadline for sending it and will need another month.
# **************************
# -------------------------
# ------>Predictions by Model
# Maria is on her way to the hotel.
# Ann hasn't seen Peter yet.
# They
# ----->Predictions Original
# Thomas, Ann and Maria will have lunch together at the hotel.
# Ann is already in the 3rd floor lobby at the red table.
# **************************
# -------------------------
# ------>Predictions by Model
# Sus and Val don't want to work.
# ----->Predictions Original
# Sus and Val don't want to work and are sleepy.
# **************************
# -------------------------
# ------>Predictions by Model
# Kate, Kai and Terry are going to the Museum of the city of NY.
# ----->Predictions Original
# Kate is at the Guggenheim Museum now, but will be in the Museum of the City of New York around 2-2:30.
# Kai may join her.
# Ish won't.
# Terry will join them for a coffee after they finish visiting the museum.
# Terry has already seen the museum.
# **************************
# -------------------------
# ------>Predictions by Model
# Cathy left her sunglasses at Brooke's house.
# She will come round at 10 tonight
# ----->Predictions Original
# Cathy left her sunglasses at Broke's house.
# She will come collect them at 10.
# **************************
# -------------------------
# ------>Predictions by Model
# Frederica will come to Bradley's birthday party tomorrow at 8 pm.
# ----->Predictions Original
# Bradley will come to Frederica's birthday party tomorrow at 8pm.
# **************************
# -------------------------
# ------>Predictions by Model
# Camilla hasn't received the money yet.
# Adrian will let Camilla know when she
# ----->Predictions Original
# Camilla still hasn't received the 250.
# She will check and let Adrian know.
# Money usually takes around two days to arrive.
# **************************
# Saving model checkpoint to test-tokenbatch6/checkpoint-2500
# Configuration saved in test-tokenbatch6/checkpoint-2500/config.json
# Model weights saved in test-tokenbatch6/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-2500/special_tokens_map.json
# Saving model checkpoint to test-tokenbatch6/checkpoint-3000
# Configuration saved in test-tokenbatch6/checkpoint-3000/config.json
# Model weights saved in test-tokenbatch6/checkpoint-3000/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-3000/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-3000/special_tokens_map.json
# Saving model checkpoint to test-tokenbatch6/checkpoint-3500
# Configuration saved in test-tokenbatch6/checkpoint-3500/config.json
# Model weights saved in test-tokenbatch6/checkpoint-3500/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-3500/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-3500/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 818
#   Batch size = 6
# -------------------------
# ------>Predictions by Model
# A will take her son to the animal shelter tomorrow afternoon.
# He will get a puppy
# ----->Predictions Original
# A will go to the animal shelter tomorrow to get a puppy for her son.
# They already visited the shelter last Monday and the son chose the puppy.
# **************************
# -------------------------
# ------>Predictions by Model
# Emma wants to buy an advent calendar for her kids.
# Rob and Lauren like the
# ----->Predictions Original
# Emma and Rob love the advent calendar.
# Lauren fits inside calendar various items, for instance, small toys and Christmas decorations.
# Her children are excited whenever they get the calendar.
# **************************
# -------------------------
# ------>Predictions by Model
# Madison is pregnant.
# ----->Predictions Original
# Madison is pregnant but she doesn't want to talk about it.
# Patricia Stevens got married and she thought she was pregnant.
# **************************
# -------------------------
# ------>Predictions by Model
# Marla found a pair of boxers under her bed.
# ----->Predictions Original
# Marla found a pair of boxers under her bed.
# **************************
# -------------------------
# ------>Predictions by Model
# Robert needs to buy guitar cable.
# Fred gives Robert the address of the music shop.
# ----->Predictions Original
# Robert wants Fred to send him the address of the music shop as he needs to buy guitar cable.
# **************************
# -------------------------
# ------>Predictions by Model
# Keith will check in the drawer next to the fridge to buy some milk and cereals
# ----->Predictions Original
# Megan needn't buy milk and cereals.
# They're in the drawer next to the fridge.
# **************************
# -------------------------
# ------>Predictions by Model
# Samantha shares a video with Evelyn and Holly.
# ----->Predictions Original
# Samantha and Evelyn after watching the video cannot believe she is able to make that noise.
# **************************
# -------------------------
# ------>Predictions by Model
# Theresa, Luis and Marion went to Tom's new place for a dinner.
# They
# ----->Predictions Original
# Tom's new place is in Fiesole.
# Luis and Marion has been there.
# **************************
# -------------------------
# ------>Predictions by Model
# Jane will make a reservation for 6 people tonight around 20:00 for six people under
# ----->Predictions Original
# Jane made a 9 PM reservation for 6 people tonight at Vegano Resto.
# **************************
# -------------------------
# ------>Predictions by Model
# Nancy is coming home in 6 weeks.
# She's having a hard time with her
# ----->Predictions Original
# Nancy's working in Texas, but the kids laugh at her Welsh accent.
# She's coming home in 6 weeks.
# Earlier than that she's going to travel with 3 other Brits.
# **************************
# -------------------------
# ------>Predictions by Model
# Laura needs a new printer.
# Jamie will buy a second hand one.
# ----->Predictions Original
# Laura is going to buy a printer.
# **************************
# -------------------------
# ------>Predictions by Model
# Barbara is in the dairy section.
# She bought coconut milk and eggs.
# ----->Predictions Original
# Haylee can't find the coconut milk yoghurt.
# **************************
# -------------------------
# ------>Predictions by Model
# Norbert and Wendy are going to catch the tour.
# Wendy is buying something at the
# ----->Predictions Original
# Wendy is shopping, but she needs to hurry up to catch the tour.
# **************************
# -------------------------
# ------>Predictions by Model
# Cheryl went to the Jandia Peninsula.
# She liked the weather there.
# ----->Predictions Original
# Cecil, Cheryl and Peter went to the Jandia Peninsula today.
# Cecil would like to explore the south of the island tomorrow, but they will decide what to do after dinner.
# **************************
# -------------------------
# ------>Predictions by Model
# Nickola has checked pockets and handbags.
# ----->Predictions Original
# Sophie still hasn't found it despite checking pockets and handbags twice.
# **************************
# -------------------------
# ------>Predictions by Model
# Rosie has to write an essay on her favourite b-movie.
# Dennis recommends T
# ----->Predictions Original
# Dennis and Elle are helping Rosie think of bad movies for her essay.
# **************************
# -------------------------
# ------>Predictions by Model
# James's biggest dream is to become a voice actor reading a character.
# ----->Predictions Original
# James has a dream of becoming a voice actor.
# He considers making a home radio station.
# **************************
# -------------------------
# ------>Predictions by Model
# Poppy and Alice are going for drinks after work.
# Poppy will join them.
# ----->Predictions Original
# Poppy and Alice are meeting for drinks after work at Nick's at 5:30.
# Alice fancies Fred, she will invite him and a bunch of other coworkers.
# **************************
# -------------------------
# ------>Predictions by Model
# Sash will see Caron before 12.
# Caron is out from 12.
# ----->Predictions Original
# Sash needs to see Caron who'll be out from 12.
# **************************
# -------------------------
# ------>Predictions by Model
# Matteo's girlfriend Gosia criticizes him because she likes football and video games
# ----->Predictions Original
# Matteo is not sure about his relationship with Gosia but likes her a lot.
# **************************
# -------------------------
# ------>Predictions by Model
# Mom is calling for supper.
# ----->Predictions Original
# Ramzi and Jannette are going for supper.
# **************************
# -------------------------
# ------>Predictions by Model
# Jeniffer, Alois and Hildegard are preparing ravioli.
# ----->Predictions Original
# Jeniffer is preparing ravioli following her grandmothers recipe.
# **************************
# -------------------------
# ------>Predictions by Model
# Lawrence will get back to Madison once he is through with the article.
# ----->Predictions Original
# Lawrence will finish writing the article soon.
# **************************
# -------------------------
# ------>Predictions by Model
# Chad shares a funny photo with Brennen.
# ----->Predictions Original
# Chad has sent Brennen a funny photo.
# Brennen does not find it very funny.
# **************************
# -------------------------
# ------>Predictions by Model
# Sadie needs to go to the dentist on Thursday after work.
# Chloe will lend Sad
# ----->Predictions Original
# Sadie will borrow Chloe's bike on Wednesday evening.
# She has a dentist appointment on Thursday after work.
# **************************
# -------------------------
# ------>Predictions by Model
# Olivia wants to launch a new restaurant in the city centre next month.
# Carter
# ----->Predictions Original
# Carter is launching a restaurant business next month.
# Olivia wants him to include a restaurant she's working for in the discount app.
# They will meet in person to discuss it.
# **************************
# -------------------------
# ------>Predictions by Model
# Kristine is back from surgery.
# She will come to the hospital on Guy's request
# ----->Predictions Original
# Kenny had a surgery, as Kristine reports.
# He will have another surgery tomorrow.
# Guy will come to St. Mark's Hospital near Asda to stay with Kristine.
# **************************
# -------------------------
# ------>Predictions by Model
# Joey cheated on Olivia with numerous girls and got a chick pregnant.
# Olivia is devastated
# ----->Predictions Original
# Skyler and Adam are surprised that Joey and Olivia broke up.
# **************************
# -------------------------
# ------>Predictions by Model
# Amanda went dancing classes with Michael yesterday.
# The instructor needed a partner to show the
# ----->Predictions Original
# Amanda goes to dancing classes with Michael.
# She volunteered to show the English Waltz steps with the instructor yesterday.
# Amanda is shy and goes to therapy.
# **************************
# -------------------------
# ------>Predictions by Model
# Taylor has a question.
# Isabel hasn't introduced Taylor's boyfriend to her yet.
# ----->Predictions Original
# Taylor wants to meet Isabel's boyfriend but she has never had any.
# **************************
# -------------------------
# ------>Predictions by Model
# Theo is leaving on Friday.
# Toby will come back by train on Monday.
# Toby
# ----->Predictions Original
# Theo's going to stay near Torino in the region of Italian Alpes.
# Toby wants to join the trip.
# Theo agrees and will pick Toby up on Friday at 7 am.
# **************************
# -------------------------
# ------>Predictions by Model
# Brandon will be late.
# Phil will prepare a report on the absenteeism and lateness
# ----->Predictions Original
# Brandon is late again.
# Clara will prepare a report on the absenteeism and lateness for Phil by Friday.
# **************************
# -------------------------
# ------>Predictions by Model
# Suzie is sick again.
# She cancelled last time because she didn't want to catch
# ----->Predictions Original
# Olga and Suzie will postpone their meeting due to Suzie's sickness.
# **************************
# -------------------------
# ------>Predictions by Model
# Kate will be Diane's daughter Lorelai's mother.
# ----->Predictions Original
# Diane is pregnant and can't wait to give birth, she thinks the waiting is the worst.
# Kate thinks she'll be an amazing mother.
# **************************
# -------------------------
# ------>Predictions by Model
# Andrew had to call in sick because he has a cold.
# Daniel will drop by after
# ----->Predictions Original
# Andrew has a cold.
# Daniel will buy him some medication.
# **************************
# -------------------------
# ------>Predictions by Model
# Alex and Sam are watching 'Millionaires' on tv.
# Sam has a chance
# ----->Predictions Original
# Alex and Sam are watching Millionaires.
# **************************
# -------------------------
# ------>Predictions by Model
# Jessica has the cinnamon cookies recipe.
# Angelica has it.
# ----->Predictions Original
# Angelica sent the cinnamon cookies recipe at Kelly's request.
# **************************
# -------------------------
# ------>Predictions by Model
# Sophie is waiting for a client.
# She will meet with Gwen in 5
# ----->Predictions Original
# Sophie is waiting for a client, who is late.
# She will meet Gwen later.
# **************************
# -------------------------
# ------>Predictions by Model
# Daniel will meet Sue downstairs in a few minutes.
# ----->Predictions Original
# Daniel is with the Volvo on his way and will be there soon.
# Sue is going downstairs to meet him.
# **************************
# -------------------------
# ------>Predictions by Model
# Betty is going to CVS to buy some salmon for George.
# ----->Predictions Original
# George is making salmon and stuffed squash for dinner.
# Betty will buy a shaving cream at CVS at his request,
# **************************
# -------------------------
# ------>Predictions by Model
# Ken's phone doesn't work properly.
# Ken's friend had a similar issue with her
# ----->Predictions Original
# Ken has installed an app for running but it is not working properly on his phone.
# **************************
# -------------------------
# ------>Predictions by Model
# Ann couldn't come to Ivan's birthday party.
# Ivan bought her something for her birthday
# ----->Predictions Original
# Ivan and Ann will meet next week.
# **************************
# -------------------------
# ------>Predictions by Model
# Ashley has some important stuff to do on Facebook.
# Rowan doesn't see Ashley
# ----->Predictions Original
# Ashley posted some nude photos on her fb page.
# **************************
# -------------------------
# ------>Predictions by Model
# Mikolaj got a breakthrough with his wife's papers.
# Magda doesn't
# ----->Predictions Original
# Mikolaj's wife needs a work permit as a foreigner.
# Government officials missed the deadline for sending it and will need another month.
# **************************
# -------------------------
# ------>Predictions by Model
# Maria is on her way to the hotel.
# Ann and Thomas will have lunch together.
# ----->Predictions Original
# Thomas, Ann and Maria will have lunch together at the hotel.
# Ann is already in the 3rd floor lobby at the red table.
# **************************
# -------------------------
# ------>Predictions by Model
# Sus doesn't want to work.
# ----->Predictions Original
# Sus and Val don't want to work and are sleepy.
# **************************
# -------------------------
# ------>Predictions by Model
# Kate, Terry and Kai are going to the Museum of the City of NY.
# Kate
# ----->Predictions Original
# Kate is at the Guggenheim Museum now, but will be in the Museum of the City of New York around 2-2:30.
# Kai may join her.
# Ish won't.
# Terry will join them for a coffee after they finish visiting the museum.
# Terry has already seen the museum.
# **************************
# -------------------------
# ------>Predictions by Model
# Cathy left her sunglasses at Brooke's house.
# She will come round at 10 tonight
# ----->Predictions Original
# Cathy left her sunglasses at Broke's house.
# She will come collect them at 10.
# **************************
# -------------------------
# ------>Predictions by Model
# Frederica will come to Bradley's birthday party tomorrow at 8 pm.
# ----->Predictions Original
# Bradley will come to Frederica's birthday party tomorrow at 8pm.
# **************************
# -------------------------
# ------>Predictions by Model
# Camilla hasn't received the money yet.
# It usually takes around two days to arrive
# ----->Predictions Original
# Camilla still hasn't received the 250.
# She will check and let Adrian know.
# Money usually takes around two days to arrive.
# **************************
# Saving model checkpoint to test-tokenbatch6/checkpoint-4000
# Configuration saved in test-tokenbatch6/checkpoint-4000/config.json
# Model weights saved in test-tokenbatch6/checkpoint-4000/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-4000/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-4000/special_tokens_map.json
# Saving model checkpoint to test-tokenbatch6/checkpoint-4500
# Configuration saved in test-tokenbatch6/checkpoint-4500/config.json
# Model weights saved in test-tokenbatch6/checkpoint-4500/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-4500/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-4500/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 818
#   Batch size = 6
# -------------------------
# ------>Predictions by Model
# A will take her son to the animal shelter tomorrow afternoon.
# He wants to get a
# ----->Predictions Original
# A will go to the animal shelter tomorrow to get a puppy for her son.
# They already visited the shelter last Monday and the son chose the puppy.
# **************************
# -------------------------
# ------>Predictions by Model
# Emma wants to make an advent calendar for her kids.
# Rob and Lauren like the
# ----->Predictions Original
# Emma and Rob love the advent calendar.
# Lauren fits inside calendar various items, for instance, small toys and Christmas decorations.
# Her children are excited whenever they get the calendar.
# **************************
# -------------------------
# ------>Predictions by Model
# Madison is pregnant.
# She doesn't want to talk about it because she's worried about
# ----->Predictions Original
# Madison is pregnant but she doesn't want to talk about it.
# Patricia Stevens got married and she thought she was pregnant.
# **************************
# -------------------------
# ------>Predictions by Model
# Marla found a box of boxers under Kiki's bed.
# She's 13
# ----->Predictions Original
# Marla found a pair of boxers under her bed.
# **************************
# -------------------------
# ------>Predictions by Model
# Robert needs to buy guitar cable.
# Fred gives him the address of the music shop.
# ----->Predictions Original
# Robert wants Fred to send him the address of the music shop as he needs to buy guitar cable.
# **************************
# -------------------------
# ------>Predictions by Model
# Keith and Megan have run out of milk and cereals.
# Megan will check in the
# ----->Predictions Original
# Megan needn't buy milk and cereals.
# They're in the drawer next to the fridge.
# **************************
# -------------------------
# ------>Predictions by Model
# ...
# Kai may join her.
# Ish won't.
# Terry will join them for a coffee after they finish visiting the museum.
# Terry has already seen the museum.
# **************************
# -------------------------
# ------>Predictions by Model
# Cathy left her sunglasses at Brooke's house.
# She might come round at 10 tonight
# ----->Predictions Original
# Cathy left her sunglasses at Broke's house.
# She will come collect them at 10.
# **************************
# -------------------------
# ------>Predictions by Model
# Frederica will come to Bradley's birthday party tomorrow at 8 pm.
# ----->Predictions Original
# Bradley will come to Frederica's birthday party tomorrow at 8pm.
# **************************
# -------------------------
# ------>Predictions by Model
# Camilla received the money.
# It usually takes around two days to arrive.
# ----->Predictions Original
# Camilla still hasn't received the 250.
# She will check and let Adrian know.
# Money usually takes around two days to arrive.
# **************************
# Saving model checkpoint to test-tokenbatch6/checkpoint-5000
# Configuration saved in test-tokenbatch6/checkpoint-5000/config.json
# Model weights saved in test-tokenbatch6/checkpoint-5000/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-5000/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-5000/special_tokens_map.json
# Saving model checkpoint to test-tokenbatch6/checkpoint-5500
# Configuration saved in test-tokenbatch6/checkpoint-5500/config.json
# Model weights saved in test-tokenbatch6/checkpoint-5500/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-5500/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-5500/special_tokens_map.json
# Saving model checkpoint to test-tokenbatch6/checkpoint-6000
# Configuration saved in test-tokenbatch6/checkpoint-6000/config.json
# Model weights saved in test-tokenbatch6/checkpoint-6000/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-6000/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-6000/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 818
#   Batch size = 6
# -------------------------
# ------>Predictions by Model
# A will take her son to the animal shelter tomorrow afternoon.
# A wants to get a
# ----->Predictions Original
# A will go to the animal shelter tomorrow to get a puppy for her son.
# They already visited the shelter last Monday and the son chose the puppy.
# **************************
# -------------------------
# ------>Predictions by Model
# Emma wants to buy an advent calendar for her kids.
# Rob likes the idea.
# ----->Predictions Original
# Emma and Rob love the advent calendar.
# Lauren fits inside calendar various items, for instance, small toys and Christmas decorations.
# Her children are excited whenever they get the calendar.
# **************************
# -------------------------
# ------>Predictions by Model
# Madison is pregnant.
# She doesn't want to talk about it because people get excited and
# ----->Predictions Original
# Madison is pregnant but she doesn't want to talk about it.
# Patricia Stevens got married and she thought she was pregnant.
# **************************
# -------------------------
# ------>Predictions by Model
# Marla found a box of boxers under her bed.
# ----->Predictions Original
# Marla found a pair of boxers under her bed.
# **************************
# -------------------------
# ------>Predictions by Model
# Robert needs to buy guitar cable.
# Fred gives him the address of the music shop Fred
# ----->Predictions Original
# Robert wants Fred to send him the address of the music shop as he needs to buy guitar cable.
# **************************
# -------------------------
# ------>Predictions by Model
# Keith will check in the drawer next to the fridge to buy some milk and cereals
# ----->Predictions Original
# Megan needn't buy milk and cereals.
# They're in the drawer next to the fridge.
# **************************
# -------------------------
# ------>Predictions by Model
# Samantha sends Evelyn and Holly a video of herself making noise.
# ----->Predictions Original
# Samantha and Evelyn after watching the video cannot believe she is able to make that noise.
# **************************
# -------------------------
# ------>Predictions by Model
# Theresa, Luis and Marion went to Tom's new place for a dinner.
# They
# ----->Predictions Original
# Tom's new place is in Fiesole.
# Luis and Marion has been there.
# **************************
# -------------------------
# ------>Predictions by Model
# Jane will make a reservation for 6 people tonight around 20:00.
# There is no
# ----->Predictions Original
# Jane made a 9 PM reservation for 6 people tonight at Vegano Resto.
# **************************
# -------------------------
# ------>Predictions by Model
# Nancy is coming home in 6 weeks.
# She's having a hard time with her
# ----->Predictions Original
# Nancy's working in Texas, but the kids laugh at her Welsh accent.
# She's coming home in 6 weeks.
# Earlier than that she's going to travel with 3 other Brits.
# **************************
# -------------------------
# ------>Predictions by Model
# Laura needs a new printer.
# Jamie will buy a second hand printer.
# ----->Predictions Original
# Laura is going to buy a printer.
# **************************
# -------------------------
# ------>Predictions by Model
# Barbara is in the dairy section.
# She bought coconut milk and eggs.
# ----->Predictions Original
# Haylee can't find the coconut milk yoghurt.
# **************************
# -------------------------
# ------>Predictions by Model
# Norbert and Wendy are going to catch the tour.
# Wendy is already at the register
# ----->Predictions Original
# Wendy is shopping, but she needs to hurry up to catch the tour.
# **************************
# -------------------------
# ------>Predictions by Model
# Cecil went to the Jandia Peninsula.
# Cecil wants to explore more the
# ----->Predictions Original
# Cecil, Cheryl and Peter went to the Jandia Peninsula today.
# Cecil would like to explore the south of the island tomorrow, but they will decide what to do after dinner.
# **************************
# -------------------------
# ------>Predictions by Model
# Sophie has checked pockets and handbags twice already.
# ----->Predictions Original
# Sophie still hasn't found it despite checking pockets and handbags twice.
# **************************
# -------------------------
# ------>Predictions by Model
# Rosie has to write an essay about bad movies.
# She will also cover "The
# ----->Predictions Original
# Dennis and Elle are helping Rosie think of bad movies for her essay.
# **************************
# -------------------------
# ------>Predictions by Model
# James wants to become a voice actor.
# His mother liked his voice.
# James wants to
# ----->Predictions Original
# James has a dream of becoming a voice actor.
# He considers making a home radio station.
# **************************
# -------------------------
# ------>Predictions by Model
# Poppy and Alice are going for drinks after work at Nick's at 5:30
# ----->Predictions Original
# Poppy and Alice are meeting for drinks after work at Nick's at 5:30.
# Alice fancies Fred, she will invite him and a bunch of other coworkers.
# **************************
# -------------------------
# ------>Predictions by Model
# Sash and Caron will meet before 12.
# Caron is out from 12.
# ----->Predictions Original
# Sash needs to see Caron who'll be out from 12.
# **************************
# -------------------------
# ------>Predictions by Model
# Matteo's girlfriend Gosia criticizes him because he likes football and video games
# ----->Predictions Original
# Matteo is not sure about his relationship with Gosia but likes her a lot.
# **************************
# -------------------------
# ------>Predictions by Model
# Mom is calling for supper.
# ----->Predictions Original
# Ramzi and Jannette are going for supper.
# **************************
# -------------------------
# ------>Predictions by Model
# Jeniffer, Alois and Hildegard are preparing ravioli.
# ----->Predictions Original
# Jeniffer is preparing ravioli following her grandmothers recipe.
# **************************
# -------------------------
# ------>Predictions by Model
# Lawrence will get back to Madison once he is through with the article.
# ----->Predictions Original
# Lawrence will finish writing the article soon.
# **************************
# -------------------------
# ------>Predictions by Model
# Chad sent Brennen a funny photo.
# ----->Predictions Original
# Chad has sent Brennen a funny photo.
# Brennen does not find it very funny.
# **************************
# -------------------------
# ------>Predictions by Model
# Sadie needs to go to the dentist on Thursday after work.
# Chloe will borrow Sad
# ----->Predictions Original
# Sadie will borrow Chloe's bike on Wednesday evening.
# She has a dentist appointment on Thursday after work.
# **************************
# -------------------------
# ------>Predictions by Model
# Olivia is planning to launch a new restaurant in the city centre next month.
# ----->Predictions Original
# Carter is launching a restaurant business next month.
# Olivia wants him to include a restaurant she's working for in the discount app.
# They will meet in person to discuss it.
# **************************
# -------------------------
# ------>Predictions by Model
# Kristine's boyfriend Kenny is back from surgery.
# He has another surgery scheduled tomorrow.
# ----->Predictions Original
# Kenny had a surgery, as Kristine reports.
# He will have another surgery tomorrow.
# Guy will come to St. Mark's Hospital near Asda to stay with Kristine.
# **************************
# -------------------------
# ------>Predictions by Model
# Joey and Olivia broke up 2 days ago.
# Joey cheated on Olivia with numerous girls
# ----->Predictions Original
# Skyler and Adam are surprised that Joey and Olivia broke up.
# **************************
# -------------------------
# ------>Predictions by Model
# Amanda went dancing classes with Michael yesterday.
# The instructor needed a partner to show the
# ----->Predictions Original
# Amanda goes to dancing classes with Michael.
# She volunteered to show the English Waltz steps with the instructor yesterday.
# Amanda is shy and goes to therapy.
# **************************
# -------------------------
# ------>Predictions by Model
# Taylor's friends' daughters bring their bf to Taylor.
# Isabel hasn't had any
# ----->Predictions Original
# Taylor wants to meet Isabel's boyfriend but she has never had any.
# **************************
# -------------------------
# ------>Predictions by Model
# Theo and Toby are leaving on Friday.
# Toby will come back by train on Monday
# ----->Predictions Original
# Theo's going to stay near Torino in the region of Italian Alpes.
# Toby wants to join the trip.
# Theo agrees and will pick Toby up on Friday at 7 am.
# **************************
# -------------------------
# ------>Predictions by Model
# Brandon will be late.
# Phil will prepare a report on the absenteeism and lateness
# ----->Predictions Original
# Brandon is late again.
# Clara will prepare a report on the absenteeism and lateness for Phil by Friday.
# **************************
# -------------------------
# ------>Predictions by Model
# Suzie is sick again and wants to cancel.
# Olga agrees to reschedule
# ----->Predictions Original
# Olga and Suzie will postpone their meeting due to Suzie's sickness.
# **************************
# -------------------------
# ------>Predictions by Model
# Kate will be Diane's daughter Lorelai's mother.
# ----->Predictions Original
# Diane is pregnant and can't wait to give birth, she thinks the waiting is the worst.
# Kate thinks she'll be an amazing mother.
# **************************
# -------------------------
# ------>Predictions by Model
# Andrew had to call in sick because he has a cold.
# Daniel will drop by after
# ----->Predictions Original
# Andrew has a cold.
# Daniel will buy him some medication.
# **************************
# -------------------------
# ------>Predictions by Model
# Alex is watching 'Millionaires' on tv.
# Sam has a chance to win
# ----->Predictions Original
# Alex and Sam are watching Millionaires.
# **************************
# -------------------------
# ------>Predictions by Model
# Jessica has the cinnamon cookies recipe.
# Angelica has it.
# ----->Predictions Original
# Angelica sent the cinnamon cookies recipe at Kelly's request.
# **************************
# -------------------------
# ------>Predictions by Model
# Sophie is waiting for a client.
# Gwen and Dee will meet at the
# ----->Predictions Original
# Sophie is waiting for a client, who is late.
# She will meet Gwen later.
# **************************
# -------------------------
# ------>Predictions by Model
# Daniel is coming downstairs.
# Sue is with the Volvo.
# ----->Predictions Original
# Daniel is with the Volvo on his way and will be there soon.
# Sue is going downstairs to meet him.
# **************************
# -------------------------
# ------>Predictions by Model
# Betty is going to CVS to buy some salmon and some squash for George.
# ----->Predictions Original
# George is making salmon and stuffed squash for dinner.
# Betty will buy a shaving cream at CVS at his request,
# **************************
# -------------------------
# ------>Predictions by Model
# Ken's phone doesn't work properly.
# Ken's friend had a similar issue with her
# ----->Predictions Original
# Ken has installed an app for running but it is not working properly on his phone.
# **************************
# -------------------------
# ------>Predictions by Model
# Ann couldn't come to Ivan's birthday party.
# Ivan bought her something for her birthday
# ----->Predictions Original
# Ivan and Ann will meet next week.
# **************************
# -------------------------
# ------>Predictions by Model
# Ashley posted nude pictures on her Facebook page.
# Rowan has more important things to
# ----->Predictions Original
# Ashley posted some nude photos on her fb page.
# **************************
# -------------------------
# ------>Predictions by Model
# Mikolaj got a breakthrough with his wife's papers.
# Magda doesn't
# ----->Predictions Original
# Mikolaj's wife needs a work permit as a foreigner.
# Government officials missed the deadline for sending it and will need another month.
# **************************
# -------------------------
# ------>Predictions by Model
# Maria, Ann and Peter are going to the hotel.
# They will have lunch together.
# ----->Predictions Original
# Thomas, Ann and Maria will have lunch together at the hotel.
# Ann is already in the 3rd floor lobby at the red table.
# **************************
# -------------------------
# ------>Predictions by Model
# Sus and Val don't want to work.
# ----->Predictions Original
# Sus and Val don't want to work and are sleepy.
# **************************
# -------------------------
# ------>Predictions by Model
# Kate, Terry and Kai are going to the Museum of the City of NY.
# They
# ----->Predictions Original
# Kate is at the Guggenheim Museum now, but will be in the Museum of the City of New York around 2-2:30.
# Kai may join her.
# Ish won't.
# Terry will join them for a coffee after they finish visiting the museum.
# Terry has already seen the museum.
# **************************
# -------------------------
# ------>Predictions by Model
# Cathy left her sunglasses at Brooke's house.
# She will come round at 10 tonight
# ----->Predictions Original
# Cathy left her sunglasses at Broke's house.
# She will come collect them at 10.
# **************************
# -------------------------
# ------>Predictions by Model
# Frederica will come to Bradley's birthday party tomorrow at 8 pm.
# ----->Predictions Original
# Bradley will come to Frederica's birthday party tomorrow at 8pm.
# **************************
# -------------------------
# ------>Predictions by Model
# Camilla received the money.
# It usually takes around two days to arrive.
# ----->Predictions Original
# Camilla still hasn't received the 250.
# She will check and let Adrian know.
# Money usually takes around two days to arrive.
# **************************
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=6135, training_loss=57.83391118675301, metrics={'train_runtime': 8371.5747, 'train_samples_per_second': 8.798, 'train_steps_per_second': 0.733, 'total_flos': 1.408779533371392e+16, 'train_loss': 57.83391118675301, 'epoch': 5.0})

# %%
trainer.train() #10 token
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 14730
#   Num Epochs = 5
#   Instantaneous batch size per device = 6
#   Total train batch size (w. parallel, distributed & accumulation) = 12
#   Gradient Accumulation steps = 2
#   Total optimization steps = 6135
#   Number of trainable parameters = 139420416
#     <div>
#
#       <progress value='6135' max='6135' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [6135/6135 2:14:45, Epoch 4/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>710.541700</td>
#       <td>1068.385864</td>
#       <td>39.249500</td>
#       <td>15.360700</td>
#       <td>31.546900</td>
#       <td>35.186000</td>
#       <td>16.819100</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>321.475500</td>
#       <td>434.005768</td>
#       <td>45.161300</td>
#       <td>21.647800</td>
#       <td>37.081200</td>
#       <td>41.469600</td>
#       <td>18.347200</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>56.166400</td>
#       <td>693.369019</td>
#       <td>45.928600</td>
#       <td>22.140500</td>
#       <td>38.291100</td>
#       <td>41.976200</td>
#       <td>17.640600</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>351.446400</td>
#       <td>269.512085</td>
#       <td>45.838300</td>
#       <td>22.310400</td>
#       <td>38.279600</td>
#       <td>41.980100</td>
#       <td>17.732300</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>839.307700</td>
#       <td>437.032196</td>
#       <td>46.397700</td>
#       <td>22.792600</td>
#       <td>38.773400</td>
#       <td>42.566600</td>
#       <td>17.678500</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to test-tokenbatch6/checkpoint-500
# Configuration saved in test-tokenbatch6/checkpoint-500/config.json
# Model weights saved in test-tokenbatch6/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-500/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-500/special_tokens_map.json
# Saving model checkpoint to test-tokenbatch6/checkpoint-1000
# Configuration saved in test-tokenbatch6/checkpoint-1000/config.json
# Model weights saved in test-tokenbatch6/checkpoint-1000/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-1000/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 818
#   Batch size = 6
#     <div>
#
#       <progress value='274' max='137' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [137/137 28:58]
#     </div>
# -------------------------
# ------>Predictions by Model
# A will get a puppy for her son tomorrow.
# ----->Predictions Original
# A will go to the animal shelter tomorrow to get a puppy for her son.
# They already visited the shelter last Monday and the son chose the puppy.
# **************************
# -------------------------
# ------>Predictions by Model
# Emma wants Rob to buy an advent calendar for Christmas for her and Lauren.
# They
# ----->Predictions Original
# Emma and Rob love the advent calendar.
# Lauren fits inside calendar various items, for instance, small toys and Christmas decorations.
# Her children are excited whenever they get the calendar.
# **************************
# -------------------------
# ------>Predictions by Model
# Jackie is pregnant and wants to have an abortion.
# ----->Predictions Original
# Madison is pregnant but she doesn't want to talk about it.
# Patricia Stevens got married and she thought she was pregnant.
# **************************
# -------------------------
# ------>Predictions by Model
# Marla and Tamara had fun in their room while they were gone.
# ----->Predictions Original
# Marla found a pair of boxers under her bed.
# **************************
# -------------------------
# ------>Predictions by Model
# Robert needs Fred's help with guitar cable.
# ----->Predictions Original
# Robert wants Fred to send him the address of the music shop as he needs to buy guitar cable.
# **************************
# -------------------------
# ------>Predictions by Model
# Keith needs Megan's help with milk and cereals.
# ----->Predictions Original
# Megan needn't buy milk and cereals.
# They're in the drawer next to the fridge.
# **************************
# -------------------------
# ------>Predictions by Model
# Samantha sent Holly a video of Samuelatha sending her the video.
# ----->Predictions Original
# Samantha and Evelyn after watching the video cannot believe she is able to make that noise.
# **************************
# -------------------------
# ------>Predictions by Model
# Marion invited Tom and Marion for dinner.
# ----->Predictions Original
# Tom's new place is in Fiesole.
# Luis and Marion has been there.
# **************************
# -------------------------
# ------>Predictions by Model
# Jane is making a reservation for 6 people tonight.
# She is afraid that there is no
# ----->Predictions Original
# Jane made a 9 PM reservation for 6 people tonight at Vegano Resto.
# **************************
# -------------------------
# ------>Predictions by Model
# Nancy and Tina are meeting in the pub in 6 weeks.
# Tina has never met
# ----->Predictions Original
# Nancy's working in Texas, but the kids laugh at her Welsh accent.
# She's coming home in 6 weeks.
# Earlier than that she's going to travel with 3 other Brits.
# **************************
# -------------------------
# ------>Predictions by Model
# Laura needs a new printer.
# Jamie suggests buying a second hand one.
# ----->Predictions Original
# Laura is going to buy a printer.
# **************************
# -------------------------
# ------>Predictions by Model
# Haylee is in dairy section.
# She asked Barbara to buy coconut milk for her.
# ----->Predictions Original
# Haylee can't find the coconut milk yoghurt.
# **************************
# -------------------------
# ------>Predictions by Model
# Wendy is buying something for the tour.
# ----->Predictions Original
# Wendy is shopping, but she needs to hurry up to catch the tour.
# **************************
# -------------------------
# ------>Predictions by Model
# Cheryl and Cecil want to explore the Jandia Peninsula, which is south
# ----->Predictions Original
# Cecil, Cheryl and Peter went to the Jandia Peninsula today.
# Cecil would like to explore the south of the island tomorrow, but they will decide what to do after dinner.
# **************************
# -------------------------
# ------>Predictions by Model
# Sophie checked them twice already.
# ----->Predictions Original
# Sophie still hasn't found it despite checking pockets and handbags twice.
# **************************
# -------------------------
# ------>Predictions by Model
# Rosie is looking for a new b-movie.
# Dennis recommends Troma Studio for
# ----->Predictions Original
# Dennis and Elle are helping Rosie think of bad movies for her essay.
# **************************
# -------------------------
# ------>Predictions by Model
# James has a voice actor in a cartoon or video game.
# He has a microphone at
# ----->Predictions Original
# James has a dream of becoming a voice actor.
# He considers making a home radio station.
# **************************
# -------------------------
# ------>Predictions by Model
# Alice and Poppy are going to meet at Nick's for drinks.
# Poppy is
# ----->Predictions Original
# Poppy and Alice are meeting for drinks after work at Nick's at 5:30.
# Alice fancies Fred, she will invite him and a bunch of other coworkers.
# **************************
# -------------------------
# ------>Predictions by Model
# Caron is out from 12.
# ----->Predictions Original
# Sash needs to see Caron who'll be out from 12.
# **************************
# -------------------------
# ------>Predictions by Model
# Matteo criticizes football and video games because they criticizes each other.
# ----->Predictions Original
# Matteo is not sure about his relationship with Gosia but likes her a lot.
# **************************
# -------------------------
# ------>Predictions by Model
# Jannette is coming to Ramzi for supper.
# ----->Predictions Original
# Ramzi and Jannette are going for supper.
# **************************
# -------------------------
# ------>Predictions by Model
# Jeniffer is preparing a ravioli recipe for her grandmother.
# ----->Predictions Original
# Jeniffer is preparing ravioli following her grandmothers recipe.
# **************************
# -------------------------
# ------>Predictions by Model
# Lawrence will get back to Madison once Lawrence is through.
# ----->Predictions Original
# Lawrence will finish writing the article soon.
# **************************
# -------------------------
# ------>Predictions by Model
# Brennen is not funny.
# Chad sent Brennen a photo of him.
# ----->Predictions Original
# Chad has sent Brennen a funny photo.
# Brennen does not find it very funny.
# **************************
# -------------------------
# ------>Predictions by Model
# Chloe will pick Sadie up from the dentist.
# ----->Predictions Original
# Sadie will borrow Chloe's bike on Wednesday evening.
# She has a dentist appointment on Thursday after work.
# **************************
# -------------------------
# ------>Predictions by Model
# Olivia is looking for a new restaurant in the city centre next month.
# Carter
# ----->Predictions Original
# Carter is launching a restaurant business next month.
# Olivia wants him to include a restaurant she's working for in the discount app.
# They will meet in person to discuss it.
# **************************
# -------------------------
# ------>Predictions by Model
# Kristine is back from surgery.
# She has another surgery scheduled tomorrow.
# Kristine is
# ----->Predictions Original
# Kenny had a surgery, as Kristine reports.
# He will have another surgery tomorrow.
# Guy will come to St. Mark's Hospital near Asda to stay with Kristine.
# **************************
# -------------------------
# ------>Predictions by Model
# Skyler cheated on Olivia with Joey.
# ----->Predictions Original
# Skyler and Adam are surprised that Joey and Olivia broke up.
# **************************
# -------------------------
# ------>Predictions by Model
# Amanda needs to show her dancing classes to Chris, because she needs a partner.
# ----->Predictions Original
# Amanda goes to dancing classes with Michael.
# She volunteered to show the English Waltz steps with the instructor yesterday.
# Amanda is shy and goes to therapy.
# **************************
# -------------------------
# ------>Predictions by Model
# Taylor wants Isabel to introduce her to her boyfriend, but Isabel hasn't had any.
# ----->Predictions Original
# Taylor wants to meet Isabel's boyfriend but she has never had any.
# **************************
# -------------------------
# ------>Predictions by Model
# Theo and Toby will meet on Friday at Torino.
# Theo will write Toby
# ----->Predictions Original
# Theo's going to stay near Torino in the region of Italian Alpes.
# Toby wants to join the trip.
# Theo agrees and will pick Toby up on Friday at 7 am.
# **************************
# -------------------------
# ------>Predictions by Model
# Clara is waiting for Brandon in Brandon's office.
# ----->Predictions Original
# Brandon is late again.
# Clara will prepare a report on the absenteeism and lateness for Phil by Friday.
# **************************
# -------------------------
# ------>Predictions by Model
# Suzie is sick.
# Olga will reschedule her meeting with Suzie.
# ----->Predictions Original
# Olga and Suzie will postpone their meeting due to Suzie's sickness.
# **************************
# -------------------------
# ------>Predictions by Model
# Kate is pregnant with Lorelai.
# Diane is waiting for her.
# ----->Predictions Original
# Diane is pregnant and can't wait to give birth, she thinks the waiting is the worst.
# Kate thinks she'll be an amazing mother.
# **************************
# -------------------------
# ------>Predictions by Model
# Daniel will pick Andrew up from pharmacy after work.
# ----->Predictions Original
# Andrew has a cold.
# Daniel will buy him some medication.
# **************************
# -------------------------
# ------>Predictions by Model
# John, Alex and Sam are going to meet tomorrow.
# ----->Predictions Original
# Alex and Sam are watching Millionaires.
# **************************
# -------------------------
# ------>Predictions by Model
# Kelly sent Angelica the recipe for cinnamon cookies.
# ----->Predictions Original
# Angelica sent the cinnamon cookies recipe at Kelly's request.
# **************************
# -------------------------
# ------>Predictions by Model
# Sophie is waiting for a client at the restaurant.
# ----->Predictions Original
# Sophie is waiting for a client, who is late.
# She will meet Gwen later.
# **************************
# -------------------------
# ------>Predictions by Model
# Sue is going downstairs to buy a Volvo.
# Daniel is on his way.
# ----->Predictions Original
# Daniel is with the Volvo on his way and will be there soon.
# Sue is going downstairs to meet him.
# **************************
# -------------------------
# ------>Predictions by Model
# George will buy some squash for Betty.
# ----->Predictions Original
# George is making salmon and stuffed squash for dinner.
# Betty will buy a shaving cream at CVS at his request,
# **************************
# -------------------------
# ------>Predictions by Model
# Ken needs Martha's help with the battery and processor.
# Martha has a problem with her
# ----->Predictions Original
# Ken has installed an app for running but it is not working properly on his phone.
# **************************
# -------------------------
# ------>Predictions by Model
# Ann can't come to Ivan's birthday party because Ivan couldn't come next week.
# ----->Predictions Original
# Ivan and Ann will meet next week.
# **************************
# -------------------------
# ------>Predictions by Model
# Rowan has some important stuff to do.
# Ashley posted Ashley's photos on Facebook.
# ----->Predictions Original
# Ashley posted some nude photos on her fb page.
# **************************
# -------------------------
# ------>Predictions by Model
# Mikolaj needs to send Magda the deadline until last week because the government
# ----->Predictions Original
# Mikolaj's wife needs a work permit as a foreigner.
# Government officials missed the deadline for sending it and will need another month.
# **************************
# -------------------------
# ------>Predictions by Model
# Ann is in the lobby and there are some people hanging around at the lobby.
# She
# ----->Predictions Original
# Thomas, Ann and Maria will have lunch together at the hotel.
# Ann is already in the 3rd floor lobby at the red table.
# **************************
# -------------------------
# ------>Predictions by Model
# Sus is tired of working.
# ----->Predictions Original
# Sus and Val don't want to work and are sleepy.
# **************************
# -------------------------
# ------>Predictions by Model
# Kate and Kai are going to the Museum of the Guggenheim in 2-
# ----->Predictions Original
# Kate is at the Guggenheim Museum now, but will be in the Museum of the City of New York around 2-2:30.
# Kai may join her.
# Ish won't.
# Terry will join them for a coffee after they finish visiting the museum.
# Terry has already seen the museum.
# **************************
# -------------------------
# ------>Predictions by Model
# Broke is waiting for Cathy to pick her sunglasses up.
# ----->Predictions Original
# Cathy left her sunglasses at Broke's house.
# She will come collect them at 10.
# **************************
# -------------------------
# ------>Predictions by Model
# Frederica and Bradley are having a birthday party tomorrow.
# They will meet tomorrow.
# ----->Predictions Original
# Bradley will come to Frederica's birthday party tomorrow at 8pm.
# **************************
# -------------------------
# ------>Predictions by Model
# Camilla will check the money in two days.
# ----->Predictions Original
# Camilla still hasn't received the 250.
# She will check and let Adrian know.
# Money usually takes around two days to arrive.
# **************************
# Saving model checkpoint to test-tokenbatch6/checkpoint-1500
# Configuration saved in test-tokenbatch6/checkpoint-1500/config.json
# Model weights saved in test-tokenbatch6/checkpoint-1500/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-1500/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-1500/special_tokens_map.json
# Saving model checkpoint to test-tokenbatch6/checkpoint-2000
# Configuration saved in test-tokenbatch6/checkpoint-2000/config.json
# Model weights saved in test-tokenbatch6/checkpoint-2000/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-2000/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 818
#   Batch size = 6
# -------------------------
# ------>Predictions by Model
# A wants to buy a puppy for her son.
# She will take him to the animal
# ----->Predictions Original
# A will go to the animal shelter tomorrow to get a puppy for her son.
# They already visited the shelter last Monday and the son chose the puppy.
# **************************
# -------------------------
# ------>Predictions by Model
# Emma wants to buy an advent calendar for her kids.
# Rob is going to buy
# ----->Predictions Original
# Emma and Rob love the advent calendar.
# Lauren fits inside calendar various items, for instance, small toys and Christmas decorations.
# Her children are excited whenever they get the calendar.
# **************************
# -------------------------
# ------>Predictions by Model
# Jackie is pregnant.
# She doesn't want to talk about it because she's afraid
# ----->Predictions Original
# Madison is pregnant but she doesn't want to talk about it.
# Patricia Stevens got married and she thought she was pregnant.
# **************************
# -------------------------
# ------>Predictions by Model
# Marla found a box of boxers under her bed.
# Marla is going to
# ----->Predictions Original
# Marla found a pair of boxers under her bed.
# **************************
# -------------------------
# ------>Predictions by Model
# Robert needs to buy guitar cable.
# Fred recommends google maps.
# ----->Predictions Original
# Robert wants Fred to send him the address of the music shop as he needs to buy guitar cable.
# **************************
# -------------------------
# ------>Predictions by Model
# Keith has run out of milk and cereals.
# Megan will check in the drawer next
# ----->Predictions Original
# Megan needn't buy milk and cereals.
# They're in the drawer next to the fridge.
# **************************
# -------------------------
# ------>Predictions by Model
# Samatha shares a video with Holly.
# ----->Predictions Original
# Samantha and Evelyn after watching the video cannot believe she is able to make that noise.
# **************************
# -------------------------
# ------>Predictions by Model
# Theresa invited Luis and Marion for dinner at Tom's new place.
# ----->Predictions Original
# Tom's new place is in Fiesole.
# Luis and Marion has been there.
# **************************
# -------------------------
# ------>Predictions by Model
# Jane will make a reservation for 6 people tonight around 20:00.
# Vegano Rest
# ----->Predictions Original
# Jane made a 9 PM reservation for 6 people tonight at Vegano Resto.
# **************************
# -------------------------
# ------>Predictions by Model
# Nancy is coming home in 6 weeks.
# Nina and Tina are going to the pub
# ----->Predictions Original
# Nancy's working in Texas, but the kids laugh at her Welsh accent.
# She's coming home in 6 weeks.
# Earlier than that she's going to travel with 3 other Brits.
# **************************
# -------------------------
# ------>Predictions by Model
# Laura needs a new printer.
# Jamie will buy a second hand one.
# ----->Predictions Original
# Laura is going to buy a printer.
# **************************
# -------------------------
# ------>Predictions by Model
# Haylee is in dairy section.
# Barbara bought coconut milk and eggs.
# ----->Predictions Original
# Haylee can't find the coconut milk yoghurt.
# **************************
# -------------------------
# ------>Predictions by Model
# Wendy is buying something for the tour.
# She missed the last one because of
# ----->Predictions Original
# Wendy is shopping, but she needs to hurry up to catch the tour.
# **************************
# -------------------------
# ------>Predictions by Model
# Cheryl and Cecil are going to the Jandia Peninsula tomorrow.
# They will
# ----->Predictions Original
# Cecil, Cheryl and Peter went to the Jandia Peninsula today.
# Cecil would like to explore the south of the island tomorrow, but they will decide what to do after dinner.
# **************************
# -------------------------
# ------>Predictions by Model
# Nickola has found Sophie's pockets and handbags.
# ----->Predictions Original
# Sophie still hasn't found it despite checking pockets and handbags twice.
# **************************
# -------------------------
# ------>Predictions by Model
# Rosie wants to write an essay about the film "The Room".
# She will also
# ----->Predictions Original
# Dennis and Elle are helping Rosie think of bad movies for her essay.
# **************************
# -------------------------
# ------>Predictions by Model
# Julia wants James to become a voice actor in a cartoon or video game.
# James
# ----->Predictions Original
# James has a dream of becoming a voice actor.
# He considers making a home radio station.
# **************************
# -------------------------
# ------>Predictions by Model
# Poppy is going for drinks after work.
# Alice didn't get lunch, so she
# ----->Predictions Original
# Poppy and Alice are meeting for drinks after work at Nick's at 5:30.
# Alice fancies Fred, she will invite him and a bunch of other coworkers.
# **************************
# -------------------------
# ------>Predictions by Model
# Caron is out from 12.
# Sash will be before 12.
# ----->Predictions Original
# Sash needs to see Caron who'll be out from 12.
# **************************
# -------------------------
# ------>Predictions by Model
# Matteo doesn't like football and video games.
# Giuseppe likes football and
# ----->Predictions Original
# Matteo is not sure about his relationship with Gosia but likes her a lot.
# **************************
# -------------------------
# ------>Predictions by Model
# Ramzi is calling for supper.
# Jannette is coming.
# ----->Predictions Original
# Ramzi and Jannette are going for supper.
# **************************
# -------------------------
# ------>Predictions by Model
# Jeniffer got the recipe from her grandmother.
# She will prepare ravioli.
# ----->Predictions Original
# Jeniffer is preparing ravioli following her grandmothers recipe.
# **************************
# -------------------------
# ------>Predictions by Model
# Lawrence will get back to Madison in a few minutes.
# ----->Predictions Original
# Lawrence will finish writing the article soon.
# **************************
# -------------------------
# ------>Predictions by Model
# Chad sent Brennen a funny photo.
# ----->Predictions Original
# Chad has sent Brennen a funny photo.
# Brennen does not find it very funny.
# **************************
# -------------------------
# ------>Predictions by Model
# Sadie will borrow Chloe's bike on Thursday after work.
# Chloe will pick it up
# ----->Predictions Original
# Sadie will borrow Chloe's bike on Wednesday evening.
# She has a dentist appointment on Thursday after work.
# **************************
# -------------------------
# ------>Predictions by Model
# Olivia is developing a new restaurant in the city centre next month.
# Olivia is
# ----->Predictions Original
# Carter is launching a restaurant business next month.
# Olivia wants him to include a restaurant she's working for in the discount app.
# They will meet in person to discuss it.
# **************************
# -------------------------
# ------>Predictions by Model
# Kristine is back from surgery.
# She's going to St Marks Hospital near Asda
# ----->Predictions Original
# Kenny had a surgery, as Kristine reports.
# He will have another surgery tomorrow.
# Guy will come to St. Mark's Hospital near Asda to stay with Kristine.
# **************************
# -------------------------
# ------>Predictions by Model
# Joey cheated on Olivia with numerous girls.
# She cheated on her with Joey and Olivia
# ----->Predictions Original
# Skyler and Adam are surprised that Joey and Olivia broke up.
# **************************
# -------------------------
# ------>Predictions by Model
# Amanda went to dance classes with Michael yesterday.
# She needed a partner to show the
# ----->Predictions Original
# Amanda goes to dancing classes with Michael.
# She volunteered to show the English Waltz steps with the instructor yesterday.
# Amanda is shy and goes to therapy.
# **************************
# -------------------------
# ------>Predictions by Model
# Taylor wants Isabel to introduce her boyfriend to him.
# Isabel hasn't had any.
# Taylor
# ----->Predictions Original
# Taylor wants to meet Isabel's boyfriend but she has never had any.
# **************************
# -------------------------
# ------>Predictions by Model
# Toby is leaving on Friday.
# Theo is thinking about the Italian Alpes.
# Toby
# ----->Predictions Original
# Theo's going to stay near Torino in the region of Italian Alpes.
# Toby wants to join the trip.
# Theo agrees and will pick Toby up on Friday at 7 am.
# **************************
# -------------------------
# ------>Predictions by Model
# Brandon will be late, because he called him to say he'd be late.
# ----->Predictions Original
# Brandon is late again.
# Clara will prepare a report on the absenteeism and lateness for Phil by Friday.
# **************************
# -------------------------
# ------>Predictions by Model
# Suzie is sick again.
# She cancelled last time because she didn't want to catch
# ----->Predictions Original
# Olga and Suzie will postpone their meeting due to Suzie's sickness.
# **************************
# -------------------------
# ------>Predictions by Model
# Diane wants to be her kids' Lorelai.
# Kate is scared before the
# ----->Predictions Original
# Diane is pregnant and can't wait to give birth, she thinks the waiting is the worst.
# Kate thinks she'll be an amazing mother.
# **************************
# -------------------------
# ------>Predictions by Model
# Andrew has to call in sick because he feels awful.
# Daniel will drop by after work
# ----->Predictions Original
# Andrew has a cold.
# Daniel will buy him some medication.
# **************************
# -------------------------
# ------>Predictions by Model
# Alex and Sam are watching "Millionaires" on Netflix.
# ----->Predictions Original
# Alex and Sam are watching Millionaires.
# **************************
# -------------------------
# ------>Predictions by Model
# Kelly has cinnamon cookies recipe for Angelica.
# ----->Predictions Original
# Angelica sent the cinnamon cookies recipe at Kelly's request.
# **************************
# -------------------------
# ------>Predictions by Model
# Sophie is waiting for a client at the restaurant.
# She will meet with Dee
# ----->Predictions Original
# Sophie is waiting for a client, who is late.
# She will meet Gwen later.
# **************************
# -------------------------
# ------>Predictions by Model
# Daniel is on his way downstairs.
# Sue is going downstairs with the Volvo.
# ----->Predictions Original
# Daniel is with the Volvo on his way and will be there soon.
# Sue is going downstairs to meet him.
# **************************
# -------------------------
# ------>Predictions by Model
# Betty is going to CVS to pick up salmon and squash for dinner.
# George
# ----->Predictions Original
# George is making salmon and stuffed squash for dinner.
# Betty will buy a shaving cream at CVS at his request,
# **************************
# -------------------------
# ------>Predictions by Model
# Ken wants to track his progress with endomondo, but it doesn't work properly
# ----->Predictions Original
# Ken has installed an app for running but it is not working properly on his phone.
# **************************
# -------------------------
# ------>Predictions by Model
# Ann couldn't come to Ivan's birthday party.
# Ivan bought Ivan something for her birthday
# ----->Predictions Original
# Ivan and Ann will meet next week.
# **************************
# -------------------------
# ------>Predictions by Model
# Rowan has some important stuff to do.
# Ashley posted a photo of Ashley on Facebook
# ----->Predictions Original
# Ashley posted some nude photos on her fb page.
# **************************
# -------------------------
# ------>Predictions by Model
# Mikolaj got a breakthrough with his wife's papers.
# The government didn't
# ----->Predictions Original
# Mikolaj's wife needs a work permit as a foreigner.
# Government officials missed the deadline for sending it and will need another month.
# **************************
# -------------------------
# ------>Predictions by Model
# Maria is at the hotel.
# Ann hasn't seen Peter yet.
# They will have lunch
# ----->Predictions Original
# Thomas, Ann and Maria will have lunch together at the hotel.
# Ann is already in the 3rd floor lobby at the red table.
# **************************
# -------------------------
# ------>Predictions by Model
# Sus is sleepy and doesn't want to work.
# ----->Predictions Original
# Sus and Val don't want to work and are sleepy.
# **************************
# -------------------------
# ------>Predictions by Model
# Kate and Kasia are going to the Museum of the city of NY.
# They will
# ----->Predictions Original
# Kate is at the Guggenheim Museum now, but will be in the Museum of the City of New York around 2-2:30.
# Kai may join her.
# Ish won't.
# Terry will join them for a coffee after they finish visiting the museum.
# Terry has already seen the museum.
# **************************
# -------------------------
# ------>Predictions by Model
# Cathy left her sunglasses at her house.
# She will come round at 10 tonight.
# ----->Predictions Original
# Cathy left her sunglasses at Broke's house.
# She will come collect them at 10.
# **************************
# -------------------------
# ------>Predictions by Model
# Bradley invites Frederica to his birthday party tomorrow at 8 pm.
# Frederica
# ----->Predictions Original
# Bradley will come to Frederica's birthday party tomorrow at 8pm.
# **************************
# -------------------------
# ------>Predictions by Model
# Camilla needs to check 250 for the money.
# Adrian will let Camilla know when
# ----->Predictions Original
# Camilla still hasn't received the 250.
# She will check and let Adrian know.
# Money usually takes around two days to arrive.
# **************************
# Saving model checkpoint to test-tokenbatch6/checkpoint-2500
# Configuration saved in test-tokenbatch6/checkpoint-2500/config.json
# Model weights saved in test-tokenbatch6/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-2500/special_tokens_map.json
# Saving model checkpoint to test-tokenbatch6/checkpoint-3000
# Configuration saved in test-tokenbatch6/checkpoint-3000/config.json
# Model weights saved in test-tokenbatch6/checkpoint-3000/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-3000/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-3000/special_tokens_map.json
# Saving model checkpoint to test-tokenbatch6/checkpoint-3500
# Configuration saved in test-tokenbatch6/checkpoint-3500/config.json
# Model weights saved in test-tokenbatch6/checkpoint-3500/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-3500/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-3500/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 818
#   Batch size = 6
# -------------------------
# ------>Predictions by Model
# A will go with B to the animal shelter tomorrow.
# She will get a puppy for
# ----->Predictions Original
# A will go to the animal shelter tomorrow to get a puppy for her son.
# They already visited the shelter last Monday and the son chose the puppy.
# **************************
# -------------------------
# ------>Predictions by Model
# Emma wants to buy an advent calendar for her kids.
# Rob likes the idea.
# ----->Predictions Original
# Emma and Rob love the advent calendar.
# Lauren fits inside calendar various items, for instance, small toys and Christmas decorations.
# Her children are excited whenever they get the calendar.
# **************************
# -------------------------
# ------>Predictions by Model
# Jackie is pregnant with Madison.
# She doesn't want to talk about it because she
# ----->Predictions Original
# Madison is pregnant but she doesn't want to talk about it.
# Patricia Stevens got married and she thought she was pregnant.
# **************************
# -------------------------
# ------>Predictions by Model
# Marla found a box of boxers under her bed.
# ----->Predictions Original
# Marla found a pair of boxers under her bed.
# **************************
# -------------------------
# ------>Predictions by Model
# Robert needs to buy guitar cable.
# Fred gives him the address of the music shop on
# ----->Predictions Original
# Robert wants Fred to send him the address of the music shop as he needs to buy guitar cable.
# **************************
# -------------------------
# ------>Predictions by Model
# Keith needs some milk and cereals.
# Megan checked in the drawer next to the fridge
# ----->Predictions Original
# Megan needn't buy milk and cereals.
# They're in the drawer next to the fridge.
# **************************
# -------------------------
# ------>Predictions by Model
# Samantha sends Holly a video of herself and Evelyn.
# ----->Predictions Original
# Samantha and Evelyn after watching the video cannot believe she is able to make that noise.
# **************************
# -------------------------
# ------>Predictions by Model
# Theresa, Luis and Marion went to Tom's new place for dinner.
# ----->Predictions Original
# Tom's new place is in Fiesole.
# Luis and Marion has been there.
# **************************
# -------------------------
# ------>Predictions by Model
# Jane will make a reservation for 6 people tonight around 20:00.
# Vegano Rest
# ----->Predictions Original
# Jane made a 9 PM reservation for 6 people tonight at Vegano Resto.
# **************************
# -------------------------
# ------>Predictions by Model
# Nancy is coming home in 6 weeks.
# Tina has a Texan drawl and
# ----->Predictions Original
# Nancy's working in Texas, but the kids laugh at her Welsh accent.
# She's coming home in 6 weeks.
# Earlier than that she's going to travel with 3 other Brits.
# **************************
# -------------------------
# ------>Predictions by Model
# Laura needs a new printer.
# Jamie will buy a second hand one.
# ----->Predictions Original
# Laura is going to buy a printer.
# **************************
# -------------------------
# ------>Predictions by Model
# Haylee is in dairy section.
# Barbara bought coconut milk and eggs.
# ----->Predictions Original
# Haylee can't find the coconut milk yoghurt.
# **************************
# -------------------------
# ------>Predictions by Model
# Norbert and Wendy are going to catch the tour.
# ----->Predictions Original
# Wendy is shopping, but she needs to hurry up to catch the tour.
# **************************
# -------------------------
# ------>Predictions by Model
# Cheryl and Peter are going to the Jandia Peninsula tomorrow.
# They will
# ----->Predictions Original
# Cecil, Cheryl and Peter went to the Jandia Peninsula today.
# Cecil would like to explore the south of the island tomorrow, but they will decide what to do after dinner.
# **************************
# -------------------------
# ------>Predictions by Model
# Nickola has found Sophie's pockets and handbags.
# ----->Predictions Original
# Sophie still hasn't found it despite checking pockets and handbags twice.
# **************************
# -------------------------
# ------>Predictions by Model
# Rosie has to write an essay about her favourite b-movie.
# She will cover
# ----->Predictions Original
# Dennis and Elle are helping Rosie think of bad movies for her essay.
# **************************
# -------------------------
# ------>Predictions by Model
# Julia wants James to become a voice actor and make a homemade radio station.
# James
# ----->Predictions Original
# James has a dream of becoming a voice actor.
# He considers making a home radio station.
# **************************
# -------------------------
# ------>Predictions by Model
# Poppy and Alice are going for drinks after work.
# Fred is going to join them
# ----->Predictions Original
# Poppy and Alice are meeting for drinks after work at Nick's at 5:30.
# Alice fancies Fred, she will invite him and a bunch of other coworkers.
# **************************
# -------------------------
# ------>Predictions by Model
# Caron is out from 12 and needs to go out.
# ----->Predictions Original
# Sash needs to see Caron who'll be out from 12.
# **************************
# -------------------------
# ------>Predictions by Model
# Matteo likes football and video games.
# Giuseppe doesn't like games.
# ----->Predictions Original
# Matteo is not sure about his relationship with Gosia but likes her a lot.
# **************************
# -------------------------
# ------>Predictions by Model
# Ramzi's mom is calling for supper.
# ----->Predictions Original
# Ramzi and Jannette are going for supper.
# **************************
# -------------------------
# ------>Predictions by Model
# Jeniffer and Alois are preparing ravioli.
# ----->Predictions Original
# Jeniffer is preparing ravioli following her grandmothers recipe.
# **************************
# -------------------------
# ------>Predictions by Model
# Lawrence will get back to Madison in a few minutes.
# ----->Predictions Original
# Lawrence will finish writing the article soon.
# **************************
# -------------------------
# ------>Predictions by Model
# Chad sent Brennen a funny photo.
# ----->Predictions Original
# Chad has sent Brennen a funny photo.
# Brennen does not find it very funny.
# **************************
# -------------------------
# ------>Predictions by Model
# Sadie needs Chloe's bike again on Thursday after work.
# Chloe will pick it up
# ----->Predictions Original
# Sadie will borrow Chloe's bike on Wednesday evening.
# She has a dentist appointment on Thursday after work.
# **************************
# -------------------------
# ------>Predictions by Model
# Olivia and Carter are planning to launch a new restaurant in the city centre next
# ----->Predictions Original
# Carter is launching a restaurant business next month.
# Olivia wants him to include a restaurant she's working for in the discount app.
# They will meet in person to discuss it.
# **************************
# -------------------------
# ------>Predictions by Model
# Kristine's back from surgery.
# She's going to the St Marks Hospital near As
# ----->Predictions Original
# Kenny had a surgery, as Kristine reports.
# He will have another surgery tomorrow.
# Guy will come to St. Mark's Hospital near Asda to stay with Kristine.
# **************************
# -------------------------
# ------>Predictions by Model
# Joey cheated on Olivia with numerous girls.
# She got pregnant 2 days ago.
# ----->Predictions Original
# Skyler and Adam are surprised that Joey and Olivia broke up.
# **************************
# -------------------------
# ------>Predictions by Model
# Amanda went to dance classes yesterday with Michael.
# The instructor needed a partner to show
# ----->Predictions Original
# Amanda goes to dancing classes with Michael.
# She volunteered to show the English Waltz steps with the instructor yesterday.
# Amanda is shy and goes to therapy.
# **************************
# -------------------------
# ------>Predictions by Model
# Taylor wants Isabel to bring her boyfriend to him.
# ----->Predictions Original
# Taylor wants to meet Isabel's boyfriend but she has never had any.
# **************************
# -------------------------
# ------>Predictions by Model
# Theo is leaving on Friday.
# Toby will pick Theo up by train on Monday.
# ----->Predictions Original
# Theo's going to stay near Torino in the region of Italian Alpes.
# Toby wants to join the trip.
# Theo agrees and will pick Toby up on Friday at 7 am.
# **************************
# -------------------------
# ------>Predictions by Model
# Brandon will be late.
# ----->Predictions Original
# Brandon is late again.
# Clara will prepare a report on the absenteeism and lateness for Phil by Friday.
# **************************
# -------------------------
# ------>Predictions by Model
# Suzie is sick again.
# She cancelled last time.
# Olga will reschedule
# ----->Predictions Original
# Olga and Suzie will postpone their meeting due to Suzie's sickness.
# **************************
# -------------------------
# ------>Predictions by Model
# Diane will be her kids' Lorelai.
# Kate is scared before the birth
# ----->Predictions Original
# Diane is pregnant and can't wait to give birth, she thinks the waiting is the worst.
# Kate thinks she'll be an amazing mother.
# **************************
# -------------------------
# ------>Predictions by Model
# Andrew has to call in sick because he has a cold.
# Daniel will drop by after
# ----->Predictions Original
# Andrew has a cold.
# Daniel will buy him some medication.
# **************************
# -------------------------
# ------>Predictions by Model
# Alex and Sam are watching "Millionaires" on Netflix.
# ----->Predictions Original
# Alex and Sam are watching Millionaires.
# **************************
# -------------------------
# ------>Predictions by Model
# Kelly needs Angelica's cinnamon cookies recipe.
# ----->Predictions Original
# Angelica sent the cinnamon cookies recipe at Kelly's request.
# **************************
# -------------------------
# ------>Predictions by Model
# Sophie is waiting for a client at the restaurant.
# She will meet with Dee
# ----->Predictions Original
# Sophie is waiting for a client, who is late.
# She will meet Gwen later.
# **************************
# -------------------------
# ------>Predictions by Model
# Daniel is on his way downstairs.
# Sue is with the Volvo.
# ----->Predictions Original
# Daniel is with the Volvo on his way and will be there soon.
# Sue is going downstairs to meet him.
# **************************
# -------------------------
# ------>Predictions by Model
# Betty is going to CVS to pick up some salmon and squash for George.
# ----->Predictions Original
# George is making salmon and stuffed squash for dinner.
# Betty will buy a shaving cream at CVS at his request,
# **************************
# -------------------------
# ------>Predictions by Model
# Ken's phone doesn't work properly.
# Ken checked it for his results and it was
# ----->Predictions Original
# Ken has installed an app for running but it is not working properly on his phone.
# **************************
# -------------------------
# ------>Predictions by Model
# Ann couldn't come to Ivan's birthday party.
# Ivan bought her something for her birthday
# ----->Predictions Original
# Ivan and Ann will meet next week.
# **************************
# -------------------------
# ------>Predictions by Model
# Ashley posted a photo on her Facebook page.
# She has some important stuff to do
# ----->Predictions Original
# Ashley posted some nude photos on her fb page.
# **************************
# -------------------------
# ------>Predictions by Model
# Mikolaj got a breakthrough with his wife's papers.
# The government had deadline
# ----->Predictions Original
# Mikolaj's wife needs a work permit as a foreigner.
# Government officials missed the deadline for sending it and will need another month.
# **************************
# -------------------------
# ------>Predictions by Model
# Maria is on her way to the hotel.
# Ann hasn't seen Peter yet.
# She
# ----->Predictions Original
# Thomas, Ann and Maria will have lunch together at the hotel.
# Ann is already in the 3rd floor lobby at the red table.
# **************************
# -------------------------
# ------>Predictions by Model
# Sus is sleepy and doesn't want to work.
# ----->Predictions Original
# Sus and Val don't want to work and are sleepy.
# **************************
# -------------------------
# ------>Predictions by Model
# Kate, Kai and Terry are going to the Museum of the City of NY.
# Kate
# ----->Predictions Original
# Kate is at the Guggenheim Museum now, but will be in the Museum of the City of New York around 2-2:30.
# Kai may join her.
# Ish won't.
# Terry will join them for a coffee after they finish visiting the museum.
# Terry has already seen the museum.
# **************************
# -------------------------
# ------>Predictions by Model
# Cathy left her sunglasses at Brooke's house.
# She will come back at 10 tonight
# ----->Predictions Original
# Cathy left her sunglasses at Broke's house.
# She will come collect them at 10.
# **************************
# -------------------------
# ------>Predictions by Model
# Bradley invites Frederica to his birthday party tomorrow at 8 pm.
# ----->Predictions Original
# Bradley will come to Frederica's birthday party tomorrow at 8pm.
# **************************
# -------------------------
# ------>Predictions by Model
# Camilla needs to check the money.
# It usually takes around two days to arrive though
# ----->Predictions Original
# Camilla still hasn't received the 250.
# She will check and let Adrian know.
# Money usually takes around two days to arrive.
# **************************
# Saving model checkpoint to test-tokenbatch6/checkpoint-4000
# Configuration saved in test-tokenbatch6/checkpoint-4000/config.json
# Model weights saved in test-tokenbatch6/checkpoint-4000/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-4000/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-4000/special_tokens_map.json
# Saving model checkpoint to test-tokenbatch6/checkpoint-4500
# Configuration saved in test-tokenbatch6/checkpoint-4500/config.json
# Model weights saved in test-tokenbatch6/checkpoint-4500/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-4500/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-4500/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 818
#   Batch size = 6
# -------------------------
# ------>Predictions by Model
# A wants to get a puppy for her son.
# She will take him to the animal
# ----->Predictions Original
# A will go to the animal shelter tomorrow to get a puppy for her son.
# They already visited the shelter last Monday and the son chose the puppy.
# **************************
# -------------------------
# ------>Predictions by Model
# Emma wants to buy an advent calendar for her kids.
# Rob is going to buy
# ----->Predictions Original
# Emma and Rob love the advent calendar.
# Lauren fits inside calendar various items, for instance, small toys and Christmas decorations.
# Her children are excited whenever they get the calendar.
# **************************
# -------------------------
# ------>Predictions by Model
# Madison is pregnant.
# ----->Predictions Original
# Madison is pregnant but she doesn't want to talk about it.
# Patricia Stevens got married and she thought she was pregnant.
# **************************
# -------------------------
# ------>Predictions by Model
# Marla found a box of boxers under her bed.
# She found them in the
# ----->Predictions Original
# Marla found a pair of boxers under her bed.
# **************************
# -------------------------
# ------>Predictions by Model
# Robert needs to buy guitar cable.
# Fred gives him directions on google maps.
# ----->Predictions Original
# Robert wants Fred to send him the address of the music shop as he needs to buy guitar cable.
# **************************
# -------------------------
# ------>Predictions by Model
# Keith and Megan are running out of milk and cereals.
# Megan will check in the
# ----->Predictions Original
# Megan needn't buy milk and cereals.
# They're in the drawer next to the fridge.
# **************************
# -------------------------
# ------>Predictions by Model
# Samantha sends Holly a video of herself and Evelyn.
# ----->Predictions Original
# Samantha and Evelyn after watching the video cannot believe she is able to make that noise.
# **************************
# -------------------------
# ------>Predictions by Model
# Theresa, Luis and Marion went to Tom's new place.
# ----->Predictions Original
# Tom's new place is in Fiesole.
# Luis and Marion has been there.
# **************************
# -------------------------
# ------>Predictions by Model
# ...
# -------------------------
# ------>Predictions by Model
# Kate, Kai and Terry are going to the Museum of the city of NY.
# They
# ----->Predictions Original
# Kate is at the Guggenheim Museum now, but will be in the Museum of the City of New York around 2-2:30.
# Kai may join her.
# Ish won't.
# Terry will join them for a coffee after they finish visiting the museum.
# Terry has already seen the museum.
# **************************
# -------------------------
# ------>Predictions by Model
# Cathy left her sunglasses at Brooke's house.
# She might come back at 10 tonight
# ----->Predictions Original
# Cathy left her sunglasses at Broke's house.
# She will come collect them at 10.
# **************************
# -------------------------
# ------>Predictions by Model
# Frederica will come to Bradley's birthday party tomorrow at 8 pm.
# ----->Predictions Original
# Bradley will come to Frederica's birthday party tomorrow at 8pm.
# **************************
# -------------------------
# ------>Predictions by Model
# Camilla hasn't received the money yet.
# Adrian will let Camilla know when she
# ----->Predictions Original
# Camilla still hasn't received the 250.
# She will check and let Adrian know.
# Money usually takes around two days to arrive.
# **************************
# Saving model checkpoint to test-tokenbatch6/checkpoint-5000
# Configuration saved in test-tokenbatch6/checkpoint-5000/config.json
# Model weights saved in test-tokenbatch6/checkpoint-5000/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-5000/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-5000/special_tokens_map.json
# Saving model checkpoint to test-tokenbatch6/checkpoint-5500
# Configuration saved in test-tokenbatch6/checkpoint-5500/config.json
# Model weights saved in test-tokenbatch6/checkpoint-5500/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-5500/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-5500/special_tokens_map.json
# Saving model checkpoint to test-tokenbatch6/checkpoint-6000
# Configuration saved in test-tokenbatch6/checkpoint-6000/config.json
# Model weights saved in test-tokenbatch6/checkpoint-6000/pytorch_model.bin
# tokenizer config file saved in test-tokenbatch6/checkpoint-6000/tokenizer_config.json
# Special tokens file saved in test-tokenbatch6/checkpoint-6000/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 818
#   Batch size = 6
# -------------------------
# ------>Predictions by Model
# A wants to get a puppy for her son.
# She will get one for him.
# ----->Predictions Original
# A will go to the animal shelter tomorrow to get a puppy for her son.
# They already visited the shelter last Monday and the son chose the puppy.
# **************************
# -------------------------
# ------>Predictions by Model
# Emma wants to buy an advent calendar for her kids.
# Rob will buy one.
# ----->Predictions Original
# Emma and Rob love the advent calendar.
# Lauren fits inside calendar various items, for instance, small toys and Christmas decorations.
# Her children are excited whenever they get the calendar.
# **************************
# -------------------------
# ------>Predictions by Model
# Madison is pregnant.
# ----->Predictions Original
# Madison is pregnant but she doesn't want to talk about it.
# Patricia Stevens got married and she thought she was pregnant.
# **************************
# -------------------------
# ------>Predictions by Model
# Marla found a box of boxers under her bed.
# ----->Predictions Original
# Marla found a pair of boxers under her bed.
# **************************
# -------------------------
# ------>Predictions by Model
# Robert needs to buy guitar cable.
# Fred suggests downloading it on google maps.
# ----->Predictions Original
# Robert wants Fred to send him the address of the music shop as he needs to buy guitar cable.
# **************************
# -------------------------
# ------>Predictions by Model
# Keith will check in the drawer next to the fridge to buy milk and cereals.
# ----->Predictions Original
# Megan needn't buy milk and cereals.
# They're in the drawer next to the fridge.
# **************************
# -------------------------
# ------>Predictions by Model
# Samantha sends Holly a video.
# ----->Predictions Original
# Samantha and Evelyn after watching the video cannot believe she is able to make that noise.
# **************************
# -------------------------
# ------>Predictions by Model
# Theresa, Luis and Adam went to Tom's new place for a dinner.
# ----->Predictions Original
# Tom's new place is in Fiesole.
# Luis and Marion has been there.
# **************************
# -------------------------
# ------>Predictions by Model
# Jane will make a reservation for 6 people tonight around 20:00.
# There is no
# ----->Predictions Original
# Jane made a 9 PM reservation for 6 people tonight at Vegano Resto.
# **************************
# -------------------------
# ------>Predictions by Model
# Nancy is coming home in 6 weeks.
# Tina is worried about Nancy's accent.
# ----->Predictions Original
# Nancy's working in Texas, but the kids laugh at her Welsh accent.
# She's coming home in 6 weeks.
# Earlier than that she's going to travel with 3 other Brits.
# **************************
# -------------------------
# ------>Predictions by Model
# Laura needs a new printer.
# Jamie will buy a second hand printer.
# ----->Predictions Original
# Laura is going to buy a printer.
# **************************
# -------------------------
# ------>Predictions by Model
# Haylee is in dairy section.
# Barbara bought coconut milk and eggs.
# ----->Predictions Original
# Haylee can't find the coconut milk yoghurt.
# **************************
# -------------------------
# ------>Predictions by Model
# Norbert and Wendy are going to catch the tour.
# ----->Predictions Original
# Wendy is shopping, but she needs to hurry up to catch the tour.
# **************************
# -------------------------
# ------>Predictions by Model
# Cecil and Cecil are going to the Jandia Peninsula tomorrow.
# Cecil
# ----->Predictions Original
# Cecil, Cheryl and Peter went to the Jandia Peninsula today.
# Cecil would like to explore the south of the island tomorrow, but they will decide what to do after dinner.
# **************************
# -------------------------
# ------>Predictions by Model
# Sophie hasn't found Nickola's pockets and handbags.
# ----->Predictions Original
# Sophie still hasn't found it despite checking pockets and handbags twice.
# **************************
# -------------------------
# ------>Predictions by Model
# Rosie wants to write an essay about her favourite b-movie.
# Dennis recommends T
# ----->Predictions Original
# Dennis and Elle are helping Rosie think of bad movies for her essay.
# **************************
# -------------------------
# ------>Predictions by Model
# James wants to become a voice actor.
# Julia suggests listening to him as a radio speaker
# ----->Predictions Original
# James has a dream of becoming a voice actor.
# He considers making a home radio station.
# **************************
# -------------------------
# ------>Predictions by Model
# Poppy and Alice are going for drinks after work.
# They are going to meet at
# ----->Predictions Original
# Poppy and Alice are meeting for drinks after work at Nick's at 5:30.
# Alice fancies Fred, she will invite him and a bunch of other coworkers.
# **************************
# -------------------------
# ------>Predictions by Model
# Caron is out from 12.
# She will see Sash before 12.
# ----->Predictions Original
# Sash needs to see Caron who'll be out from 12.
# **************************
# -------------------------
# ------>Predictions by Model
# Matteo likes football and video games.
# Giuseppe doesn't like games.
# ----->Predictions Original
# Matteo is not sure about his relationship with Gosia but likes her a lot.
# **************************
# -------------------------
# ------>Predictions by Model
# Ramzi's mom is calling for supper.
# Jannette is coming.
# ----->Predictions Original
# Ramzi and Jannette are going for supper.
# **************************
# -------------------------
# ------>Predictions by Model
# Jeniffer is preparing ravioli for Alois and Hildegard.
# ----->Predictions Original
# Jeniffer is preparing ravioli following her grandmothers recipe.
# **************************
# -------------------------
# ------>Predictions by Model
# Lawrence will get back to Madison once he finishes with the article.
# ----->Predictions Original
# Lawrence will finish writing the article soon.
# **************************
# -------------------------
# ------>Predictions by Model
# Chad sends Brennen a funny photo.
# ----->Predictions Original
# Chad has sent Brennen a funny photo.
# Brennen does not find it very funny.
# **************************
# -------------------------
# ------>Predictions by Model
# Chloe will borrow Sadie's bike on Wednesday evening.
# ----->Predictions Original
# Sadie will borrow Chloe's bike on Wednesday evening.
# She has a dentist appointment on Thursday after work.
# **************************
# -------------------------
# ------>Predictions by Model
# Olivia wants to start a new restaurant in the city centre next month.
# Carter
# ----->Predictions Original
# Carter is launching a restaurant business next month.
# Olivia wants him to include a restaurant she's working for in the discount app.
# They will meet in person to discuss it.
# **************************
# -------------------------
# ------>Predictions by Model
# Kristine is back from surgery.
# She will be back at St Marks Hospital near As
# ----->Predictions Original
# Kenny had a surgery, as Kristine reports.
# He will have another surgery tomorrow.
# Guy will come to St. Mark's Hospital near Asda to stay with Kristine.
# **************************
# -------------------------
# ------>Predictions by Model
# Joey cheated on Olivia with numerous girls.
# He cheated on her 2 days ago.
# ----->Predictions Original
# Skyler and Adam are surprised that Joey and Olivia broke up.
# **************************
# -------------------------
# ------>Predictions by Model
# Amanda went to dance classes with Michael yesterday.
# She needed a partner to show the
# ----->Predictions Original
# Amanda goes to dancing classes with Michael.
# She volunteered to show the English Waltz steps with the instructor yesterday.
# Amanda is shy and goes to therapy.
# **************************
# -------------------------
# ------>Predictions by Model
# Taylor doesn't know why Isabel hasn't introduced her boyfriend to him.
# ----->Predictions Original
# Taylor wants to meet Isabel's boyfriend but she has never had any.
# **************************
# -------------------------
# ------>Predictions by Model
# Theo is leaving for Italy on Friday.
# Toby will pick Theo up by train.
# ----->Predictions Original
# Theo's going to stay near Torino in the region of Italian Alpes.
# Toby wants to join the trip.
# Theo agrees and will pick Toby up on Friday at 7 am.
# **************************
# -------------------------
# ------>Predictions by Model
# Brandon will be late.
# ----->Predictions Original
# Brandon is late again.
# Clara will prepare a report on the absenteeism and lateness for Phil by Friday.
# **************************
# -------------------------
# ------>Predictions by Model
# Suzie is sick again.
# She cancelled last time.
# Olga will reschedule
# ----->Predictions Original
# Olga and Suzie will postpone their meeting due to Suzie's sickness.
# **************************
# -------------------------
# ------>Predictions by Model
# Diane will be pregnant with Lorelai.
# ----->Predictions Original
# Diane is pregnant and can't wait to give birth, she thinks the waiting is the worst.
# Kate thinks she'll be an amazing mother.
# **************************
# -------------------------
# ------>Predictions by Model
# Andrew has to call in sick because he has a cold.
# Daniel will drop by after
# ----->Predictions Original
# Andrew has a cold.
# Daniel will buy him some medication.
# **************************
# -------------------------
# ------>Predictions by Model
# Alex and Sam are watching "Millionaires" on tv.
# ----->Predictions Original
# Alex and Sam are watching Millionaires.
# **************************
# -------------------------
# ------>Predictions by Model
# Jessica has the cinnamon cookies recipe.
# Angelica sends Kelly a photo.
# ----->Predictions Original
# Angelica sent the cinnamon cookies recipe at Kelly's request.
# **************************
# -------------------------
# ------>Predictions by Model
# Sophie is waiting for Dee at the restaurant.
# They will meet in 5 minutes
# ----->Predictions Original
# Sophie is waiting for a client, who is late.
# She will meet Gwen later.
# **************************
# -------------------------
# ------>Predictions by Model
# Daniel is on his way.
# Sue is with the Volvo.
# ----->Predictions Original
# Daniel is with the Volvo on his way and will be there soon.
# Sue is going downstairs to meet him.
# **************************
# -------------------------
# ------>Predictions by Model
# Betty is going to CVS to pick up salmon and squash for George.
# George
# ----->Predictions Original
# George is making salmon and stuffed squash for dinner.
# Betty will buy a shaving cream at CVS at his request,
# **************************
# -------------------------
# ------>Predictions by Model
# Ken's phone doesn't work properly.
# He used endomondo to track his progress
# ----->Predictions Original
# Ken has installed an app for running but it is not working properly on his phone.
# **************************
# -------------------------
# ------>Predictions by Model
# Ivan hasn't been at Ann's birthday party.
# Ivan bought her something for her
# ----->Predictions Original
# Ivan and Ann will meet next week.
# **************************
# -------------------------
# ------>Predictions by Model
# Rowan has some important stuff to do.
# Ashley posted some pictures on Facebook.
# Ashley
# ----->Predictions Original
# Ashley posted some nude photos on her fb page.
# **************************
# -------------------------
# ------>Predictions by Model
# Mikolaj got a breakthrough with his wife's papers.
# The government didn't
# ----->Predictions Original
# Mikolaj's wife needs a work permit as a foreigner.
# Government officials missed the deadline for sending it and will need another month.
# **************************
# -------------------------
# ------>Predictions by Model
# Maria is on her way to the hotel.
# Ann hasn't seen Peter yet.
# She
# ----->Predictions Original
# Thomas, Ann and Maria will have lunch together at the hotel.
# Ann is already in the 3rd floor lobby at the red table.
# **************************
# -------------------------
# ------>Predictions by Model
# Sus is sleepy and doesn't want to work.
# ----->Predictions Original
# Sus and Val don't want to work and are sleepy.
# **************************
# -------------------------
# ------>Predictions by Model
# Kate, Kai and Terry are going to the Museum of the city of NY.
# They
# ----->Predictions Original
# Kate is at the Guggenheim Museum now, but will be in the Museum of the City of New York around 2-2:30.
# Kai may join her.
# Ish won't.
# Terry will join them for a coffee after they finish visiting the museum.
# Terry has already seen the museum.
# **************************
# -------------------------
# ------>Predictions by Model
# Cathy left her sunglasses at Brooke's house.
# She might come over at 10 tonight
# ----->Predictions Original
# Cathy left her sunglasses at Broke's house.
# She will come collect them at 10.
# **************************
# -------------------------
# ------>Predictions by Model
# Frederica will come to Bradley's birthday party tomorrow at 8 pm.
# ----->Predictions Original
# Bradley will come to Frederica's birthday party tomorrow at 8pm.
# **************************
# -------------------------
# ------>Predictions by Model
# Camilla needs to check the money as it usually takes around two days to arrive.
# ----->Predictions Original
# Camilla still hasn't received the 250.
# She will check and let Adrian know.
# Money usually takes around two days to arrive.
# **************************
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=6135, training_loss=630.6079075524938, metrics={'train_runtime': 8086.5653, 'train_samples_per_second': 9.108, 'train_steps_per_second': 0.759, 'total_flos': 1.410922066305024e+16, 'train_loss': 630.6079075524938, 'epoch': 5.0})

# %%
trainer.evaluate()
# Out:
# ***** Running Evaluation *****
#   Num examples = 818
#   Batch size = 6
#     <div>
#
#       <progress value='137' max='137' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [137/137 01:50]
#     </div>
# -------------------------
# ------>Predictions by Model
# A wants to get a puppy for her son.
# She will get one for him.
# ----->Predictions Original
# A will go to the animal shelter tomorrow to get a puppy for her son.
# They already visited the shelter last Monday and the son chose the puppy.
# **************************
# -------------------------
# ------>Predictions by Model
# Emma wants to buy an advent calendar for her kids.
# Rob will buy one.
# ----->Predictions Original
# Emma and Rob love the advent calendar.
# Lauren fits inside calendar various items, for instance, small toys and Christmas decorations.
# Her children are excited whenever they get the calendar.
# **************************
# -------------------------
# ------>Predictions by Model
# Madison is pregnant.
# ----->Predictions Original
# Madison is pregnant but she doesn't want to talk about it.
# Patricia Stevens got married and she thought she was pregnant.
# **************************
# -------------------------
# ------>Predictions by Model
# Marla found a box of boxers under her bed.
# ----->Predictions Original
# Marla found a pair of boxers under her bed.
# **************************
# -------------------------
# ------>Predictions by Model
# Robert needs to buy guitar cable.
# Fred suggests downloading it on google maps.
# ----->Predictions Original
# Robert wants Fred to send him the address of the music shop as he needs to buy guitar cable.
# **************************
# -------------------------
# ------>Predictions by Model
# Keith will check in the drawer next to the fridge to buy milk and cereals.
# ----->Predictions Original
# Megan needn't buy milk and cereals.
# They're in the drawer next to the fridge.
# **************************
# -------------------------
# ------>Predictions by Model
# Samantha sends Holly a video.
# ----->Predictions Original
# Samantha and Evelyn after watching the video cannot believe she is able to make that noise.
# **************************
# -------------------------
# ------>Predictions by Model
# Theresa, Luis and Adam went to Tom's new place for a dinner.
# ----->Predictions Original
# Tom's new place is in Fiesole.
# Luis and Marion has been there.
# **************************
# -------------------------
# ------>Predictions by Model
# Jane will make a reservation for 6 people tonight around 20:00.
# There is no
# ----->Predictions Original
# Jane made a 9 PM reservation for 6 people tonight at Vegano Resto.
# **************************
# -------------------------
# ------>Predictions by Model
# Nancy is coming home in 6 weeks.
# Tina is worried about Nancy's accent.
# ----->Predictions Original
# Nancy's working in Texas, but the kids laugh at her Welsh accent.
# She's coming home in 6 weeks.
# Earlier than that she's going to travel with 3 other Brits.
# **************************
# -------------------------
# ------>Predictions by Model
# Laura needs a new printer.
# Jamie will buy a second hand printer.
# ----->Predictions Original
# Laura is going to buy a printer.
# **************************
# -------------------------
# ------>Predictions by Model
# Haylee is in dairy section.
# Barbara bought coconut milk and eggs.
# ----->Predictions Original
# Haylee can't find the coconut milk yoghurt.
# **************************
# -------------------------
# ------>Predictions by Model
# Norbert and Wendy are going to catch the tour.
# ----->Predictions Original
# Wendy is shopping, but she needs to hurry up to catch the tour.
# **************************
# -------------------------
# ------>Predictions by Model
# Cecil and Cecil are going to the Jandia Peninsula tomorrow.
# Cecil
# ----->Predictions Original
# Cecil, Cheryl and Peter went to the Jandia Peninsula today.
# Cecil would like to explore the south of the island tomorrow, but they will decide what to do after dinner.
# **************************
# -------------------------
# ------>Predictions by Model
# Sophie hasn't found Nickola's pockets and handbags.
# ----->Predictions Original
# Sophie still hasn't found it despite checking pockets and handbags twice.
# **************************
# -------------------------
# ------>Predictions by Model
# Rosie wants to write an essay about her favourite b-movie.
# Dennis recommends T
# ----->Predictions Original
# Dennis and Elle are helping Rosie think of bad movies for her essay.
# **************************
# -------------------------
# ------>Predictions by Model
# James wants to become a voice actor.
# Julia suggests listening to him as a radio speaker
# ----->Predictions Original
# James has a dream of becoming a voice actor.
# He considers making a home radio station.
# **************************
# -------------------------
# ------>Predictions by Model
# Poppy and Alice are going for drinks after work.
# They are going to meet at
# ----->Predictions Original
# Poppy and Alice are meeting for drinks after work at Nick's at 5:30.
# Alice fancies Fred, she will invite him and a bunch of other coworkers.
# **************************
# -------------------------
# ------>Predictions by Model
# Caron is out from 12.
# She will see Sash before 12.
# ----->Predictions Original
# Sash needs to see Caron who'll be out from 12.
# **************************
# -------------------------
# ------>Predictions by Model
# Matteo likes football and video games.
# Giuseppe doesn't like games.
# ----->Predictions Original
# Matteo is not sure about his relationship with Gosia but likes her a lot.
# **************************
# -------------------------
# ------>Predictions by Model
# Ramzi's mom is calling for supper.
# Jannette is coming.
# ----->Predictions Original
# Ramzi and Jannette are going for supper.
# **************************
# -------------------------
# ------>Predictions by Model
# Jeniffer is preparing ravioli for Alois and Hildegard.
# ----->Predictions Original
# Jeniffer is preparing ravioli following her grandmothers recipe.
# **************************
# -------------------------
# ------>Predictions by Model
# Lawrence will get back to Madison once he finishes with the article.
# ----->Predictions Original
# Lawrence will finish writing the article soon.
# **************************
# -------------------------
# ------>Predictions by Model
# Chad sends Brennen a funny photo.
# ----->Predictions Original
# Chad has sent Brennen a funny photo.
# Brennen does not find it very funny.
# **************************
# -------------------------
# ------>Predictions by Model
# Chloe will borrow Sadie's bike on Wednesday evening.
# ----->Predictions Original
# Sadie will borrow Chloe's bike on Wednesday evening.
# She has a dentist appointment on Thursday after work.
# **************************
# -------------------------
# ------>Predictions by Model
# Olivia wants to start a new restaurant in the city centre next month.
# Carter
# ----->Predictions Original
# Carter is launching a restaurant business next month.
# Olivia wants him to include a restaurant she's working for in the discount app.
# They will meet in person to discuss it.
# **************************
# -------------------------
# ------>Predictions by Model
# Kristine is back from surgery.
# She will be back at St Marks Hospital near As
# ----->Predictions Original
# Kenny had a surgery, as Kristine reports.
# He will have another surgery tomorrow.
# Guy will come to St. Mark's Hospital near Asda to stay with Kristine.
# **************************
# -------------------------
# ------>Predictions by Model
# Joey cheated on Olivia with numerous girls.
# He cheated on her 2 days ago.
# ----->Predictions Original
# Skyler and Adam are surprised that Joey and Olivia broke up.
# **************************
# -------------------------
# ------>Predictions by Model
# Amanda went to dance classes with Michael yesterday.
# She needed a partner to show the
# ----->Predictions Original
# Amanda goes to dancing classes with Michael.
# She volunteered to show the English Waltz steps with the instructor yesterday.
# Amanda is shy and goes to therapy.
# **************************
# -------------------------
# ------>Predictions by Model
# Taylor doesn't know why Isabel hasn't introduced her boyfriend to him.
# ----->Predictions Original
# Taylor wants to meet Isabel's boyfriend but she has never had any.
# **************************
# -------------------------
# ------>Predictions by Model
# Theo is leaving for Italy on Friday.
# Toby will pick Theo up by train.
# ----->Predictions Original
# Theo's going to stay near Torino in the region of Italian Alpes.
# Toby wants to join the trip.
# Theo agrees and will pick Toby up on Friday at 7 am.
# **************************
# -------------------------
# ------>Predictions by Model
# Brandon will be late.
# ----->Predictions Original
# Brandon is late again.
# Clara will prepare a report on the absenteeism and lateness for Phil by Friday.
# **************************
# -------------------------
# ------>Predictions by Model
# Suzie is sick again.
# She cancelled last time.
# Olga will reschedule
# ----->Predictions Original
# Olga and Suzie will postpone their meeting due to Suzie's sickness.
# **************************
# -------------------------
# ------>Predictions by Model
# Diane will be pregnant with Lorelai.
# ----->Predictions Original
# Diane is pregnant and can't wait to give birth, she thinks the waiting is the worst.
# Kate thinks she'll be an amazing mother.
# **************************
# -------------------------
# ------>Predictions by Model
# Andrew has to call in sick because he has a cold.
# Daniel will drop by after
# ----->Predictions Original
# Andrew has a cold.
# Daniel will buy him some medication.
# **************************
# -------------------------
# ------>Predictions by Model
# Alex and Sam are watching "Millionaires" on tv.
# ----->Predictions Original
# Alex and Sam are watching Millionaires.
# **************************
# -------------------------
# ------>Predictions by Model
# Jessica has the cinnamon cookies recipe.
# Angelica sends Kelly a photo.
# ----->Predictions Original
# Angelica sent the cinnamon cookies recipe at Kelly's request.
# **************************
# -------------------------
# ------>Predictions by Model
# Sophie is waiting for Dee at the restaurant.
# They will meet in 5 minutes
# ----->Predictions Original
# Sophie is waiting for a client, who is late.
# She will meet Gwen later.
# **************************
# -------------------------
# ------>Predictions by Model
# Daniel is on his way.
# Sue is with the Volvo.
# ----->Predictions Original
# Daniel is with the Volvo on his way and will be there soon.
# Sue is going downstairs to meet him.
# **************************
# -------------------------
# ------>Predictions by Model
# Betty is going to CVS to pick up salmon and squash for George.
# George
# ----->Predictions Original
# George is making salmon and stuffed squash for dinner.
# Betty will buy a shaving cream at CVS at his request,
# **************************
# -------------------------
# ------>Predictions by Model
# Ken's phone doesn't work properly.
# He used endomondo to track his progress
# ----->Predictions Original
# Ken has installed an app for running but it is not working properly on his phone.
# **************************
# -------------------------
# ------>Predictions by Model
# Ivan hasn't been at Ann's birthday party.
# Ivan bought her something for her
# ----->Predictions Original
# Ivan and Ann will meet next week.
# **************************
# -------------------------
# ------>Predictions by Model
# Rowan has some important stuff to do.
# Ashley posted some pictures on Facebook.
# Ashley
# ----->Predictions Original
# Ashley posted some nude photos on her fb page.
# **************************
# -------------------------
# ------>Predictions by Model
# Mikolaj got a breakthrough with his wife's papers.
# The government didn't
# ----->Predictions Original
# Mikolaj's wife needs a work permit as a foreigner.
# Government officials missed the deadline for sending it and will need another month.
# **************************
# -------------------------
# ------>Predictions by Model
# Maria is on her way to the hotel.
# Ann hasn't seen Peter yet.
# She
# ----->Predictions Original
# Thomas, Ann and Maria will have lunch together at the hotel.
# Ann is already in the 3rd floor lobby at the red table.
# **************************
# -------------------------
# ------>Predictions by Model
# Sus is sleepy and doesn't want to work.
# ----->Predictions Original
# Sus and Val don't want to work and are sleepy.
# **************************
# -------------------------
# ------>Predictions by Model
# Kate, Kai and Terry are going to the Museum of the city of NY.
# They
# ----->Predictions Original
# Kate is at the Guggenheim Museum now, but will be in the Museum of the City of New York around 2-2:30.
# Kai may join her.
# Ish won't.
# Terry will join them for a coffee after they finish visiting the museum.
# Terry has already seen the museum.
# **************************
# -------------------------
# ------>Predictions by Model
# Cathy left her sunglasses at Brooke's house.
# She might come over at 10 tonight
# ----->Predictions Original
# Cathy left her sunglasses at Broke's house.
# She will come collect them at 10.
# **************************
# -------------------------
# ------>Predictions by Model
# Frederica will come to Bradley's birthday party tomorrow at 8 pm.
# ----->Predictions Original
# Bradley will come to Frederica's birthday party tomorrow at 8pm.
# **************************
# -------------------------
# ------>Predictions by Model
# Camilla needs to check the money as it usually takes around two days to arrive.
# ----->Predictions Original
# Camilla still hasn't received the 250.
# She will check and let Adrian know.
# Money usually takes around two days to arrive.
# **************************
# {'eval_loss': 390.1603698730469,
#  'eval_rouge1': 46.3977,
#  'eval_rouge2': 22.7926,
#  'eval_rougeL': 38.7734,
#  'eval_rougeLsum': 42.5666,
#  'eval_gen_len': 17.6785,
#  'eval_runtime': 113.04,
#  'eval_samples_per_second': 7.236,
#  'eval_steps_per_second': 1.212,
#  'epoch': 5.0}

# %% [markdown]
# ## T5

# %% [markdown]
# ### Preprocessing the data

# %%
model_checkpoint = "t5-base"

# %%
from transformers import AutoTokenizer
    
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

from transformers import AutoModelForSeq2SeqLM, DataCollatorForSeq2Seq, Seq2SeqTrainingArguments, Seq2SeqTrainer
model = AutoModelForSeq2SeqLM.from_pretrained(model_checkpoint)
# Out:
# Could not locate the tokenizer configuration file, will try to use the model config instead.
# Downloading:   0%|          | 0.00/1.20k [00:00<?, ?B/s]
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--t5-base/snapshots/23aa4f41cb7c08d4b05c8f327b22bfa0eb8c7ad9/config.json
# Model config T5Config {
#   "_name_or_path": "t5-base",
#   "architectures": [
#     "T5WithLMHeadModel"
#   ],
#   "d_ff": 3072,
#   "d_kv": 64,
#   "d_model": 768,
#   "decoder_start_token_id": 0,
#   "dense_act_fn": "relu",
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "feed_forward_proj": "relu",
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "is_gated_act": false,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_decoder_layers": 12,
#   "num_heads": 12,
#   "num_layers": 12,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_max_distance": 128,
#   "relative_attention_num_buckets": 32,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "max_length": 200,
#       "min_length": 30,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4,
#       "prefix": "summarize: "
#     },
#     "translation_en_to_de": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to German: "
#     },
#     "translation_en_to_fr": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to French: "
#     },
#     "translation_en_to_ro": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to Romanian: "
#     }
#   },
#   "transformers_version": "4.24.0",
#   "use_cache": true,
#   "vocab_size": 32128
# }
# Downloading:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# loading file spiece.model from cache at /root/.cache/huggingface/hub/models--t5-base/snapshots/23aa4f41cb7c08d4b05c8f327b22bfa0eb8c7ad9/spiece.model
# loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--t5-base/snapshots/23aa4f41cb7c08d4b05c8f327b22bfa0eb8c7ad9/tokenizer.json
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at None
# loading file tokenizer_config.json from cache at None
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--t5-base/snapshots/23aa4f41cb7c08d4b05c8f327b22bfa0eb8c7ad9/config.json
# Model config T5Config {
#   "_name_or_path": "t5-base",
#   "architectures": [
#     "T5WithLMHeadModel"
#   ],
#   "d_ff": 3072,
#   "d_kv": 64,
#   "d_model": 768,
#   "decoder_start_token_id": 0,
#   "dense_act_fn": "relu",
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "feed_forward_proj": "relu",
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "is_gated_act": false,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_decoder_layers": 12,
#   "num_heads": 12,
#   "num_layers": 12,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_max_distance": 128,
#   "relative_attention_num_buckets": 32,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "max_length": 200,
#       "min_length": 30,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4,
#       "prefix": "summarize: "
#     },
#     "translation_en_to_de": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to German: "
#     },
#     "translation_en_to_fr": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to French: "
#     },
#     "translation_en_to_ro": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to Romanian: "
#     }
#   },
#   "transformers_version": "4.24.0",
#   "use_cache": true,
#   "vocab_size": 32128
# }
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/t5/tokenization_t5_fast.py:166: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-base automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   FutureWarning,
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--t5-base/snapshots/23aa4f41cb7c08d4b05c8f327b22bfa0eb8c7ad9/config.json
# Model config T5Config {
#   "_name_or_path": "t5-base",
#   "architectures": [
#     "T5WithLMHeadModel"
#   ],
#   "d_ff": 3072,
#   "d_kv": 64,
#   "d_model": 768,
#   "decoder_start_token_id": 0,
#   "dense_act_fn": "relu",
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "feed_forward_proj": "relu",
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "is_gated_act": false,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_decoder_layers": 12,
#   "num_heads": 12,
#   "num_layers": 12,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_max_distance": 128,
#   "relative_attention_num_buckets": 32,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "max_length": 200,
#       "min_length": 30,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4,
#       "prefix": "summarize: "
#     },
#     "translation_en_to_de": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to German: "
#     },
#     "translation_en_to_fr": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to French: "
#     },
#     "translation_en_to_ro": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to Romanian: "
#     }
#   },
#   "transformers_version": "4.24.0",
#   "use_cache": true,
#   "vocab_size": 32128
# }
# Downloading:   0%|          | 0.00/892M [00:00<?, ?B/s]
# loading weights file pytorch_model.bin from cache at /root/.cache/huggingface/hub/models--t5-base/snapshots/23aa4f41cb7c08d4b05c8f327b22bfa0eb8c7ad9/pytorch_model.bin
# All model checkpoint weights were used when initializing T5ForConditionalGeneration.
#
# All the weights of T5ForConditionalGeneration were initialized from the model checkpoint at t5-base.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use T5ForConditionalGeneration for predictions without further training.

# %%
max_input_length = 512
max_target_length = 128

def preprocess_function(examples):
    task_prefix = "summarize: "
    inputs = examples["dialogue"]
    model_inputs = tokenizer([task_prefix + dialogue for dialogue in inputs], 
                             padding="max_length",
                             max_length=max_input_length, 
                             truncation=True)

    # Setup the tokenizer for targets
    labels = tokenizer(examples["summary"], 
                        padding="max_length",
                        max_length=max_target_length, 
                        truncation=True)

    model_inputs["labels"] = [
        [-100 if token == tokenizer.pad_token_id else token for token in l]
        for l in labels["input_ids"]]
        
    return model_inputs

# %%
tokenized_datasets = raw_datasets.map(preprocess_function, batched=True)
# Out:
#   0%|          | 0/15 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
# sample a small set for development
# tokenized_datasets_train = tokenized_datasets['train'].select(range(100))
# tokenized_datasets_val = tokenized_datasets['validation'].select(range(70))


tokenized_datasets_train = tokenized_datasets['train']
tokenized_datasets_val = tokenized_datasets['validation']

# %% [markdown]
# ### Fine-tuning the model

# %%
# Parameters\
batch_size=8
training_args = Seq2SeqTrainingArguments(
    output_dir="t5_results",
    num_train_epochs=5,
    do_train=True,
    do_eval=True,
    evaluation_strategy = "epoch",
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    learning_rate=1e-4,
    warmup_steps=500,
    weight_decay=0.1,
    # label_smoothing_factor=0.1, ## causes to throw an error
    predict_with_generate=True,
    # logging_dir="logs",
    logging_steps=10,
    save_total_limit=3,
)


data_collator = DataCollatorForSeq2Seq(tokenizer, model=model)

trainer = CustomTrainer(
    model=model,
    args=training_args,
    data_collator=data_collator,
    train_dataset=tokenized_datasets_train,
    eval_dataset=tokenized_datasets_val,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
)
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
# evaluate before training for comparison
trainer.evaluate()
# Out:
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: summary, id, dialogue. If summary, id, dialogue are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 818
#   Batch size = 8
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='103' max='103' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [103/103 02:12]
#     </div>
# -------------------------
# ------>Predictions by Model
# a hamster named lemmy is named after his dead hamster.
# ----->Predictions Original
# A will go to the animal shelter tomorrow to get a puppy for her son.
# They already visited the shelter last Monday and the son chose the puppy.
# **************************
# -------------------------
# ------>Predictions by Model
# x-mas advent calendars are filled with various things.
# i love the idea
# ----->Predictions Original
# Emma and Rob love the advent calendar.
# Lauren fits inside calendar various items, for instance, small toys and Christmas decorations.
# Her children are excited whenever they get the calendar.
# **************************
# -------------------------
# ------>Predictions by Model
# Madison is pregnant Iggy: ok, she's probably worrying about it Iggy:
# ----->Predictions Original
# Madison is pregnant but she doesn't want to talk about it.
# Patricia Stevens got married and she thought she was pregnant.
# **************************
# -------------------------
# ------>Predictions by Model
# a teen girl's underwear was found under her bed.
# it was probably
# ----->Predictions Original
# Marla found a pair of boxers under her bed.
# **************************
# -------------------------
# ------>Predictions by Model
# m8: i have to buy guitar cable Fred: file_other>
# ----->Predictions Original
# Robert wants Fred to send him the address of the music shop as he needs to buy guitar cable.
# **************************
# -------------------------
# ------>Predictions by Model
# a drawer next to the fridge has cereal and milk.
# a false alarm, we
# ----->Predictions Original
# Megan needn't buy milk and cereals.
# They're in the drawer next to the fridge.
# **************************
# -------------------------
# ------>Predictions by Model
# Holly: I'm surprised!
# Holly: 'i'm surprised!'
# ----->Predictions Original
# Samantha and Evelyn after watching the video cannot believe she is able to make that noise.
# **************************
# -------------------------
# ------>Predictions by Model
# Luis: a bit outside the city Adam: where exactly?
# ----->Predictions Original
# Tom's new place is in Fiesole.
# Luis and Marion has been there.
# **************************
# -------------------------
# ------>Predictions by Model
# vegano resto: sorry, there is no room at 20:00. but he
# ----->Predictions Original
# Jane made a 9 PM reservation for 6 people tonight at Vegano Resto.
# **************************
# -------------------------
# ------>Predictions by Model
# a Texan drawl is a Texan drawl, girl!
# ----->Predictions Original
# Nancy's working in Texas, but the kids laugh at her Welsh accent.
# She's coming home in 6 weeks.
# Earlier than that she's going to travel with 3 other Brits.
# **************************
# -------------------------
# ------>Predictions by Model
# Jamie: you're sure you need a new printer?
# Laura: you can buy
# ----->Predictions Original
# Laura is going to buy a printer.
# **************************
# -------------------------
# ------>Predictions by Model
# yoghurt is a yoghurt made with coconut milk.
# it'
# ----->Predictions Original
# Haylee can't find the coconut milk yoghurt.
# **************************
# -------------------------
# ------>Predictions by Model
# Wendy: ok, am buying something.
# be right out!
# Wendy: ok, am
# ----->Predictions Original
# Wendy is shopping, but she needs to hurry up to catch the tour.
# **************************
# -------------------------
# ------>Predictions by Model
# Cecil: "it's always windy here" but he took some nice pics
# ----->Predictions Original
# Cecil, Cheryl and Peter went to the Jandia Peninsula today.
# Cecil would like to explore the south of the island tomorrow, but they will decide what to do after dinner.
# **************************
# -------------------------
# ------>Predictions by Model
# Sophie: Checked all pockets and handbags.
# ----->Predictions Original
# Sophie still hasn't found it despite checking pockets and handbags twice.
# **************************
# -------------------------
# ------>Predictions by Model
# b-movies like toxic avenger and poultrygeist are among your favorites
# ----->Predictions Original
# Dennis and Elle are helping Rosie think of bad movies for her essay.
# **************************
# -------------------------
# ------>Predictions by Model
# Julia: I've had this dream for some time now, to become a voice actor
# ----->Predictions Original
# James has a dream of becoming a voice actor.
# He considers making a home radio station.
# **************************
# -------------------------
# ------>Predictions by Model
# Alice: I'm in the same shape as you!
# What a long day!
# Alice
# ----->Predictions Original
# Poppy and Alice are meeting for drinks after work at Nick's at 5:30.
# Alice fancies Fred, she will invite him and a bunch of other coworkers.
# **************************
# -------------------------
# ------>Predictions by Model
# caron: i'm out from 12 Sash: will be before Sash:
# ----->Predictions Original
# Sash needs to see Caron who'll be out from 12.
# **************************
# -------------------------
# ------>Predictions by Model
# he's a little strange Giuseppe: why is she so strange?
# ----->Predictions Original
# Matteo is not sure about his relationship with Gosia but likes her a lot.
# **************************
# -------------------------
# ------>Predictions by Model
# Ramzi: Mom is calling for supper Jannette: Ok Im coming Ramzi
# ----->Predictions Original
# Ramzi and Jannette are going for supper.
# **************************
# -------------------------
# ------>Predictions by Model
# ravioli are a real treasure.
# nobody makes them better than your family.
# ----->Predictions Original
# Jeniffer is preparing ravioli following her grandmothers recipe.
# **************************
# -------------------------
# ------>Predictions by Model
# Madison: Okay.
# but make it quick.
# Lawrence: Okay.
# I will get back to you
# ----->Predictions Original
# Lawrence will finish writing the article soon.
# **************************
# -------------------------
# ------>Predictions by Model
# hahahahahahahahahahahahahahahahahahaha
# ----->Predictions Original
# Chad has sent Brennen a funny photo.
# Brennen does not find it very funny.
# **************************
# -------------------------
# ------>Predictions by Model
# Chloe: i need to go to the dentist quickly after work.
# sure
# ----->Predictions Original
# Sadie will borrow Chloe's bike on Wednesday evening.
# She has a dentist appointment on Thursday after work.
# **************************
# -------------------------
# ------>Predictions by Model
# Olivia: I am currently involved with a new restaurant in the city centre.
# Olivia:
# ----->Predictions Original
# Carter is launching a restaurant business next month.
# Olivia wants him to include a restaurant she's working for in the discount app.
# They will meet in person to discuss it.
# **************************
# -------------------------
# ------>Predictions by Model
# he's back from surgery, but the doctors don't know if he
# ----->Predictions Original
# Kenny had a surgery, as Kristine reports.
# He will have another surgery tomorrow.
# Guy will come to St. Mark's Hospital near Asda to stay with Kristine.
# **************************
# -------------------------
# ------>Predictions by Model
# Skyler: i know, he cheated on her with numerous girls.
# ----->Predictions Original
# Skyler and Adam are surprised that Joey and Olivia broke up.
# **************************
# -------------------------
# ------>Predictions by Model
# i'm pregnant!
# i'm so proud of myself!
# i'm
# ----->Predictions Original
# Amanda goes to dancing classes with Michael.
# She volunteered to show the English Waltz steps with the instructor yesterday.
# Amanda is shy and goes to therapy.
# **************************
# -------------------------
# ------>Predictions by Model
# Isabel: I haven’t had any!
# (;)(;)(
# ----->Predictions Original
# Taylor wants to meet Isabel's boyfriend but she has never had any.
# **************************
# -------------------------
# ------>Predictions by Model
# theo: we're going to the italian Alpes, but we'll be back
# ----->Predictions Original
# Theo's going to stay near Torino in the region of Italian Alpes.
# Toby wants to join the trip.
# Theo agrees and will pick Toby up on Friday at 7 am.
# **************************
# -------------------------
# ------>Predictions by Model
# Brandon hasn't called to say he'd be late.
# he'
# ----->Predictions Original
# Brandon is late again.
# Clara will prepare a report on the absenteeism and lateness for Phil by Friday.
# **************************
# -------------------------
# ------>Predictions by Model
# Olga: I'm sick again... and I'm caughing like crazy
# ----->Predictions Original
# Olga and Suzie will postpone their meeting due to Suzie's sickness.
# **************************
# -------------------------
# ------>Predictions by Model
# awww :3 Kate: yes, I'm terrified.
# awww
# ----->Predictions Original
# Diane is pregnant and can't wait to give birth, she thinks the waiting is the worst.
# Kate thinks she'll be an amazing mother.
# **************************
# -------------------------
# ------>Predictions by Model
# Andrew: i can never guess the weather right you know?
# he says it's
# ----->Predictions Original
# Andrew has a cold.
# Daniel will buy him some medication.
# **************************
# -------------------------
# ------>Predictions by Model
# 'Millionaires' on tvn Sam: ok, fingers crossed then
# ----->Predictions Original
# Alex and Sam are watching Millionaires.
# **************************
# -------------------------
# ------>Predictions by Model
# Kelly: Thanks :*
# ----->Predictions Original
# Angelica sent the cinnamon cookies recipe at Kelly's request.
# **************************
# -------------------------
# ------>Predictions by Model
# Sophie: he's already 40 min late Sophie: i hate this!
# ----->Predictions Original
# Sophie is waiting for a client, who is late.
# She will meet Gwen later.
# **************************
# -------------------------
# ------>Predictions by Model
# Sue: i'm going downstairs now Daniel: 'i'm on my way
# ----->Predictions Original
# Daniel is with the Volvo on his way and will be there soon.
# Sue is going downstairs to meet him.
# **************************
# -------------------------
# ------>Predictions by Model
# stuffed squash with salmon?
# Probably.
# stuffed squash with salmon?
# i'
# ----->Predictions Original
# George is making salmon and stuffed squash for dinner.
# Betty will buy a shaving cream at CVS at his request,
# **************************
# -------------------------
# ------>Predictions by Model
# endomondo doesn't work properly I think or maybe there's something wrong with
# ----->Predictions Original
# Ken has installed an app for running but it is not working properly on his phone.
# **************************
# -------------------------
# ------>Predictions by Model
# Ivan: ok, you'll come next time Ivan: ok, you
# ----->Predictions Original
# Ivan and Ann will meet next week.
# **************************
# -------------------------
# ------>Predictions by Model
# Ashley's nude fb page is a hit with her students.
# she
# ----->Predictions Original
# Ashley posted some nude photos on her fb page.
# **************************
# -------------------------
# ------>Predictions by Model
# a letter says that the papers won't be sent in time and need another month
# ----->Predictions Original
# Mikolaj's wife needs a work permit as a foreigner.
# Government officials missed the deadline for sending it and will need another month.
# **************************
# -------------------------
# ------>Predictions by Model
# Maria: ok, why not?
# ----->Predictions Original
# Thomas, Ann and Maria will have lunch together at the hotel.
# Ann is already in the 3rd floor lobby at the red table.
# **************************
# -------------------------
# ------>Predictions by Model
# sus: don't wanna work :D Val: I know :D
# ----->Predictions Original
# Sus and Val don't want to work and are sleepy.
# **************************
# -------------------------
# ------>Predictions by Model
# we're at the Guggenheim right now, so it will take a bit
# ----->Predictions Original
# Kate is at the Guggenheim Museum now, but will be in the Museum of the City of New York around 2-2:30.
# Kai may join her.
# Ish won't.
# Terry will join them for a coffee after they finish visiting the museum.
# Terry has already seen the museum.
# **************************
# -------------------------
# ------>Predictions by Model
# Cathy: i left my sunglasses at your house Broke: Yeah, they are waiting
# ----->Predictions Original
# Cathy left her sunglasses at Broke's house.
# She will come collect them at 10.
# **************************
# -------------------------
# ------>Predictions by Model
# Frederica: ok, see you tomorrow!
# Bradley: Great!
# you?
# Freder
# ----->Predictions Original
# Bradley will come to Frederica's birthday party tomorrow at 8pm.
# **************************
# -------------------------
# ------>Predictions by Model
# Adrian: Did you receive the money?
# Camilla: Yes, let me know when you have
# ----->Predictions Original
# Camilla still hasn't received the 250.
# She will check and let Adrian know.
# Money usually takes around two days to arrive.
# **************************
# {'eval_loss': 2.411588191986084,
#  'eval_rouge1': 24.5734,
#  'eval_rouge2': 7.6639,
#  'eval_rougeL': 20.7835,
#  'eval_rougeLsum': 22.5135,
#  'eval_gen_len': 18.3191,
#  'eval_runtime': 135.4583,
#  'eval_samples_per_second': 6.039,
#  'eval_steps_per_second': 0.76}

# %%
trainer.train()
# Out:
# The following columns in the training set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: summary, id, dialogue. If summary, id, dialogue are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 14732
#   Num Epochs = 5
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 9210
#   Number of trainable parameters = 222903552
#     <div>
#
#       <progress value='86' max='9210' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [  86/9210 01:48 < 3:16:55, 0.77 it/s, Epoch 0.05/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-3435b262f1ae> in <module>
# ----> 1 trainer.train()
#
# /usr/local/lib/python3.7/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1503             resume_from_checkpoint=resume_from_checkpoint,
#    1504             trial=trial,
# -> 1505             ignore_keys_for_eval=ignore_keys_for_eval,
#    1506         )
#    1507
#
# /usr/local/lib/python3.7/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1747                         tr_loss_step = self.training_step(model, inputs)
#    1748                 else:
# -> 1749                     tr_loss_step = self.training_step(model, inputs)
#    1750
#    1751                 if (
#
# /usr/local/lib/python3.7/dist-packages/transformers/trainer.py in training_step(self, model, inputs)
#    2506
#    2507         with self.compute_loss_context_manager():
# -> 2508             loss = self.compute_loss(model, inputs)
#    2509
#    2510         if self.args.n_gpu > 1:
#
# /content/drive/.shortcut-targets-by-id/1rtx_hDSeJwDb-klWtlCm9K2tgW55qG0Q/NLP Project with SCL/trainer.py in compute_loss(self, model, inputs, return_outputs)
#      13         else:
#      14             labels = None
# ---> 15         outputs = model(**inputs)
#      16
#      17         # Save past state if it exists
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/t5/modeling_t5.py in forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1658             output_attentions=output_attentions,
#    1659             output_hidden_states=output_hidden_states,
# -> 1660             return_dict=return_dict,
#    1661         )
#    1662
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/t5/modeling_t5.py in forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, inputs_embeds, head_mask, cross_attn_head_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1049                     past_key_value=past_key_value,
#    1050                     use_cache=use_cache,
# -> 1051                     output_attentions=output_attentions,
#    1052                 )
#    1053
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/t5/modeling_t5.py in forward(self, hidden_states, attention_mask, position_bias, encoder_hidden_states, encoder_attention_mask, encoder_decoder_position_bias, layer_head_mask, cross_attn_layer_head_mask, past_key_value, use_cache, output_attentions, return_dict)
#     678             past_key_value=self_attn_past_key_value,
#     679             use_cache=use_cache,
# --> 680             output_attentions=output_attentions,
#     681         )
#     682         hidden_states, present_key_value_state = self_attention_outputs[:2]
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/t5/modeling_t5.py in forward(self, hidden_states, attention_mask, position_bias, layer_head_mask, past_key_value, use_cache, output_attentions)
#     584             past_key_value=past_key_value,
#     585             use_cache=use_cache,
# --> 586             output_attentions=output_attentions,
#     587         )
#     588         hidden_states = hidden_states + self.dropout(attention_output[0])
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/t5/modeling_t5.py in forward(self, hidden_states, mask, key_value_states, position_bias, past_key_value, layer_head_mask, query_length, use_cache, output_attentions)
#     503         )
#     504         value_states = project(
# --> 505             hidden_states, self.v, key_value_states, past_key_value[1] if past_key_value is not None else None
#     506         )
#     507
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/t5/modeling_t5.py in project(hidden_states, proj_layer, key_value_states, past_key_value)
#     479                 # self-attn
#     480                 # (batch_size, n_heads, seq_length, dim_per_head)
# --> 481                 hidden_states = shape(proj_layer(hidden_states))
#     482             elif past_key_value is None:
#     483                 # cross-attn
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     112
#     113     def forward(self, input: Tensor) -> Tensor:
# --> 114         return F.linear(input, self.weight, self.bias)
#     115
#     116     def extra_repr(self) -> str:
#
# KeyboardInterrupt:

# %%
trainer.evaluate()
