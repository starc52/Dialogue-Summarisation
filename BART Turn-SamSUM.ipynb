# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

# %%
# !pip install wandb
# !wandb login
# Out:
# Requirement already satisfied: wandb in /usr/local/lib/python3.7/dist-packages (0.13.5)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.9.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (7.1.2)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.3)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (5.4.8)
# Requirement already satisfied: pathtools in /usr/local/lib/python3.7/dist-packages (from wandb) (0.1.2)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.7/dist-packages (from wandb) (1.3.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.23.0)
# Requirement already satisfied: protobuf!=4.0.*,!=4.21.0,<5,>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.17.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from wandb) (6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from wandb) (57.4.0)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.15.0)
# Requirement already satisfied: shortuuid>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.0.11)
# Requirement already satisfied: GitPython>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.1.29)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb) (4.0.10)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb) (3.10.0.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from gitdb<5,>=4.0.1->GitPython>=1.0.0->wandb) (5.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# wandb: Currently logged in as: hiteshwarjmu (akatsuki_leaf). Use `wandb login --relogin` to force relogin

# %%
import wandb

wandb.init(project="BART-Turn-SAMSum", entity="akatsuki_leaf")
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: hiteshwarjmu (akatsuki_leaf). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221203_210437-3kenspnr</code>
# Syncing run <strong><a href="https://wandb.ai/akatsuki_leaf/BART-Turn-SAMSum/runs/3kenspnr" target="_blank">dashing-fog-4</a></strong> to <a href="https://wandb.ai/akatsuki_leaf/BART-Turn-SAMSum" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src="https://wandb.ai/akatsuki_leaf/BART-Turn-SAMSum/runs/3kenspnr?jupyter=true" style="border:none;width:100%;height:420px;display:none;"></iframe>

# %%
import torch

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
print()

if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    
    print('Memory Usage:',round(torch.cuda.get_device_properties(0).total_memory/1024**3,1), 'GB')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_cached(0)/1024**3,1), 'GB')
# Out:
# Using device: cuda
#
# Tesla T4
# Memory Usage: 14.8 GB
# Allocated: 0.0 GB
# Cached:    0.0 GB
# /usr/local/lib/python3.7/dist-packages/torch/cuda/memory.py:386: FutureWarning: torch.cuda.memory_cached has been renamed to torch.cuda.memory_reserved
#   FutureWarning)

# %%
import torch
import numpy as np
import random

def set_random_seed(seed):
     torch.manual_seed(seed)
     torch.cuda.manual_seed_all(seed)
     np.random.seed(seed)
     random.seed(seed)
     torch.backends.cudnn.deterministic = True
set_random_seed(0)

# %%
! pip install datasets transformers rouge-score nltk py7zr
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.7/dist-packages (2.7.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.25.1)
# Requirement already satisfied: rouge-score in /usr/local/lib/python3.7/dist-packages (0.1.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.2.5)
# Requirement already satisfied: py7zr in /usr/local/lib/python3.7/dist-packages (0.20.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets) (0.70.12.2)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.11.1)
# Requirement already satisfied: dill<0.3.7 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.4)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets) (3.8.3)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (2022.11.0)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.18.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets) (4.11.1)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2.23.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets) (1.21.5)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (4.62.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.7/dist-packages (from datasets) (3.1.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (21.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (6.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (3.10.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.8.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (2.0.12)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (0.13.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (3.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets) (3.0.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2021.10.8)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.13.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from rouge-score) (1.0.0)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from rouge-score) (1.15.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from py7zr) (5.4.8)
# Requirement already satisfied: inflate64>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from py7zr) (0.3.1)
# Requirement already satisfied: pyzstd>=0.14.4 in /usr/local/lib/python3.7/dist-packages (from py7zr) (0.15.3)
# Requirement already satisfied: multivolumefile>=0.2.3 in /usr/local/lib/python3.7/dist-packages (from py7zr) (0.2.3)
# Requirement already satisfied: pyppmd<1.1.0,>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from py7zr) (1.0.0)
# Requirement already satisfied: brotli>=1.0.9 in /usr/local/lib/python3.7/dist-packages (from py7zr) (1.0.9)
# Requirement already satisfied: pycryptodomex>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from py7zr) (3.16.0)
# Requirement already satisfied: texttable in /usr/local/lib/python3.7/dist-packages (from py7zr) (1.6.7)
# Requirement already satisfied: pybcj>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from py7zr) (1.0.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets) (3.7.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.2)

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/NLP Project with SCL

# %% [markdown]
# # Fine-tuning a model on a summarization task

# %% [markdown]
# ## Loading the dataset

# %%
from datasets import load_dataset, load_metric

raw_datasets = load_dataset("samsum")

metric = load_metric("rouge")
# Out:
# Found cached dataset samsum (/root/.cache/huggingface/datasets/samsum/samsum/0.0.0/f1d7c6b7353e6de335d444e424dc002ef70d1277109031327bc9cc6af5d3d46e)
#   0%|          | 0/3 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   """

# %% [markdown]
# ## BART

# %% [markdown]
# ### Preprocessing the data

# %%
model_checkpoint = "facebook/bart-base"

# %%
from transformers import AutoTokenizer
    
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

# %%
def check_token_length(dataset):
    ids=[]
    for i in range(len(dataset['dialogue'])):
        if len(tokenizer(dataset['dialogue'][i])['input_ids'])>1000:
            ids.append(i)
    print(ids)
    return ids
def remove_idx(list_idx, dataset):
    return dataset.select((
          i for i in range(len(dataset)) 
          if i not in set(list_idx)))
    
train_ids=check_token_length(raw_datasets['train'])
validation_ids=check_token_length(raw_datasets['validation'])
test_ids = check_token_length(raw_datasets['test'])
changed_datasets_train=remove_idx(train_ids, raw_datasets['train'])
changed_datasets_val = remove_idx(validation_ids, raw_datasets['validation'])
changed_datasets_test = remove_idx(test_ids, raw_datasets['test'])
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (1081 > 1024). Running this sequence through the model will result in indexing errors
# [4269, 8198]
# []
# Parameter 'indices'=<generator object remove_idx.<locals>.<genexpr> at 0x7f8267a67d50> of the transform datasets.arrow_dataset.Dataset.select couldn't be hashed properly, a random hash was used instead. Make sure your transforms and parameters are serializable with pickle or dill for the dataset fingerprinting and caching to work. If you reuse this transform, the caching mechanism will consider it to be different from the previous calls and recompute everything. This warning is only showed once. Subsequent hashing failures won't be showed.
# []

# %%
max_input_length = 1024
max_target_length = 128

def make_one_hot_sequence(input_ids, sequence_ids):
    changed_sequence_id=[0]
    token_to_speaker_id={}
    uniq_id = 1
    for dic in sequence_ids:
        if str(input_ids[dic['spk'][0]:dic['spk'][1]]) in token_to_speaker_id:
            speaker_id = token_to_speaker_id[str(input_ids[dic['spk'][0]:dic['spk'][1]])]
        else:
            token_to_speaker_id[str(input_ids[dic['spk'][0]:dic['spk'][1]])] = uniq_id
            speaker_id = uniq_id
            uniq_id+=1
        for _ in range(dic['spk'][0], dic['spk'][1]):
            changed_sequence_id.append(speaker_id)
        for _ in range(dic['utt'][0], dic['utt'][1]):
            changed_sequence_id.append(-1)
    changed_sequence_id.append(0)
    return changed_sequence_id 


def preprocess_function(examples): ## hit gold here. change this preprocess function to include speaker and turn information. 
    slash_n = tokenizer(["\r\n"])['input_ids'][0][1:-1]
    slash_n_mask = tokenizer(["\r\n"])['attention_mask'][0][1:-1]
    inputs_list=[]
    masks_list=[]
    pos_list=[]
    for index in range(len(examples['dialogue'])):
        # breaking the dialogue for spk:utt info
        broken=[]
        for utt in examples['dialogue'][index].split("\r\n"):
            first_ind = utt.find(':')
            broken.append(utt[:first_ind])
            broken.append(utt[first_ind:])
        
        tokenized_broken = tokenizer(broken)['input_ids']
        attention_broken = tokenizer(broken)['attention_mask']
        
        # adding \r\n tokens
        for i in range(1, len(tokenized_broken)-1, 2):
            tokenized_broken[i].insert(-1, slash_n[0])
            tokenized_broken[i].insert(-1, slash_n[1])
            attention_broken[i].insert(-1, slash_n_mask[0])
            attention_broken[i].insert(-1, slash_n_mask[1])
        joined = tokenized_broken[0]

        # annotating for spk_utt_pos
        assoc_dict={}
        assoc_dict['spk'] = [1, len(tokenized_broken[0])-1] # the range is actually exclusive of the last index. 
        odd_bool = True
        running_length = len(tokenized_broken[0])
        sequence_ids=[]
        for inner in tokenized_broken[1:]:
            if odd_bool==True:
                assoc_dict['utt']=[running_length-1, running_length+len(inner)-3]
                odd_bool=False
                sequence_ids.append(assoc_dict)
                assoc_dict={}
            else:
                assoc_dict['spk']=[running_length-1, running_length+len(inner)-3]
                odd_bool=True
            joined = joined[:-1]+inner[1:]
            running_length += (len(inner)-2)
        
        # test for CUDA assert error
        if(len(joined)>1024):
            print("input tokens list length greater than 1024, skipping example", end=' ')
            print("equal to", len(joined))
            print(tokenizer.decode(joined))
        
        # creating inputs list
        inputs_list.append(joined)
        pos_list.append(make_one_hot_sequence(joined, sequence_ids))
        
        # creating new mask
        joined_mask = attention_broken[0]
        for inner_attention in attention_broken[1:]:
            joined_mask = joined_mask[:-1]+inner_attention[1:]
        masks_list.append(joined_mask)
    
    # overriding normal model_inputs
    inputs = [doc for doc in examples["dialogue"]]
    model_inputs = tokenizer(inputs, max_length=max_input_length, truncation=True)
    model_inputs['input_ids'] = inputs_list
    model_inputs['attention_mask'] = masks_list
    model_inputs['spk_utt_pos'] = pos_list
    with tokenizer.as_target_tokenizer():
        labels = tokenizer(examples["summary"], max_length=max_target_length, truncation=True)

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# %%
tokenized_datasets_train_o = changed_datasets_train.map(preprocess_function, batched=True)
tokenized_datasets_val_o = changed_datasets_val.map(preprocess_function, batched=True)
tokenized_datasets_test_o = changed_datasets_test.map(preprocess_function, batched=True)

# tokenized_datasets = raw_datasets.map(preprocess_function, batched=True)
tokenized_datasets_train = tokenized_datasets_train_o.remove_columns(['id', 'dialogue', 'summary'])
tokenized_datasets_val = tokenized_datasets_val_o.remove_columns(['id', 'dialogue', 'summary'])
tokenized_datasets_test = tokenized_datasets_test_o.remove_columns(['id', 'dialogue', 'summary'])
# Out:
# Loading cached processed dataset at /root/.cache/huggingface/datasets/samsum/samsum/0.0.0/f1d7c6b7353e6de335d444e424dc002ef70d1277109031327bc9cc6af5d3d46e/cache-af3edf4ad62c7168.arrow
#   0%|          | 0/1 [00:00<?, ?ba/s]
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:3579: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   "`as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your "
# Loading cached processed dataset at /root/.cache/huggingface/datasets/samsum/samsum/0.0.0/f1d7c6b7353e6de335d444e424dc002ef70d1277109031327bc9cc6af5d3d46e/cache-7fa8170f3deb22d9.arrow

# %%
from transformers import Seq2SeqTrainer
from transformers.modeling_utils import unwrap_model
from transformers.models.auto.modeling_auto import MODEL_FOR_CAUSAL_LM_MAPPING_NAMES


class CustomTrainer(Seq2SeqTrainer):
    def compute_loss(self, model, inputs, return_outputs=False):
        # How the loss is computed by Trainer. By default, all models return the loss in the first element.
        # Subclass and override for custom behavior.
        # print(inputs)
        if self.label_smoother is not None and "labels" in inputs:
            labels = inputs.pop("labels")
        else:
            labels = None
        outputs = model(**inputs)

        # Save past state if it exists
        # TODO: this needs to be fixed and mselfade cleaner later.

        if self.args.past_index >= 0:
            self._past = outputs[self.args.past_index]

        if labels is not None:
            if unwrap_model(model)._get_name() in MODEL_FOR_CAUSAL_LM_MAPPING_NAMES.values():
                loss = self.label_smoother(outputs, labels, shift_labels=True)
            else:
                loss = self.label_smoother(outputs, labels)
        else:
            if isinstance(outputs, dict) and "loss" not in outputs:
                raise ValueError(
                    "The model did not return a loss from the inputs, only the following keys: "
                    f"{','.join(outputs.keys())}. For reference, the inputs it received are {','.join(inputs.keys())}."
                )
            # We don't use .loss here since the model may return tuples instead of ModelOutput.
            loss = outputs["loss"] if isinstance(outputs, dict) else outputs[0]
        return (loss, outputs) if return_outputs else loss

# %%
from transformers import PreTrainedTokenizerBase
from transformers.utils import PaddingStrategy
from transformers import DataCollatorForSeq2Seq
from typing import Optional, Any, Union
import numpy as np


class CustomCollatorForSeq2Seq(DataCollatorForSeq2Seq):
    r"""
    Data collator that will dynamically pad the inputs received, as well as the labels.
    Args:
        tokenizer ([`PreTrainedTokenizer`] or [`PreTrainedTokenizerFast`]):
            The tokenizer used for encoding the data.
        model ([`PreTrainedModel`]):
            The model that is being trained. If set and has the *prepare_decoder_input_ids_from_labels*, use it to
            prepare the *decoder_input_ids*
            This is useful when using *label_smoothing* to avoid calculating loss twice.
        padding (`bool`, `str` or [`~utils.PaddingStrategy`], *optional*, defaults to `True`):
            Select a strategy to pad the returned sequences (according to the model's padding side and padding index)
            among:
            - `True` or `'longest'`: Pad to the longest sequence in the batch (or no padding if only a single sequence
              is provided).
            - `'max_length'`: Pad to a maximum length specified with the argument `max_length` or to the maximum
              acceptable input length for the model if that argument is not provided.
            - `False` or `'do_not_pad'` (default): No padding (i.e., can output a batch with sequences of different
              lengths).
        max_length (`int`, *optional*):
            Maximum length of the returned list and optionally padding length (see above).
        pad_to_multiple_of (`int`, *optional*):
            If set will pad the sequence to a multiple of the provided value.
            This is especially useful to enable the use of Tensor Cores on NVIDIA hardware with compute capability >=
            7.5 (Volta).
        label_pad_token_id (`int`, *optional*, defaults to -100):
            The id to use when padding the labels (-100 will be automatically ignored by PyTorch loss functions).
        return_tensors (`str`):
            The type of Tensor to return. Allowable values are "np", "pt" and "tf".
    """

    tokenizer: PreTrainedTokenizerBase
    model: Optional[Any] = None
    padding: Union[bool, str, PaddingStrategy] = True
    max_length: Optional[int] = None
    pad_to_multiple_of: Optional[int] = None
    label_pad_token_id: int = -100
    return_tensors: str = "pt"

    def __call__(self, features, return_tensors=None):
        if return_tensors is None:
            return_tensors = self.return_tensors
        labels = [feature["labels"] for feature in features] if "labels" in features[0].keys() else None
        # We have to pad the labels before calling `tokenizer.pad` as this method won't pad them and needs them of the
        # same length to return tensors.
        if labels is not None:
            max_label_length = max(len(l) for l in labels)
            if self.pad_to_multiple_of is not None:
                max_label_length = (
                        (max_label_length + self.pad_to_multiple_of - 1)
                        // self.pad_to_multiple_of
                        * self.pad_to_multiple_of
                )

            padding_side = self.tokenizer.padding_side
            for feature in features:
                remainder = [self.label_pad_token_id] * (max_label_length - len(feature["labels"]))
                if isinstance(feature["labels"], list):
                    feature["labels"] = (
                        feature["labels"] + remainder if padding_side == "right" else remainder + feature["labels"]
                    )
                elif padding_side == "right":
                    feature["labels"] = np.concatenate([feature["labels"], remainder]).astype(np.int64)
                else:
                    feature["labels"] = np.concatenate([remainder, feature["labels"]]).astype(np.int64)
        # added here
        spk_utt_pos = [feature["spk_utt_pos"] for feature in features]
        max_spk_utt_pos_length = max(len(l) for l in spk_utt_pos)

        if self.pad_to_multiple_of is not None:
            max_spk_utt_pos_length = (
                    (max_spk_utt_pos_length + self.pad_to_multiple_of - 1)
                    // self.pad_to_multiple_of
                    * self.pad_to_multiple_of
            )

        padding_side = self.tokenizer.padding_side
        for feature in features:
            remainder = [0] * (max_spk_utt_pos_length - len(feature["spk_utt_pos"]))
            if isinstance(feature["spk_utt_pos"], list):
                feature["spk_utt_pos"] = (
                    feature["spk_utt_pos"] + remainder if padding_side == "right" else remainder + feature[
                        "spk_utt_pos"]
                )
            elif padding_side == "right":
                feature["spk_utt_pos"] = np.concatenate([feature["spk_utt_pos"], remainder]).astype(np.int64)
            else:
                feature["spk_utt_pos"] = np.concatenate([remainder, feature["spk_utt_pos"]]).astype(np.int64)

        features = self.tokenizer.pad(
            features,
            padding=self.padding,
            max_length=self.max_length,
            pad_to_multiple_of=self.pad_to_multiple_of,
            return_tensors=return_tensors,
        )

        # prepare decoder_input_ids
        if (
                labels is not None
                and self.model is not None
                and hasattr(self.model, "prepare_decoder_input_ids_from_labels")
        ):
            decoder_input_ids = self.model.prepare_decoder_input_ids_from_labels(labels=features["labels"])
            features["decoder_input_ids"] = decoder_input_ids

        return features

# %%
from torch import nn
from transformers import BartForConditionalGeneration, DataCollatorForSeq2Seq, Seq2SeqTrainingArguments, Seq2SeqTrainer
from transformers.modeling_utils import unwrap_model
from transformers.models.auto.modeling_auto import MODEL_FOR_CAUSAL_LM_MAPPING_NAMES

from transformers.models.bart.modeling_bart import BartConfig
import torch
from typing import *
from transformers.modeling_outputs import Seq2SeqLMOutput
from transformers.models.bart.modeling_bart import shift_tokens_right
import random
from tqdm import tqdm
import gc
import itertools

class BartWithSCL(BartForConditionalGeneration):
    def __init__(self, config: BartConfig):
        super().__init__(config)

    def set_losses_list(self, SCLossesList=['token']):
        self.SCLossesList = SCLossesList
    def set_scl_coeff(self, scl_coeff=1e-1):
        self.scl_coeff=scl_coeff
    def token_scl(self,
                  last_hidden_state: torch.FloatTensor,
                  spk_utt_pos: torch.LongTensor,
    ) -> torch.FloatTensor:
        r"""
        last_hidden_state (torch.LongTensor) of shape (batch_size, sequence_length, n_dims):
            Output of the last layer of the encoder.
        spk_utt_pos (torch.LongTensor) of shape (batch_size, sequence_length,):
            metadata about the speaker tokens and utterance tokens
        Returns:
        Token Level Supervised Constrastive Loss (torch.LongTensor)
        """
        batch_scl = 0
        for i in range(len(spk_utt_pos)):
            batch_element = spk_utt_pos[i]
            spk_utt_list = []
            spk_dict = {'start': 0, 'end': 0, 'spk_id': 0, 'bool': False}
            utt_dict = {'start': 0, 'end': 0, 'spk_id': 0, 'bool': False}
            for j in range(len(batch_element)):
                if batch_element[j] == 0 and j > 0:
                    utt_dict['end'] = j
                    utt_dict['bool'] = False
                    spk_utt_list.append({'spk': [spk_dict['start'], spk_dict['end'], spk_dict['spk_id']],
                                         'utt': [utt_dict['start'], utt_dict['end'], utt_dict['spk_id']]})
                    break
                if batch_element[j] > 0 and spk_dict['bool'] == False:
                    utt_dict['end'] = j
                    utt_dict['bool'] = False
                    if j > 1:
                        spk_utt_list.append({'spk': [spk_dict['start'], spk_dict['end'], spk_dict['spk_id']],
                                             'utt': [utt_dict['start'], utt_dict['end'], utt_dict['spk_id']]})
                    spk_dict['start'] = j
                    spk_dict['bool'] = True
                    spk_dict['spk_id'] = batch_element[j]
                    

                if batch_element[j] < 0 and spk_dict['bool'] == True:
                    spk_dict['end'] = j
                    spk_dict['bool'] = False
                    utt_dict['spk_id'] = spk_dict['spk_id']
                    utt_dict['start'] = j
                    utt_dict['bool'] = True
            # uniq spks
            if spk_utt_list[0]['spk'][2]==0:
                continue
            uniq_spks = list(set([int(dic['spk'][2].cpu()) for dic in spk_utt_list]))
            if len(uniq_spks)==1:
                continue
            # spk_utt_states
            spk_utt_states = {spk: [] for spk in uniq_spks}

            for spk in uniq_spks:
                for dic in spk_utt_list:
                    if spk == dic['utt'][2]:
                        spk_utt_states[spk].append(last_hidden_state[i, dic['utt'][0]:dic['utt'][1]])
            
            
            #---------- hitesh------------------------------
            # positive samples
            # L_pos = 0
            # L_neg = 0 

            # sampled_spk_utt_states = []           

            # for spk in uniq_spks:
            #     utts = len(spk_utt_states[spk])
            #     spk_utt = []
            #     if utts > 1:
            #         # ids = random.sample(list(range(len(spk_utt_states[spk]))), random.randint(1, utts))
            #         ids = random.sample(list(range(len(spk_utt_states[spk]))), 2)
            #         for i in ids:
            #           spk_utt.append(spk_utt_states[spk][i])
            #     sampled_spk_utt_states.append(spk_utt)

            # for instance in sampled_spk_utt_states:
            #   for i in range(len(instance)):
            #     for j in range(len(instance)):
            #       mat_mul = torch.einsum('ij, kj->ik', instance[i], instance[j])
            #       sigm = torch.sigmoid(mat_mul)
            #       log = torch.log(sigm)
            #       L_pos += torch.sum(-1 * log)
            # # print("L_pos", L_pos)

            # #negative loss
            # for i in range(0,len(sampled_spk_utt_states)):
            #   instance = sampled_spk_utt_states[i]

            #   neg_instances = sampled_spk_utt_states[:i]+sampled_spk_utt_states[i+1:]
            #   neg_instances = list(itertools.chain(*neg_instances))
            #   # neg_instances = random.choices(neg_instances,k = random.randint(1, len(neg_instances)))
            #   if len(neg_instances)>0:
            #     # print(len(neg_instances))
            #     # print("-------------------------")
            #     # print(sampled_spk_utt_states)
            #     neg_instances = random.choices(neg_instances,k = 2)
            #     for i in range(len(instance)):
            #       for j in range(len(neg_instances)):
            #         mat_mul = torch.einsum('ij, kj->ik', instance[i], neg_instances[j])
            #         sigm = torch.sigmoid(mat_mul)
            #         log = torch.log(1 - sigm+1e-5)
            #         L_neg += torch.sum(-1 * log)
            #---------- hitesh------------------------------
            
            
            # positive samples
            L_pos = 0
            for spk in uniq_spks:
                if len(spk_utt_states[spk]) > 1:
                    ids = random.sample(list(range(len(spk_utt_states[spk]))), 2)
                    id1 = ids[0]
                    id2 = ids[1]
                    mat_mul = torch.einsum('ij, kj->ik', spk_utt_states[spk][id1], spk_utt_states[spk][id1])
                    sigm = torch.sigmoid(mat_mul)
                    log = torch.log(sigm)
                    L_pos += torch.sum(-1 * log)
                    L_pos = torch.nan_to_num(L_pos, posinf = 1e10, neginf = -1e10)
            # print("L_pos", L_pos)
            # negative samples
            
            L_neg = 0
            for spk in uniq_spks:
                new_uniq_spks = uniq_spks.copy()
                new_uniq_spks.remove(spk)

                spk2 = random.choice(new_uniq_spks)

                id1 = random.randint(0, len(spk_utt_states[spk])-1)
                id2 = random.randint(0, len(spk_utt_states[spk2])-1)

                mat_mul = torch.einsum('ij, kj->ik', spk_utt_states[spk][id1], spk_utt_states[spk2][id2])
                sigm = torch.sigmoid(mat_mul)
                # print(1 - sigm)
                # print(1 - sigm+1e-5)
                log = torch.log(1 - sigm+1e-5)
                L_neg += torch.sum(-1 * log)
                
                L_neg = torch.nan_to_num(L_neg, posinf = 1e10, neginf = -1e10)

            # print("L_neg", L_neg)
            
            batch_scl += L_pos
            batch_scl += L_neg
            # wand.log({"batch-scl-token", batch_scl})
        batch_scl /= last_hidden_state.size(0)
        gc.collect()
        return batch_scl
    
    def turn_scl(self,
                  last_hidden_state: torch.FloatTensor,
                  spk_utt_pos: torch.LongTensor,
    ) -> torch.FloatTensor:
        r"""
        last_hidden_state (torch.LongTensor) of shape (batch_size, sequence_length, n_dims):
            Output of the last layer of the encoder.
        spk_utt_pos (torch.LongTensor) of shape (batch_size, sequence_length,):
            metadata about the speaker tokens and utterance tokens
        Returns:
        Turn Level Supervised Constrastive Loss (torch.LongTensor)
        """
        batch_scl = 0
        for i in range(len(spk_utt_pos)):
            batch_element = spk_utt_pos[i]
            spk_utt_list = []
            spk_dict = {'start': 0, 'end': 0, 'spk_id': 0, 'bool': False}
            utt_dict = {'start': 0, 'end': 0, 'spk_id': 0, 'bool': False}
            for j in range(len(batch_element)):
                if batch_element[j] == 0 and j > 0:
                    utt_dict['end'] = j
                    utt_dict['bool'] = False
                    spk_utt_list.append({'spk': [spk_dict['start'], spk_dict['end'], spk_dict['spk_id']],
                                         'utt': [utt_dict['start'], utt_dict['end'], utt_dict['spk_id']]})
                    break
                if batch_element[j] > 0 and spk_dict['bool'] == False:
                    utt_dict['end'] = j
                    utt_dict['bool'] = False
                    if j > 1:
                        spk_utt_list.append({'spk': [spk_dict['start'], spk_dict['end'], spk_dict['spk_id']],
                                             'utt': [utt_dict['start'], utt_dict['end'], utt_dict['spk_id']]})
                    spk_dict['start'] = j
                    spk_dict['bool'] = True
                    spk_dict['spk_id'] = batch_element[j]
                    

                if batch_element[j] < 0 and spk_dict['bool'] == True:
                    spk_dict['end'] = j
                    spk_dict['bool'] = False
                    utt_dict['spk_id'] = spk_dict['spk_id']
                    utt_dict['start'] = j
                    utt_dict['bool'] = True
            # uniq spks
            if spk_utt_list[0]['spk'][2]==0:
                continue
            uniq_spks = list(set([int(dic['spk'][2].cpu()) for dic in spk_utt_list]))
            if len(uniq_spks)==1:
                continue
            # spk_utt_states
            spk_utt_states = {spk: [] for spk in uniq_spks}

            for spk in uniq_spks:
                for dic in spk_utt_list:
                    if spk == dic['utt'][2]:
                        mean_pool = torch.mean(last_hidden_state[i, dic['utt'][0]:dic['utt'][1]], 0)
                        spk_utt_states[spk].append(mean_pool)

            # positive samples
            L_pos = 0
            for spk in uniq_spks:
                if len(spk_utt_states[spk]) > 1:
                    ids = random.sample(list(range(len(spk_utt_states[spk]))), 2)
                    id1 = ids[0]
                    id2 = ids[1]
                    mat_mul = torch.einsum('i, j->', spk_utt_states[spk][id1], spk_utt_states[spk][id1])
                    sigm = torch.sigmoid(mat_mul)
                    log = torch.log(sigm)
                    L_pos += torch.sum(-1 * log)
                    # L_pos = torch.nan_to_num(L_pos, posinf = 1e10, neginf = -1e10)
            # print("L_pos", L_pos)
            # negative samples
            L_neg = 0
            for spk in uniq_spks:
                new_uniq_spks = uniq_spks.copy()
                new_uniq_spks.remove(spk)

                spk2 = random.choice(new_uniq_spks)

                id1 = random.randint(0, len(spk_utt_states[spk])-1)
                id2 = random.randint(0, len(spk_utt_states[spk2])-1)

                mat_mul = torch.einsum('i, j->', spk_utt_states[spk][id1], spk_utt_states[spk2][id2])
                sigm = torch.sigmoid(mat_mul)
                # print(1 - sigm)
                # print(1 - sigm+1e-5)
                log = torch.log(1 - sigm+1e-5)
                L_neg += torch.sum(-1 * log)
                
                # L_neg = torch.nan_to_num(L_neg, posinf = 1e10, neginf = -1e10)

            # print("L_neg", L_neg)
            
            batch_scl += L_pos
            batch_scl += L_neg
            # wand.log({"batch-scl-turn", batch_scl})

        batch_scl /= last_hidden_state.size(0)
        gc.collect()
        return batch_scl
    
    def global_scl(self,
                  last_hidden_state: torch.FloatTensor,
                  spk_utt_pos: torch.LongTensor,
    ) -> torch.FloatTensor:
        r"""
        last_hidden_state (torch.LongTensor) of shape (batch_size, sequence_length, n_dims):
            Output of the last layer of the encoder.
        spk_utt_pos (torch.LongTensor) of shape (batch_size, sequence_length,):
            metadata about the speaker tokens and utterance tokens
        Returns:
        Turn Level Supervised Constrastive Loss (torch.LongTensor)
        """
        batch_scl = 0
        for i in range(len(spk_utt_pos)):
            batch_element = spk_utt_pos[i]
            spk_utt_list = []
            spk_dict = {'start': 0, 'end': 0, 'spk_id': 0, 'bool': False}
            utt_dict = {'start': 0, 'end': 0, 'spk_id': 0, 'bool': False}
            for j in range(len(batch_element)):
                if batch_element[j] == 0 and j > 0:
                    utt_dict['end'] = j
                    utt_dict['bool'] = False
                    spk_utt_list.append({'spk': [spk_dict['start'], spk_dict['end'], spk_dict['spk_id']],
                                         'utt': [utt_dict['start'], utt_dict['end'], utt_dict['spk_id']]})
                    break
                if batch_element[j] > 0 and spk_dict['bool'] == False:
                    utt_dict['end'] = j
                    utt_dict['bool'] = False
                    if j > 1:
                        spk_utt_list.append({'spk': [spk_dict['start'], spk_dict['end'], spk_dict['spk_id']],
                                             'utt': [utt_dict['start'], utt_dict['end'], utt_dict['spk_id']]})
                    spk_dict['start'] = j
                    spk_dict['bool'] = True
                    spk_dict['spk_id'] = batch_element[j]
                    

                if batch_element[j] < 0 and spk_dict['bool'] == True:
                    spk_dict['end'] = j
                    spk_dict['bool'] = False
                    utt_dict['spk_id'] = spk_dict['spk_id']
                    utt_dict['start'] = j
                    utt_dict['bool'] = True
            # uniq spks
            if spk_utt_list[0]['spk'][2]==0:
                continue
            uniq_spks = list(set([int(dic['spk'][2].cpu()) for dic in spk_utt_list]))
            if len(uniq_spks)==1:
                continue
            # spk_utt_states
            spk_utt_states = {spk: [] for spk in uniq_spks}

            for spk in uniq_spks:
                for dic in spk_utt_list:
                    if spk == dic['utt'][2]:
                        mean_pool = torch.mean(last_hidden_state[i, dic['utt'][0]:dic['utt'][1]], 0)
                        spk_utt_states[spk].append(mean_pool)

            # positive samples
            L_pos = 0
            L_neg = 0
            for spk in uniq_spks:
                if len(spk_utt_states[spk]) > 1:
                    ids = random.choice(list(range(len(spk_utt_states[spk]))))
                    
                    spk_mean_exc = torch.mean(torch.vstack([spk_utt_states[spk][temp] for temp in range(len(spk_utt_states[spk])) if temp != ids]), 0)
                    
                    pos_mat_mul = torch.einsum('i, j->', spk_utt_states[spk][ids], spk_mean_exc)
                    pos_sigm = torch.sigmoid(pos_mat_mul)
                    pos_log = torch.log(pos_sigm)
                    L_pos += torch.sum(-1 * pos_log)

                    # negative sample

                    new_uniq_spks = uniq_spks.copy()
                    new_uniq_spks.remove(spk)
                    
                    spk2 = random.choice(new_uniq_spks)
                    id_neg = random.choice(list(range(len(spk_utt_states[spk2]))))
                    neg_mat_mul = torch.einsum('i, j->', spk_utt_states[spk2][id_neg], spk_mean_exc)
                    neg_sigm = torch.sigmoid(neg_mat_mul)
                    neg_log = torch.log(1 - neg_sigm+1e-5)
                    L_neg += torch.sum(-1 * neg_log)
                

            # print("L_neg", L_neg)
            
            batch_scl += L_pos
            batch_scl += L_neg
            # wand.log({"batch-scl-global", batch_scl})

        batch_scl /= last_hidden_state.size(0)
        gc.collect()
        return batch_scl

    def forward(
            self,
            input_ids: torch.LongTensor = None,
            attention_mask: Optional[torch.Tensor] = None,
            spk_utt_pos: Optional[torch.Tensor] = None, ##changed here
            decoder_input_ids: Optional[torch.LongTensor] = None,
            decoder_attention_mask: Optional[torch.LongTensor] = None,
            head_mask: Optional[torch.Tensor] = None,
            decoder_head_mask: Optional[torch.Tensor] = None,
            cross_attn_head_mask: Optional[torch.Tensor] = None,
            encoder_outputs: Optional[List[torch.FloatTensor]] = None,
            past_key_values: Optional[List[torch.FloatTensor]] = None,
            inputs_embeds: Optional[torch.FloatTensor] = None,
            decoder_inputs_embeds: Optional[torch.FloatTensor] = None,
            labels: Optional[torch.LongTensor] = None,
            use_cache: Optional[bool] = None,
            output_attentions: Optional[bool] = None,
            output_hidden_states: Optional[bool] = None,
            return_dict: Optional[bool] = None,
    ) -> Union[Tuple, Seq2SeqLMOutput]:
        r"""
        labels (`torch.LongTensor` of shape `(batch_size, sequence_length)`, *optional*):
            Labels for computing the masked language modeling loss. Indices should either be in `[0, ...,
            config.vocab_size]` or -100 (see `input_ids` docstring). Tokens with indices set to `-100` are ignored
            (masked), the loss is only computed for the tokens with labels in `[0, ..., config.vocab_size]`.
        Returns:
        """
        return_dict = return_dict if return_dict is not None else self.config.use_return_dict

        if labels is not None:
            if use_cache:
                logger.warning("The `use_cache` argument is changed to `False` since `labels` is provided.")
            use_cache = False
            if decoder_input_ids is None and decoder_inputs_embeds is None:
                decoder_input_ids = shift_tokens_right(
                    labels, self.config.pad_token_id, self.config.decoder_start_token_id
                )
        outputs = self.model(
            input_ids,
            attention_mask=attention_mask,
            decoder_input_ids=decoder_input_ids,
            encoder_outputs=encoder_outputs,
            decoder_attention_mask=decoder_attention_mask,
            head_mask=head_mask,
            decoder_head_mask=decoder_head_mask,
            cross_attn_head_mask=cross_attn_head_mask,
            past_key_values=past_key_values,
            inputs_embeds=inputs_embeds,
            decoder_inputs_embeds=decoder_inputs_embeds,
            use_cache=use_cache,
            output_attentions=output_attentions,
            output_hidden_states=output_hidden_states,
            return_dict=return_dict,
        )

        if encoder_outputs is None:
            encoder = self.get_encoder()
            # TODO: mask the speaker names from the input IDs using the speaker pos info
            turn_attention_mask=None
            token_encoder_outputs=None
            tog_encoder_outputs=None
            
            if 'token' in self.SCLossesList:
                token_encoder_outputs = encoder(
                    input_ids=input_ids,
                    attention_mask=attention_mask,
                    head_mask=head_mask,
                    inputs_embeds=inputs_embeds,
                    output_attentions=output_attentions,
                    output_hidden_states=output_hidden_states,
                    return_dict=return_dict,
                )

            if 'turn' in self.SCLossesList or 'global' in self.SCLossesList:
                tog_attention_mask = torch.where(spk_utt_pos>0, 0, attention_mask)
                tog_encoder_outputs = encoder(
                    input_ids=input_ids,
                    attention_mask=tog_attention_mask,
                    head_mask=head_mask,
                    inputs_embeds=inputs_embeds,
                    output_attentions=output_attentions,
                    output_hidden_states=output_hidden_states,
                    return_dict=return_dict,
                )
        # if 'hidden_states' in encoder_outputs:
        #     print("encoder_outputs['last_hidden_state'].size(), encoder_outputs['hidden_states'].size()",
        #     encoder_outputs['last_hidden_state'].size(), encoder_outputs['hidden_states'].size())
        # else:
        #     print("encoder_outputs['last_hidden_state'].size()", encoder_outputs['last_hidden_state'].size())

        lm_logits = self.lm_head(outputs[0])
        lm_logits = lm_logits + self.final_logits_bias.to(lm_logits.device)

        masked_lm_loss = None
        if labels is not None:
            loss_fct = torch.nn.CrossEntropyLoss()
            masked_lm_loss = loss_fct(lm_logits.view(-1, self.config.vocab_size), labels.view(-1))
        # added here
        sc_loss = 0
        if 'token' in self.SCLossesList and labels is not None:
            sc_loss += self.token_scl(last_hidden_state=token_encoder_outputs['last_hidden_state'], spk_utt_pos=spk_utt_pos)
            # print(sc_loss)
        if 'turn' in self.SCLossesList and labels is not None:
            sc_loss += self.turn_scl(last_hidden_state=tog_encoder_outputs['last_hidden_state'], spk_utt_pos=spk_utt_pos)
        
        if 'global' in self.SCLossesList and labels is not None:
            sc_loss += self.global_scl(last_hidden_state=tog_encoder_outputs['last_hidden_state'], spk_utt_pos=spk_utt_pos)
        
        if not return_dict:
            output = (lm_logits,) + outputs[1:]
            return ((masked_lm_loss+(self.scl_coeff*sc_loss),) + output) if masked_lm_loss is not None else output
        loss = None
        if masked_lm_loss is None:
            loss = None
        else:
            loss = masked_lm_loss+(self.scl_coeff*sc_loss)
        return Seq2SeqLMOutput(
            loss=loss,
            logits=lm_logits,
            past_key_values=outputs.past_key_values,
            decoder_hidden_states=outputs.decoder_hidden_states,
            decoder_attentions=outputs.decoder_attentions,
            cross_attentions=outputs.cross_attentions,
            encoder_last_hidden_state=outputs.encoder_last_hidden_state,
            encoder_hidden_states=outputs.encoder_hidden_states,
            encoder_attentions=outputs.encoder_attentions,
        )

# %% [markdown]
# ### Fine-tuning the model

# %%
# from models import BartWithSCL
# from datacollator import CustomCollatorForSeq2Seq
# from trainer import CustomTrainer


from transformers import BartForConditionalGeneration, DataCollatorForSeq2Seq, Seq2SeqTrainingArguments, Seq2SeqTrainer
from transformers.modeling_utils import unwrap_model
from transformers.models.auto.modeling_auto import MODEL_FOR_CAUSAL_LM_MAPPING_NAMES

# %%
model = BartWithSCL.from_pretrained(model_checkpoint)
model.set_losses_list(['turn'])
model.set_scl_coeff(1)

# %%
batch_size = 4
args = Seq2SeqTrainingArguments(
    "bart-token-b6c0.1",
    evaluation_strategy = "epoch",
    # eval_steps=5,
    learning_rate=2e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    gradient_accumulation_steps=2,
    weight_decay=0.01,
    # save_total_limit=2,
    num_train_epochs=5,
    logging_steps = 10, ## added
    predict_with_generate=True,
    remove_unused_columns=False, ## added
    fp16=True,
)

# %%
data_collator = CustomCollatorForSeq2Seq(tokenizer, model=model)

# %%
import nltk
import numpy as np
import torch
torch.cuda.empty_cache()
def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    # Replace -100 in the labels as we can't decode them.
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)
    
    # Rouge expects a newline after each sentence
    decoded_preds = ["\n".join(nltk.sent_tokenize(pred.strip())) for pred in decoded_preds]
    decoded_labels = ["\n".join(nltk.sent_tokenize(label.strip())) for label in decoded_labels]
    for i in range(0,50):
      # print(tokenized_datasets_val["dialogue"][i])
      print("-----------",i,"--------------")
      print("------>Predictions by Model")
      print(decoded_preds[i])
      print("----->Predictions Original")
      print(decoded_labels[i])
      print("**************************")
    result = metric.compute(predictions=decoded_preds, references=decoded_labels, use_stemmer=True)
    # Extract a few results
    result = {key: value.mid.fmeasure * 100 for key, value in result.items()}
    
    # Add mean generated length
    prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id) for pred in predictions]
    result["gen_len"] = np.mean(prediction_lens)
    
    return {k: round(v, 4) for k, v in result.items()}

# %%
trainer = CustomTrainer(
    model,
    args,
    train_dataset=tokenized_datasets_train,
    eval_dataset=tokenized_datasets_val,
    data_collator=data_collator,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)
# Out:
# Using cuda_amp half precision backend

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
trainer.train()# 1
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 14730
#   Num Epochs = 5
#   Instantaneous batch size per device = 4
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 2
#   Total optimization steps = 9205
#   Number of trainable parameters = 139420416
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# You're using a BartTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='9206' max='9205' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [9205/9205 2:46:15, Epoch 5.00/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.056400</td>
#       <td>3.747261</td>
#       <td>46.759100</td>
#       <td>22.969300</td>
#       <td>38.997200</td>
#       <td>43.021800</td>
#       <td>18.305600</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.546900</td>
#       <td>3.625081</td>
#       <td>47.486400</td>
#       <td>24.227000</td>
#       <td>40.195500</td>
#       <td>43.941900</td>
#       <td>17.687000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.547600</td>
#       <td>3.572148</td>
#       <td>48.217600</td>
#       <td>25.305100</td>
#       <td>41.113100</td>
#       <td>44.576000</td>
#       <td>17.813000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.613500</td>
#       <td>3.472829</td>
#       <td>48.674300</td>
#       <td>25.332300</td>
#       <td>41.070200</td>
#       <td>44.872200</td>
#       <td>18.072100</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='149' max='205' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [149/205 01:46 < 00:40, 1.39 it/s]
#     </div>
# Saving model checkpoint to bart-token-b6c0.1/checkpoint-500
# Configuration saved in bart-token-b6c0.1/checkpoint-500/config.json
# Model weights saved in bart-token-b6c0.1/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in bart-token-b6c0.1/checkpoint-500/tokenizer_config.json
# Special tokens file saved in bart-token-b6c0.1/checkpoint-500/special_tokens_map.json
# Saving model checkpoint to bart-token-b6c0.1/checkpoint-1000
# Configuration saved in bart-token-b6c0.1/checkpoint-1000/config.json
# Model weights saved in bart-token-b6c0.1/checkpoint-1000/pytorch_model.bin
# tokenizer config file saved in bart-token-b6c0.1/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in bart-token-b6c0.1/checkpoint-1000/special_tokens_map.json
# Saving model checkpoint to bart-token-b6c0.1/checkpoint-1500
# Configuration saved in bart-token-b6c0.1/checkpoint-1500/config.json
# Model weights saved in bart-token-b6c0.1/checkpoint-1500/pytorch_model.bin
# tokenizer config file saved in bart-token-b6c0.1/checkpoint-1500/tokenizer_config.json
# Special tokens file saved in bart-token-b6c0.1/checkpoint-1500/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 818
#   Batch size = 4
# ----------- 0 --------------
# ------>Predictions by Model
# A wants to get a puppy for her son.
# She will take him to the animal
# ----->Predictions Original
# A will go to the animal shelter tomorrow to get a puppy for her son.
# They already visited the shelter last Monday and the son chose the puppy.
# **************************
# ----------- 1 --------------
# ------>Predictions by Model
# Emma is looking for an advent calendar for her kids.
# She likes the idea of
# ----->Predictions Original
# Emma and Rob love the advent calendar.
# Lauren fits inside calendar various items, for instance, small toys and Christmas decorations.
# Her children are excited whenever they get the calendar.
# **************************
# ----------- 2 --------------
# ------>Predictions by Model
# Madison is pregnant, but she doesn't want to talk about it because she's taking
# ----->Predictions Original
# Madison is pregnant but she doesn't want to talk about it.
# Patricia Stevens got married and she thought she was pregnant.
# **************************
# ----------- 3 --------------
# ------>Predictions by Model
# Marla found a pair of boxers under her bed.
# Tamara thinks it's
# ----->Predictions Original
# Marla found a pair of boxers under her bed.
# **************************
# ----------- 4 --------------
# ------>Predictions by Model
# Robert has to buy guitar cable.
# Fred will give him the address of the music shop
# ----->Predictions Original
# Robert wants Fred to send him the address of the music shop as he needs to buy guitar cable.
# **************************
# ----------- 5 --------------
# ------>Predictions by Model
# Meg will check in the drawer next to the fridge to buy some milk and cereals
# ----->Predictions Original
# Megan needn't buy milk and cereals.
# They're in the drawer next to the fridge.
# **************************
# ----------- 6 --------------
# ------>Predictions by Model
# Samantha is surprised that Evelyn is making that noise.
# ----->Predictions Original
# Samantha and Evelyn after watching the video cannot believe she is able to make that noise.
# **************************
# ----------- 7 --------------
# ------>Predictions by Model
# Tom invited Marion and Adam to Fiesole for a dinner.
# ----->Predictions Original
# Tom's new place is in Fiesole.
# Luis and Marion has been there.
# **************************
# ----------- 8 --------------
# ------>Predictions by Model
# Vegano Resto will make a reservation for 6 people at 20:00 for
# ----->Predictions Original
# Jane made a 9 PM reservation for 6 people tonight at Vegano Resto.
# **************************
# ----------- 9 --------------
# ------>Predictions by Model
# Nancy is travelling with 3 other Brits working in Cardiff.
# She's coming home
# ----->Predictions Original
# Nancy's working in Texas, but the kids laugh at her Welsh accent.
# She's coming home in 6 weeks.
# Earlier than that she's going to travel with 3 other Brits.
# **************************
# ----------- 10 --------------
# ------>Predictions by Model
# Laura needs a new printer.
# Jamie will buy a second hand one.
# ----->Predictions Original
# Laura is going to buy a printer.
# **************************
# ----------- 11 --------------
# ------>Predictions by Model
# Haylee is in dairy section and can't find the coconut milk one.
# She asked
# ----->Predictions Original
# Haylee can't find the coconut milk yoghurt.
# **************************
# ----------- 12 --------------
# ------>Predictions by Model
# Norbert and Wendy need to hurry to catch the tour.
# Wendy is at the register
# ----->Predictions Original
# Wendy is shopping, but she needs to hurry up to catch the tour.
# **************************
# ----------- 13 --------------
# ------>Predictions by Model
# Cecil and Lidia went to Fuerteventura in the summer.
# ----->Predictions Original
# Cecil, Cheryl and Peter went to the Jandia Peninsula today.
# Cecil would like to explore the south of the island tomorrow, but they will decide what to do after dinner.
# **************************
# ----------- 14 --------------
# ------>Predictions by Model
# Sophie has checked pockets and handbags twice already.
# ----->Predictions Original
# Sophie still hasn't found it despite checking pockets and handbags twice.
# **************************
# ----------- 15 --------------
# ------>Predictions by Model
# Rosie has to write an essay about bad movies.
# Dennis recommends "Troma Studio
# ----->Predictions Original
# Dennis and Elle are helping Rosie think of bad movies for her essay.
# **************************
# ----------- 16 --------------
# ------>Predictions by Model
# James has a dream to become a voice actor.
# He wants to be a part of
# ----->Predictions Original
# James has a dream of becoming a voice actor.
# He considers making a home radio station.
# **************************
# ----------- 17 --------------
# ------>Predictions by Model
# Poppy is going for drinks after work.
# Alice didn't get lunch because she had
# ----->Predictions Original
# Poppy and Alice are meeting for drinks after work at Nick's at 5:30.
# Alice fancies Fred, she will invite him and a bunch of other coworkers.
# **************************
# ----------- 18 --------------
# ------>Predictions by Model
# Caron is out from 12.
# She needs to go out.
# ----->Predictions Original
# Sash needs to see Caron who'll be out from 12.
# **************************
# ----------- 19 --------------
# ------>Predictions by Model
# Giuseppe is dating Gosia.
# Giuseppe doesn't like football and video
# ----->Predictions Original
# Matteo is not sure about his relationship with Gosia but likes her a lot.
# **************************
# ----------- 20 --------------
# ------>Predictions by Model
# Jannette is calling Ramzi for supper.
# ----->Predictions Original
# Ramzi and Jannette are going for supper.
# **************************
# ----------- 21 --------------
# ------>Predictions by Model
# Jeniffer is preparing ravioli with the recipe from her grandmother.
# ----->Predictions Original
# Jeniffer is preparing ravioli following her grandmothers recipe.
# **************************
# ----------- 22 --------------
# ------>Predictions by Model
# Lawrence is not yet through with the article.
# Madison will get back to Lawrence once
# ----->Predictions Original
# Lawrence will finish writing the article soon.
# **************************
# ----------- 23 --------------
# ------>Predictions by Model
# Chad wants Brennen to be there.
# ----->Predictions Original
# Chad has sent Brennen a funny photo.
# Brennen does not find it very funny.
# **************************
# ----------- 24 --------------
# ------>Predictions by Model
# Sadie needs to go to the dentist quickly after work.
# Chloe will pick it up
# ----->Predictions Original
# Sadie will borrow Chloe's bike on Wednesday evening.
# She has a dentist appointment on Thursday after work.
# **************************
# ----------- 25 --------------
# ------>Predictions by Model
# Olivia wants to launch a new restaurant in the city centre next month.
# Carter
# ----->Predictions Original
# Carter is launching a restaurant business next month.
# Olivia wants him to include a restaurant she's working for in the discount app.
# They will meet in person to discuss it.
# **************************
# ----------- 26 --------------
# ------>Predictions by Model
# Kristine is worried about Kenny's health.
# He has another surgery scheduled tomorrow, but
# ----->Predictions Original
# Kenny had a surgery, as Kristine reports.
# He will have another surgery tomorrow.
# Guy will come to St. Mark's Hospital near Asda to stay with Kristine.
# **************************
# ----------- 27 --------------
# ------>Predictions by Model
# Joey and Olivia broke up after all these years.
# Olivia cheated on Joey with numerous
# ----->Predictions Original
# Skyler and Adam are surprised that Joey and Olivia broke up.
# **************************
# ----------- 28 --------------
# ------>Predictions by Model
# Amanda is pregnant.
# She went to dancing classes with Michael.
# The instructor needed a
# ----->Predictions Original
# Amanda goes to dancing classes with Michael.
# She volunteered to show the English Waltz steps with the instructor yesterday.
# Amanda is shy and goes to therapy.
# **************************
# ----------- 29 --------------
# ------>Predictions by Model
# Taylor wants Isabel to bring her boyfriend to her.
# Isabel hasn't had any.
# Taylor
# ----->Predictions Original
# Taylor wants to meet Isabel's boyfriend but she has never had any.
# **************************
# ----------- 30 --------------
# ------>Predictions by Model
# Toby and Theo are going to the Italian Alpes on Friday.
# Toby will pick
# ----->Predictions Original
# Theo's going to stay near Torino in the region of Italian Alpes.
# Toby wants to join the trip.
# Theo agrees and will pick Toby up on Friday at 7 am.
# **************************
# ----------- 31 --------------
# ------>Predictions by Model
# Brandon hasn't called to say he'd be late.
# Clara will prepare a report on
# ----->Predictions Original
# Brandon is late again.
# Clara will prepare a report on the absenteeism and lateness for Phil by Friday.
# **************************
# ----------- 32 --------------
# ------>Predictions by Model
# Suzie is sick again.
# Olga and Suzie are going to reschedule
# ----->Predictions Original
# Olga and Suzie will postpone their meeting due to Suzie's sickness.
# **************************
# ----------- 33 --------------
# ------>Predictions by Model
# Diane wants Kate to be her kids' mother.
# Kate is scared before the birth
# ----->Predictions Original
# Diane is pregnant and can't wait to give birth, she thinks the waiting is the worst.
# Kate thinks she'll be an amazing mother.
# **************************
# ----------- 34 --------------
# ------>Predictions by Model
# Andrew has to call in sick because he feels awful.
# Daniel will drop by after work
# ----->Predictions Original
# Andrew has a cold.
# Daniel will buy him some medication.
# **************************
# ----------- 35 --------------
# ------>Predictions by Model
# Alex and Sam are watching 'Millionaires' on tv.
# Sam has a chance
# ----->Predictions Original
# Alex and Sam are watching Millionaires.
# **************************
# ----------- 36 --------------
# ------>Predictions by Model
# Jessica has the cinnamon cookies recipe.
# Angelica has it.
# ----->Predictions Original
# Angelica sent the cinnamon cookies recipe at Kelly's request.
# **************************
# ----------- 37 --------------
# ------>Predictions by Model
# Sophie is waiting for a client who is 40 minutes late.
# Gwen will
# ----->Predictions Original
# Sophie is waiting for a client, who is late.
# She will meet Gwen later.
# **************************
# ----------- 38 --------------
# ------>Predictions by Model
# Daniel is on his way to meet Sue in a few minutes.
# ----->Predictions Original
# Daniel is with the Volvo on his way and will be there soon.
# Sue is going downstairs to meet him.
# **************************
# ----------- 39 --------------
# ------>Predictions by Model
# George is going to CVS to buy some shaving cream.
# ----->Predictions Original
# George is making salmon and stuffed squash for dinner.
# Betty will buy a shaving cream at CVS at his request,
# **************************
# ----------- 40 --------------
# ------>Predictions by Model
# Ken started running and wanted to track his progress but his phone doesn't work properly.
# ----->Predictions Original
# Ken has installed an app for running but it is not working properly on his phone.
# **************************
# ----------- 41 --------------
# ------>Predictions by Model
# Ann hasn't been at Ivan's birthday party yet.
# Ivan bought her something for her
# ----->Predictions Original
# Ivan and Ann will meet next week.
# **************************
# ----------- 42 --------------
# ------>Predictions by Model
# Delilah and Rowan are going to look at Ashley's fb page.
# ----->Predictions Original
# Ashley posted some nude photos on her fb page.
# **************************
# ----------- 43 --------------
# ------>Predictions by Model
# Mikolaj got the letter with working permission from the government.
# Magda is
# ----->Predictions Original
# Mikolaj's wife needs a work permit as a foreigner.
# Government officials missed the deadline for sending it and will need another month.
# **************************
# ----------- 44 --------------
# ------>Predictions by Model
# Maria is on her way to the hotel.
# Ann is at the 3rd floor lobby
# ----->Predictions Original
# Thomas, Ann and Maria will have lunch together at the hotel.
# Ann is already in the 3rd floor lobby at the red table.
# **************************
# ----------- 45 --------------
# ------>Predictions by Model
# Sus is sleepy and doesn't want to work.
# ----->Predictions Original
# Sus and Val don't want to work and are sleepy.
# **************************
# ----------- 46 --------------
# ------>Predictions by Model
# Kate and Terry are going to the Guggenheim Museum of the city of NY
# ----->Predictions Original
# Kate is at the Guggenheim Museum now, but will be in the Museum of the City of New York around 2-2:30.
# Kai may join her.
# Ish won't.
# Terry will join them for a coffee after they finish visiting the museum.
# Terry has already seen the museum.
# **************************
# ----------- 47 --------------
# ------>Predictions by Model
# Cathy left her sunglasses at Broke's house.
# He will come round at 10
# ----->Predictions Original
# Cathy left her sunglasses at Broke's house.
# She will come collect them at 10.
# **************************
# ----------- 48 --------------
# ------>Predictions by Model
# Frederica will come to Bradley's birthday party tomorrow at 8 pm.
# ----->Predictions Original
# Bradley will come to Frederica's birthday party tomorrow at 8pm.
# **************************
# ----------- 49 --------------
# ------>Predictions by Model
# Camilla will let Adrian know when she received the money.
# ----->Predictions Original
# Camilla still hasn't received the 250.
# She will check and let Adrian know.
# Money usually takes around two days to arrive.
# **************************
# Saving model checkpoint to bart-token-b6c0.1/checkpoint-2000
# Configuration saved in bart-token-b6c0.1/checkpoint-2000/config.json
# Model weights saved in bart-token-b6c0.1/checkpoint-2000/pytorch_model.bin
# tokenizer config file saved in bart-token-b6c0.1/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in bart-token-b6c0.1/checkpoint-2000/special_tokens_map.json
# Saving model checkpoint to bart-token-b6c0.1/checkpoint-2500
# Configuration saved in bart-token-b6c0.1/checkpoint-2500/config.json
# Model weights saved in bart-token-b6c0.1/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in bart-token-b6c0.1/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in bart-token-b6c0.1/checkpoint-2500/special_tokens_map.json
# Saving model checkpoint to bart-token-b6c0.1/checkpoint-3000
# Configuration saved in bart-token-b6c0.1/checkpoint-3000/config.json
# Model weights saved in bart-token-b6c0.1/checkpoint-3000/pytorch_model.bin
# tokenizer config file saved in bart-token-b6c0.1/checkpoint-3000/tokenizer_config.json
# Special tokens file saved in bart-token-b6c0.1/checkpoint-3000/special_tokens_map.json
# Saving model checkpoint to bart-token-b6c0.1/checkpoint-3500
# Configuration saved in bart-token-b6c0.1/checkpoint-3500/config.json
# Model weights saved in bart-token-b6c0.1/checkpoint-3500/pytorch_model.bin
# tokenizer config file saved in bart-token-b6c0.1/checkpoint-3500/tokenizer_config.json
# Special tokens file saved in bart-token-b6c0.1/checkpoint-3500/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 818
#   Batch size = 4
# ----------- 0 --------------
# ------>Predictions by Model
# A wants to get a puppy for her son.
# She took him to the animal shelter
# ----->Predictions Original
# A will go to the animal shelter tomorrow to get a puppy for her son.
# They already visited the shelter last Monday and the son chose the puppy.
# **************************
# ----------- 1 --------------
# ------>Predictions by Model
# Emma wants to get an advent calendar for her kids.
# Rob and his sister are
# ----->Predictions Original
# Emma and Rob love the advent calendar.
# Lauren fits inside calendar various items, for instance, small toys and Christmas decorations.
# Her children are excited whenever they get the calendar.
# **************************
# ----------- 2 --------------
# ------>Predictions by Model
# Madison is pregnant.
# She doesn't want to talk about it.
# ----->Predictions Original
# Madison is pregnant but she doesn't want to talk about it.
# Patricia Stevens got married and she thought she was pregnant.
# **************************
# ----------- 3 --------------
# ------>Predictions by Model
# Marla found her underwear under her bed.
# She's 13 and her sister convinced her
# ----->Predictions Original
# Marla found a pair of boxers under her bed.
# **************************
# ----------- 4 --------------
# ------>Predictions by Model
# Robert has to buy guitar cable.
# Fred gives him the address of the music shop Robert
# ----->Predictions Original
# Robert wants Fred to send him the address of the music shop as he needs to buy guitar cable.
# **************************
# ----------- 5 --------------
# ------>Predictions by Model
# Keith will check in the drawer next to the fridge to buy some milk and cereals
# ----->Predictions Original
# Megan needn't buy milk and cereals.
# They're in the drawer next to the fridge.
# **************************
# ----------- 6 --------------
# ------>Predictions by Model
# Samantha sends Evelyn a video of herself making a noise.
# ----->Predictions Original
# Samantha and Evelyn after watching the video cannot believe she is able to make that noise.
# **************************
# ----------- 7 --------------
# ------>Predictions by Model
# Marion and Adam are at Tom's new place.
# It's a bit outside the
# ----->Predictions Original
# Tom's new place is in Fiesole.
# Luis and Marion has been there.
# **************************
# ----------- 8 --------------
# ------>Predictions by Model
# Vegano Resto will offer Jane a table for six at 21:00 tonight
# ----->Predictions Original
# Jane made a 9 PM reservation for 6 people tonight at Vegano Resto.
# **************************
# ----------- 9 --------------
# ------>Predictions by Model
# Nancy is coming home in 6 weeks.
# She's going travelling with 3 other Brit
# ----->Predictions Original
# Nancy's working in Texas, but the kids laugh at her Welsh accent.
# She's coming home in 6 weeks.
# Earlier than that she's going to travel with 3 other Brits.
# **************************
# ----------- 10 --------------
# ------>Predictions by Model
# Laura needs a new printer.
# Jamie suggests she buy a second hand one.
# ----->Predictions Original
# Laura is going to buy a printer.
# **************************
# ----------- 11 --------------
# ------>Predictions by Model
# Barbara got everything for Haylee in the dairy section.
# ----->Predictions Original
# Haylee can't find the coconut milk yoghurt.
# **************************
# ----------- 12 --------------
# ------>Predictions by Model
# Norbert and Wendy need to hurry to catch the tour.
# Wendy is buying something.
# ----->Predictions Original
# Wendy is shopping, but she needs to hurry up to catch the tour.
# **************************
# ----------- 13 --------------
# ------>Predictions by Model
# Cecil and Lidia went to the Jandia Peninsula.
# Cecil is driving
# ----->Predictions Original
# Cecil, Cheryl and Peter went to the Jandia Peninsula today.
# Cecil would like to explore the south of the island tomorrow, but they will decide what to do after dinner.
# **************************
# ----------- 14 --------------
# ------>Predictions by Model
# Sophie hasn't found it.
# She checked pockets and handbags twice already.
# ----->Predictions Original
# Sophie still hasn't found it despite checking pockets and handbags twice.
# **************************
# ----------- 15 --------------
# ------>Predictions by Model
# Rosie has to write an essay about her favorite b-movie, Toxic avenger
# ----->Predictions Original
# Dennis and Elle are helping Rosie think of bad movies for her essay.
# **************************
# ----------- 16 --------------
# ------>Predictions by Model
# James has a dream to become a voice actor.
# ----->Predictions Original
# James has a dream of becoming a voice actor.
# He considers making a home radio station.
# **************************
# ----------- 17 --------------
# ------>Predictions by Model
# Poppy and Alice are going for drinks after work.
# Alice didn't get lunch because
# ----->Predictions Original
# Poppy and Alice are meeting for drinks after work at Nick's at 5:30.
# Alice fancies Fred, she will invite him and a bunch of other coworkers.
# **************************
# ----------- 18 --------------
# ------>Predictions by Model
# Caron is out from 12.
# Sash will come before her.
# ----->Predictions Original
# Sash needs to see Caron who'll be out from 12.
# **************************
# ----------- 19 --------------
# ------>Predictions by Model
# Giuseppe likes Gosia, but she criticizes him because he likes football and
# ----->Predictions Original
# Matteo is not sure about his relationship with Gosia but likes her a lot.
# **************************
# ----------- 20 --------------
# ------>Predictions by Model
# Jannette is coming for supper.
# ----->Predictions Original
# Ramzi and Jannette are going for supper.
# **************************
# ----------- 21 --------------
# ------>Predictions by Model
# Jeniffer got the recipe from her grandmother.
# ----->Predictions Original
# Jeniffer is preparing ravioli following her grandmothers recipe.
# **************************
# ----------- 22 --------------
# ------>Predictions by Model
# Lawrence will get back to Madison once he is through with the article.
# ----->Predictions Original
# Lawrence will finish writing the article soon.
# **************************
# ----------- 23 --------------
# ------>Predictions by Model
# Chad sent Brennen a funny photo.
# ----->Predictions Original
# Chad has sent Brennen a funny photo.
# Brennen does not find it very funny.
# **************************
# ----------- 24 --------------
# ------>Predictions by Model
# Sadie needs to go to the dentist on Thursday.
# Chloe will pick it up on
# ----->Predictions Original
# Sadie will borrow Chloe's bike on Wednesday evening.
# She has a dentist appointment on Thursday after work.
# **************************
# ----------- 25 --------------
# ------>Predictions by Model
# Olivia wants to launch a new restaurant in the city centre next month.
# Carter
# ----->Predictions Original
# Carter is launching a restaurant business next month.
# Olivia wants him to include a restaurant she's working for in the discount app.
# They will meet in person to discuss it.
# **************************
# ----------- 26 --------------
# ------>Predictions by Model
# Kristine is worried about Kenny.
# He's back from surgery, but the doctors don
# ----->Predictions Original
# Kenny had a surgery, as Kristine reports.
# He will have another surgery tomorrow.
# Guy will come to St. Mark's Hospital near Asda to stay with Kristine.
# **************************
# ----------- 27 --------------
# ------>Predictions by Model
# Joey and Olivia broke up after all these years.
# ----->Predictions Original
# Skyler and Adam are surprised that Joey and Olivia broke up.
# **************************
# ----------- 28 --------------
# ------>Predictions by Model
# Amanda is pregnant.
# She went to the dancing classes with Michael yesterday.
# The instructor
# ----->Predictions Original
# Amanda goes to dancing classes with Michael.
# She volunteered to show the English Waltz steps with the instructor yesterday.
# Amanda is shy and goes to therapy.
# **************************
# ----------- 29 --------------
# ------>Predictions by Model
# Isabel hasn't introduced Taylor's daughter to her boyfriend.
# Taylor will bring her boyfriend
# ----->Predictions Original
# Taylor wants to meet Isabel's boyfriend but she has never had any.
# **************************
# ----------- 30 --------------
# ------>Predictions by Model
# Toby and Theo are leaving on Friday.
# Toby will come back by train on Monday
# ----->Predictions Original
# Theo's going to stay near Torino in the region of Italian Alpes.
# Toby wants to join the trip.
# Theo agrees and will pick Toby up on Friday at 7 am.
# **************************
# ----------- 31 --------------
# ------>Predictions by Model
# Brandon hasn't called to say he'd be late.
# ----->Predictions Original
# Brandon is late again.
# Clara will prepare a report on the absenteeism and lateness for Phil by Friday.
# **************************
# ----------- 32 --------------
# ------>Predictions by Model
# Suzie is sick again.
# She cancelled last time because she didn't want to catch
# ----->Predictions Original
# Olga and Suzie will postpone their meeting due to Suzie's sickness.
# **************************
# ----------- 33 --------------
# ------>Predictions by Model
# Diane wants Kate to be her kids' mother.
# ----->Predictions Original
# Diane is pregnant and can't wait to give birth, she thinks the waiting is the worst.
# Kate thinks she'll be an amazing mother.
# **************************
# ----------- 34 --------------
# ------>Predictions by Model
# Andrew had to call in sick because he has a cold.
# Daniel will drop by after
# ----->Predictions Original
# Andrew has a cold.
# Daniel will buy him some medication.
# **************************
# ----------- 35 --------------
# ------>Predictions by Model
# Alex and Sam are watching 'Millionaires' on tv.
# ----->Predictions Original
# Alex and Sam are watching Millionaires.
# **************************
# ----------- 36 --------------
# ------>Predictions by Model
# Jessica has Angelica's cinnamon cookies recipe.
# ----->Predictions Original
# Angelica sent the cinnamon cookies recipe at Kelly's request.
# **************************
# ----------- 37 --------------
# ------>Predictions by Model
# Sophie is waiting for a client who is 40 minutes late.
# Gwen will
# ----->Predictions Original
# Sophie is waiting for a client, who is late.
# She will meet Gwen later.
# **************************
# ----------- 38 --------------
# ------>Predictions by Model
# Daniel is on his way downstairs.
# Sue is with the Volvo.
# ----->Predictions Original
# Daniel is with the Volvo on his way and will be there soon.
# Sue is going downstairs to meet him.
# **************************
# ----------- 39 --------------
# ------>Predictions by Model
# Betty is going to CVS to buy some salmon and some shaving cream for George
# ----->Predictions Original
# George is making salmon and stuffed squash for dinner.
# Betty will buy a shaving cream at CVS at his request,
# **************************
# ----------- 40 --------------
# ------>Predictions by Model
# Ken started running and wanted to track his progress, but the battery was almost depleted.
# ----->Predictions Original
# Ken has installed an app for running but it is not working properly on his phone.
# **************************
# ----------- 41 --------------
# ------>Predictions by Model
# Ann couldn't come to Ivan's birthday party.
# Ivan bought her something for her birthday
# ----->Predictions Original
# Ivan and Ann will meet next week.
# **************************
# ----------- 42 --------------
# ------>Predictions by Model
# Ashley posted nude pictures on her Facebook page.
# Rowan has some important stuff to
# ----->Predictions Original
# Ashley posted some nude photos on her fb page.
# **************************
# ----------- 43 --------------
# ------>Predictions by Model
# Mikolaj got his wife's papers with working permission.
# Magda doesn't
# ----->Predictions Original
# Mikolaj's wife needs a work permit as a foreigner.
# Government officials missed the deadline for sending it and will need another month.
# **************************
# ----------- 44 --------------
# ------>Predictions by Model
# Ann is at the hotel.
# Peter is still there.
# They will have lunch together.
# ----->Predictions Original
# Thomas, Ann and Maria will have lunch together at the hotel.
# Ann is already in the 3rd floor lobby at the red table.
# **************************
# ----------- 45 --------------
# ------>Predictions by Model
# Sus is sleepy and doesn't want to work.
# ----->Predictions Original
# Sus and Val don't want to work and are sleepy.
# **************************
# ----------- 46 --------------
# ------>Predictions by Model
# Kate and Terry are at the Guggenheim right now.
# They want to go
# ----->Predictions Original
# Kate is at the Guggenheim Museum now, but will be in the Museum of the City of New York around 2-2:30.
# Kai may join her.
# Ish won't.
# Terry will join them for a coffee after they finish visiting the museum.
# Terry has already seen the museum.
# **************************
# ----------- 47 --------------
# ------>Predictions by Model
# Cathy left her sunglasses at Brooke's house.
# She will come round at 10 tonight
# ----->Predictions Original
# Cathy left her sunglasses at Broke's house.
# She will come collect them at 10.
# **************************
# ----------- 48 --------------
# ------>Predictions by Model
# Frederica will come to Bradley's birthday party tomorrow at 8 pm.
# ----->Predictions Original
# Bradley will come to Frederica's birthday party tomorrow at 8pm.
# **************************
# ----------- 49 --------------
# ------>Predictions by Model
# Camilla received 250 from Adrian.
# ----->Predictions Original
# Camilla still hasn't received the 250.
# She will check and let Adrian know.
# Money usually takes around two days to arrive.
# **************************
# Saving model checkpoint to bart-token-b6c0.1/checkpoint-4000
# Configuration saved in bart-token-b6c0.1/checkpoint-4000/config.json
# Model weights saved in bart-token-b6c0.1/checkpoint-4000/pytorch_model.bin
# tokenizer config file saved in bart-token-b6c0.1/checkpoint-4000/tokenizer_config.json
# Special tokens file saved in bart-token-b6c0.1/checkpoint-4000/special_tokens_map.json
# Saving model checkpoint to bart-token-b6c0.1/checkpoint-4500
# Configuration saved in bart-token-b6c0.1/checkpoint-4500/config.json
# Model weights saved in bart-token-b6c0.1/checkpoint-4500/pytorch_model.bin
# tokenizer config file saved in bart-token-b6c0.1/checkpoint-4500/tokenizer_config.json
# Special tokens file saved in bart-token-b6c0.1/checkpoint-4500/special_tokens_map.json
# Saving model checkpoint to bart-token-b6c0.1/checkpoint-5000
# Configuration saved in bart-token-b6c0.1/checkpoint-5000/config.json
# Model weights saved in bart-token-b6c0.1/checkpoint-5000/pytorch_model.bin
# tokenizer config file saved in bart-token-b6c0.1/checkpoint-5000/tokenizer_config.json
# Special tokens file saved in bart-token-b6c0.1/checkpoint-5000/special_tokens_map.json
# Saving model checkpoint to bart-token-b6c0.1/checkpoint-5500
# Configuration saved in bart-token-b6c0.1/checkpoint-5500/config.json
# Model weights saved in bart-token-b6c0.1/checkpoint-5500/pytorch_model.bin
# tokenizer config file saved in bart-token-b6c0.1/checkpoint-5500/tokenizer_config.json
# Special tokens file saved in bart-token-b6c0.1/checkpoint-5500/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 818
#   Batch size = 4
# ----------- 0 --------------
# ------>Predictions by Model
# A wants to get a puppy for her son.
# She will take him to the animal
# ----->Predictions Original
# A will go to the animal shelter tomorrow to get a puppy for her son.
# They already visited the shelter last Monday and the son chose the puppy.
# **************************
# ----------- 1 --------------
# ------>Predictions by Model
# Emma wants to buy an advent calendar for her children.
# ----->Predictions Original
# Emma and Rob love the advent calendar.
# Lauren fits inside calendar various items, for instance, small toys and Christmas decorations.
# Her children are excited whenever they get the calendar.
# **************************
# ----------- 2 --------------
# ------>Predictions by Model
# Madison is pregnant.
# ----->Predictions Original
# Madison is pregnant but she doesn't want to talk about it.
# Patricia Stevens got married and she thought she was pregnant.
# **************************
# ----------- 3 --------------
# ------>Predictions by Model
# Marla found a pair of boxers under her bed.
# ----->Predictions Original
# Marla found a pair of boxers under her bed.
# **************************
# ----------- 4 --------------
# ------>Predictions by Model
# Robert has to buy guitar cable.
# Fred gives Robert the address of the music shop.
# ----->Predictions Original
# Robert wants Fred to send him the address of the music shop as he needs to buy guitar cable.
# **************************
# ----------- 5 --------------
# ------>Predictions by Model
# Keith will check in the drawer next to the fridge to buy some milk and cereals
# ----->Predictions Original
# Megan needn't buy milk and cereals.
# They're in the drawer next to the fridge.
# **************************
# ----------- 6 --------------
# ------>Predictions by Model
# Samantha sent a video to Evelyn and Holly.
# ----->Predictions Original
# Samantha and Evelyn after watching the video cannot believe she is able to make that noise.
# **************************
# ----------- 7 --------------
# ------>Predictions by Model
# Theresa, Luis and Adam are going to Tom's new place for dinner.
# ----->Predictions Original
# Tom's new place is in Fiesole.
# Luis and Marion has been there.
# **************************
# ----------- 8 --------------
# ------>Predictions by Model
# Vegano Resto will make a reservation for 6 people tonight at 21:00
# ----->Predictions Original
# Jane made a 9 PM reservation for 6 people tonight at Vegano Resto.
# **************************
# ----------- 9 --------------
# ------>Predictions by Model
# Nancy is coming home in 6 weeks.
# She's going travelling with 3 other Brit
# ----->Predictions Original
# Nancy's working in Texas, but the kids laugh at her Welsh accent.
# She's coming home in 6 weeks.
# Earlier than that she's going to travel with 3 other Brits.
# **************************
# ----------- 10 --------------
# ------>Predictions by Model
# Laura needs a new printer.
# Jamie suggests she can buy a second hand one.
# ----->Predictions Original
# Laura is going to buy a printer.
# **************************
# ----------- 11 --------------
# ------>Predictions by Model
# Haylee will buy coconut milk yoghurt in the dairy section.
# ----->Predictions Original
# Haylee can't find the coconut milk yoghurt.
# **************************
# ----------- 12 --------------
# ------>Predictions by Model
# Norbert and Wendy need to hurry to catch the tour.
# Wendy is at the register
# ----->Predictions Original
# Wendy is shopping, but she needs to hurry up to catch the tour.
# **************************
# ----------- 13 --------------
# ------>Predictions by Model
# Cecil is driving to the Jandia Peninsula.
# Cecil wants to explore more
# ----->Predictions Original
# Cecil, Cheryl and Peter went to the Jandia Peninsula today.
# Cecil would like to explore the south of the island tomorrow, but they will decide what to do after dinner.
# **************************
# ----------- 14 --------------
# ------>Predictions by Model
# Sophie hasn't found it.
# Nickola checked pockets and handbags twice already
# ----->Predictions Original
# Sophie still hasn't found it despite checking pockets and handbags twice.
# **************************
# ----------- 15 --------------
# ------>Predictions by Model
# Rosie has to write an essay on bad movies.
# She will cover "The Room
# ----->Predictions Original
# Dennis and Elle are helping Rosie think of bad movies for her essay.
# **************************
# ----------- 16 --------------
# ------>Predictions by Model
# James has a dream to become a voice actor.
# He has a microphone at home and
# ----->Predictions Original
# James has a dream of becoming a voice actor.
# He considers making a home radio station.
# **************************
# ----------- 17 --------------
# ------>Predictions by Model
# Poppy and Alice are going for drinks after work.
# Poppy will invite Fred to
# ----->Predictions Original
# Poppy and Alice are meeting for drinks after work at Nick's at 5:30.
# Alice fancies Fred, she will invite him and a bunch of other coworkers.
# **************************
# ----------- 18 --------------
# ------>Predictions by Model
# Sash will see Caron before 12.
# Caron needs to go out.
# ----->Predictions Original
# Sash needs to see Caron who'll be out from 12.
# **************************
# ----------- 19 --------------
# ------>Predictions by Model
# Giuseppe likes Gosia a lot.
# Matteo doesn't like football and video
# ----->Predictions Original
# Matteo is not sure about his relationship with Gosia but likes her a lot.
# **************************
# ----------- 20 --------------
# ------>Predictions by Model
# Jannette is coming for supper.
# ----->Predictions Original
# Ramzi and Jannette are going for supper.
# **************************
# ----------- 21 --------------
# ------>Predictions by Model
# Jeniffer got the recipe from her grandmother.
# ----->Predictions Original
# Jeniffer is preparing ravioli following her grandmothers recipe.
# **************************
# ----------- 22 --------------
# ------>Predictions by Model
# Lawrence will be back in a few minutes.
# The piece is needed by today.
# ----->Predictions Original
# Lawrence will finish writing the article soon.
# **************************
# ----------- 23 --------------
# ------>Predictions by Model
# Chad sent Brennen a funny photo.
# ----->Predictions Original
# Chad has sent Brennen a funny photo.
# Brennen does not find it very funny.
# **************************
# ----------- 24 --------------
# ------>Predictions by Model
# Sadie will borrow Chloe's bike on Wednesday evening.
# ----->Predictions Original
# Sadie will borrow Chloe's bike on Wednesday evening.
# She has a dentist appointment on Thursday after work.
# **************************
# ----------- 25 --------------
# ------>Predictions by Model
# Olivia and Carter are planning to launch a new restaurant in the city centre next
# ----->Predictions Original
# Carter is launching a restaurant business next month.
# Olivia wants him to include a restaurant she's working for in the discount app.
# They will meet in person to discuss it.
# **************************
# ----------- 26 --------------
# ------>Predictions by Model
# Kristine is worried about Kenny's health.
# He has another surgery scheduled tomorrow.
# He
# ----->Predictions Original
# Kenny had a surgery, as Kristine reports.
# He will have another surgery tomorrow.
# Guy will come to St. Mark's Hospital near Asda to stay with Kristine.
# **************************
# ----------- 27 --------------
# ------>Predictions by Model
# Joey and Olivia broke up after all these years.
# ----->Predictions Original
# Skyler and Adam are surprised that Joey and Olivia broke up.
# **************************
# ----------- 28 --------------
# ------>Predictions by Model
# Amanda went to dance classes with Michael yesterday.
# The instructor needed a partner to show
# ----->Predictions Original
# Amanda goes to dancing classes with Michael.
# She volunteered to show the English Waltz steps with the instructor yesterday.
# Amanda is shy and goes to therapy.
# **************************
# ----------- 29 --------------
# ------>Predictions by Model
# Taylor's friends' daughters bring their bf to Taylor.
# Isabel hasn't had any
# ----->Predictions Original
# Taylor wants to meet Isabel's boyfriend but she has never had any.
# **************************
# ----------- 30 --------------
# ------>Predictions by Model
# Theo is leaving on Friday.
# Toby will come back by train on Monday.
# Toby
# ----->Predictions Original
# Theo's going to stay near Torino in the region of Italian Alpes.
# Toby wants to join the trip.
# Theo agrees and will pick Toby up on Friday at 7 am.
# **************************
# ----------- 31 --------------
# ------>Predictions by Model
# Brandon hasn't called Clara to say he'd be late.
# Clara will prepare a report
# ----->Predictions Original
# Brandon is late again.
# Clara will prepare a report on the absenteeism and lateness for Phil by Friday.
# **************************
# ----------- 32 --------------
# ------>Predictions by Model
# Suzie is sick again.
# She will cancel the meeting with Olga.
# ----->Predictions Original
# Olga and Suzie will postpone their meeting due to Suzie's sickness.
# **************************
# ----------- 33 --------------
# ------>Predictions by Model
# Diane wants Kate to be her kids' mother.
# ----->Predictions Original
# Diane is pregnant and can't wait to give birth, she thinks the waiting is the worst.
# Kate thinks she'll be an amazing mother.
# **************************
# ----------- 34 --------------
# ------>Predictions by Model
# Andrew had to call in sick because of a cold.
# Daniel will drop by after work
# ----->Predictions Original
# Andrew has a cold.
# Daniel will buy him some medication.
# **************************
# ----------- 35 --------------
# ------>Predictions by Model
# Alex and Sam are watching 'Millionaires' on tv.
# ----->Predictions Original
# Alex and Sam are watching Millionaires.
# **************************
# ----------- 36 --------------
# ------>Predictions by Model
# Jessica has Angelica's cinnamon cookies recipe.
# ----->Predictions Original
# Angelica sent the cinnamon cookies recipe at Kelly's request.
# **************************
# ----------- 37 --------------
# ------>Predictions by Model
# Sophie is waiting for a client who is 40 minutes late.
# Gwen will
# ----->Predictions Original
# Sophie is waiting for a client, who is late.
# She will meet Gwen later.
# **************************
# ----------- 38 --------------
# ------>Predictions by Model
# Daniel is on his way downstairs.
# He will see Sue in a few minutes.
# ----->Predictions Original
# Daniel is with the Volvo on his way and will be there soon.
# Sue is going downstairs to meet him.
# **************************
# ----------- 39 --------------
# ------>Predictions by Model
# Betty is going to CVS to buy some salmon and some shaving cream for George
# ----->Predictions Original
# George is making salmon and stuffed squash for dinner.
# Betty will buy a shaving cream at CVS at his request,
# **************************
# ----------- 40 --------------
# ------>Predictions by Model
# Ken's phone doesn't work properly.
# Martha's friend had a similar issue.
# Ken
# ----->Predictions Original
# Ken has installed an app for running but it is not working properly on his phone.
# **************************
# ----------- 41 --------------
# ------>Predictions by Model
# Ann couldn't come to Ivan's birthday party.
# Ivan bought her something for her birthday
# ----->Predictions Original
# Ivan and Ann will meet next week.
# **************************
# ----------- 42 --------------
# ------>Predictions by Model
# Ashley posted some pictures on her Facebook page.
# Rowan has some important stuff to
# ----->Predictions Original
# Ashley posted some nude photos on her fb page.
# **************************
# ----------- 43 --------------
# ------>Predictions by Model
# Mikolaj got a letter from the government saying that his wife's papers won
# ----->Predictions Original
# Mikolaj's wife needs a work permit as a foreigner.
# Government officials missed the deadline for sending it and will need another month.
# **************************
# ----------- 44 --------------
# ------>Predictions by Model
# Ann is at the 3rd floor lobby.
# Peter is still at the hotel.
# Ann
# ----->Predictions Original
# Thomas, Ann and Maria will have lunch together at the hotel.
# Ann is already in the 3rd floor lobby at the red table.
# **************************
# ----------- 45 --------------
# ------>Predictions by Model
# Sus is sleepy and doesn't want to work.
# ----->Predictions Original
# Sus and Val don't want to work and are sleepy.
# **************************
# ----------- 46 --------------
# ------>Predictions by Model
# Kate and Terry are at the Guggenheim right now.
# They want to go
# ----->Predictions Original
# Kate is at the Guggenheim Museum now, but will be in the Museum of the City of New York around 2-2:30.
# Kai may join her.
# Ish won't.
# Terry will join them for a coffee after they finish visiting the museum.
# Terry has already seen the museum.
# **************************
# ----------- 47 --------------
# ------>Predictions by Model
# Cathy left her sunglasses at Brooke's house.
# She will come round at 10 tonight
# ----->Predictions Original
# Cathy left her sunglasses at Broke's house.
# She will come collect them at 10.
# **************************
# ----------- 48 --------------
# ------>Predictions by Model
# Frederica will come to Bradley's birthday party tomorrow at 8 pm.
# ----->Predictions Original
# Bradley will come to Frederica's birthday party tomorrow at 8pm.
# **************************
# ----------- 49 --------------
# ------>Predictions by Model
# Camilla received 250.
# She will let Adrian know when she has received the money.
# ----->Predictions Original
# Camilla still hasn't received the 250.
# She will check and let Adrian know.
# Money usually takes around two days to arrive.
# **************************
# Saving model checkpoint to bart-token-b6c0.1/checkpoint-6000
# Configuration saved in bart-token-b6c0.1/checkpoint-6000/config.json
# Model weights saved in bart-token-b6c0.1/checkpoint-6000/pytorch_model.bin
# tokenizer config file saved in bart-token-b6c0.1/checkpoint-6000/tokenizer_config.json
# Special tokens file saved in bart-token-b6c0.1/checkpoint-6000/special_tokens_map.json
# Saving model checkpoint to bart-token-b6c0.1/checkpoint-6500
# Configuration saved in bart-token-b6c0.1/checkpoint-6500/config.json
# ...
# Saving model checkpoint to bart-token-b6c0.1/checkpoint-9000
# Configuration saved in bart-token-b6c0.1/checkpoint-9000/config.json
# Model weights saved in bart-token-b6c0.1/checkpoint-9000/pytorch_model.bin
# tokenizer config file saved in bart-token-b6c0.1/checkpoint-9000/tokenizer_config.json
# Special tokens file saved in bart-token-b6c0.1/checkpoint-9000/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 818
#   Batch size = 4
#     <div>
#
#       <progress value='9205' max='9205' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [9205/9205 2:48:45, Epoch 4/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.056400</td>
#       <td>3.747261</td>
#       <td>46.759100</td>
#       <td>22.969300</td>
#       <td>38.997200</td>
#       <td>43.021800</td>
#       <td>18.305600</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.546900</td>
#       <td>3.625081</td>
#       <td>47.486400</td>
#       <td>24.227000</td>
#       <td>40.195500</td>
#       <td>43.941900</td>
#       <td>17.687000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.547600</td>
#       <td>3.572148</td>
#       <td>48.217600</td>
#       <td>25.305100</td>
#       <td>41.113100</td>
#       <td>44.576000</td>
#       <td>17.813000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.613500</td>
#       <td>3.472829</td>
#       <td>48.674300</td>
#       <td>25.332300</td>
#       <td>41.070200</td>
#       <td>44.872200</td>
#       <td>18.072100</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.865500</td>
#       <td>3.500222</td>
#       <td>48.543100</td>
#       <td>25.402200</td>
#       <td>41.131900</td>
#       <td>44.844100</td>
#       <td>18.112500</td>
#     </tr>
#   </tbody>
# </table><p>
# ----------- 0 --------------
# ------>Predictions by Model
# A wants to get a puppy for her son.
# She took him to the animal shelter
# ----->Predictions Original
# A will go to the animal shelter tomorrow to get a puppy for her son.
# They already visited the shelter last Monday and the son chose the puppy.
# **************************
# ----------- 1 --------------
# ------>Predictions by Model
# Emma wants to buy an advent calendar for her kids.
# Rob used to get one
# ----->Predictions Original
# Emma and Rob love the advent calendar.
# Lauren fits inside calendar various items, for instance, small toys and Christmas decorations.
# Her children are excited whenever they get the calendar.
# **************************
# ----------- 2 --------------
# ------>Predictions by Model
# Madison is pregnant, but she doesn't want to talk about it.
# Iggy's
# ----->Predictions Original
# Madison is pregnant but she doesn't want to talk about it.
# Patricia Stevens got married and she thought she was pregnant.
# **************************
# ----------- 3 --------------
# ------>Predictions by Model
# Marla found a pair of boxers under her bed.
# Her sister convinced someone to
# ----->Predictions Original
# Marla found a pair of boxers under her bed.
# **************************
# ----------- 4 --------------
# ------>Predictions by Model
# Robert has to buy guitar cable.
# Fred gives Robert the address of the music shop.
# ----->Predictions Original
# Robert wants Fred to send him the address of the music shop as he needs to buy guitar cable.
# **************************
# ----------- 5 --------------
# ------>Predictions by Model
# Keith will check in the drawer next to the fridge to buy some milk and cereals
# ----->Predictions Original
# Megan needn't buy milk and cereals.
# They're in the drawer next to the fridge.
# **************************
# ----------- 6 --------------
# ------>Predictions by Model
# Samantha sends Evelyn a video of herself making a noise.
# ----->Predictions Original
# Samantha and Evelyn after watching the video cannot believe she is able to make that noise.
# **************************
# ----------- 7 --------------
# ------>Predictions by Model
# Tom invited Theresa, Luis and Adam to Fiesole for dinner.
# ----->Predictions Original
# Tom's new place is in Fiesole.
# Luis and Marion has been there.
# **************************
# ----------- 8 --------------
# ------>Predictions by Model
# Vegano Resto will make a reservation for 6 people tonight at 21:00
# ----->Predictions Original
# Jane made a 9 PM reservation for 6 people tonight at Vegano Resto.
# **************************
# ----------- 9 --------------
# ------>Predictions by Model
# Nancy is coming home in 6 weeks.
# She has 3 other Brits working here
# ----->Predictions Original
# Nancy's working in Texas, but the kids laugh at her Welsh accent.
# She's coming home in 6 weeks.
# Earlier than that she's going to travel with 3 other Brits.
# **************************
# ----------- 10 --------------
# ------>Predictions by Model
# Laura needs a new printer.
# Jamie suggests she can buy a second hand one.
# ----->Predictions Original
# Laura is going to buy a printer.
# **************************
# ----------- 11 --------------
# ------>Predictions by Model
# Haylee will buy coconut milk yoghurt in the dairy section.
# ----->Predictions Original
# Haylee can't find the coconut milk yoghurt.
# **************************
# ----------- 12 --------------
# ------>Predictions by Model
# Norbert and Wendy need to hurry to catch the tour.
# Wendy is at the register
# ----->Predictions Original
# Wendy is shopping, but she needs to hurry up to catch the tour.
# **************************
# ----------- 13 --------------
# ------>Predictions by Model
# Cecil and Peter went to the Jandia Peninsula.
# Cecil is driving.
# ----->Predictions Original
# Cecil, Cheryl and Peter went to the Jandia Peninsula today.
# Cecil would like to explore the south of the island tomorrow, but they will decide what to do after dinner.
# **************************
# ----------- 14 --------------
# ------>Predictions by Model
# Sophie hasn't found it yet.
# Nickola checks pockets and handbags.
# ----->Predictions Original
# Sophie still hasn't found it despite checking pockets and handbags twice.
# **************************
# ----------- 15 --------------
# ------>Predictions by Model
# Rosie has to write an essay about bad movies.
# She will cover "The Room
# ----->Predictions Original
# Dennis and Elle are helping Rosie think of bad movies for her essay.
# **************************
# ----------- 16 --------------
# ------>Predictions by Model
# James has a dream to become a voice actor.
# He wants to be a part of
# ----->Predictions Original
# James has a dream of becoming a voice actor.
# He considers making a home radio station.
# **************************
# ----------- 17 --------------
# ------>Predictions by Model
# Poppy and Alice are going for drinks after work.
# They will meet at Nick's
# ----->Predictions Original
# Poppy and Alice are meeting for drinks after work at Nick's at 5:30.
# Alice fancies Fred, she will invite him and a bunch of other coworkers.
# **************************
# ----------- 18 --------------
# ------>Predictions by Model
# Sash will see Caron before 12.
# Caron needs to go out.
# ----->Predictions Original
# Sash needs to see Caron who'll be out from 12.
# **************************
# ----------- 19 --------------
# ------>Predictions by Model
# Matteo likes Gosia a lot.
# Giuseppe doesn't like football and
# ----->Predictions Original
# Matteo is not sure about his relationship with Gosia but likes her a lot.
# **************************
# ----------- 20 --------------
# ------>Predictions by Model
# Ramzi's mother is calling for supper.
# Jannette is coming.
# ----->Predictions Original
# Ramzi and Jannette are going for supper.
# **************************
# ----------- 21 --------------
# ------>Predictions by Model
# Jeniffer and Hildegard are preparing ravioli.
# ----->Predictions Original
# Jeniffer is preparing ravioli following her grandmothers recipe.
# **************************
# ----------- 22 --------------
# ------>Predictions by Model
# Lawrence hasn't finished with the article yet.
# He will be back in a few
# ----->Predictions Original
# Lawrence will finish writing the article soon.
# **************************
# ----------- 23 --------------
# ------>Predictions by Model
# Chad sent Brennen a funny photo.
# ----->Predictions Original
# Chad has sent Brennen a funny photo.
# Brennen does not find it very funny.
# **************************
# ----------- 24 --------------
# ------>Predictions by Model
# Chloe will borrow Sadie's bike on Wednesday evening.
# ----->Predictions Original
# Sadie will borrow Chloe's bike on Wednesday evening.
# She has a dentist appointment on Thursday after work.
# **************************
# ----------- 25 --------------
# ------>Predictions by Model
# Olivia and Carter want to launch a new restaurant in the city centre next month
# ----->Predictions Original
# Carter is launching a restaurant business next month.
# Olivia wants him to include a restaurant she's working for in the discount app.
# They will meet in person to discuss it.
# **************************
# ----------- 26 --------------
# ------>Predictions by Model
# Kristine is worried about Kenny because he's back from surgery.
# He has another surgery
# ----->Predictions Original
# Kenny had a surgery, as Kristine reports.
# He will have another surgery tomorrow.
# Guy will come to St. Mark's Hospital near Asda to stay with Kristine.
# **************************
# ----------- 27 --------------
# ------>Predictions by Model
# Joey cheated on Olivia with numerous girls and got some chick pregnant.
# Olivia is devastated
# ----->Predictions Original
# Skyler and Adam are surprised that Joey and Olivia broke up.
# **************************
# ----------- 28 --------------
# ------>Predictions by Model
# Amanda is pregnant.
# She went to dancing classes with Michael yesterday.
# The instructor needed
# ----->Predictions Original
# Amanda goes to dancing classes with Michael.
# She volunteered to show the English Waltz steps with the instructor yesterday.
# Amanda is shy and goes to therapy.
# **************************
# ----------- 29 --------------
# ------>Predictions by Model
# Taylor wants Isabel to introduce her boyfriend to her daughter.
# Isabel hasn't had any.
# ----->Predictions Original
# Taylor wants to meet Isabel's boyfriend but she has never had any.
# **************************
# ----------- 30 --------------
# ------>Predictions by Model
# Theo is leaving on Friday.
# Toby will come back by train on Monday.
# Toby
# ----->Predictions Original
# Theo's going to stay near Torino in the region of Italian Alpes.
# Toby wants to join the trip.
# Theo agrees and will pick Toby up on Friday at 7 am.
# **************************
# ----------- 31 --------------
# ------>Predictions by Model
# Brandon hasn't called to say he'd be late.
# Clara will prepare a report on
# ----->Predictions Original
# Brandon is late again.
# Clara will prepare a report on the absenteeism and lateness for Phil by Friday.
# **************************
# ----------- 32 --------------
# ------>Predictions by Model
# Suzie is sick again and wants to cancel the meeting with Olga.
# ----->Predictions Original
# Olga and Suzie will postpone their meeting due to Suzie's sickness.
# **************************
# ----------- 33 --------------
# ------>Predictions by Model
# Kate will be Diane's daughter Lorelai's mother.
# ----->Predictions Original
# Diane is pregnant and can't wait to give birth, she thinks the waiting is the worst.
# Kate thinks she'll be an amazing mother.
# **************************
# ----------- 34 --------------
# ------>Predictions by Model
# Andrew had to call in sick because he feels awful.
# Daniel will drop by after work
# ----->Predictions Original
# Andrew has a cold.
# Daniel will buy him some medication.
# **************************
# ----------- 35 --------------
# ------>Predictions by Model
# Alex and Sam are watching 'Millionaires' on tv.
# ----->Predictions Original
# Alex and Sam are watching Millionaires.
# **************************
# ----------- 36 --------------
# ------>Predictions by Model
# Jessica has Angelica's cinnamon cookies recipe.
# ----->Predictions Original
# Angelica sent the cinnamon cookies recipe at Kelly's request.
# **************************
# ----------- 37 --------------
# ------>Predictions by Model
# Sophie is waiting for a client who is 40 minutes late.
# Gwen will
# ----->Predictions Original
# Sophie is waiting for a client, who is late.
# She will meet Gwen later.
# **************************
# ----------- 38 --------------
# ------>Predictions by Model
# Daniel is on his way to meet Sue in a few minutes.
# ----->Predictions Original
# Daniel is with the Volvo on his way and will be there soon.
# Sue is going downstairs to meet him.
# **************************
# ----------- 39 --------------
# ------>Predictions by Model
# Betty is going to CVS to buy some salmon and some shaving cream for George
# ----->Predictions Original
# George is making salmon and stuffed squash for dinner.
# Betty will buy a shaving cream at CVS at his request,
# **************************
# ----------- 40 --------------
# ------>Predictions by Model
# Ken started running and wanted to track his progress.
# Ken's phone battery was almost depleted
# ----->Predictions Original
# Ken has installed an app for running but it is not working properly on his phone.
# **************************
# ----------- 41 --------------
# ------>Predictions by Model
# Ann couldn't come to Ivan's birthday party.
# Ivan bought her something for her birthday
# ----->Predictions Original
# Ivan and Ann will meet next week.
# **************************
# ----------- 42 --------------
# ------>Predictions by Model
# Ashley posted nude pictures on her Facebook page.
# Rowan has some important stuff to
# ----->Predictions Original
# Ashley posted some nude photos on her fb page.
# **************************
# ----------- 43 --------------
# ------>Predictions by Model
# Mikolaj got his wife's papers with working permission.
# The government had a
# ----->Predictions Original
# Mikolaj's wife needs a work permit as a foreigner.
# Government officials missed the deadline for sending it and will need another month.
# **************************
# ----------- 44 --------------
# ------>Predictions by Model
# Ann is at the 3rd floor lobby.
# Peter is still there.
# Ann and Maria
# ----->Predictions Original
# Thomas, Ann and Maria will have lunch together at the hotel.
# Ann is already in the 3rd floor lobby at the red table.
# **************************
# ----------- 45 --------------
# ------>Predictions by Model
# Sus and Val don't want to work.
# ----->Predictions Original
# Sus and Val don't want to work and are sleepy.
# **************************
# ----------- 46 --------------
# ------>Predictions by Model
# Kate and Terry are at the Guggenheim right now.
# They want to go
# ----->Predictions Original
# Kate is at the Guggenheim Museum now, but will be in the Museum of the City of New York around 2-2:30.
# Kai may join her.
# Ish won't.
# Terry will join them for a coffee after they finish visiting the museum.
# Terry has already seen the museum.
# **************************
# ----------- 47 --------------
# ------>Predictions by Model
# Cathy left her sunglasses at Brooke's house.
# She will come round at 10 tonight
# ----->Predictions Original
# Cathy left her sunglasses at Broke's house.
# She will come collect them at 10.
# **************************
# ----------- 48 --------------
# ------>Predictions by Model
# Frederica will come to Bradley's birthday party tomorrow at 8 pm.
# ----->Predictions Original
# Bradley will come to Frederica's birthday party tomorrow at 8pm.
# **************************
# ----------- 49 --------------
# ------>Predictions by Model
# Camilla received 250.
# Camilla will let Adrian know when she receives the money.
# ----->Predictions Original
# Camilla still hasn't received the 250.
# She will check and let Adrian know.
# Money usually takes around two days to arrive.
# **************************
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=9205, training_loss=3.7543430039314134, metrics={'train_runtime': 10126.7838, 'train_samples_per_second': 7.273, 'train_steps_per_second': 0.909, 'total_flos': 1.239353421336576e+16, 'train_loss': 3.7543430039314134, 'epoch': 5.0})

# %%
trainer.train()# 0.1
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 14730
#   Num Epochs = 5
#   Instantaneous batch size per device = 4
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 2
#   Total optimization steps = 9205
#   Number of trainable parameters = 139420416
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# You're using a BartTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='1662' max='9205' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1662/9205 28:54 < 2:11:23, 0.96 it/s, Epoch 0.90/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# Saving model checkpoint to bart-token-b6c0.1/checkpoint-500
# Configuration saved in bart-token-b6c0.1/checkpoint-500/config.json
# Model weights saved in bart-token-b6c0.1/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in bart-token-b6c0.1/checkpoint-500/tokenizer_config.json
# Special tokens file saved in bart-token-b6c0.1/checkpoint-500/special_tokens_map.json
# Saving model checkpoint to bart-token-b6c0.1/checkpoint-1000
# Configuration saved in bart-token-b6c0.1/checkpoint-1000/config.json
# Model weights saved in bart-token-b6c0.1/checkpoint-1000/pytorch_model.bin
# tokenizer config file saved in bart-token-b6c0.1/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in bart-token-b6c0.1/checkpoint-1000/special_tokens_map.json
# Saving model checkpoint to bart-token-b6c0.1/checkpoint-1500
# Configuration saved in bart-token-b6c0.1/checkpoint-1500/config.json
# Model weights saved in bart-token-b6c0.1/checkpoint-1500/pytorch_model.bin
# tokenizer config file saved in bart-token-b6c0.1/checkpoint-1500/tokenizer_config.json
# Special tokens file saved in bart-token-b6c0.1/checkpoint-1500/special_tokens_map.json
#     <div>
#
#       <progress value='9205' max='9205' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [9205/9205 2:51:46, Epoch 4/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.008400</td>
#       <td>1.757944</td>
#       <td>47.199800</td>
#       <td>23.803300</td>
#       <td>39.717700</td>
#       <td>43.710600</td>
#       <td>18.361900</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.753200</td>
#       <td>1.707096</td>
#       <td>47.520900</td>
#       <td>24.752800</td>
#       <td>40.564600</td>
#       <td>44.147900</td>
#       <td>17.644300</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.505000</td>
#       <td>1.690901</td>
#       <td>48.678400</td>
#       <td>25.490400</td>
#       <td>41.344800</td>
#       <td>44.929500</td>
#       <td>18.037900</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.598100</td>
#       <td>1.664601</td>
#       <td>48.758200</td>
#       <td>25.729000</td>
#       <td>41.454000</td>
#       <td>45.069500</td>
#       <td>18.133300</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.626000</td>
#       <td>1.666132</td>
#       <td>48.903200</td>
#       <td>25.660700</td>
#       <td>41.323000</td>
#       <td>45.224100</td>
#       <td>18.150400</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 818
#   Batch size = 4
# ----------- 0 --------------
# ------>Predictions by Model
# A wants to get a puppy for her son.
# She will take him to the animal
# ----->Predictions Original
# A will go to the animal shelter tomorrow to get a puppy for her son.
# They already visited the shelter last Monday and the son chose the puppy.
# **************************
# ----------- 1 --------------
# ------>Predictions by Model
# Emma wants to buy an advent calendar for her kids.
# Rob used to get one
# ----->Predictions Original
# Emma and Rob love the advent calendar.
# Lauren fits inside calendar various items, for instance, small toys and Christmas decorations.
# Her children are excited whenever they get the calendar.
# **************************
# ----------- 2 --------------
# ------>Predictions by Model
# Madison is pregnant, but she doesn't want to talk about it because people get excited
# ----->Predictions Original
# Madison is pregnant but she doesn't want to talk about it.
# Patricia Stevens got married and she thought she was pregnant.
# **************************
# ----------- 3 --------------
# ------>Predictions by Model
# Marla found a pair of boxers under her bed.
# She is 13.
# She
# ----->Predictions Original
# Marla found a pair of boxers under her bed.
# **************************
# ----------- 4 --------------
# ------>Predictions by Model
# Robert has to buy guitar cable.
# Fred will find it on google maps.
# ----->Predictions Original
# Robert wants Fred to send him the address of the music shop as he needs to buy guitar cable.
# **************************
# ----------- 5 --------------
# ------>Predictions by Model
# Keith and Megan are going to buy milk and cereals.
# Megan checked in the drawer
# ----->Predictions Original
# Megan needn't buy milk and cereals.
# They're in the drawer next to the fridge.
# **************************
# ----------- 6 --------------
# ------>Predictions by Model
# Samantha sends Evelyn a video of herself making a noise.
# ----->Predictions Original
# Samantha and Evelyn after watching the video cannot believe she is able to make that noise.
# **************************
# ----------- 7 --------------
# ------>Predictions by Model
# Theresa, Luis and Adam are going to Tom's new place for a dinner.
# ----->Predictions Original
# Tom's new place is in Fiesole.
# Luis and Marion has been there.
# **************************
# ----------- 8 --------------
# ------>Predictions by Model
# Jane wants to make a reservation for 6 people tonight around 20:00.
# There is
# ----->Predictions Original
# Jane made a 9 PM reservation for 6 people tonight at Vegano Resto.
# **************************
# ----------- 9 --------------
# ------>Predictions by Model
# Nancy is working in a Texan drawl.
# She is coming home in 6
# ----->Predictions Original
# Nancy's working in Texas, but the kids laugh at her Welsh accent.
# She's coming home in 6 weeks.
# Earlier than that she's going to travel with 3 other Brits.
# **************************
# ----------- 10 --------------
# ------>Predictions by Model
# Laura needs a new printer.
# Jamie suggests she can buy a second hand one.
# ----->Predictions Original
# Laura is going to buy a printer.
# **************************
# ----------- 11 --------------
# ------>Predictions by Model
# Barbara and Haylee are in dairy section.
# Haylee wants coconut milk yogh
# ----->Predictions Original
# Haylee can't find the coconut milk yoghurt.
# **************************
# ----------- 12 --------------
# ------>Predictions by Model
# Norbert and Wendy need to hurry to catch the tour.
# Wendy is buying something.
# ----->Predictions Original
# Wendy is shopping, but she needs to hurry up to catch the tour.
# **************************
# ----------- 13 --------------
# ------>Predictions by Model
# Cecil is driving Cecil to the Jandia Peninsula.
# Cecil wants to explore
# ----->Predictions Original
# Cecil, Cheryl and Peter went to the Jandia Peninsula today.
# Cecil would like to explore the south of the island tomorrow, but they will decide what to do after dinner.
# **************************
# ----------- 14 --------------
# ------>Predictions by Model
# Sophie has checked pockets and handbags twice already.
# ----->Predictions Original
# Sophie still hasn't found it despite checking pockets and handbags twice.
# **************************
# ----------- 15 --------------
# ------>Predictions by Model
# Rosie has to write an essay about bad movies.
# Dennis recommends "Troma Studio
# ----->Predictions Original
# Dennis and Elle are helping Rosie think of bad movies for her essay.
# **************************
# ----------- 16 --------------
# ------>Predictions by Model
# James has a dream to become a voice actor.
# He wants to be a part of
# ----->Predictions Original
# James has a dream of becoming a voice actor.
# He considers making a home radio station.
# **************************
# ----------- 17 --------------
# ------>Predictions by Model
# Poppy has a long day at work.
# Alice is going for drinks after work.
# ----->Predictions Original
# Poppy and Alice are meeting for drinks after work at Nick's at 5:30.
# Alice fancies Fred, she will invite him and a bunch of other coworkers.
# **************************
# ----------- 18 --------------
# ------>Predictions by Model
# Caron is out from 12.
# She needs to go out soon.
# ----->Predictions Original
# Sash needs to see Caron who'll be out from 12.
# **************************
# ----------- 19 --------------
# ------>Predictions by Model
# Giuseppe is dating Gosia.
# Giuseppe doesn't like football and video
# ----->Predictions Original
# Matteo is not sure about his relationship with Gosia but likes her a lot.
# **************************
# ----------- 20 --------------
# ------>Predictions by Model
# Jannette is calling Ramzi for supper.
# ----->Predictions Original
# Ramzi and Jannette are going for supper.
# **************************
# ----------- 21 --------------
# ------>Predictions by Model
# Jeniffer is preparing ravioli from her grandmother.
# ----->Predictions Original
# Jeniffer is preparing ravioli following her grandmothers recipe.
# **************************
# ----------- 22 --------------
# ------>Predictions by Model
# Lawrence is not through with the article yet.
# He will be in a few minutes
# ----->Predictions Original
# Lawrence will finish writing the article soon.
# **************************
# ----------- 23 --------------
# ------>Predictions by Model
# Chad sends Brennen a funny photo.
# ----->Predictions Original
# Chad has sent Brennen a funny photo.
# Brennen does not find it very funny.
# **************************
# ----------- 24 --------------
# ------>Predictions by Model
# Sadie needs to go to the dentist quickly after work.
# Chloe will pick it up
# ----->Predictions Original
# Sadie will borrow Chloe's bike on Wednesday evening.
# She has a dentist appointment on Thursday after work.
# **************************
# ----------- 25 --------------
# ------>Predictions by Model
# Olivia wants to launch a new restaurant in the city centre next month.
# Carter
# ----->Predictions Original
# Carter is launching a restaurant business next month.
# Olivia wants him to include a restaurant she's working for in the discount app.
# They will meet in person to discuss it.
# **************************
# ----------- 26 --------------
# ------>Predictions by Model
# Kristine is worried about Kenny's health.
# He has another surgery scheduled tomorrow, but
# ----->Predictions Original
# Kenny had a surgery, as Kristine reports.
# He will have another surgery tomorrow.
# Guy will come to St. Mark's Hospital near Asda to stay with Kristine.
# **************************
# ----------- 27 --------------
# ------>Predictions by Model
# Joey and Olivia broke up after all these years.
# Olivia cheated on Joey with numerous
# ----->Predictions Original
# Skyler and Adam are surprised that Joey and Olivia broke up.
# **************************
# ----------- 28 --------------
# ------>Predictions by Model
# Amanda went to dancing classes with Michael.
# The instructor needed a partner to show the
# ----->Predictions Original
# Amanda goes to dancing classes with Michael.
# She volunteered to show the English Waltz steps with the instructor yesterday.
# Amanda is shy and goes to therapy.
# **************************
# ----------- 29 --------------
# ------>Predictions by Model
# Taylor wants Isabel to bring her boyfriend to her.
# Isabel hasn't had any.
# Taylor
# ----->Predictions Original
# Taylor wants to meet Isabel's boyfriend but she has never had any.
# **************************
# ----------- 30 --------------
# ------>Predictions by Model
# Toby and Theo are going to the Italian Alpes on Friday.
# Toby will join
# ----->Predictions Original
# Theo's going to stay near Torino in the region of Italian Alpes.
# Toby wants to join the trip.
# Theo agrees and will pick Toby up on Friday at 7 am.
# **************************
# ----------- 31 --------------
# ------>Predictions by Model
# Brandon hasn't called Clara to say he'd be late.
# She will prepare a report
# ----->Predictions Original
# Brandon is late again.
# Clara will prepare a report on the absenteeism and lateness for Phil by Friday.
# **************************
# ----------- 32 --------------
# ------>Predictions by Model
# Suzie is sick again.
# She wants Olga to reschedule.
# Suzie
# ----->Predictions Original
# Olga and Suzie will postpone their meeting due to Suzie's sickness.
# **************************
# ----------- 33 --------------
# ------>Predictions by Model
# Diane wants Kate to be her kids' mother.
# Kate is not sure if she
# ----->Predictions Original
# Diane is pregnant and can't wait to give birth, she thinks the waiting is the worst.
# Kate thinks she'll be an amazing mother.
# **************************
# ----------- 34 --------------
# ------>Predictions by Model
# Andrew had to call in sick because of a cold.
# Daniel will drop by after work
# ----->Predictions Original
# Andrew has a cold.
# Daniel will buy him some medication.
# **************************
# ----------- 35 --------------
# ------>Predictions by Model
# Alex and Sam are watching 'Millionaires' on tv.
# Sam has a chance
# ----->Predictions Original
# Alex and Sam are watching Millionaires.
# **************************
# ----------- 36 --------------
# ------>Predictions by Model
# Jessica has the cinnamon cookies recipe.
# Angelica has it.
# ----->Predictions Original
# Angelica sent the cinnamon cookies recipe at Kelly's request.
# **************************
# ----------- 37 --------------
# ------>Predictions by Model
# Sophie is waiting for a client who is 40 minutes late.
# Gwen will
# ----->Predictions Original
# Sophie is waiting for a client, who is late.
# She will meet Gwen later.
# **************************
# ----------- 38 --------------
# ------>Predictions by Model
# Daniel is on his way downstairs.
# Sue is with the Volvo.
# ----->Predictions Original
# Daniel is with the Volvo on his way and will be there soon.
# Sue is going downstairs to meet him.
# **************************
# ----------- 39 --------------
# ------>Predictions by Model
# George is going to CVS to buy some shaving cream.
# ----->Predictions Original
# George is making salmon and stuffed squash for dinner.
# Betty will buy a shaving cream at CVS at his request,
# **************************
# ----------- 40 --------------
# ------>Predictions by Model
# Ken is using endomondo everyday.
# Ken's phone doesn't work properly.
# He
# ----->Predictions Original
# Ken has installed an app for running but it is not working properly on his phone.
# **************************
# ----------- 41 --------------
# ------>Predictions by Model
# Ann hasn't been at Ivan's birthday party.
# Ivan bought her something for her birthday
# ----->Predictions Original
# Ivan and Ann will meet next week.
# **************************
# ----------- 42 --------------
# ------>Predictions by Model
# Delilah and Rowan are going to look at Ashley's fb page.
# ----->Predictions Original
# Ashley posted some nude photos on her fb page.
# **************************
# ----------- 43 --------------
# ------>Predictions by Model
# Mikolaj has got the working permission for his wife's papers.
# Magda
# ----->Predictions Original
# Mikolaj's wife needs a work permit as a foreigner.
# Government officials missed the deadline for sending it and will need another month.
# **************************
# ----------- 44 --------------
# ------>Predictions by Model
# Ann is at the hotel.
# Peter is still at the lobby and the 3rd floor
# ----->Predictions Original
# Thomas, Ann and Maria will have lunch together at the hotel.
# Ann is already in the 3rd floor lobby at the red table.
# **************************
# ----------- 45 --------------
# ------>Predictions by Model
# Sus and Val don't want to work.
# ----->Predictions Original
# Sus and Val don't want to work and are sleepy.
# **************************
# ----------- 46 --------------
# ------>Predictions by Model
# Kate and Terry are going to the Guggenheim Museum of the city of NY
# ----->Predictions Original
# Kate is at the Guggenheim Museum now, but will be in the Museum of the City of New York around 2-2:30.
# Kai may join her.
# Ish won't.
# Terry will join them for a coffee after they finish visiting the museum.
# Terry has already seen the museum.
# **************************
# ----------- 47 --------------
# ------>Predictions by Model
# Cathy left her sunglasses at Brooke's house.
# She will come round at 10 tonight
# ----->Predictions Original
# Cathy left her sunglasses at Broke's house.
# She will come collect them at 10.
# **************************
# ----------- 48 --------------
# ------>Predictions by Model
# Bradley will come to Freddie's birthday party tomorrow at 8 pm.
# ----->Predictions Original
# Bradley will come to Frederica's birthday party tomorrow at 8pm.
# **************************
# ----------- 49 --------------
# ------>Predictions by Model
# Camilla received 250 dollars from Adrian.
# Camilla will let him know when she has
# ----->Predictions Original
# Camilla still hasn't received the 250.
# She will check and let Adrian know.
# Money usually takes around two days to arrive.
# **************************
# Saving model checkpoint to bart-token-b6c0.1/checkpoint-2000
# Configuration saved in bart-token-b6c0.1/checkpoint-2000/config.json
# Model weights saved in bart-token-b6c0.1/checkpoint-2000/pytorch_model.bin
# tokenizer config file saved in bart-token-b6c0.1/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in bart-token-b6c0.1/checkpoint-2000/special_tokens_map.json
# Saving model checkpoint to bart-token-b6c0.1/checkpoint-2500
# Configuration saved in bart-token-b6c0.1/checkpoint-2500/config.json
# Model weights saved in bart-token-b6c0.1/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in bart-token-b6c0.1/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in bart-token-b6c0.1/checkpoint-2500/special_tokens_map.json
# Saving model checkpoint to bart-token-b6c0.1/checkpoint-3000
# Configuration saved in bart-token-b6c0.1/checkpoint-3000/config.json
# Model weights saved in bart-token-b6c0.1/checkpoint-3000/pytorch_model.bin
# tokenizer config file saved in bart-token-b6c0.1/checkpoint-3000/tokenizer_config.json
# Special tokens file saved in bart-token-b6c0.1/checkpoint-3000/special_tokens_map.json
# Saving model checkpoint to bart-token-b6c0.1/checkpoint-3500
# Configuration saved in bart-token-b6c0.1/checkpoint-3500/config.json
# Model weights saved in bart-token-b6c0.1/checkpoint-3500/pytorch_model.bin
# tokenizer config file saved in bart-token-b6c0.1/checkpoint-3500/tokenizer_config.json
# Special tokens file saved in bart-token-b6c0.1/checkpoint-3500/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 818
#   Batch size = 4
# ----------- 0 --------------
# ------>Predictions by Model
# A wants to get a puppy for her son.
# She will take him to the animal
# ----->Predictions Original
# A will go to the animal shelter tomorrow to get a puppy for her son.
# They already visited the shelter last Monday and the son chose the puppy.
# **************************
# ----------- 1 --------------
# ------>Predictions by Model
# Emma wants to get an advent calendar for her kids.
# Rob used to get one
# ----->Predictions Original
# Emma and Rob love the advent calendar.
# Lauren fits inside calendar various items, for instance, small toys and Christmas decorations.
# Her children are excited whenever they get the calendar.
# **************************
# ----------- 2 --------------
# ------>Predictions by Model
# Madison is pregnant.
# ----->Predictions Original
# Madison is pregnant but she doesn't want to talk about it.
# Patricia Stevens got married and she thought she was pregnant.
# **************************
# ----------- 3 --------------
# ------>Predictions by Model
# Marla found a pair of boxers under her bed.
# ----->Predictions Original
# Marla found a pair of boxers under her bed.
# **************************
# ----------- 4 --------------
# ------>Predictions by Model
# Robert has to buy guitar cable.
# Fred sends Robert the address of the music shop he
# ----->Predictions Original
# Robert wants Fred to send him the address of the music shop as he needs to buy guitar cable.
# **************************
# ----------- 5 --------------
# ------>Predictions by Model
# Keith wants Megan to buy some milk and cereals.
# Megan didn't check in the
# ----->Predictions Original
# Megan needn't buy milk and cereals.
# They're in the drawer next to the fridge.
# **************************
# ----------- 6 --------------
# ------>Predictions by Model
# Samantha sends Evelyn a video of herself making a noise.
# ----->Predictions Original
# Samantha and Evelyn after watching the video cannot believe she is able to make that noise.
# **************************
# ----------- 7 --------------
# ------>Predictions by Model
# Marion has been to Tom's new place.
# It's a bit outside the city
# ----->Predictions Original
# Tom's new place is in Fiesole.
# Luis and Marion has been there.
# **************************
# ----------- 8 --------------
# ------>Predictions by Model
# Vegano Resto will make a reservation for 6 people tonight at 21:00
# ----->Predictions Original
# Jane made a 9 PM reservation for 6 people tonight at Vegano Resto.
# **************************
# ----------- 9 --------------
# ------>Predictions by Model
# Nancy is coming home in 6 weeks.
# She's going travelling with 3 other Brit
# ----->Predictions Original
# Nancy's working in Texas, but the kids laugh at her Welsh accent.
# She's coming home in 6 weeks.
# Earlier than that she's going to travel with 3 other Brits.
# **************************
# ----------- 10 --------------
# ------>Predictions by Model
# Laura needs a new printer.
# Jamie suggests she buy a second hand one.
# ----->Predictions Original
# Laura is going to buy a printer.
# **************************
# ----------- 11 --------------
# ------>Predictions by Model
# Haylee is in the dairy section.
# Barbara bought coconut milk yoghurt.
# ----->Predictions Original
# Haylee can't find the coconut milk yoghurt.
# **************************
# ----------- 12 --------------
# ------>Predictions by Model
# Norbert and Wendy need to hurry to catch the tour.
# Wendy is buying something.
# ----->Predictions Original
# Wendy is shopping, but she needs to hurry up to catch the tour.
# **************************
# ----------- 13 --------------
# ------>Predictions by Model
# Cheryl went to the Jandia Peninsula.
# Cecil wants to explore more the
# ----->Predictions Original
# Cecil, Cheryl and Peter went to the Jandia Peninsula today.
# Cecil would like to explore the south of the island tomorrow, but they will decide what to do after dinner.
# **************************
# ----------- 14 --------------
# ------>Predictions by Model
# Sophie hasn't found it.
# Nickola will check pockets and handbags.
# ----->Predictions Original
# Sophie still hasn't found it despite checking pockets and handbags twice.
# **************************
# ----------- 15 --------------
# ------>Predictions by Model
# Rosie has to write an essay about bad movies.
# She will cover "The Room
# ----->Predictions Original
# Dennis and Elle are helping Rosie think of bad movies for her essay.
# **************************
# ----------- 16 --------------
# ------>Predictions by Model
# James has a dream to become a voice actor.
# ----->Predictions Original
# James has a dream of becoming a voice actor.
# He considers making a home radio station.
# **************************
# ----------- 17 --------------
# ------>Predictions by Model
# Poppy and Alice are going for drinks after work.
# Poppy didn't get lunch
# ----->Predictions Original
# Poppy and Alice are meeting for drinks after work at Nick's at 5:30.
# Alice fancies Fred, she will invite him and a bunch of other coworkers.
# **************************
# ----------- 18 --------------
# ------>Predictions by Model
# Caron is out from 12.
# Sash will be before 12.
# ----->Predictions Original
# Sash needs to see Caron who'll be out from 12.
# **************************
# ----------- 19 --------------
# ------>Predictions by Model
# Matteo likes Gosia a lot.
# She criticizes him because he likes football
# ----->Predictions Original
# Matteo is not sure about his relationship with Gosia but likes her a lot.
# **************************
# ----------- 20 --------------
# ------>Predictions by Model
# Ramzi's mom is calling for supper.
# Jannette is coming.
# ----->Predictions Original
# Ramzi and Jannette are going for supper.
# **************************
# ----------- 21 --------------
# ------>Predictions by Model
# Jeniffer got the recipe from her grandmother.
# ----->Predictions Original
# Jeniffer is preparing ravioli following her grandmothers recipe.
# **************************
# ----------- 22 --------------
# ------>Predictions by Model
# Lawrence will be back to Madison in a few minutes.
# ----->Predictions Original
# Lawrence will finish writing the article soon.
# **************************
# ----------- 23 --------------
# ------>Predictions by Model
# Chad sends Brennen a funny photo.
# ----->Predictions Original
# Chad has sent Brennen a funny photo.
# Brennen does not find it very funny.
# **************************
# ----------- 24 --------------
# ------>Predictions by Model
# Chloe will pick up Sadie's bike on Wednesday evening.
# ----->Predictions Original
# Sadie will borrow Chloe's bike on Wednesday evening.
# She has a dentist appointment on Thursday after work.
# **************************
# ----------- 25 --------------
# ------>Predictions by Model
# Olivia wants to launch a new restaurant in the city centre next month.
# Carter
# ----->Predictions Original
# Carter is launching a restaurant business next month.
# Olivia wants him to include a restaurant she's working for in the discount app.
# They will meet in person to discuss it.
# **************************
# ----------- 26 --------------
# ------>Predictions by Model
# Kristine is worried about Kenny.
# He's back from surgery, but the doctors don
# ----->Predictions Original
# Kenny had a surgery, as Kristine reports.
# He will have another surgery tomorrow.
# Guy will come to St. Mark's Hospital near Asda to stay with Kristine.
# **************************
# ----------- 27 --------------
# ------>Predictions by Model
# Joey and Olivia broke up after all these years.
# ----->Predictions Original
# Skyler and Adam are surprised that Joey and Olivia broke up.
# **************************
# ----------- 28 --------------
# ------>Predictions by Model
# Amanda went to dancing classes yesterday.
# The instructor needed a partner to show the steps
# ----->Predictions Original
# Amanda goes to dancing classes with Michael.
# She volunteered to show the English Waltz steps with the instructor yesterday.
# Amanda is shy and goes to therapy.
# **************************
# ----------- 29 --------------
# ------>Predictions by Model
# Taylor wants Isabel to bring her boyfriend to her.
# Isabel hasn't had any.
# ----->Predictions Original
# Taylor wants to meet Isabel's boyfriend but she has never had any.
# **************************
# ----------- 30 --------------
# ------>Predictions by Model
# Theo is leaving on Friday.
# Toby will come back by train to Torino.
# ----->Predictions Original
# Theo's going to stay near Torino in the region of Italian Alpes.
# Toby wants to join the trip.
# Theo agrees and will pick Toby up on Friday at 7 am.
# **************************
# ----------- 31 --------------
# ------>Predictions by Model
# Brandon hasn't called Clara to say he'd be late.
# ----->Predictions Original
# Brandon is late again.
# Clara will prepare a report on the absenteeism and lateness for Phil by Friday.
# **************************
# ----------- 32 --------------
# ------>Predictions by Model
# Suzie is sick again and she's caughing like crazy.
# She will cancel
# ----->Predictions Original
# Olga and Suzie will postpone their meeting due to Suzie's sickness.
# **************************
# ----------- 33 --------------
# ------>Predictions by Model
# Kate will be Diane's daughter Lorelai's mother.
# ----->Predictions Original
# Diane is pregnant and can't wait to give birth, she thinks the waiting is the worst.
# Kate thinks she'll be an amazing mother.
# **************************
# ----------- 34 --------------
# ------>Predictions by Model
# Andrew had to call in sick because he feels awful.
# Daniel will drop by after work
# ----->Predictions Original
# Andrew has a cold.
# Daniel will buy him some medication.
# **************************
# ----------- 35 --------------
# ------>Predictions by Model
# Alex and Sam are watching 'Millionaires' on tv.
# ----->Predictions Original
# Alex and Sam are watching Millionaires.
# **************************
# ----------- 36 --------------
# ------>Predictions by Model
# Jessica has the cinnamon cookies recipe.
# ----->Predictions Original
# Angelica sent the cinnamon cookies recipe at Kelly's request.
# **************************
# ----------- 37 --------------
# ------>Predictions by Model
# Sophie is waiting for a client.
# She will meet with Gwen in 15
# ----->Predictions Original
# Sophie is waiting for a client, who is late.
# She will meet Gwen later.
# **************************
# ----------- 38 --------------
# ------>Predictions by Model
# Daniel is on his way.
# Sue is going downstairs now.
# ----->Predictions Original
# Daniel is with the Volvo on his way and will be there soon.
# Sue is going downstairs to meet him.
# **************************
# ----------- 39 --------------
# ------>Predictions by Model
# Betty is going to CVS to pick up some shaving cream for George.
# ----->Predictions Original
# George is making salmon and stuffed squash for dinner.
# Betty will buy a shaving cream at CVS at his request,
# **************************
# ----------- 40 --------------
# ------>Predictions by Model
# Ken's phone doesn't work properly.
# He used endomondo everyday.
# It works
# ----->Predictions Original
# Ken has installed an app for running but it is not working properly on his phone.
# **************************
# ----------- 41 --------------
# ------>Predictions by Model
# Ann couldn't come to Ivan's birthday party.
# Ivan bought her something for her birthday
# ----->Predictions Original
# Ivan and Ann will meet next week.
# **************************
# ----------- 42 --------------
# ------>Predictions by Model
# Ashley posted nude pictures on her Facebook page.
# Rowan has some important stuff to
# ----->Predictions Original
# Ashley posted some nude photos on her fb page.
# **************************
# ----------- 43 --------------
# ------>Predictions by Model
# Mikolaj got his wife's papers with the working permission.
# The government had
# ----->Predictions Original
# Mikolaj's wife needs a work permit as a foreigner.
# Government officials missed the deadline for sending it and will need another month.
# **************************
# ----------- 44 --------------
# ------>Predictions by Model
# Ann and Thomas are going to have lunch together at the hotel.
# ----->Predictions Original
# Thomas, Ann and Maria will have lunch together at the hotel.
# Ann is already in the 3rd floor lobby at the red table.
# **************************
# ----------- 45 --------------
# ------>Predictions by Model
# Sus and Val don't want to work.
# ----->Predictions Original
# Sus and Val don't want to work and are sleepy.
# **************************
# ----------- 46 --------------
# ------>Predictions by Model
# Kate and Terry are going to the Museum of the city of NY around 2-2
# ----->Predictions Original
# Kate is at the Guggenheim Museum now, but will be in the Museum of the City of New York around 2-2:30.
# Kai may join her.
# Ish won't.
# Terry will join them for a coffee after they finish visiting the museum.
# Terry has already seen the museum.
# **************************
# ----------- 47 --------------
# ------>Predictions by Model
# Cathy left her sunglasses at Brooke's house.
# She will come round at 10 tonight
# ----->Predictions Original
# Cathy left her sunglasses at Broke's house.
# She will come collect them at 10.
# **************************
# ----------- 48 --------------
# ------>Predictions by Model
# Frederica will come to Bradley's birthday party tomorrow at 8 pm.
# ----->Predictions Original
# Bradley will come to Frederica's birthday party tomorrow at 8pm.
# **************************
# ----------- 49 --------------
# ------>Predictions by Model
# Camilla received the money.
# It usually takes around two days to arrive though.
# ----->Predictions Original
# Camilla still hasn't received the 250.
# She will check and let Adrian know.
# Money usually takes around two days to arrive.
# **************************
# Saving model checkpoint to bart-token-b6c0.1/checkpoint-4000
# Configuration saved in bart-token-b6c0.1/checkpoint-4000/config.json
# Model weights saved in bart-token-b6c0.1/checkpoint-4000/pytorch_model.bin
# tokenizer config file saved in bart-token-b6c0.1/checkpoint-4000/tokenizer_config.json
# Special tokens file saved in bart-token-b6c0.1/checkpoint-4000/special_tokens_map.json
# Saving model checkpoint to bart-token-b6c0.1/checkpoint-4500
# Configuration saved in bart-token-b6c0.1/checkpoint-4500/config.json
# Model weights saved in bart-token-b6c0.1/checkpoint-4500/pytorch_model.bin
# tokenizer config file saved in bart-token-b6c0.1/checkpoint-4500/tokenizer_config.json
# Special tokens file saved in bart-token-b6c0.1/checkpoint-4500/special_tokens_map.json
# Saving model checkpoint to bart-token-b6c0.1/checkpoint-5000
# Configuration saved in bart-token-b6c0.1/checkpoint-5000/config.json
# Model weights saved in bart-token-b6c0.1/checkpoint-5000/pytorch_model.bin
# tokenizer config file saved in bart-token-b6c0.1/checkpoint-5000/tokenizer_config.json
# Special tokens file saved in bart-token-b6c0.1/checkpoint-5000/special_tokens_map.json
# Saving model checkpoint to bart-token-b6c0.1/checkpoint-5500
# Configuration saved in bart-token-b6c0.1/checkpoint-5500/config.json
# Model weights saved in bart-token-b6c0.1/checkpoint-5500/pytorch_model.bin
# tokenizer config file saved in bart-token-b6c0.1/checkpoint-5500/tokenizer_config.json
# Special tokens file saved in bart-token-b6c0.1/checkpoint-5500/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 818
#   Batch size = 4
# ----------- 0 --------------
# ------>Predictions by Model
# A wants to get a puppy for her son.
# She will take him to the animal
# ----->Predictions Original
# A will go to the animal shelter tomorrow to get a puppy for her son.
# They already visited the shelter last Monday and the son chose the puppy.
# **************************
# ----------- 1 --------------
# ------>Predictions by Model
# Emma wants to buy an advent calendar for her children.
# Rob used to get one
# ----->Predictions Original
# Emma and Rob love the advent calendar.
# Lauren fits inside calendar various items, for instance, small toys and Christmas decorations.
# Her children are excited whenever they get the calendar.
# **************************
# ----------- 2 --------------
# ------>Predictions by Model
# Madison is pregnant.
# She doesn't want to talk about it.
# Iggy's friend
# ----->Predictions Original
# Madison is pregnant but she doesn't want to talk about it.
# Patricia Stevens got married and she thought she was pregnant.
# **************************
# ----------- 3 --------------
# ------>Predictions by Model
# Marla found a pair of boxers under her bed.
# ----->Predictions Original
# Marla found a pair of boxers under her bed.
# **************************
# ----------- 4 --------------
# ------>Predictions by Model
# Robert needs to buy guitar cable.
# Fred gives him the address of the music shop.
# ----->Predictions Original
# Robert wants Fred to send him the address of the music shop as he needs to buy guitar cable.
# **************************
# ----------- 5 --------------
# ------>Predictions by Model
# Keith will buy some milk and cereals.
# Megan will check in the drawer next to
# ----->Predictions Original
# Megan needn't buy milk and cereals.
# They're in the drawer next to the fridge.
# **************************
# ----------- 6 --------------
# ------>Predictions by Model
# Samantha sends a video of herself making a noise.
# ----->Predictions Original
# Samantha and Evelyn after watching the video cannot believe she is able to make that noise.
# **************************
# ----------- 7 --------------
# ------>Predictions by Model
# Theresa, Luis and Adam are at Tom's new place.
# It's a bit
# ----->Predictions Original
# Tom's new place is in Fiesole.
# Luis and Marion has been there.
# **************************
# ----------- 8 --------------
# ------>Predictions by Model
# Jane will make a reservation for 6 people tonight at 21:00.
# ----->Predictions Original
# Jane made a 9 PM reservation for 6 people tonight at Vegano Resto.
# **************************
# ----------- 9 --------------
# ------>Predictions by Model
# Nancy is enjoying her job in Cardiff.
# She is coming home in 6 weeks.
# ----->Predictions Original
# Nancy's working in Texas, but the kids laugh at her Welsh accent.
# She's coming home in 6 weeks.
# Earlier than that she's going to travel with 3 other Brits.
# **************************
# ----------- 10 --------------
# ------>Predictions by Model
# Laura needs a new printer.
# Jamie suggests she can buy a second hand one.
# ----->Predictions Original
# Laura is going to buy a printer.
# **************************
# ----------- 11 --------------
# ------>Predictions by Model
# Haylee will buy coconut milk yoghurt in the dairy section.
# ----->Predictions Original
# Haylee can't find the coconut milk yoghurt.
# **************************
# ----------- 12 --------------
# ------>Predictions by Model
# Norbert and Wendy need to hurry to catch the tour.
# Wendy is buying something.
# ----->Predictions Original
# Wendy is shopping, but she needs to hurry up to catch the tour.
# **************************
# ----------- 13 --------------
# ------>Predictions by Model
# Cecil went to the Jandia Peninsula.
# Cecil wants to explore more the
# ----->Predictions Original
# Cecil, Cheryl and Peter went to the Jandia Peninsula today.
# Cecil would like to explore the south of the island tomorrow, but they will decide what to do after dinner.
# **************************
# ----------- 14 --------------
# ------>Predictions by Model
# Sophie hasn't found it.
# Nickola reminds Sophie to check pockets and hand
# ----->Predictions Original
# Sophie still hasn't found it despite checking pockets and handbags twice.
# **************************
# ----------- 15 --------------
# ------>Predictions by Model
# Rosie has to write an essay about bad movies.
# She will cover "The Room
# ----->Predictions Original
# Dennis and Elle are helping Rosie think of bad movies for her essay.
# **************************
# ----------- 16 --------------
# ------>Predictions by Model
# James has a nice voice and wants to become a voice actor.
# Julia will listen to
# ----->Predictions Original
# James has a dream of becoming a voice actor.
# He considers making a home radio station.
# **************************
# ----------- 17 --------------
# ------>Predictions by Model
# Poppy and Alice are going for drinks after work.
# They will meet at Nick's
# ----->Predictions Original
# Poppy and Alice are meeting for drinks after work at Nick's at 5:30.
# Alice fancies Fred, she will invite him and a bunch of other coworkers.
# **************************
# ----------- 18 --------------
# ------>Predictions by Model
# Caron is out from 12.
# Sash will be before 12.
# Caron will
# ----->Predictions Original
# Sash needs to see Caron who'll be out from 12.
# **************************
# ----------- 19 --------------
# ------>Predictions by Model
# Giuseppe is dating Gosia.
# Gosia always criticizes him because she likes
# ----->Predictions Original
# Matteo is not sure about his relationship with Gosia but likes her a lot.
# **************************
# ----------- 20 --------------
# ------>Predictions by Model
# Jannette is coming to Ramzi's for supper.
# ----->Predictions Original
# Ramzi and Jannette are going for supper.
# **************************
# ----------- 21 --------------
# ------>Predictions by Model
# Jeniffer got the recipe from her grandmother.
# ----->Predictions Original
# Jeniffer is preparing ravioli following her grandmothers recipe.
# **************************
# ----------- 22 --------------
# ------>Predictions by Model
# Lawrence is not through with the article yet, but he will be in a few
# ----->Predictions Original
# Lawrence will finish writing the article soon.
# **************************
# ----------- 23 --------------
# ------>Predictions by Model
# Chad sent Brennen a funny photo.
# ----->Predictions Original
# Chad has sent Brennen a funny photo.
# Brennen does not find it very funny.
# **************************
# ----------- 24 --------------
# ------>Predictions by Model
# Sadie will borrow Chloe's bike on Wednesday evening.
# ----->Predictions Original
# Sadie will borrow Chloe's bike on Wednesday evening.
# She has a dentist appointment on Thursday after work.
# **************************
# ----------- 25 --------------
# ------>Predictions by Model
# Olivia and Carter want to launch a new restaurant in the city centre next month
# ----->Predictions Original
# Carter is launching a restaurant business next month.
# Olivia wants him to include a restaurant she's working for in the discount app.
# They will meet in person to discuss it.
# **************************
# ----------- 26 --------------
# ------>Predictions by Model
# Kristine is worried about Kenny.
# He's back from surgery, but the doctors don
# ----->Predictions Original
# Kenny had a surgery, as Kristine reports.
# He will have another surgery tomorrow.
# Guy will come to St. Mark's Hospital near Asda to stay with Kristine.
# **************************
# ----------- 27 --------------
# ------>Predictions by Model
# Joey and Olivia broke up after all these years.
# Olivia cheated on her with numerous
# ----->Predictions Original
# Skyler and Adam are surprised that Joey and Olivia broke up.
# **************************
# ----------- 28 --------------
# ------>Predictions by Model
# Amanda is pregnant.
# She went to dance classes with Michael yesterday.
# The instructor needed
# ----->Predictions Original
# Amanda goes to dancing classes with Michael.
# She volunteered to show the English Waltz steps with the instructor yesterday.
# Amanda is shy and goes to therapy.
# **************************
# ----------- 29 --------------
# ------>Predictions by Model
# Taylor wants Isabel to introduce her boyfriend to her daughter.
# Isabel hasn't had any.
# ----->Predictions Original
# Taylor wants to meet Isabel's boyfriend but she has never had any.
# **************************
# ----------- 30 --------------
# ------>Predictions by Model
# Theo is leaving on Friday.
# Toby will come back by train on Monday.
# Toby
# ----->Predictions Original
# Theo's going to stay near Torino in the region of Italian Alpes.
# Toby wants to join the trip.
# Theo agrees and will pick Toby up on Friday at 7 am.
# **************************
# ----------- 31 --------------
# ------>Predictions by Model
# Brandon hasn't called Clara to say he'd be late.
# She will prepare a report
# ----->Predictions Original
# Brandon is late again.
# Clara will prepare a report on the absenteeism and lateness for Phil by Friday.
# **************************
# ----------- 32 --------------
# ------>Predictions by Model
# Suzie is sick again.
# She will cancel the meeting with Olga.
# ----->Predictions Original
# Olga and Suzie will postpone their meeting due to Suzie's sickness.
# **************************
# ----------- 33 --------------
# ------>Predictions by Model
# Kate will be Diane's daughter Lorelai's mother.
# ----->Predictions Original
# Diane is pregnant and can't wait to give birth, she thinks the waiting is the worst.
# Kate thinks she'll be an amazing mother.
# **************************
# ----------- 34 --------------
# ------>Predictions by Model
# Andrew had to call in sick because of a cold.
# Daniel will drop by after work
# ----->Predictions Original
# Andrew has a cold.
# Daniel will buy him some medication.
# **************************
# ----------- 35 --------------
# ------>Predictions by Model
# Alex and Sam are watching 'Millionaires' on tv.
# ----->Predictions Original
# Alex and Sam are watching Millionaires.
# **************************
# ----------- 36 --------------
# ------>Predictions by Model
# Jessica and Angelica have the cinnamon cookies recipe.
# ----->Predictions Original
# Angelica sent the cinnamon cookies recipe at Kelly's request.
# **************************
# ----------- 37 --------------
# ------>Predictions by Model
# Sophie is waiting for a client who is 40 minutes late.
# Gwen will
# ----->Predictions Original
# Sophie is waiting for a client, who is late.
# She will meet Gwen later.
# **************************
# ----------- 38 --------------
# ------>Predictions by Model
# Daniel is on his way.
# Sue is going downstairs now.
# Daniel is with the Volvo
# ----->Predictions Original
# Daniel is with the Volvo on his way and will be there soon.
# Sue is going downstairs to meet him.
# **************************
# ----------- 39 --------------
# ------>Predictions by Model
# Betty is going to CVS to buy some shaving cream for George.
# ----->Predictions Original
# George is making salmon and stuffed squash for dinner.
# Betty will buy a shaving cream at CVS at his request,
# **************************
# ----------- 40 --------------
# ------>Predictions by Model
# Ken's phone doesn't work properly.
# He had it with him while he was j
# ----->Predictions Original
# Ken has installed an app for running but it is not working properly on his phone.
# **************************
# ----------- 41 --------------
# ------>Predictions by Model
# Ann couldn't come to Ivan's birthday party.
# Ivan bought her something for her birthday
# ----->Predictions Original
# Ivan and Ann will meet next week.
# **************************
# ----------- 42 --------------
# ------>Predictions by Model
# Ashley posted some pictures on her Facebook page.
# Rowan has some important stuff to
# ----->Predictions Original
# Ashley posted some nude photos on her fb page.
# **************************
# ----------- 43 --------------
# ------>Predictions by Model
# Mikolaj got a letter from the government saying that his wife's papers won
# ----->Predictions Original
# Mikolaj's wife needs a work permit as a foreigner.
# Government officials missed the deadline for sending it and will need another month.
# **************************
# ----------- 44 --------------
# ------>Predictions by Model
# Ann is at the 3rd floor lobby.
# Peter is still there.
# Maria is on
# ----->Predictions Original
# Thomas, Ann and Maria will have lunch together at the hotel.
# Ann is already in the 3rd floor lobby at the red table.
# **************************
# ----------- 45 --------------
# ------>Predictions by Model
# Sus and Val don't want to work.
# ----->Predictions Original
# Sus and Val don't want to work and are sleepy.
# **************************
# ----------- 46 --------------
# ------>Predictions by Model
# Kate and Terry are going to the Museum of the city of NY around 2-2
# ----->Predictions Original
# Kate is at the Guggenheim Museum now, but will be in the Museum of the City of New York around 2-2:30.
# Kai may join her.
# Ish won't.
# Terry will join them for a coffee after they finish visiting the museum.
# Terry has already seen the museum.
# **************************
# ----------- 47 --------------
# ------>Predictions by Model
# Cathy left her sunglasses at Brooke's house.
# She will come round at 10 tonight
# ----->Predictions Original
# Cathy left her sunglasses at Broke's house.
# She will come collect them at 10.
# **************************
# ----------- 48 --------------
# ------>Predictions by Model
# Frederica will come to Bradley's birthday party tomorrow at 8 pm.
# ----->Predictions Original
# Bradley will come to Frederica's birthday party tomorrow at 8pm.
# **************************
# ----------- 49 --------------
# ------>Predictions by Model
# Camilla received 250.
# Camilla will let Adrian know when she has checked.
# ----->Predictions Original
# Camilla still hasn't received the 250.
# She will check and let Adrian know.
# Money usually takes around two days to arrive.
# **************************
# Saving model checkpoint to bart-token-b6c0.1/checkpoint-6000
# Configuration saved in bart-token-b6c0.1/checkpoint-6000/config.json
# ...
# ----->Predictions Original
# Bradley will come to Frederica's birthday party tomorrow at 8pm.
# **************************
# ----------- 49 --------------
# ------>Predictions by Model
# Camilla received 250.
# Camilla will let Adrian know when she has received the money
# ----->Predictions Original
# Camilla still hasn't received the 250.
# She will check and let Adrian know.
# Money usually takes around two days to arrive.
# **************************
# Saving model checkpoint to bart-token-b6c0.1/checkpoint-7500
# Configuration saved in bart-token-b6c0.1/checkpoint-7500/config.json
# Model weights saved in bart-token-b6c0.1/checkpoint-7500/pytorch_model.bin
# tokenizer config file saved in bart-token-b6c0.1/checkpoint-7500/tokenizer_config.json
# Special tokens file saved in bart-token-b6c0.1/checkpoint-7500/special_tokens_map.json
# Saving model checkpoint to bart-token-b6c0.1/checkpoint-8000
# Configuration saved in bart-token-b6c0.1/checkpoint-8000/config.json
# Model weights saved in bart-token-b6c0.1/checkpoint-8000/pytorch_model.bin
# tokenizer config file saved in bart-token-b6c0.1/checkpoint-8000/tokenizer_config.json
# Special tokens file saved in bart-token-b6c0.1/checkpoint-8000/special_tokens_map.json
# Saving model checkpoint to bart-token-b6c0.1/checkpoint-8500
# Configuration saved in bart-token-b6c0.1/checkpoint-8500/config.json
# Model weights saved in bart-token-b6c0.1/checkpoint-8500/pytorch_model.bin
# tokenizer config file saved in bart-token-b6c0.1/checkpoint-8500/tokenizer_config.json
# Special tokens file saved in bart-token-b6c0.1/checkpoint-8500/special_tokens_map.json
# Saving model checkpoint to bart-token-b6c0.1/checkpoint-9000
# Configuration saved in bart-token-b6c0.1/checkpoint-9000/config.json
# Model weights saved in bart-token-b6c0.1/checkpoint-9000/pytorch_model.bin
# tokenizer config file saved in bart-token-b6c0.1/checkpoint-9000/tokenizer_config.json
# Special tokens file saved in bart-token-b6c0.1/checkpoint-9000/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 818
#   Batch size = 4
# ----------- 0 --------------
# ------>Predictions by Model
# A wants to get a puppy for her son.
# She will take him to the animal
# ----->Predictions Original
# A will go to the animal shelter tomorrow to get a puppy for her son.
# They already visited the shelter last Monday and the son chose the puppy.
# **************************
# ----------- 1 --------------
# ------>Predictions by Model
# Emma wants to buy an advent calendar for her children.
# Rob used to get one
# ----->Predictions Original
# Emma and Rob love the advent calendar.
# Lauren fits inside calendar various items, for instance, small toys and Christmas decorations.
# Her children are excited whenever they get the calendar.
# **************************
# ----------- 2 --------------
# ------>Predictions by Model
# Madison is pregnant, but she doesn't want to talk about it.
# Iggy's
# ----->Predictions Original
# Madison is pregnant but she doesn't want to talk about it.
# Patricia Stevens got married and she thought she was pregnant.
# **************************
# ----------- 3 --------------
# ------>Predictions by Model
# Marla found a pair of boxers under her bed.
# ----->Predictions Original
# Marla found a pair of boxers under her bed.
# **************************
# ----------- 4 --------------
# ------>Predictions by Model
# Robert needs to buy guitar cable.
# Fred gives him the address of the music shop.
# ----->Predictions Original
# Robert wants Fred to send him the address of the music shop as he needs to buy guitar cable.
# **************************
# ----------- 5 --------------
# ------>Predictions by Model
# Keith will buy some milk and cereals for Megan.
# Megan checked in the drawer next
# ----->Predictions Original
# Megan needn't buy milk and cereals.
# They're in the drawer next to the fridge.
# **************************
# ----------- 6 --------------
# ------>Predictions by Model
# Samantha sends Evelyn and Holly a video of a woman making noise.
# ----->Predictions Original
# Samantha and Evelyn after watching the video cannot believe she is able to make that noise.
# **************************
# ----------- 7 --------------
# ------>Predictions by Model
# Tom invited Theresa, Luis and Adam for dinner at Fiesole.
# ----->Predictions Original
# Tom's new place is in Fiesole.
# Luis and Marion has been there.
# **************************
# ----------- 8 --------------
# ------>Predictions by Model
# Jane will make a reservation for 6 people at 21:00 for a table for six
# ----->Predictions Original
# Jane made a 9 PM reservation for 6 people tonight at Vegano Resto.
# **************************
# ----------- 9 --------------
# ------>Predictions by Model
# Nancy is coming home in 6 weeks.
# She has 3 other Brits working here
# ----->Predictions Original
# Nancy's working in Texas, but the kids laugh at her Welsh accent.
# She's coming home in 6 weeks.
# Earlier than that she's going to travel with 3 other Brits.
# **************************
# ----------- 10 --------------
# ------>Predictions by Model
# Laura needs a new printer.
# Jamie suggests she can buy a second hand one.
# ----->Predictions Original
# Laura is going to buy a printer.
# **************************
# ----------- 11 --------------
# ------>Predictions by Model
# Haylee will buy coconut milk yoghurt in the dairy section.
# ----->Predictions Original
# Haylee can't find the coconut milk yoghurt.
# **************************
# ----------- 12 --------------
# ------>Predictions by Model
# Norbert and Wendy need to hurry to catch the tour.
# Wendy is buying something.
# ----->Predictions Original
# Wendy is shopping, but she needs to hurry up to catch the tour.
# **************************
# ----------- 13 --------------
# ------>Predictions by Model
# Cecil went to the Jandia Peninsula.
# Cecil wants to explore more the
# ----->Predictions Original
# Cecil, Cheryl and Peter went to the Jandia Peninsula today.
# Cecil would like to explore the south of the island tomorrow, but they will decide what to do after dinner.
# **************************
# ----------- 14 --------------
# ------>Predictions by Model
# Sophie hasn't found it yet.
# Nickola reminds Sophie to check pockets and
# ----->Predictions Original
# Sophie still hasn't found it despite checking pockets and handbags twice.
# **************************
# ----------- 15 --------------
# ------>Predictions by Model
# Rosie has to write an essay about bad movies.
# She will cover "The Room
# ----->Predictions Original
# Dennis and Elle are helping Rosie think of bad movies for her essay.
# **************************
# ----------- 16 --------------
# ------>Predictions by Model
# James has a dream to become a voice actor.
# He wants to be a part of
# ----->Predictions Original
# James has a dream of becoming a voice actor.
# He considers making a home radio station.
# **************************
# ----------- 17 --------------
# ------>Predictions by Model
# Poppy and Alice are going for drinks after work.
# They will meet at Nick's
# ----->Predictions Original
# Poppy and Alice are meeting for drinks after work at Nick's at 5:30.
# Alice fancies Fred, she will invite him and a bunch of other coworkers.
# **************************
# ----------- 18 --------------
# ------>Predictions by Model
# Sash will see Caron before 12.
# Caron needs to go out.
# ----->Predictions Original
# Sash needs to see Caron who'll be out from 12.
# **************************
# ----------- 19 --------------
# ------>Predictions by Model
# Matteo's girlfriend Gosia criticizes him because he likes football and video games
# ----->Predictions Original
# Matteo is not sure about his relationship with Gosia but likes her a lot.
# **************************
# ----------- 20 --------------
# ------>Predictions by Model
# Ramzi's mom is calling for supper.
# Jannette is coming.
# ----->Predictions Original
# Ramzi and Jannette are going for supper.
# **************************
# ----------- 21 --------------
# ------>Predictions by Model
# Jeniffer got the recipe from her grandmother.
# ----->Predictions Original
# Jeniffer is preparing ravioli following her grandmothers recipe.
# **************************
# ----------- 22 --------------
# ------>Predictions by Model
# Lawrence is not done with the article yet, but he will be in a few
# ----->Predictions Original
# Lawrence will finish writing the article soon.
# **************************
# ----------- 23 --------------
# ------>Predictions by Model
# Chad sent Brennen a funny photo.
# ----->Predictions Original
# Chad has sent Brennen a funny photo.
# Brennen does not find it very funny.
# **************************
# ----------- 24 --------------
# ------>Predictions by Model
# Chloe will pick up Sadie's bike on Wednesday evening.
# ----->Predictions Original
# Sadie will borrow Chloe's bike on Wednesday evening.
# She has a dentist appointment on Thursday after work.
# **************************
# ----------- 25 --------------
# ------>Predictions by Model
# Olivia and Carter want to launch a new restaurant in the city centre next month
# ----->Predictions Original
# Carter is launching a restaurant business next month.
# Olivia wants him to include a restaurant she's working for in the discount app.
# They will meet in person to discuss it.
# **************************
# ----------- 26 --------------
# ------>Predictions by Model
# Kristine is worried about Kenny because he's back from surgery.
# He has another surgery
# ----->Predictions Original
# Kenny had a surgery, as Kristine reports.
# He will have another surgery tomorrow.
# Guy will come to St. Mark's Hospital near Asda to stay with Kristine.
# **************************
# ----------- 27 --------------
# ------>Predictions by Model
# Joey and Olivia broke up after all these years.
# Joey cheated on her with numerous
# ----->Predictions Original
# Skyler and Adam are surprised that Joey and Olivia broke up.
# **************************
# ----------- 28 --------------
# ------>Predictions by Model
# Amanda is pregnant.
# She went to dancing classes with Michael yesterday.
# The instructor needed
# ----->Predictions Original
# Amanda goes to dancing classes with Michael.
# She volunteered to show the English Waltz steps with the instructor yesterday.
# Amanda is shy and goes to therapy.
# **************************
# ----------- 29 --------------
# ------>Predictions by Model
# Taylor wants Isabel to introduce her boyfriend to her daughter.
# Isabel hasn't had any.
# ----->Predictions Original
# Taylor wants to meet Isabel's boyfriend but she has never had any.
# **************************
# ----------- 30 --------------
# ------>Predictions by Model
# Theo is leaving on Friday.
# Toby will come back by train on Monday.
# Toby
# ----->Predictions Original
# Theo's going to stay near Torino in the region of Italian Alpes.
# Toby wants to join the trip.
# Theo agrees and will pick Toby up on Friday at 7 am.
# **************************
# ----------- 31 --------------
# ------>Predictions by Model
# Brandon hasn't called Clara to say he'd be late.
# She will prepare a report
# ----->Predictions Original
# Brandon is late again.
# Clara will prepare a report on the absenteeism and lateness for Phil by Friday.
# **************************
# ----------- 32 --------------
# ------>Predictions by Model
# Suzie is sick again.
# She will cancel the meeting with Olga.
# ----->Predictions Original
# Olga and Suzie will postpone their meeting due to Suzie's sickness.
# **************************
# ----------- 33 --------------
# ------>Predictions by Model
# Kate will be Diane's daughter Lorelai's mother.
# ----->Predictions Original
# Diane is pregnant and can't wait to give birth, she thinks the waiting is the worst.
# Kate thinks she'll be an amazing mother.
# **************************
# ----------- 34 --------------
# ------>Predictions by Model
# Andrew had to call in sick because he feels awful.
# Daniel will drop by after work
# ----->Predictions Original
# Andrew has a cold.
# Daniel will buy him some medication.
# **************************
# ----------- 35 --------------
# ------>Predictions by Model
# Alex and Sam are watching 'Millionaires' on tv.
# ----->Predictions Original
# Alex and Sam are watching Millionaires.
# **************************
# ----------- 36 --------------
# ------>Predictions by Model
# Jessica has the cinnamon cookies recipe.
# ----->Predictions Original
# Angelica sent the cinnamon cookies recipe at Kelly's request.
# **************************
# ----------- 37 --------------
# ------>Predictions by Model
# Gwen and Dee will meet at the restaurant in 5 minutes.
# ----->Predictions Original
# Sophie is waiting for a client, who is late.
# She will meet Gwen later.
# **************************
# ----------- 38 --------------
# ------>Predictions by Model
# Daniel is on his way.
# Sue is going downstairs now.
# Daniel is with the Volvo
# ----->Predictions Original
# Daniel is with the Volvo on his way and will be there soon.
# Sue is going downstairs to meet him.
# **************************
# ----------- 39 --------------
# ------>Predictions by Model
# Betty is going to CVS to buy some shaving cream for George.
# ----->Predictions Original
# George is making salmon and stuffed squash for dinner.
# Betty will buy a shaving cream at CVS at his request,
# **************************
# ----------- 40 --------------
# ------>Predictions by Model
# Ken's phone doesn't work properly.
# He had it with him while he was j
# ----->Predictions Original
# Ken has installed an app for running but it is not working properly on his phone.
# **************************
# ----------- 41 --------------
# ------>Predictions by Model
# Ann couldn't come to Ivan's birthday party.
# Ivan bought her something for her birthday
# ----->Predictions Original
# Ivan and Ann will meet next week.
# **************************
# ----------- 42 --------------
# ------>Predictions by Model
# Ashley posted some pictures on her Facebook page.
# Rowan has some important stuff to
# ----->Predictions Original
# Ashley posted some nude photos on her fb page.
# **************************
# ----------- 43 --------------
# ------>Predictions by Model
# Mikolaj got his wife's papers with working permission.
# The government didn't
# ----->Predictions Original
# Mikolaj's wife needs a work permit as a foreigner.
# Government officials missed the deadline for sending it and will need another month.
# **************************
# ----------- 44 --------------
# ------>Predictions by Model
# Ann is at the 3rd floor lobby.
# Peter is still there.
# Ann and Thomas
# ----->Predictions Original
# Thomas, Ann and Maria will have lunch together at the hotel.
# Ann is already in the 3rd floor lobby at the red table.
# **************************
# ----------- 45 --------------
# ------>Predictions by Model
# Sus and Val don't want to work.
# ----->Predictions Original
# Sus and Val don't want to work and are sleepy.
# **************************
# ----------- 46 --------------
# ------>Predictions by Model
# Kate and Terry are going to the Museum of the city of NY around 2-2
# ----->Predictions Original
# Kate is at the Guggenheim Museum now, but will be in the Museum of the City of New York around 2-2:30.
# Kai may join her.
# Ish won't.
# Terry will join them for a coffee after they finish visiting the museum.
# Terry has already seen the museum.
# **************************
# ----------- 47 --------------
# ------>Predictions by Model
# Cathy left her sunglasses at Brooke's house.
# She will come round at 10 tonight
# ----->Predictions Original
# Cathy left her sunglasses at Broke's house.
# She will come collect them at 10.
# **************************
# ----------- 48 --------------
# ------>Predictions by Model
# Frederica will come to Bradley's birthday party tomorrow at 8 pm.
# ----->Predictions Original
# Bradley will come to Frederica's birthday party tomorrow at 8pm.
# **************************
# ----------- 49 --------------
# ------>Predictions by Model
# Camilla received 250.
# Camilla will let Adrian know when she has received the money
# ----->Predictions Original
# Camilla still hasn't received the 250.
# She will check and let Adrian know.
# Money usually takes around two days to arrive.
# **************************
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=9205, training_loss=1.742990126602032, metrics={'train_runtime': 10308.3256, 'train_samples_per_second': 7.145, 'train_steps_per_second': 0.893, 'total_flos': 1.239353421336576e+16, 'train_loss': 1.742990126602032, 'epoch': 5.0})

# %%
trainer.evaluate()
# Out:
# ***** Running Evaluation *****
#   Num examples = 818
#   Batch size = 4
#     <div>
#
#       <progress value='205' max='205' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [205/205 02:30]
#     </div>
# ----------- 0 --------------
# ------>Predictions by Model
# A wants to get a puppy for her son.
# She will take him to the animal
# ----->Predictions Original
# A will go to the animal shelter tomorrow to get a puppy for her son.
# They already visited the shelter last Monday and the son chose the puppy.
# **************************
# ----------- 1 --------------
# ------>Predictions by Model
# Emma wants to buy an advent calendar for her children.
# Rob used to get one
# ----->Predictions Original
# Emma and Rob love the advent calendar.
# Lauren fits inside calendar various items, for instance, small toys and Christmas decorations.
# Her children are excited whenever they get the calendar.
# **************************
# ----------- 2 --------------
# ------>Predictions by Model
# Madison is pregnant, but she doesn't want to talk about it.
# Iggy's
# ----->Predictions Original
# Madison is pregnant but she doesn't want to talk about it.
# Patricia Stevens got married and she thought she was pregnant.
# **************************
# ----------- 3 --------------
# ------>Predictions by Model
# Marla found a pair of boxers under her bed.
# ----->Predictions Original
# Marla found a pair of boxers under her bed.
# **************************
# ----------- 4 --------------
# ------>Predictions by Model
# Robert needs to buy guitar cable.
# Fred gives him the address of the music shop.
# ----->Predictions Original
# Robert wants Fred to send him the address of the music shop as he needs to buy guitar cable.
# **************************
# ----------- 5 --------------
# ------>Predictions by Model
# Keith will buy some milk and cereals for Megan.
# Megan checked in the drawer next
# ----->Predictions Original
# Megan needn't buy milk and cereals.
# They're in the drawer next to the fridge.
# **************************
# ----------- 6 --------------
# ------>Predictions by Model
# Samantha sends Evelyn and Holly a video of a woman making noise.
# ----->Predictions Original
# Samantha and Evelyn after watching the video cannot believe she is able to make that noise.
# **************************
# ----------- 7 --------------
# ------>Predictions by Model
# Tom invited Theresa, Luis and Adam for dinner at Fiesole.
# ----->Predictions Original
# Tom's new place is in Fiesole.
# Luis and Marion has been there.
# **************************
# ----------- 8 --------------
# ------>Predictions by Model
# Jane will make a reservation for 6 people at 21:00 for a table for six
# ----->Predictions Original
# Jane made a 9 PM reservation for 6 people tonight at Vegano Resto.
# **************************
# ----------- 9 --------------
# ------>Predictions by Model
# Nancy is coming home in 6 weeks.
# She has 3 other Brits working here
# ----->Predictions Original
# Nancy's working in Texas, but the kids laugh at her Welsh accent.
# She's coming home in 6 weeks.
# Earlier than that she's going to travel with 3 other Brits.
# **************************
# ----------- 10 --------------
# ------>Predictions by Model
# Laura needs a new printer.
# Jamie suggests she can buy a second hand one.
# ----->Predictions Original
# Laura is going to buy a printer.
# **************************
# ----------- 11 --------------
# ------>Predictions by Model
# Haylee will buy coconut milk yoghurt in the dairy section.
# ----->Predictions Original
# Haylee can't find the coconut milk yoghurt.
# **************************
# ----------- 12 --------------
# ------>Predictions by Model
# Norbert and Wendy need to hurry to catch the tour.
# Wendy is buying something.
# ----->Predictions Original
# Wendy is shopping, but she needs to hurry up to catch the tour.
# **************************
# ----------- 13 --------------
# ------>Predictions by Model
# Cecil went to the Jandia Peninsula.
# Cecil wants to explore more the
# ----->Predictions Original
# Cecil, Cheryl and Peter went to the Jandia Peninsula today.
# Cecil would like to explore the south of the island tomorrow, but they will decide what to do after dinner.
# **************************
# ----------- 14 --------------
# ------>Predictions by Model
# Sophie hasn't found it yet.
# Nickola reminds Sophie to check pockets and
# ----->Predictions Original
# Sophie still hasn't found it despite checking pockets and handbags twice.
# **************************
# ----------- 15 --------------
# ------>Predictions by Model
# Rosie has to write an essay about bad movies.
# She will cover "The Room
# ----->Predictions Original
# Dennis and Elle are helping Rosie think of bad movies for her essay.
# **************************
# ----------- 16 --------------
# ------>Predictions by Model
# James has a dream to become a voice actor.
# He wants to be a part of
# ----->Predictions Original
# James has a dream of becoming a voice actor.
# He considers making a home radio station.
# **************************
# ----------- 17 --------------
# ------>Predictions by Model
# Poppy and Alice are going for drinks after work.
# They will meet at Nick's
# ----->Predictions Original
# Poppy and Alice are meeting for drinks after work at Nick's at 5:30.
# Alice fancies Fred, she will invite him and a bunch of other coworkers.
# **************************
# ----------- 18 --------------
# ------>Predictions by Model
# Sash will see Caron before 12.
# Caron needs to go out.
# ----->Predictions Original
# Sash needs to see Caron who'll be out from 12.
# **************************
# ----------- 19 --------------
# ------>Predictions by Model
# Matteo's girlfriend Gosia criticizes him because he likes football and video games
# ----->Predictions Original
# Matteo is not sure about his relationship with Gosia but likes her a lot.
# **************************
# ----------- 20 --------------
# ------>Predictions by Model
# Ramzi's mom is calling for supper.
# Jannette is coming.
# ----->Predictions Original
# Ramzi and Jannette are going for supper.
# **************************
# ----------- 21 --------------
# ------>Predictions by Model
# Jeniffer got the recipe from her grandmother.
# ----->Predictions Original
# Jeniffer is preparing ravioli following her grandmothers recipe.
# **************************
# ----------- 22 --------------
# ------>Predictions by Model
# Lawrence is not done with the article yet, but he will be in a few
# ----->Predictions Original
# Lawrence will finish writing the article soon.
# **************************
# ----------- 23 --------------
# ------>Predictions by Model
# Chad sent Brennen a funny photo.
# ----->Predictions Original
# Chad has sent Brennen a funny photo.
# Brennen does not find it very funny.
# **************************
# ----------- 24 --------------
# ------>Predictions by Model
# Chloe will pick up Sadie's bike on Wednesday evening.
# ----->Predictions Original
# Sadie will borrow Chloe's bike on Wednesday evening.
# She has a dentist appointment on Thursday after work.
# **************************
# ----------- 25 --------------
# ------>Predictions by Model
# Olivia and Carter want to launch a new restaurant in the city centre next month
# ----->Predictions Original
# Carter is launching a restaurant business next month.
# Olivia wants him to include a restaurant she's working for in the discount app.
# They will meet in person to discuss it.
# **************************
# ----------- 26 --------------
# ------>Predictions by Model
# Kristine is worried about Kenny because he's back from surgery.
# He has another surgery
# ----->Predictions Original
# Kenny had a surgery, as Kristine reports.
# He will have another surgery tomorrow.
# Guy will come to St. Mark's Hospital near Asda to stay with Kristine.
# **************************
# ----------- 27 --------------
# ------>Predictions by Model
# Joey and Olivia broke up after all these years.
# Joey cheated on her with numerous
# ----->Predictions Original
# Skyler and Adam are surprised that Joey and Olivia broke up.
# **************************
# ----------- 28 --------------
# ------>Predictions by Model
# Amanda is pregnant.
# She went to dancing classes with Michael yesterday.
# The instructor needed
# ----->Predictions Original
# Amanda goes to dancing classes with Michael.
# She volunteered to show the English Waltz steps with the instructor yesterday.
# Amanda is shy and goes to therapy.
# **************************
# ----------- 29 --------------
# ------>Predictions by Model
# Taylor wants Isabel to introduce her boyfriend to her daughter.
# Isabel hasn't had any.
# ----->Predictions Original
# Taylor wants to meet Isabel's boyfriend but she has never had any.
# **************************
# ----------- 30 --------------
# ------>Predictions by Model
# Theo is leaving on Friday.
# Toby will come back by train on Monday.
# Toby
# ----->Predictions Original
# Theo's going to stay near Torino in the region of Italian Alpes.
# Toby wants to join the trip.
# Theo agrees and will pick Toby up on Friday at 7 am.
# **************************
# ----------- 31 --------------
# ------>Predictions by Model
# Brandon hasn't called Clara to say he'd be late.
# She will prepare a report
# ----->Predictions Original
# Brandon is late again.
# Clara will prepare a report on the absenteeism and lateness for Phil by Friday.
# **************************
# ----------- 32 --------------
# ------>Predictions by Model
# Suzie is sick again.
# She will cancel the meeting with Olga.
# ----->Predictions Original
# Olga and Suzie will postpone their meeting due to Suzie's sickness.
# **************************
# ----------- 33 --------------
# ------>Predictions by Model
# Kate will be Diane's daughter Lorelai's mother.
# ----->Predictions Original
# Diane is pregnant and can't wait to give birth, she thinks the waiting is the worst.
# Kate thinks she'll be an amazing mother.
# **************************
# ----------- 34 --------------
# ------>Predictions by Model
# Andrew had to call in sick because he feels awful.
# Daniel will drop by after work
# ----->Predictions Original
# Andrew has a cold.
# Daniel will buy him some medication.
# **************************
# ----------- 35 --------------
# ------>Predictions by Model
# Alex and Sam are watching 'Millionaires' on tv.
# ----->Predictions Original
# Alex and Sam are watching Millionaires.
# **************************
# ----------- 36 --------------
# ------>Predictions by Model
# Jessica has the cinnamon cookies recipe.
# ----->Predictions Original
# Angelica sent the cinnamon cookies recipe at Kelly's request.
# **************************
# ----------- 37 --------------
# ------>Predictions by Model
# Gwen and Dee will meet at the restaurant in 5 minutes.
# ----->Predictions Original
# Sophie is waiting for a client, who is late.
# She will meet Gwen later.
# **************************
# ----------- 38 --------------
# ------>Predictions by Model
# Daniel is on his way.
# Sue is going downstairs now.
# Daniel is with the Volvo
# ----->Predictions Original
# Daniel is with the Volvo on his way and will be there soon.
# Sue is going downstairs to meet him.
# **************************
# ----------- 39 --------------
# ------>Predictions by Model
# Betty is going to CVS to buy some shaving cream for George.
# ----->Predictions Original
# George is making salmon and stuffed squash for dinner.
# Betty will buy a shaving cream at CVS at his request,
# **************************
# ----------- 40 --------------
# ------>Predictions by Model
# Ken's phone doesn't work properly.
# He had it with him while he was j
# ----->Predictions Original
# Ken has installed an app for running but it is not working properly on his phone.
# **************************
# ----------- 41 --------------
# ------>Predictions by Model
# Ann couldn't come to Ivan's birthday party.
# Ivan bought her something for her birthday
# ----->Predictions Original
# Ivan and Ann will meet next week.
# **************************
# ----------- 42 --------------
# ------>Predictions by Model
# Ashley posted some pictures on her Facebook page.
# Rowan has some important stuff to
# ----->Predictions Original
# Ashley posted some nude photos on her fb page.
# **************************
# ----------- 43 --------------
# ------>Predictions by Model
# Mikolaj got his wife's papers with working permission.
# The government didn't
# ----->Predictions Original
# Mikolaj's wife needs a work permit as a foreigner.
# Government officials missed the deadline for sending it and will need another month.
# **************************
# ----------- 44 --------------
# ------>Predictions by Model
# Ann is at the 3rd floor lobby.
# Peter is still there.
# Ann and Thomas
# ----->Predictions Original
# Thomas, Ann and Maria will have lunch together at the hotel.
# Ann is already in the 3rd floor lobby at the red table.
# **************************
# ----------- 45 --------------
# ------>Predictions by Model
# Sus and Val don't want to work.
# ----->Predictions Original
# Sus and Val don't want to work and are sleepy.
# **************************
# ----------- 46 --------------
# ------>Predictions by Model
# Kate and Terry are going to the Museum of the city of NY around 2-2
# ----->Predictions Original
# Kate is at the Guggenheim Museum now, but will be in the Museum of the City of New York around 2-2:30.
# Kai may join her.
# Ish won't.
# Terry will join them for a coffee after they finish visiting the museum.
# Terry has already seen the museum.
# **************************
# ----------- 47 --------------
# ------>Predictions by Model
# Cathy left her sunglasses at Brooke's house.
# She will come round at 10 tonight
# ----->Predictions Original
# Cathy left her sunglasses at Broke's house.
# She will come collect them at 10.
# **************************
# ----------- 48 --------------
# ------>Predictions by Model
# Frederica will come to Bradley's birthday party tomorrow at 8 pm.
# ----->Predictions Original
# Bradley will come to Frederica's birthday party tomorrow at 8pm.
# **************************
# ----------- 49 --------------
# ------>Predictions by Model
# Camilla received 250.
# Camilla will let Adrian know when she has received the money
# ----->Predictions Original
# Camilla still hasn't received the 250.
# She will check and let Adrian know.
# Money usually takes around two days to arrive.
# **************************
# {'epoch': 5.0,
#  'eval_gen_len': 18.1504,
#  'eval_loss': 1.6692224740982056,
#  'eval_rouge1': 48.9032,
#  'eval_rouge2': 25.6607,
#  'eval_rougeL': 41.323,
#  'eval_rougeLsum': 45.2241,
#  'eval_runtime': 154.519,
#  'eval_samples_per_second': 5.294,
#  'eval_steps_per_second': 1.327}
